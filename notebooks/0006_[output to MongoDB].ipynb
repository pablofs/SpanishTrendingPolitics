# %% [markdown]
# # Scraping

# %% [markdown]
# ### Mètodes i utilitats

# %%
# http://stackoverflow.com/questions/7100125/storing-python-dictionaries

import json
from bson import json_util
import yaml

# http://api.mongodb.org/python/1.10.1/api/bson/json_util.html
# Mètodes per grabar y carregar fitxers en format json
def save_dict_json(dict, filename):
    with open(filename, 'wb') as fp:
        json.dump(dict, fp, default=json_util.default)

def load_dict_json(filename):
    with open(filename, 'rb') as fp:
        return json.load(fp, object_hook=json_util.object_hook)

# http://stackoverflow.com/questions/956867/how-to-get-string-objects-instead-of-unicode-ones-from-json-in-python
def load_dict_yaml(filename):
    with open(filename, 'rb') as fp:
        return yaml.load(fp)
    
# Mètode per grabar un fitxer de texte
def save_text_file(text, file_name, encoding = 'utf-8'):
    with open(file_name, "w") as text_file:
        if encoding:
            text_file.write(text.encode(encoding))
        else:
            text_file.write(text)
            
# Mètode per grabar un fitxer de texte
def save_list_text_file(text_list, file_name):
    with open(file_name, "w") as text_file:
        for item in text_list:
            text_file.write("%s\n" % item)
        
# Mètode per carregar un fitxer de texte
def load_text_file(file_name, encoding = 'utf-8'):
    with open(file_name, "r") as text_file:
        if encoding:
            return text_file.read().decode(encoding)
        else:
            return text_file.read()
        
# Mètode per eliminar caracters incorrectes als noms de fitxers (potser millor utilitzar: https://pypi.python.org/pypi/goldfinch/0.4)
invalid_filename_chars_windows = '\/:*?"<>|'
def del_invalid_chars(value, deletechars):
    for c in deletechars:
        value = value.replace(c,'')
    return value;

import datetime

# Mètode per cambiar de format de data de format_1 a format_2
def format_date(strFecha, format_1, format_2):
    dtDate = datetime.datetime.strptime(strFecha, format_1)
    return dtDate.strftime(format_2)

# Mètode que ens diu si una data cau en dimecres
# https://docs.python.org/2/library/datetime.html#datetime.date.weekday
def isWednesday(my_date):
    if my_date.date().weekday() == 2:  # 0: Monday, 1: Tuesday, 2: Wednesday, ...
        return True
    else:
        return False
    
# print "24/03/2015", "isWednesday:", isWednesday("24/03/2015")
# print "11/03/2015", "isWednesday:", isWednesday("11/03/2015")

# %%
def get_text_between( s, first, last, include_limits = False, first_ocurrences = True ):
    try:
        if first_ocurrences:
            if include_limits:
                start = s.index( first )
                end = s.rindex( last, start ) + len(last)
                return s[start:end]
            else:
                start = s.index( first ) + len( first )
                end = s.rindex( last, start ) 
                return s[start:end]
        else: 
            # look for last ocurrences of first and last
            if include_limits:
                start = s.rindex( first )
                end = s.index( last ) + len(last)
                return s[start:end]
            else:
                start = s.rindex( first ) + len( first )
                end = s.index( last ) 
                return s[start:end]            
    except ValueError:
        return ""
    
def remove_text_between( s, first, last, include_limits = False ):
    try:
        if include_limits:
            start = s.index( first ) + len( first )
            end = s.index( last, start ) 
            return s[:start] + s[end:] 
        else:
            start = s.index( first )
            end = s.index( last, start ) + len(last)
            return s[:start] + s[end:]
    except ValueError:
        return ""
    
def remove_spaces_and_newline(s):
    return re.sub(r'\s+', ' ', s.replace('\n',''))

# %%
# http://stackoverflow.com/questions/16571150/how-to-capture-stdout-output-from-a-python-function-call

from StringIO import StringIO
# import io
import sys

class Capturing(list):
    def __enter__(self):
        self._stdout = sys.stdout
        sys.stdout = self._stringio = StringIO()
        return self
    def __exit__(self, *args):
        try:
            self.extend(self._stringio.getvalue().splitlines())
        except UnicodeDecodeError as e:
            print "UnicodeDecodeError:" 
            print "from:\n", self._stringio.getvalue()
            print "-------------------------------------------"
            print traceback.format_exc()
        self.extend(self._stringio.getvalue().splitlines())
        self._stringio.truncate(0)
        sys.stdout = self._stdout

# %%
# Reset to original sys.__stdout__
# sys.stdout = sys.__stdout__

#
with Capturing() as output:
    print "Hola..."
    print u'unicode'
    print u'áéíóúÁÉÍÓÚñÑ'
    print "Adios."

# Log output
print "Prueba"
print 'output:\n', output
# Out:
# Prueba
# output:
# [u'Hola...', u'unicode', u'\xe1\xe9\xed\xf3\xfa\xc1\xc9\xcd\xd3\xda\xf1\xd1', u'Adios.', u'Hola...', u'unicode', u'\xe1\xe9\xed\xf3\xfa\xc1\xc9\xcd\xd3\xda\xf1\xd1', u'Adios.']

# %%
# https://docs.python.org/2/howto/logging.html
# Logging to a file
# http://stackoverflow.com/questions/24722240/where-are-python-logs-default-stored-when-ran-through-ipython-notebook

import logging
logger = logging.getLogger()
logger.handlers

# %%
logging.basicConfig(format='%(asctime)s [%(levelname)s] %(message)s', datefmt='%d/%m/%Y %I:%M:%S %p', filename='myfile.log',level=logging.DEBUG)
logging.debug('This message should appear on the console')
logging.debug('This message should appear on the console')

# %% [markdown]
# ## Scraping de la web de documents del Congrés

# %% [markdown]
# ### Obtenim el llistat de tots els diputats del Congrés amb els seus grups polítics.

# %%
import unicodedata
import sys

# Mètode que treu els accents a un string (en format unicode)
def remove_accents(input_str):
    nkfd_form = unicodedata.normalize('NFKD', input_str)
    return u"".join([c for c in nkfd_form if not unicodedata.combining(c)])

#
def get_group(member_group_dict, legislature):
    if legislature:
        for key in member_group_dict:
            if legislature in member_group_dict[key]:
                return key
    else:
        legislature = 0
        for key in member_group_dict:
            if legislature < max(member_group_dict[key]):
                legislature = max(member_group_dict[key])
        return get_group(member_group_dict, legislature)

#
def get_member_group_by_id(diputados_dict, id, legislature):
    if len(diputados_dict[id]['group']) == 1:
        return diputados_dict[id]['group'].keys()[0]
    else:
        return get_group(loaded_diputados_dict[id]['group'], legislature)

# Mètode per buscar un diputat al dictionari
def search_diputado_in_dict(my_dict, dip_surname, dip_name = "", ignore_accents = False):
    result = []
    for key in my_dict:
        if 'surname' in my_dict[key]:
            if ignore_accents:
                if remove_accents(unicode(dip_surname, encoding='utf-8').upper()) == remove_accents(unicode(my_dict[key]['surname']).upper()):
                    result.append(key)                
            else:
                if dip_surname.upper() == my_dict[key]['surname'].upper():
                    result.append(key)
            
    if len(result) == 0:
        print "ERROR en search_diputado_in_dict. No s'ha trobat:", dip_surname
        return None
    elif len(result) == 1:
        return result[0]
    else: # len(result) > 1:
        # print "search_diputado_in_dict, len(result) > 1:", result
        if dip_name != "":
            f_result = []
            for i in result:
                if dip_name.upper() == my_dict[i]['name'].upper():
                    f_result.append(i)
            
            if len(f_result) == 0:
                # print "ERROR en search_diputado_in_dict. No s'ha trobat:", dip_surname
                return None
            elif len(f_result) == 1:
                return f_result[0]
            else: # len(f_result) > 1:
                # print "search_diputado_in_dict, len(f_result) > 1:", f_result
                str_f_result = ""
                for i in f_result:
                    str_f_result += str(i) + ": " + my_dict[i]['surname'] + ", " + my_dict[i]['name'] + "\n"
                print "ERROR en search_diputado_in_dict. S'ha trobat més d'un resultat:\n", str_f_result.encode('utf-8')
                return f_result[0]
        else:
            str_result = ""
            for i in result:
                str_result += str(i) + ": " + my_dict[i]['surname'] + ", " + my_dict[i]['name'] + "\n"
            print "ERROR en search_diputado_in_dict. S'ha trobat més d'un resultat:\n", str_result.encode('utf-8')
            return result[0]

def search_diputado_in_dict_v2(my_dict, dip_surname, dip_name = "", verbose=False):
    result = []
    
    if dip_name != "":
        for key in my_dict:
            if remove_accents(dip_surname.upper()) == my_dict[key]['surname'] and remove_accents(dip_name.upper()) == my_dict[key]['name']:
                result.append(key)            
    else:
        for key in my_dict:
            if remove_accents(dip_surname.upper()) == my_dict[key]['surname']:
                result.append(key)

    if len(result) == 0:
        if verbose:
            print "ERROR en search_diputado_in_dict_v2. No s'ha trobat:", dip_surname, ",", dip_name
        return None
    elif len(result) == 1:
        return result[0]
    else: # len(result) > 1:
        if verbose:
            str_result = ""
            for i in result:
                str_result += str(i) + ": " + my_dict[i]['surname'] + ", " + my_dict[i]['name'] + "\n"
            print "ERROR en search_diputado_in_dict_v2. S'ha trobat més d'un resultat:\n", str_result.encode('utf-8')
        return result[0]
        
''' '''
loaded_diputados_dict = load_dict_json('diputados_dict.json')

s = "Aznar López"
n = "José María"
id = search_diputado_in_dict(loaded_diputados_dict,s,n, True)
if id:
    print id, ":", loaded_diputados_dict[id]
    print "group:", get_member_group_by_id(loaded_diputados_dict, id, 10)
else:
    print "ERROR en search_diputado_in_dict. No s'ha trobat:", s, n

s = u"Aznar López"
n = u"José María"
id = search_diputado_in_dict_v2(loaded_diputados_dict,s,n)
if id:
    print id, ":", loaded_diputados_dict[id]
    print "group:", get_member_group_by_id(loaded_diputados_dict, id, 10)
else:
    print "ERROR en search_diputado_in_dict_v2. No s'ha trobat:", s, n
# Out:
# 36 : {u'surname': u'AZNAR LOPEZ', u'group': {u'GP': [5, 6, 7]}, u'r_surname': u'Aznar L\xf3pez', u'r_name': u'Jos\xe9 Mar\xeda', u'name': u'JOSE MARIA'}
# group: GP
# 36 : {u'surname': u'AZNAR LOPEZ', u'group': {u'GP': [5, 6, 7]}, u'r_surname': u'Aznar L\xf3pez', u'r_name': u'Jos\xe9 Mar\xeda', u'name': u'JOSE MARIA'}
# group: GP

# %%
# Búsqueda amb dos paràmetres: pàgina i idLegislatura
# http://www.congreso.es/portal/page/portal/Congreso/Congreso/Diputados?_piref73_2874067_73_1333049_1333049.next_page=/wc/busquedaAlfabeticaDiputados&paginaActual=1&idLegislatura=4&tipoBusqueda=completo

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
from bs4 import BeautifulSoup
import os
import time

def add_member_to_dict(members_dict, surname, name, group, legislature, num_member):
    f_surname = remove_accents(unicode(surname).upper())
    f_name = remove_accents(unicode(name).upper())
    diputados_dict[num_member] = {'surname':f_surname, 'r_surname':surname, 'name':f_name, 'r_name':name, 'group':{group:[legislature]}}

os.environ["PATH"] = 'C:\Users\pablo_000\Documents\P\Data Science\chromedriver' \
    + os.pathsep + 'C:\Users\pfernandezs\Documents\P\Cosas\Data Science\posgrau\chromedriver'

browser = webdriver.Chrome()

delay = 5
element_id = "PIE"

diputados_dict = {}
num_diputado = 0
legislatura = 5

while legislatura < 11:

    continue_scraping = True
    web_page = 0

    while continue_scraping :
        
        url_page = "http://www.congreso.es/portal/page/portal/Congreso/Congreso/Diputados?_piref73_2874067_73_1333049_1333049.next_page=/wc/busquedaAlfabeticaDiputados&paginaActual={}&idLegislatura={}&tipoBusqueda=completo".format(web_page, legislatura)
        browser.get(url_page)
        
        # Wait for the page to load
        # http://selenium-python.readthedocs.org/en/latest/waits.html
        try:
            WebDriverWait(browser, delay).until(EC.presence_of_element_located((By.ID, element_id)))
            # print "Page is ready!"
        except TimeoutException:
            print "Loading took too much time!"
        except NoSuchElementException:
            print "Element id didn't find: " + element_id        

        html_page=browser.page_source

        if html_page is not None:
            print "Parsing: ..." + url_page[-80:]

            soup = BeautifulSoup(html_page)

            div_listado = soup.find('div', {'class' : 'listado_1'})
            if div_listado:
                li_tags = div_listado.findAll('li')
                if len(li_tags) > 0 :
                    for li_tag in li_tags:

                        spam_tag = li_tag.find('span')
                        group = get_text_between(spam_tag.getText(),'(',')')

                        link_tag = li_tag.find('a')
                        name = link_tag.getText().split(', ')
                        if len(name) == 0:
                            name = link_tag.getText().split(' ')
                        
                        
                        id = search_diputado_in_dict_v2(diputados_dict, name[0], name[1])
                        if id:
                            if group in diputados_dict[id]['group']:
                                diputados_dict[id]['group'][group].append(legislatura)
                            else:
                                diputados_dict[id]['group'].update({group:[legislatura]})
                        else:
                            add_member_to_dict(diputados_dict, name[0], name[1], group, legislatura, num_diputado)
                            num_diputado += 1
                        '''
                        id = search_diputado_in_dict(diputados_dict, name[0], name[1])
                        if id:
                            if name[1] == diputados_dict[id]['name']:
                                # print "Match:", name[1], "==", diputados_dict[id]['name']
                                if group in diputados_dict[id]['group']:
                                    diputados_dict[id]['group'][group].append(legislatura)
                                else:
                                    diputados_dict[id]['group'].update({group:[legislatura]})
                            else:
                                # print "Not match:", name[1], "<>", diputados_dict[id]['name']
                                diputados_dict[num_diputado] = {'surname':name[0], 'name':name[1], 'group':{group:[legislatura]}}
                                num_diputado += 1
                        else:
                            diputados_dict[num_diputado] = {'surname':name[0], 'name':name[1], 'group':{group:[legislatura]}}
                            num_diputado += 1
                        '''
                else:
                    print "No more results"
                    continue_scraping = False
            else:
                print "Tag not found: soup.find('div', {'class' : 'listado_1'})"
                continue_scraping = False
        else:
            print "URL not found:", url_page
            continue_scraping = False

        web_page += 1

        if web_page > 50:
            print "Reached web_page limit:", web_page
            continue_scraping = False
    
    legislatura += 1

print "Num. diputados:", len(diputados_dict)
# print diputados_dict
print "Saving 'diputados_dict'..."
save_dict_json(diputados_dict, 'diputados_dict.json')
# Out:
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=0&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=1&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=2&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=3&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=4&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=5&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=6&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=7&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=8&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=9&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=10&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=11&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=12&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=13&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=14&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=15&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=16&idLegislatura=5&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=17&idLegislatura=5&tipoBusqueda=completo
# No more results
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=0&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=1&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=2&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=3&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=4&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=5&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=6&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=7&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=8&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=9&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=10&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=11&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=12&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=13&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=14&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=15&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=16&idLegislatura=6&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=17&idLegislatura=6&tipoBusqueda=completo
# No more results
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=0&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=1&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=2&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=3&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=4&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=5&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=6&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=7&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=8&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=9&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=10&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=11&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=12&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=13&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=14&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=15&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=16&idLegislatura=7&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=17&idLegislatura=7&tipoBusqueda=completo
# No more results
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=0&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=1&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=2&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=3&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=4&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=5&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=6&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=7&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=8&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=9&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=10&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=11&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=12&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=13&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=14&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=15&idLegislatura=8&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=16&idLegislatura=8&tipoBusqueda=completo
# No more results
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=0&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=1&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=2&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=3&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=4&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=5&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=6&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=7&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=8&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...busquedaAlfabeticaDiputados&paginaActual=9&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=10&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=11&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=12&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=13&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=14&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=15&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=16&idLegislatura=9&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=17&idLegislatura=9&tipoBusqueda=completo
# No more results
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=0&idLegislatura=10&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=1&idLegislatura=10&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=2&idLegislatura=10&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=3&idLegislatura=10&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=4&idLegislatura=10&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=5&idLegislatura=10&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=6&idLegislatura=10&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=7&idLegislatura=10&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=8&idLegislatura=10&tipoBusqueda=completo
# Parsing: ...usquedaAlfabeticaDiputados&paginaActual=9&idLegislatura=10&tipoBusqueda=completo
# Parsing: ...squedaAlfabeticaDiputados&paginaActual=10&idLegislatura=10&tipoBusqueda=completo
# Parsing: ...squedaAlfabeticaDiputados&paginaActual=11&idLegislatura=10&tipoBusqueda=completo
# Parsing: ...squedaAlfabeticaDiputados&paginaActual=12&idLegislatura=10&tipoBusqueda=completo
# Parsing: ...squedaAlfabeticaDiputados&paginaActual=13&idLegislatura=10&tipoBusqueda=completo
# Parsing: ...squedaAlfabeticaDiputados&paginaActual=14&idLegislatura=10&tipoBusqueda=completo
# No more results
# Num. diputados: 1374
# Saving 'diputados_dict'...

# %% [markdown]
# A la base de dades no hi apareixen alguns ministres i altres membres del gobern que, en canvi, sí intervenen a les sessions de control del Congrés.  Els afegirem a mà:

# %%
# MINISTRO DE JUSTICIA (Catalá Polo)  -->  http://es.wikipedia.org/wiki/Rafael_Catal%C3%A1_Polo
add_member_to_dict(diputados_dict, u"Catalá Polo", u"Rafael", u"GP", 10, len(diputados_dict))
# MINISTRO DE EDUCACIÓN, CULTURA Y DEPORTE (Wert Ortega)  -->  http://es.wikipedia.org/wiki/Jos%C3%A9_Ignacio_Wert
add_member_to_dict(diputados_dict, u"Wert Ortega", u"José Ignacio", u"GP", 10, len(diputados_dict))
# MINISTRA DE AGRICULTURA, ALIMENTACIÓN Y MEDIO AMBIENTE (García Tejerina)  -->  http://es.wikipedia.org/wiki/Isabel_Garc%C3%ADa_Tejerina
add_member_to_dict(diputados_dict, u"García Tejerina", u"Isabel", u"GP", 10, len(diputados_dict))

# El diputat Yuste Cabello, Chesús no apareix en el diccionari perque es va donar de baixa el 02/07/2014:
# http://www.congreso.es/portal/page/portal/Congreso/Congreso/Diputados/BusqForm?_piref73_1333155_73_1333154_1333154.next_page=/wc/fichaDiputado&idDiputado=71
# Ver diputados que han causado baja:
# http://www.congreso.es/portal/page/portal/Congreso/Congreso/Diputados/BajasLegAct?_piref73_2496066_73_2496053_2496053.next_page=/wc/diputadosBajaLegActual&paginaActual=0

print "Num. diputados:", len(diputados_dict)
# print diputados_dict
print "Saving 'diputados_dict'..."
save_dict_json(diputados_dict, 'diputados_dict.json')
# Out:
# Num. diputados: 1377
# Saving 'diputados_dict'...

# %% [markdown]
# ### Creació de la base de dades del Congrés

# %%
import pymongo

# Create the connection to MongoDB
try:
    connection=pymongo.MongoClient()
    print "Connection to Mongo Daemon successful!!!"
except pymongo.errors.ConnectionFailure, e:
    print "Could not connect to MongoDB: %s" % e
    
# Obtenim la BD del Congrés
db = connection['congres']
#
print "Collections:", db.collection_names()
# Out:
# Connection to Mongo Daemon successful!!!
# Collections: [u'system.indexes', u'legislatures', u'all_document', u'document', u'congres_members', u'congres_groups']

# %% [markdown]
# Check the database status
# http://127.0.0.1:28017/

# %%
connection.close()

# %% [markdown]
# #### Guardem el diccionari dels diputats a la BD

# %%
#
congres_members_collection = db['congres_members']
congres_members_collection.drop()

#
loaded_diputados_dict = load_dict_json('diputados_dict.json')
print "num. of members:", len(loaded_diputados_dict)
for key in loaded_diputados_dict:
    congres_members_collection.insert(loaded_diputados_dict[key])

#
print "num. of rows: ", congres_members_collection.count()
for doc in congres_members_collection.find():
    print doc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-38ca6d3b0ed4> in <module>()
#       1 #
# ----> 2 congres_members_collection = db['congres_members']
#       3 congres_members_collection.drop()
#       4
#       5 #
#
# NameError: name 'db' is not defined

# %% [markdown]
# #### Creació d'indexos per millorar el temps de recerca

# %%
#
congres_members_collection = db['congres_members']

s = "Llamazares Trigo"
n = "Gaspar"

result = congres_members_collection.find({"surname":s.upper(), "name":n.upper()})
if result.count()>0:
    print "Result:", result[0]
else:
    print "No results"

print congres_members_collection.find({"surname":s.upper(), "name":n.upper()}).explain()["cursor"]
print congres_members_collection.find({"surname":s.upper(), "name":n.upper()}).explain()["nscanned"]
# Out:
# Result: {u'group': {u'GIU': [7], u'GIP': [10], u'GER-IU-ICV': [9], u'GIU-ICV': [8]}, u'name': u'GASPAR', u'r_name': u'Gaspar', u'surname': u'LLAMAZARES TRIGO', u'_id': ObjectId('551f91587c4c671d6037ad4c'), u'r_surname': u'Llamazares Trigo'}
# BtreeCursor surname_1_name_1
# 1

# %% [markdown]
# Les recerques a la col.lecció 'congres_members' utilitza un 'BasicCursor' equivalent a un 'table scan'. Afegirem uns indexos als camps 'surname' i 'name' per millorar la recerca:

# %%
# http://api.mongodb.org/python/current/tutorial.html#indexing
# http://docs.mongodb.org/manual/core/index-creation/
# http://docs.mongodb.org/manual/reference/indexes/

from pymongo import ASCENDING, DESCENDING

congres_members_collection.create_index([("surname", ASCENDING), ("name", ASCENDING)])
# Out:
# u'surname_1_name_1'

# %%
for index in congres_members_collection.index_information():
    print index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f861d2afa05a> in <module>()
# ----> 1 for index in congres_members_collection.index_information():
#       2     print index
#
# NameError: name 'congres_members_collection' is not defined

# %%
s = "Llamazares Trigo"
n = "Gaspar"

print congres_members_collection.find({"surname":s.upper(), "name":n.upper()}).explain()["cursor"]
print congres_members_collection.find({"surname":s.upper(), "name":n.upper()}).explain()["nscanned"]

print '\nObservació: la recerca amb "re.compile(s, re.IGNORECASE)" no aprofita l\'index creat, recorre tots els elements de la taula:', congres_members_collection.count()
import re
# http://stackoverflow.com/questions/6266555/querying-mongodb-via-pymongo-in-case-insensitive-efficiently
print congres_members_collection.find({'surname': re.compile(s, re.IGNORECASE), "name":re.compile(n, re.IGNORECASE)}).explain()["cursor"]
print congres_members_collection.find({'surname': re.compile(s, re.IGNORECASE), "name":re.compile(n, re.IGNORECASE)}).explain()["nscanned"]
# Out:
# BtreeCursor surname_1_name_1
# 1
#
# Observació: la recerca amb "re.compile(s, re.IGNORECASE)" no aprofita l'index creat, recorre tots els elements de la taula: 1377
# BtreeCursor surname_1_name_1
# 1377

# %%
# Metode per buscar un diputat a la BD
# TODO: canviar la query per afegir el parametre 'legislature'
def search_diputado_in_BD(collection, s, n="", legislature=0, verbose=False):
    if n=="":
        result = collection.find({'surname': remove_accents(s.upper())})
    else:
        result = collection.find({'surname': remove_accents(s.upper()), "name": remove_accents(n.upper())})
            
    if result.count() == 0:
        if verbose:
            print "WARN en search_diputado_in_BD: No s'han trobat resultats per:", s, "; ", n
        return None
    elif result.count() == 1:
        return result[0]
    else: # result.count() > 1:

        if legislature > 0:
            f_result = []
            for result_obj in result:
                found = False
                for group in result_obj['group']:
                    if legislature in result_obj['group'][group]:
                        found = True
                if found:
                    f_result.append(result_obj)

            if len(f_result) == 0:
                print "WARN en search_diputado_in_BD: No s'han trobat resultats per:", s, "; ", n, ", legislature:", legislature
                result.rewind()
                return result[0]
            elif len(f_result) == 1:
                return f_result[0]
            else:
                if verbose:
                    print "WARN en search_diputado_in_BD: S'ha trobat més d'un resultat per: ", s, "; ", n
                    for f_result_obj in f_result:
                        print "\t", f_result_obj
                return f_result[0]
        else:
            if verbose:
                print "WARN en search_diputado_in_BD: S'ha trobat més d'un resultat per: ", s, "; ", n
                for result_obj in result:
                    print "\t", result_obj
                # http://stackoverflow.com/questions/9872891/is-it-possible-to-iterate-a-mongo-cursor-twice
                result.rewind()
            return result[0]


def get_group(group_dict, legislature):
    for key in group_dict:
        if legislature in group_dict[key]:
            return key
    return group_dict[0]

''' '''
#
congres_members_collection = db['congres_members']

# El paràmetre de recerca en unicode
s = u"Llamazares Trigo"
n = u"Gaspar"
dip = search_diputado_in_BD(congres_members_collection,s,n)
if dip:
    print dip
    if len(dip['group']) == 1:
        print "Group:", dip['group'].keys()[0]
    else:
        print "Groups:", dip['group']
        group = get_group(dip['group'], 10)
        if group:
            print s, ",", n, "-->", group
else:
    print "ERROR en search_diputado_in_BD. No s'ha trobat:", s, n

s = u"Fernández Díaz"
dip = search_diputado_in_BD(congres_members_collection, s, legislature=10, verbose=True)
if dip:
    print dip
    if len(dip['group']) == 1:
        print "Group:", dip['group'].keys()[0]
    else:
        print "Groups:", dip['group']
        group = get_group(dip['group'], 10)
        if group:
            print s, ",", n, "-->", group
else:
    print "ERROR en search_diputado_in_BD. No s'ha trobat:", s
# Out:
# {u'group': {u'GIU': [7], u'GIP': [10], u'GER-IU-ICV': [9], u'GIU-ICV': [8]}, u'name': u'GASPAR', u'r_name': u'Gaspar', u'surname': u'LLAMAZARES TRIGO', u'_id': ObjectId('551f91587c4c671d6037ad4c'), u'r_surname': u'Llamazares Trigo'}
# Groups: {u'GIU': [7], u'GIP': [10], u'GER-IU-ICV': [9], u'GIU-ICV': [8]}
# Llamazares Trigo , Gaspar --> GIP
# {u'group': {u'GP': [5, 6, 7, 8, 9, 10]}, u'name': u'JORGE', u'r_name': u'Jorge', u'surname': u'FERNANDEZ DIAZ', u'_id': ObjectId('551f91597c4c671d6037b19c'), u'r_surname': u'Fern\xe1ndez D\xedaz'}
# Group: GP

# %% [markdown]
# ### Llistat de grups de parlamentaris del Congrés

# %%
# Diferents grups trobats al diccionari de diputats

loaded_diputados_dict = load_dict_json('diputados_dict.json')

all_groups = []

for key in loaded_diputados_dict:
    for subkey in loaded_diputados_dict[key]['group']:
        try:
            all_groups.index(subkey)
        except ValueError:
            all_groups.append(subkey)

print len(all_groups), "groups"
print all_groups
# Out:
# 16 groups
# [u'GP', u'GS', u'GIU-IC', u'GMX', u'GV (EAJ-PNV)', u'GV-PNV', u'GCC', u'GMx', u'GCC-NC', u'GC-CiU', u'GIP', u'GUPyD', u'GIU', u'GIU-ICV', u'GER-IU-ICV', u'GER-ERC']

# %%
# http://www.congreso.es/portal/page/portal/Congreso/Congreso/GruPar?_piref73_2914053_73_1339199_1339199.next_page=/wc/cambioLegislatura
# http://www.w3schools.com/html/html_colornames.asp
groups_dict = {
    '0':{'code':'GP', 'description':'Grupo Parlamentario Popular en el Congreso','color':'steelblue'},
    '1':{'code':'GS', 'description':'Grupo Parlamentario Socialista','color':'red'},
    '2':{'code':'GC-CiU', 'description':'Grupo Parlamentario Catalán (Convergència i Unió)','color':'orange'},
    '3':{'code':'GIU', 'description':'Grupo Parlamentario Federal de Izquierda Unida','color':'green'},
    '4':{'code':'GIP', 'description':'Grupo Parlamentario de IU, ICV-EUiA, CHA: La Izquierda Plural','color':'green'},
    '5':{'code':'GIU-IC', 'description':'Grupo Parlamentario Federal Izquierda Unida-Iniciativa per Catalunya','color':'green'},
    '6':{'code':'GIU-ICV', 'description':'Grupo Parlamentario de Izquierda Unida-Iniciativa per Catalunya Verds','color':'green'},
    '7':{'code':'GER-IU-ICV', 'description':'Grupo Parlamentario de Esquerra Republicana-Izquierda Unida-Iniciativa per Catalunya Verds','color':'green'},
    '8':{'code':'GER-ERC', 'description':'Grupo Parlamentario de Esquerra Republicana (ERC)','color':'gold'},
    '9':{'code':'GUPyD', 'description':'Grupo Parlamentario de Unión Progreso y Democracia','color':'pink'},
    '10':{'code':'GV (EAJ-PNV)', 'description':'Grupo Parlamentario Vasco (EAJ-PNV)','color':'brown'},
    '11':{'code':'GV-PNV', 'description':'Grupo Parlamentario Vasco (PNV)','color':'brown'},
    '12':{'code':'GCC', 'description':'Grupo Parlamentario de Coalición Canaria','color':'yellow'},
    '13':{'code':'GCC-NC', 'description':'Grupo Parlamentario de Coalición Canaria-Nueva Canarias','color':'yellow'},
    '14':{'code':'GMX', 'description':'Grupo Parlamentario Mixto','color':'grey'},
    '15':{'code':'GMx', 'description':'Grupo Parlamentario Mixto','color':'grey'}
}

print "Num. groups:", len(groups_dict)
print groups_dict
print "Saving 'groups_dict'..."
save_dict_json(groups_dict, 'groups_dict.json')
# Out:
# Num. groups: 16
# {'11': {'color': 'brown', 'code': 'GV-PNV', 'description': 'Grupo Parlamentario Vasco (PNV)'}, '10': {'color': 'brown', 'code': 'GV (EAJ-PNV)', 'description': 'Grupo Parlamentario Vasco (EAJ-PNV)'}, '13': {'color': 'yellow', 'code': 'GCC-NC', 'description': 'Grupo Parlamentario de Coalici\xc3\xb3n Canaria-Nueva Canarias'}, '12': {'color': 'yellow', 'code': 'GCC', 'description': 'Grupo Parlamentario de Coalici\xc3\xb3n Canaria'}, '15': {'color': 'grey', 'code': 'GMx', 'description': 'Grupo Parlamentario Mixto'}, '14': {'color': 'grey', 'code': 'GMX', 'description': 'Grupo Parlamentario Mixto'}, '1': {'color': 'red', 'code': 'GS', 'description': 'Grupo Parlamentario Socialista'}, '0': {'color': 'steelblue', 'code': 'GP', 'description': 'Grupo Parlamentario Popular en el Congreso'}, '3': {'color': 'green', 'code': 'GIU', 'description': 'Grupo Parlamentario Federal de Izquierda Unida'}, '2': {'color': 'orange', 'code': 'GC-CiU', 'description': 'Grupo Parlamentario Catal\xc3\xa1n (Converg\xc3\xa8ncia i Uni\xc3\xb3)'}, '5': {'color': 'green', 'code': 'GIU-IC', 'description': 'Grupo Parlamentario Federal Izquierda Unida-Iniciativa per Catalunya'}, '4': {'color': 'green', 'code': 'GIP', 'description': 'Grupo Parlamentario de IU, ICV-EUiA, CHA: La Izquierda Plural'}, '7': {'color': 'green', 'code': 'GER-IU-ICV', 'description': 'Grupo Parlamentario de Esquerra Republicana-Izquierda Unida-Iniciativa per Catalunya Verds'}, '6': {'color': 'green', 'code': 'GIU-ICV', 'description': 'Grupo Parlamentario de Izquierda Unida-Iniciativa per Catalunya Verds'}, '9': {'color': 'pink', 'code': 'GUPyD', 'description': 'Grupo Parlamentario de Uni\xc3\xb3n Progreso y Democracia'}, '8': {'color': 'gold', 'code': 'GER-ERC', 'description': 'Grupo Parlamentario de Esquerra Republicana (ERC)'}}
# Saving 'groups_dict'...

# %%
#
congres_groups_collection = db['congres_groups']
congres_groups_collection.drop()

#
loaded_groups_dict = load_dict_json('groups_dict.json')
print "num. of groups:", len(loaded_groups_dict)
for key in loaded_groups_dict:
    congres_groups_collection.insert(loaded_groups_dict[key])

#
print "num. of rows: ", congres_groups_collection.count()
for doc in congres_groups_collection.find():
    print doc
# Out:
# num. of groups: 16
# num. of rows:  16
# {u'color': u'brown', u'_id': ObjectId('552062f97c4c671994a624dd'), u'description': u'Grupo Parlamentario Vasco (PNV)', u'code': u'GV-PNV'}
# {u'color': u'brown', u'_id': ObjectId('552062f97c4c671994a624de'), u'description': u'Grupo Parlamentario Vasco (EAJ-PNV)', u'code': u'GV (EAJ-PNV)'}
# {u'color': u'yellow', u'_id': ObjectId('552062f97c4c671994a624df'), u'description': u'Grupo Parlamentario de Coalici\xf3n Canaria-Nueva Canarias', u'code': u'GCC-NC'}
# {u'color': u'yellow', u'_id': ObjectId('552062f97c4c671994a624e0'), u'description': u'Grupo Parlamentario de Coalici\xf3n Canaria', u'code': u'GCC'}
# {u'color': u'grey', u'_id': ObjectId('552062f97c4c671994a624e1'), u'description': u'Grupo Parlamentario Mixto', u'code': u'GMx'}
# {u'color': u'grey', u'_id': ObjectId('552062f97c4c671994a624e2'), u'description': u'Grupo Parlamentario Mixto', u'code': u'GMX'}
# {u'color': u'red', u'_id': ObjectId('552062f97c4c671994a624e3'), u'description': u'Grupo Parlamentario Socialista', u'code': u'GS'}
# {u'color': u'steelblue', u'_id': ObjectId('552062f97c4c671994a624e4'), u'description': u'Grupo Parlamentario Popular en el Congreso', u'code': u'GP'}
# {u'color': u'green', u'_id': ObjectId('552062f97c4c671994a624e5'), u'description': u'Grupo Parlamentario Federal de Izquierda Unida', u'code': u'GIU'}
# {u'color': u'orange', u'_id': ObjectId('552062f97c4c671994a624e6'), u'description': u'Grupo Parlamentario Catal\xe1n (Converg\xe8ncia i Uni\xf3)', u'code': u'GC-CiU'}
# {u'color': u'green', u'_id': ObjectId('552062f97c4c671994a624e7'), u'description': u'Grupo Parlamentario Federal Izquierda Unida-Iniciativa per Catalunya', u'code': u'GIU-IC'}
# {u'color': u'green', u'_id': ObjectId('552062f97c4c671994a624e8'), u'description': u'Grupo Parlamentario de IU, ICV-EUiA, CHA: La Izquierda Plural', u'code': u'GIP'}
# {u'color': u'green', u'_id': ObjectId('552062f97c4c671994a624e9'), u'description': u'Grupo Parlamentario de Esquerra Republicana-Izquierda Unida-Iniciativa per Catalunya Verds', u'code': u'GER-IU-ICV'}
# {u'color': u'green', u'_id': ObjectId('552062f97c4c671994a624ea'), u'description': u'Grupo Parlamentario de Izquierda Unida-Iniciativa per Catalunya Verds', u'code': u'GIU-ICV'}
# {u'color': u'pink', u'_id': ObjectId('552062f97c4c671994a624eb'), u'description': u'Grupo Parlamentario de Uni\xf3n Progreso y Democracia', u'code': u'GUPyD'}
# {u'color': u'gold', u'_id': ObjectId('552062f97c4c671994a624ec'), u'description': u'Grupo Parlamentario de Esquerra Republicana (ERC)', u'code': u'GER-ERC'}

# %%
def search_group_in_text_DB(text, congres_groups_col):
    
    for congres_group in congres_groups_col.find():
        description = congres_group['description'].upper()
        if description in text.upper():
            return congres_group['code']
    return None

# Test

doc_text= u'''
    ? DEL DIPUTADO DON ALFRED BOSCH I PASCUAL, DEL GRUPO PARLAMENTARIO MIXTO,
    QUE FORMULA AL SEÑOR PRESIDENTE DEL GOBIERNO: ¿CONSIDERA EL GOBIERNO
    ADECUADO PARA ERRADICAR LA POBREZA INFANTIL EN CATALUÑA LOS 2,25 EUROS
    POR NIÑO QUE DESTINÓ PARA COMBATIRLA MEDIANTE EL FONDO CORRESPONDIENTE?
    (Número de expediente 180/001217).
'''

congres_groups_collection = db['congres_groups']

print search_group_in_text_DB(doc_text, congres_groups_collection)
# Out:
# GMx

# %% [markdown]
# ### Llistat de les legislatures V-X amb els intervals de duració

# %%
# http://www.congreso.es/portal/page/portal/Congreso/Congreso/Diputados/Historia
# http://www.congreso.es/portal/page/portal/Congreso/Congreso/Diputados/Historia/VLeg
# V LEGISLATURA 1993-1996 (Del 29 de junio de 1993 al 26 de marzo de 1996)
# http://www.congreso.es/portal/page/portal/Congreso/Congreso/Diputados/Historia/VILeg
# VI LEGISLATURA 1996-2000 (Del 27 de marzo de 1996 al 4 de abril de 2000)
# http://www.congreso.es/portal/page/portal/Congreso/Congreso/Diputados/Historia/VIILeg
# VII LEGISLATURA 2000-2004 (Del 5 de abril de 2000 al 1 de abril de 2004)
# http://www.congreso.es/portal/page/portal/Congreso/Congreso/Diputados/Historia/VIIILeg
# VIII LEGISLATURA  2004-2008 (Del 2 de abril de 2004 al 31 de marzo de 2008)
# http://www.congreso.es/portal/page/portal/Congreso/Congreso/Diputados/Historia/LegIX
# IX LEGISLATURA  2008-2011 (Del 1 de abril de 2008 al 13 de diciembre de 2011)
# X LEGISLATURA  2011-Actualidad (Del 14 de diciembre de 2011 hasta la actualidad)

def get_legislature(legislatures_dict, doc_date):
    d_doc_date = datetime.datetime.strptime(doc_date, "%d/%m/%Y")
    for key in legislatures_dict:
        if legislatures_dict[key]['start'].date() <= d_doc_date.date() <= legislatures_dict[key]['end'].date():
            return legislatures_dict[key]['_id']
    print "ERROR, get_legislature: date out of range:", doc_date
    return -1

legislatures_dict = {
    '0':{'_id':5, 'start' : datetime.datetime.strptime("29/06/1993", "%d/%m/%Y"), 'end' : datetime.datetime.strptime("26/03/1996", "%d/%m/%Y"),
         'description':'V LEGISLATURA 1993-1996 (Del 29 de junio de 1993 al 26 de marzo de 1996)'},
    '1':{'_id':6, 'start' : datetime.datetime.strptime("27/03/1996", "%d/%m/%Y"), 'end' : datetime.datetime.strptime("04/04/2000", "%d/%m/%Y"),
         'description':'VI LEGISLATURA 1996-2000 (Del 27 de marzo de 1996 al 4 de abril de 2000)'},
    '2':{'_id':7, 'start' : datetime.datetime.strptime("05/04/2000", "%d/%m/%Y"), 'end' : datetime.datetime.strptime("01/04/2004", "%d/%m/%Y"),
         'description':'VII LEGISLATURA 2000-2004 (Del 5 de abril de 2000 al 1 de abril de 2004)'},
    '3':{'_id':8, 'start' : datetime.datetime.strptime("02/04/2004", "%d/%m/%Y"), 'end' : datetime.datetime.strptime("31/03/2008", "%d/%m/%Y"),
         'description':'VIII LEGISLATURA  2004-2008 (Del 2 de abril de 2004 al 31 de marzo de 2008)'},
    '4':{'_id':9, 'start' : datetime.datetime.strptime("01/04/2008", "%d/%m/%Y"), 'end' : datetime.datetime.strptime("13/12/2011", "%d/%m/%Y"),
         'description':'IX LEGISLATURA  2008-2011 (Del 1 de abril de 2008 al 13 de diciembre de 2011)'},
    '5':{'_id':10, 'start' : datetime.datetime.strptime("14/12/2011", "%d/%m/%Y"), 'end' : datetime.datetime.today(),
         'description':'X LEGISLATURA  2011-Actualidad (Del 14 de diciembre de 2011 hasta la actualidad)'}
}

print "Num. legislatures:", len(legislatures_dict)
print legislatures_dict
print "Saving 'legislatures_dict'..."
save_dict_json(legislatures_dict, 'legislatures_dict.json')
# Out:
#  Num. legislatures: 6
# {'1': {'start': datetime.datetime(1996, 3, 27, 0, 0), '_id': 6, 'end': datetime.datetime(2000, 4, 4, 0, 0), 'description': 'VI LEGISLATURA 1996-2000 (Del 27 de marzo de 1996 al 4 de abril de 2000)'}, '0': {'start': datetime.datetime(1993, 6, 29, 0, 0), '_id': 5, 'end': datetime.datetime(1996, 3, 26, 0, 0), 'description': 'V LEGISLATURA 1993-1996 (Del 29 de junio de 1993 al 26 de marzo de 1996)'}, '3': {'start': datetime.datetime(2004, 4, 2, 0, 0), '_id': 8, 'end': datetime.datetime(2008, 3, 31, 0, 0), 'description': 'VIII LEGISLATURA  2004-2008 (Del 2 de abril de 2004 al 31 de marzo de 2008)'}, '2': {'start': datetime.datetime(2000, 4, 5, 0, 0), '_id': 7, 'end': datetime.datetime(2004, 4, 1, 0, 0), 'description': 'VII LEGISLATURA 2000-2004 (Del 5 de abril de 2000 al 1 de abril de 2004)'}, '5': {'start': datetime.datetime(2011, 12, 14, 0, 0), '_id': 10, 'end': datetime.datetime(2015, 4, 3, 22, 52, 7, 268000), 'description': 'X LEGISLATURA  2011-Actualidad (Del 14 de diciembre de 2011 hasta la actualidad)'}, '4': {'start': datetime.datetime(2008, 4, 1, 0, 0), '_id': 9, 'end': datetime.datetime(2011, 12, 13, 0, 0), 'description': 'IX LEGISLATURA  2008-2011 (Del 1 de abril de 2008 al 13 de diciembre de 2011)'}}
# Saving 'legislatures_dict'...

# %%
loaded_legislatures_dict = load_dict_json('legislatures_dict.json')

my_date = "03/06/2007"
print "my_date:", my_date, ", legislature:", get_legislature(loaded_legislatures_dict, my_date)
my_date = "03/06/2012"
print "my_date:", my_date, ", legislature:", get_legislature(loaded_legislatures_dict, my_date)
my_date = "03/06/1996"
print "my_date:", my_date, ", legislature:", get_legislature(loaded_legislatures_dict, my_date)
# Out:
# my_date: 03/06/2007 , legislature:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ee6957eecca5> in <module>()
#       2
#       3 my_date = "03/06/2007"
# ----> 4 print "my_date:", my_date, ", legislature:", get_legislature(loaded_legislatures_dict, my_date)
#       5 my_date = "03/06/2012"
#       6 print "my_date:", my_date, ", legislature:", get_legislature(loaded_legislatures_dict, my_date)
#
# NameError: name 'get_legislature' is not defined

# %%
#
legislatures_collection = db['legislatures']
legislatures_collection.drop()

#
loaded_legislatures_dict = load_dict_json('legislatures_dict.json')
print "num. of legislatures:", len(loaded_legislatures_dict)
for key in loaded_legislatures_dict:
    legislatures_collection.insert(loaded_legislatures_dict[key])

#
print "num. of rows: ", legislatures_collection.count()
for doc in legislatures_collection.find():
    print doc
# Out:
# num. of legislatures: 6
# num. of rows:  6
# {u'start': datetime.datetime(1996, 3, 27, 0, 0), u'_id': 6, u'end': datetime.datetime(2000, 4, 4, 0, 0), u'description': u'VI LEGISLATURA 1996-2000 (Del 27 de marzo de 1996 al 4 de abril de 2000)'}
# {u'start': datetime.datetime(1993, 6, 29, 0, 0), u'_id': 5, u'end': datetime.datetime(1996, 3, 26, 0, 0), u'description': u'V LEGISLATURA 1993-1996 (Del 29 de junio de 1993 al 26 de marzo de 1996)'}
# {u'start': datetime.datetime(2004, 4, 2, 0, 0), u'_id': 8, u'end': datetime.datetime(2008, 3, 31, 0, 0), u'description': u'VIII LEGISLATURA  2004-2008 (Del 2 de abril de 2004 al 31 de marzo de 2008)'}
# {u'start': datetime.datetime(2000, 4, 5, 0, 0), u'_id': 7, u'end': datetime.datetime(2004, 4, 1, 0, 0), u'description': u'VII LEGISLATURA 2000-2004 (Del 5 de abril de 2000 al 1 de abril de 2004)'}
# {u'start': datetime.datetime(2011, 12, 14, 0, 0), u'_id': 10, u'end': datetime.datetime(2015, 4, 3, 22, 52, 7, 268000), u'description': u'X LEGISLATURA  2011-Actualidad (Del 14 de diciembre de 2011 hasta la actualidad)'}
# {u'start': datetime.datetime(2008, 4, 1, 0, 0), u'_id': 9, u'end': datetime.datetime(2011, 12, 13, 0, 0), u'description': u'IX LEGISLATURA  2008-2011 (Del 1 de abril de 2008 al 13 de diciembre de 2011)'}

# %%
my_date = "03/06/2007"
d_doc_date = datetime.datetime.strptime(my_date, "%d/%m/%Y")
result = legislatures_collection.find({'start':{'$lte':d_doc_date}, 'end':{'$gte':d_doc_date}})
print result.explain()
# Out:
# {u'nYields': 0, u'nscannedAllPlans': 6, u'filterSet': False, u'allPlans': [{u'nChunkSkips': 0, u'n': 1, u'cursor': u'BasicCursor', u'scanAndOrder': False, u'nscannedObjects': 6, u'isMultiKey': False, u'indexOnly': False, u'nscanned': 6}], u'millis': 0, u'nChunkSkips': 0, u'server': u'PFS:27017', u'n': 1, u'cursor': u'BasicCursor', u'scanAndOrder': False, u'nscannedObjectsAllPlans': 6, u'isMultiKey': False, u'stats': {u'works': 8, u'docsTested': 6, u'isEOF': 1, u'needFetch': 0, u'needTime': 6, u'yields': 0, u'invalidates': 0, u'unyields': 0, u'type': u'COLLSCAN', u'children': [], u'advanced': 1}, u'indexOnly': False, u'nscanned': 6, u'nscannedObjects': 6}

# %%
def get_legislature_DB(legislatures_col, d_doc_date):
    result = legislatures_col.find({'start':{'$lte':d_doc_date}, 'end':{'$gte':d_doc_date}})
    
    if result.count() == 1:
        return result[0]['_id']
    else:
        print "ERROR, get_legislature: date out of range:", doc_date
        return -1

# Test
legislatures_collection = db['legislatures']
    
my_date = datetime.datetime.strptime("03/06/2007", "%d/%m/%Y")
print "my_date:", my_date, ", legislature:", get_legislature_DB(legislatures_collection, my_date)
my_date = datetime.datetime.strptime("03/06/2012", "%d/%m/%Y")
print "my_date:", my_date, ", legislature:", get_legislature_DB(legislatures_collection, my_date)
my_date = datetime.datetime.strptime("03/06/1996", "%d/%m/%Y")
print "my_date:", my_date, ", legislature:", get_legislature_DB(legislatures_collection, my_date)
# Out:
# my_date: 2007-06-03 00:00:00 , legislature: 8
# my_date: 2012-06-03 00:00:00 , legislature: 10
# my_date: 1996-06-03 00:00:00 , legislature: 6

# %% [markdown]
# ### Scraping per descarregar els documents de les sessions del Congrés [ Edición oficial / Búsqueda de publicaciones ]

# %% [markdown]
# #### Estructura del diccionari de documents

# %%
'''
all_document_dictionary = {
    'date': <data del document (Diario de sesiones del congreso de los diputados)>,
    'url': <url del document>,
    'description': <descripció del document>
    'id': <id del document a document_dictionary>
}

document_dictionary = {
    'date': <data del document (Diario de sesiones del congreso de los diputados)>,
    'url': <url del document>,
    'content_doc': <contingut del document en format html (sense tractar)>
    'updated_content_doc': <data d'actualització del camp 'content_doc'>
    <session_dictionary, diccionari amb les preguntes i intervencions de la sessió de control>
    'updated_session_dictionary': <data d'actualització del camp 'session_dictionary'>
}

session_dictionary = [{
    'question': <texte de la pregunta realitzada>,
    'speaker': <nom i cognoms de qui realitza la pregunta>,
    'group': <grup parlamentari que fa la pregunta o al que pertany qui realitza la pregunta>,
    'expedient_number': <número d'expedient de la pregunta>, 
    'intervention_dictonary' : [], diccionari amb les intervencions de la sessió de control i les persones que les van realitzar>
}, ..., ]

intervention_dictonary = [{
    {
        'text': <text de la intervenció>,
        'who': {  
            'surname': <cognoms de la persona que realitza la intervenció>,
            'name': <nom de la persona que realitza la intervenció>,
            'group': <grup al que pertany la persona: 'GP' (Grupo Popular), 'GS' (Grupo Socialista), ...>
        }
    }, ..., ]
}
'''

# %%
# Congreso de los Diputados / Edición oficial / Búsqueda de publicaciones

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException

from bs4 import BeautifulSoup
import re

import os
import time
import datetime


os.environ["PATH"] = 'C:\Users\pablo_000\Documents\P\Data Science\chromedriver' \
    + os.pathsep + 'C:\Users\pfernandezs\Documents\P\Cosas\Data Science\posgrau\chromedriver'
    
browser = webdriver.Chrome()

# Congreso de los Diputados / Edición oficial / Búsqueda de publicaciones
url_page = "http://www.congreso.es/portal/page/portal/Congreso/Congreso/Publicaciones"
web_congreso = 'http://www.congreso.es'

idLegislatura = ["PUW0", "PUW1", "PUW2", "PUW3", "PUW4", "PUW5", "PUW6", "PUW7", "PUW8", "PUW9", "PU10"]

# Descarregarem els documents desde la V legislatura fins la X legislatura (actual), és a dir, els documents desde 1993 fins ara.
legislatura = 5

# Data 'desde' al formulari
d_day = "01"
d_month = "01"
d_year = "1993"

# Data 'hasta' al formulari
h_d = datetime.date.today()
h_day = h_d.strftime('%d')
h_month = h_d.strftime('%m')
h_year = h_d.strftime('%Y')

delay = 5
element_idLegislatura_id = "idLegislatura"
element_PIE_id = "PIE"
    
num_docs = 0
all_document_dictionary = {}

while legislatura < 11:

    continue_scraping = True

    browser.get(url_page)
    
    # Wait for the page to load
    try:
        WebDriverWait(browser, delay).until(EC.presence_of_element_located((By.ID, element_idLegislatura_id)))
        # print "Page is ready!"
    except TimeoutException:
        print "Loading took too much time!"
    except NoSuchElementException:
        print "Element id didn't find: " + element_idLegislatura_id
    
    print "Starting scraping legislature:", legislatura
        
    html_page=browser.page_source

    # Omplim el formulari
    # http://selenium-python.readthedocs.org/navigating.html#filling-in-forms

    # <select name="BASE" id="idLegislatura" onchange="cambiarLegislatura()">
    #   <option selected value="PU10">X Legislatura ( 2011-Actualidad ) </option>
    #   <option value="PUW9">IX Legislatura ( 2008-2011 ) </option>
    #   <option value="PUW8">VIII Legislatura ( 2004-2008 ) </option>
    #   <option value="PUW7">VII Legislatura ( 2000-2004 ) </option>
    #   <option value="PUW6">VI Legislatura ( 1996-2000 ) </option>
    #   <option value="PUW5">V Legislatura ( 1993-1996 ) </option>
    #   <option value="PUW4">IV Legislatura ( 1989-1993 ) </option>
    #   <option value="PUW3">III Legislatura ( 1986-1989 ) </option>
    #   <option value="PUW2">II Legislatura ( 1982-1986 ) </option>
    #   <option value="PUW1">I Legislatura ( 1979-1982 ) </option>
    #   <option value="PUW0">Legislatura Constituyente ( 1977-1979 ) </option>
    element_idLegislatura = browser.find_element_by_id("idLegislatura")
    select = Select(element_idLegislatura)
    select.select_by_value(idLegislatura[legislatura])

    # Wait for the page to load
    try:
        WebDriverWait(browser, delay).until(EC.presence_of_element_located((By.ID, element_PIE_id)))
        # print "Page is ready!"
    except TimeoutException:
        print "Loading took too much time!"
    except NoSuchElementException:
        print "Element id didn't find: " + element_PIE_id

    # Tipo Búsqueda
    # <select name="TIPOB" id="TIPOB">
    #    <option value="1">Simple</option>
    #    <option value="2">Detallada por p&aacute;ginas</option>
    element_tipob = browser.find_element_by_id("TIPOB")
    select = Select(element_tipob)
    select.select_by_value("1")

    # Publicación
    # <select name="PUBL" id="PUBL">
    #    <option value="B">Boletines Oficiales</option>
    #    <option value="D">Diarios de sesiones</option>
    element_publ = browser.find_element_by_id("PUBL")
    element_publ.send_keys("D")

    # Sección
    # <select name="SECC" id="SECC">
    #    <option value="Congreso">Congreso de los Diputados</option>
    #    <option value="Cortes">Cortes Generales</option>
    #    <option value="Senado">Senado</option>
    element_secc = browser.find_element_by_id("SECC")
    element_secc.send_keys("Congreso")

    # Serie/Aptdo./Órgano
    # <input type="text" name="ORSE"  id="idOrse" value=''  />
    element_orse = browser.find_element_by_id("idOrse")
    element_orse.send_keys("Pleno")

    # Descripción
    # <input type="text" name="SUDE" id="SUDE" value='' />

    # <p>Fecha desde:</p>
    # <input type="text" name="ddia" id="ddia" maxlength="2" value="" class="caja_mini" />
    element_ddia = browser.find_element_by_id("ddia")
    element_ddia.send_keys(d_day)
    # <input type="text" name="dmes" id="dmes" maxlength="2" value="" class="caja_mini" />
    element_dmes = browser.find_element_by_id("dmes")
    element_dmes.send_keys(d_month)
    # <input type="text" name="dano" id="dano" maxlength="4" value="" class="caja_mini_ano" />
    element_dano = browser.find_element_by_id("dano")
    element_dano.send_keys(d_year)

    # <p class="fecha">Fecha hasta:</p>
    # <input type="text" name="hdia" id="hdia" maxlength="2" value="" class="caja_mini" />
    element_hdia = browser.find_element_by_id("hdia")
    element_hdia.send_keys(h_day)
    # <input type="text" name="hmes" id="hmes" maxlength="2" value="" class="caja_mini" />
    element_hmes = browser.find_element_by_id("hmes")
    element_hmes.send_keys(h_month)
    # <input type="text" name="hano" id="hano" maxlength="4" value="" class="caja_mini_ano" />
    element_hano = browser.find_element_by_id("hano")
    element_hano.send_keys(h_year)

    # <INPUT type="IMAGE" Alt='Buscar' value='Buscar' src="/wc/htdocs/web/img/btn_buscar.gif" />
    element_buscar = browser.find_element_by_xpath("//input[@src='/wc/htdocs/web/img/btn_buscar.gif']")
    element_buscar.click()
    
    legislature_page = 1

    while continue_scraping:
        
        # Wait for the page to load
        try:
            WebDriverWait(browser, delay).until(EC.presence_of_element_located((By.ID, element_PIE_id)))
            # print "Page is ready!"
        except TimeoutException:
            print "Loading took too much time!"
        except NoSuchElementException:
            print "Element id didn't find: " + element_PIE_id
        
        html_page=browser.page_source

        print "Scraping page:", legislature_page
        
        soup = BeautifulSoup(html_page)

        # <div class="RESULTADOS_BUSQUEDA">
        div_resultados = soup.find('div', {'id' : 'RESULTADOS_BUSQUEDA'})
        if div_resultados:
            for div_resultados_encontrados in div_resultados.findAll('div', {'class' : 'resultados_encontrados'}):
                link_tag = div_resultados_encontrados.find('a', attrs={'href': re.compile("^/portal")})
                if link_tag:
                    url_document = web_congreso + link_tag.get('href')
                    description = remove_spaces_and_newline(remove_text_between(link_tag.getText(),'(',')').strip())
                    doc_date = datetime.datetime.strptime(description.split(', de ')[1][:10], "%d/%m/%Y")

                    all_document_dictionary[num_docs] = {'description': description, 'url':url_document, 'date':doc_date, 'id':''}
                    num_docs += 1
                else:
                    print "Tag not found: div_resultados_encontrados.find('a', attrs={'href': re.compile('^/portal')})"
        else:
            print "Tag not found: soup.find('div', {'id' : 'RESULTADOS_BUSQUEDA'})"

        try:
            element_siguiente = browser.find_element_by_xpath("//*[contains(text(), 'Siguiente')]")
            element_siguiente.click()
        except NoSuchElementException as e:
            # print e
            print "Scraping legislature", legislatura, "finished..."
            continue_scraping = False
            
        legislature_page += 1
            
    legislatura += 1
    
print "Num. documents:", len(all_document_dictionary)
print "Saving dictionary..."
save_dict_json(all_document_dictionary, 'all_document_dictionary.json')
# Out:
# Starting scraping legislature: 5
# Scraping page:
#  1
# Scraping page:
#  2
# Scraping page:
#  3
# Scraping page:
#  4
# Scraping page:
#  5
# Scraping page:
#  6
# Scraping page:
#  7
# Scraping page:
#  8
# Scraping legislature
#  5 finished...
# Starting scraping legislature:
#  6
# Scraping page:
#  1
# Scraping page:
#  2
# Scraping page:
#  3
# Scraping page:
#  4
# Scraping page:
#  5
# Scraping page:
#  6
# Scraping page:
#  7
# Scraping page:
#  8
# Scraping page:
#  9
# Scraping page:
#  10
# Scraping page:
#  11
# Scraping legislature
#  6 finished...
# Starting scraping legislature:
#  7
# Scraping page:
#  1
# Scraping page:
#  2
# Scraping page:
#  3
# Scraping page:
#  4
# Scraping page:
#  5
# Scraping page:
#  6
# Scraping page:
#  7
# Scraping page:
#  8
# Scraping page:
#  9
# Scraping page:
#  10
# Scraping page:
#  11
# Scraping page:
#  12
# Scraping legislature
#  7 finished...
# Starting scraping legislature:
#  8
# Scraping page:
#  1
# Scraping page:
#  2
# Scraping page:
#  3
# Scraping page:
#  4
# Scraping page:
#  5
# Scraping page:
#  6
# Scraping page:
#  7
# Scraping page:
#  8
# Scraping page:
#  9
# Scraping page:
#  10
# Scraping page:
#  11
# Scraping page:
#  12
# Scraping legislature
#  8 finished...
# Starting scraping legislature:
#  9
# Scraping page:
#  1
# Scraping page:
#  2
# Scraping page:
#  3
# Scraping page:
#  4
# Scraping page:
#  5
# Scraping page:
#  6
# Scraping page:
#  7
# Scraping page:
#  8
# Scraping page:
#  9
# Scraping page:
#  10
# Scraping page:
#  11
# Scraping legislature
#  9 finished...
# Starting scraping legislature:
#  10
# Scraping page:
#  1
# Scraping page:
#  2
# Scraping page:
#  3
# Scraping page:
#  4
# Scraping page:
#  5
# Scraping page:
#  6
# Scraping page:
#  7
# Scraping page:
#  8
# Scraping page:
#  9
# Scraping page:
#  10
# Scraping page:
#  11
# Scraping legislature 10 finished...
# Num. documents: 1566
# Saving dictionary...

# %% [markdown]
# #### Saving 'all_document_dictionary' to MongoDB, in 'all_document' collection

# %%
#
collection = db['all_document']
collection.drop()

#
loaded_all_document_dictionary = load_dict_json('all_document_dictionary.json')
print "num. of documents:", len(loaded_all_document_dictionary)
for key in loaded_all_document_dictionary:
    collection.insert(loaded_all_document_dictionary[key])

#
print "num. of rows: ", collection.count()
for doc in collection.find():
    print doc
# Out:
# num. of documents: 1566
# num. of rows:
#  1566
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805120157.CODI.#1', u'date': datetime.datetime(1998, 5, 12, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a555'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 157, de 12/05/1998', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805130158.CODI.#1', u'date': datetime.datetime(1998, 5, 13, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a556'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 158, de 13/05/1998', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805140159.CODI.#1', u'date': datetime.datetime(1998, 5, 14, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a557'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 159, de 14/05/1998', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805190160.CODI.#1', u'date': datetime.datetime(1998, 5, 19, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a558'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 160, de 19/05/1998', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199804230153.CODI.#1', u'date': datetime.datetime(1998, 4, 23, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a559'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 153, de 23/04/1998', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199804280154.CODI.#1', u'date': datetime.datetime(1998, 4, 28, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a55a'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 154, de 28/04/1998', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199804290155.CODI.#1', u'date': datetime.datetime(1998, 4, 29, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a55b'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 155, de 29/04/1998', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199804300156.CODI.#1', u'date': datetime.datetime(1998, 4, 30, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a55c'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 156, de 30/04/1998', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805200161.CODI.#1', u'date': datetime.datetime(1998, 5, 20, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a55d'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 161, de 20/05/1998', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805210162.CODI.#1', u'date': datetime.datetime(1998, 5, 21, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a55e'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 162, de 21/05/1998', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710280110.CODI.#1', u'date': datetime.datetime(1997, 10, 28, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a55f'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 110, de 28/10/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710290111.CODI.#1', u'date': datetime.datetime(1997, 10, 29, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a560'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 111, de 29/10/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710220108.CODI.#1', u'date': datetime.datetime(1997, 10, 22, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a561'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 108, de 22/10/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710230109.CODI.#1', u'date': datetime.datetime(1997, 10, 23, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a562'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 109, de 23/10/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710080106.CODI.#1', u'date': datetime.datetime(1997, 10, 8, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a563'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 106, de 08/10/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710090107.CODI.#1', u'date': datetime.datetime(1997, 10, 9, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a564'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 107, de 09/10/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199709250104.CODI.#1', u'date': datetime.datetime(1997, 9, 25, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a565'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 104, de 25/09/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710070105.CODI.#1', u'date': datetime.datetime(1997, 10, 7, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a566'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 105, de 07/10/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199709230102.CODI.#1', u'date': datetime.datetime(1997, 9, 23, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a567'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 102, de 23/09/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199709240103.CODI.#1', u'date': datetime.datetime(1997, 9, 24, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a568'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 103, de 24/09/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705070081.CODI.#1', u'date': datetime.datetime(1997, 5, 7, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a569'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 81, de 07/05/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705080082.CODI.#1', u'date': datetime.datetime(1997, 5, 8, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a56a'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 82, de 08/05/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705200083.CODI.#1', u'date': datetime.datetime(1997, 5, 20, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a56b'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 83, de 20/05/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705210084.CODI.#1', u'date': datetime.datetime(1997, 5, 21, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a56c'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 84, de 21/05/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705220085.CODI.#1', u'date': datetime.datetime(1997, 5, 22, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a56d'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 85, de 22/05/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705270086.CODI.#1', u'date': datetime.datetime(1997, 5, 27, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a56e'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 86, de 27/05/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705280087.CODI.#1', u'date': datetime.datetime(1997, 5, 28, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a56f'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 87, de 28/05/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705290088.CODI.#1', u'date': datetime.datetime(1997, 5, 29, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a570'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 88, de 29/05/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199706030089.CODI.#1', u'date': datetime.datetime(1997, 6, 3, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a571'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 89, de 03/06/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW6&PIECE=PUW6&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199706040090.CODI.#1', u'date': datetime.datetime(1997, 6, 4, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a572'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 90, de 04/06/1997', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411290110.CODI.#1', u'date': datetime.datetime(1994, 11, 29, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a573'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 110, de 29/11/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411300111.CODI.#1', u'date': datetime.datetime(1994, 11, 30, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a574'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 111, de 30/11/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411160104.CODI.#1', u'date': datetime.datetime(1994, 11, 16, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a575'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 104, de 16/11/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411170105.CODI.#1', u'date': datetime.datetime(1994, 11, 17, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a576'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 105, de 17/11/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411030102.CODI.#1', u'date': datetime.datetime(1994, 11, 3, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a577'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 102, de 03/11/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411150103.CODI.#1', u'date': datetime.datetime(1994, 11, 15, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a578'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 103, de 15/11/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411230108.CODI.#1', u'date': datetime.datetime(1994, 11, 23, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a579'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 108, de 23/11/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411240109.CODI.#1', u'date': datetime.datetime(1994, 11, 24, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a57a'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 109, de 24/11/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411210106.CODI.#1', u'date': datetime.datetime(1994, 11, 21, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a57b'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 106, de 21/11/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411220107.CODI.#1', u'date': datetime.datetime(1994, 11, 22, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a57c'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 107, de 22/11/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PU10&PIECE=PUWD&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-63.CODI.#1', u'date': datetime.datetime(2012, 10, 9, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a57d'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 63, de 09/10/2012', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW8&PIECE=PUW8&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200705310259.CODI.#1', u'date': datetime.datetime(2007, 5, 31, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a57e'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 259, de 31/05/2007', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201005260168.CODI.#1', u'date': datetime.datetime(2010, 5, 26, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a57f'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 168, de 26/05/2010', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PU10&PIECE=PUWD&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-66.CODI.#1', u'date': datetime.datetime(2012, 10, 22, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a580'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 66, de 22/10/2012', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PU10&PIECE=PUWD&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-65.CODI.#1', u'date': datetime.datetime(2012, 10, 11, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a581'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 65, de 11/10/2012', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411020101.CODI.#1', u'date': datetime.datetime(1994, 11, 2, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a582'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 101, de 02/11/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199410270100.CODI.#1', u'date': datetime.datetime(1994, 10, 27, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a583'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 100, de 27/10/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199409280093.CODI.#1', u'date': datetime.datetime(1994, 9, 28, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a584'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 93, de 28/09/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199409270092.CODI.#1', u'date': datetime.datetime(1994, 9, 27, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a585'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 92, de 27/09/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199410040095.CODI.#1', u'date': datetime.datetime(1994, 10, 4, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a586'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 95, de 04/10/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199409290094.CODI.#1', u'date': datetime.datetime(1994, 9, 29, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a587'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 94, de 29/09/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199410060097.CODI.#1', u'date': datetime.datetime(1994, 10, 6, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a588'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 97, de 06/10/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199410050096.CODI.#1', u'date': datetime.datetime(1994, 10, 5, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a589'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 96, de 05/10/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199410260099.CODI.#1', u'date': datetime.datetime(1994, 10, 26, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a58a'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 99, de 26/10/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199410250098.CODI.#1', u'date': datetime.datetime(1994, 10, 25, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a58b'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 98, de 25/10/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PU10&PIECE=PUWD&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-68.CODI.#1', u'date': datetime.datetime(2012, 10, 24, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a58c'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 68, de 24/10/2012', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200109060099.CODI.#1', u'date': datetime.datetime(2001, 9, 6, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a58d'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 99, de 06/09/2001', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200107260098.CODI.#1', u'date': datetime.datetime(2001, 7, 26, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a58e'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 98, de 26/07/2001', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106210094.CODI.#1', u'date': datetime.datetime(2001, 6, 21, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a58f'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 94, de 21/06/2001', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106200093.CODI.#1', u'date': datetime.datetime(2001, 6, 20, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a590'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 93, de 20/06/2001', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106270096.CODI.#1', u'date': datetime.datetime(2001, 6, 27, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a591'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 96, de 27/06/2001', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106260095.CODI.#1', u'date': datetime.datetime(2001, 6, 26, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a592'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 95, de 26/06/2001', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106130090.CODI.#1', u'date': datetime.datetime(2001, 6, 13, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a593'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 90, de 13/06/2001', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106120089.CODI.#1', u'date': datetime.datetime(2001, 6, 12, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a594'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 89, de 12/06/2001', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106190092.CODI.#1', u'date': datetime.datetime(2001, 6, 19, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a595'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 92, de 19/06/2001', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106140091.CODI.#1', u'date': datetime.datetime(2001, 6, 14, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a596'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 91, de 14/06/2001', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PU10&PIECE=PUWD&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-135.CODI.#1', u'date': datetime.datetime(2013, 9, 11, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a597'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 135, de 11/09/2013', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201004220157.CODI.#1', u'date': datetime.datetime(2010, 4, 22, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a598'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 157, de 22/04/2010', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201004210156.CODI.#1', u'date': datetime.datetime(2010, 4, 21, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a599'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 156, de 21/04/2010', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201003180149.CODI.#1', u'date': datetime.datetime(2010, 3, 18, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a59a'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 149, de 18/03/2010', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201003170148.CODI.#1', u'date': datetime.datetime(2010, 3, 17, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a59b'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 148, de 17/03/2010', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201003240151.CODI.#1', u'date': datetime.datetime(2010, 3, 24, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a59c'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 151, de 24/03/2010', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201003230150.CODI.#1', u'date': datetime.datetime(2010, 3, 23, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a59d'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 150, de 23/03/2010', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201004130153.CODI.#1', u'date': datetime.datetime(2010, 4, 13, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a59e'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 153, de 13/04/2010', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201003250152.CODI.#1', u'date': datetime.datetime(2010, 3, 25, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a59f'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 152, de 25/03/2010', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201004200155.CODI.#1', u'date': datetime.datetime(2010, 4, 20, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5a0'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 155, de 20/04/2010', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201004140154.CODI.#1', u'date': datetime.datetime(2010, 4, 14, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5a1'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 154, de 14/04/2010', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912220134.CODI.#1', u'date': datetime.datetime(2009, 12, 22, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5a2'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 134, de 22/12/2009', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912170133.CODI.#1', u'date': datetime.datetime(2009, 12, 17, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5a3'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 133, de 17/12/2009', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912160132.CODI.#1', u'date': datetime.datetime(2009, 12, 16, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5a4'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 132, de 16/12/2009', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912150131.CODI.#1', u'date': datetime.datetime(2009, 12, 15, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5a5'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 131, de 15/12/2009', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912030130.CODI.#1', u'date': datetime.datetime(2009, 12, 3, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5a6'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 130, de 03/12/2009', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912020129.CODI.#1', u'date': datetime.datetime(2009, 12, 2, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5a7'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 129, de 02/12/2009', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912010128.CODI.#1', u'date': datetime.datetime(2009, 12, 1, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5a8'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 128, de 01/12/2009', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200911260127.CODI.#1', u'date': datetime.datetime(2009, 11, 26, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5a9'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 127, de 26/11/2009', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201002100137.CODI.#1', u'date': datetime.datetime(2010, 2, 10, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5aa'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 137, de 10/02/2010', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201002090136.CODI.#1', u'date': datetime.datetime(2010, 2, 9, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5ab'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 136, de 09/02/2010', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200012120048.CODI.#1', u'date': datetime.datetime(2000, 12, 12, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5ac'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 48, de 12/12/2000', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200011300047.CODI.#1', u'date': datetime.datetime(2000, 11, 30, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5ad'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 47, de 30/11/2000', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200012140050.CODI.#1', u'date': datetime.datetime(2000, 12, 14, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5ae'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 50, de 14/12/2000', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201105240246.CODI.#1', u'date': datetime.datetime(2011, 5, 24, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5af'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 246, de 24/05/2011', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201105120245.CODI.#1', u'date': datetime.datetime(2011, 5, 12, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5b0'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 245, de 12/05/2011', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201105260248.CODI.#1', u'date': datetime.datetime(2011, 5, 26, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5b1'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 248, de 26/05/2011', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200012130049.CODI.#1', u'date': datetime.datetime(2000, 12, 13, 0, 0), u'_id': ObjectId('551f13017c4c671d6037a5b2'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 49, de 13/12/2000', u'id': u''}
# ...
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402150046.CODI.#1', u'date': datetime.datetime(1994, 2, 15, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab54'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 46, de 15/02/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402160047.CODI.#1', u'date': datetime.datetime(1994, 2, 16, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab55'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 47, de 16/02/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402090044.CODI.#1', u'date': datetime.datetime(1994, 2, 9, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab56'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 44, de 09/02/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402100045.CODI.#1', u'date': datetime.datetime(1994, 2, 10, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab57'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 45, de 10/02/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199401200042.CODI.#1', u'date': datetime.datetime(1994, 1, 20, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab58'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 42, de 20/01/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW5&PIECE=PUW5&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402080043.CODI.#1', u'date': datetime.datetime(1994, 2, 8, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab59'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 43, de 08/02/1994', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201107120260.CODI.#1', u'date': datetime.datetime(2011, 7, 12, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab5a'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 260, de 12/07/2011', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201107130261.CODI.#1', u'date': datetime.datetime(2011, 7, 13, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab5b'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 261, de 13/07/2011', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106160253.CODI.#1', u'date': datetime.datetime(2011, 6, 16, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab5c'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 253, de 16/06/2011', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106210254.CODI.#1', u'date': datetime.datetime(2011, 6, 21, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab5d'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 254, de 21/06/2011', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106140251.CODI.#1', u'date': datetime.datetime(2011, 6, 14, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab5e'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 251, de 14/06/2011', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106150252.CODI.#1', u'date': datetime.datetime(2011, 6, 15, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab5f'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 252, de 15/06/2011', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106290257.CODI.#1', u'date': datetime.datetime(2011, 6, 29, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab60'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 257, de 29/06/2011', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106300258.CODI.#1', u'date': datetime.datetime(2011, 6, 30, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab61'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 258, de 30/06/2011', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106220255.CODI.#1', u'date': datetime.datetime(2011, 6, 22, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab62'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 255, de 22/06/2011', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106280256.CODI.#1', u'date': datetime.datetime(2011, 6, 28, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab63'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 256, de 28/06/2011', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200005240009.CODI.#1', u'date': datetime.datetime(2000, 5, 24, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab64'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 9, de 24/05/2000', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200005300010.CODI.#1', u'date': datetime.datetime(2000, 5, 30, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab65'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 10, de 30/05/2000', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW9&PIECE=PUW9&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201004280159.CODI.#1', u'date': datetime.datetime(2010, 4, 28, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab66'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 159, de 28/04/2010', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200005170007.CODI.#1', u'date': datetime.datetime(2000, 5, 17, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab67'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 7, de 17/05/2000', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200005230008.CODI.#1', u'date': datetime.datetime(2000, 5, 23, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab68'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 8, de 23/05/2000', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PU10&PIECE=PUWD&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-55-C1+DSCD-10-PL-55.CODI.#1', u'date': datetime.datetime(2012, 9, 11, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab69'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 55, de 11/09/2012', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PU10&PIECE=PUWD&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-56.CODI.#1', u'date': datetime.datetime(2012, 9, 12, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab6a'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 56, de 12/09/2012', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PU10&PIECE=PUWD&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201207190051.CODI.#1', u'date': datetime.datetime(2012, 7, 19, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab6b'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 51, de 19/07/2012', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PU10&PIECE=PUWD&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201207240053.CODI.#1', u'date': datetime.datetime(2012, 7, 24, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab6c'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 53, de 24/07/2012', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PU10&PIECE=PUWD&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201207170049.CODI.#1', u'date': datetime.datetime(2012, 7, 17, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab6d'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 49, de 17/07/2012', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PU10&PIECE=PUWD&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201207180050.CODI.#1', u'date': datetime.datetime(2012, 7, 18, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab6e'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 50, de 18/07/2012', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200006140013.CODI.#1', u'date': datetime.datetime(2000, 6, 14, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab6f'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 13, de 14/06/2000', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PUW7&PIECE=PUW7&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200006200014.CODI.#1', u'date': datetime.datetime(2000, 6, 20, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab70'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 14, de 20/06/2000', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PU10&PIECE=PUWD&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-59.CODI.#1', u'date': datetime.datetime(2012, 9, 19, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab71'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 59, de 19/09/2012', u'id': u''}
# {u'url': u'http://www.congreso.es/portal/page/portal/Congreso/PopUpCGI?CMD=VERDOC&CONF=BRSPUB.cnf&BASE=PU10&PIECE=PUWD&DOCS=1-1&FMT=PUWTXDTS.fmt&OPDEF=Y&QUERY=%40FECH%26gt%3B%3D19930101+%26+%40FECH%26lt%3B%3D20150404+%26+%28D%29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-60.CODI.#1', u'date': datetime.datetime(2012, 9, 20, 0, 0), u'_id': ObjectId('551f13027c4c671d6037ab72'), u'description': u'Congreso de los Diputados, Pleno y Dip. Perm., n\xfam. 60, de 20/09/2012', u'id': u''}

# %%
# Mètode per descarregar els documents del diccionari 'all_document_dictionary' que corresponen a sessions de control del Congrés

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
import os
import datetime

def download_docs_to_DB(all_doc_collection, doc_collection, overwrite = False):
    
    os.environ["PATH"] = 'C:\Users\pablo_000\Documents\P\Data Science\chromedriver' \
        + os.pathsep + 'C:\Users\pfernandezs\Documents\P\Cosas\Data Science\posgrau\chromedriver'

    delay = 10
    element_id = 'PIE_POPUP'
    
    browser = webdriver.Chrome()
    
    for doc in all_doc_collection.find():
        if doc['id']=="" or overwrite:
            print "Loading: ...", doc['url'][-80:]
            browser.get(doc['url'])
            
            # Wait for the page to load
            # http://selenium-python.readthedocs.org/en/latest/waits.html
            try:
                WebDriverWait(browser, delay).until(EC.presence_of_element_located((By.ID, element_id)))
                # print "Page is ready!"
            except TimeoutException:
                print "Loading took too much time!"
            except NoSuchElementException:
                print "Element id didn't find: " + element_id
            
            html_page = browser.page_source
            
            # Aquí es filtra els documents a guardar per data (dimecres hi ha sessió de control al Congrés) 
            # i també buscant al texte del diari de la sessió (buscant p.e. 'PREGUNTAS:')
            if isWednesday(doc['date']) and 'PREGUNTAS:' in html_page:
                print "Saving: ...", doc['url'][-80:]
                new_doc = {'date':doc['date'], \
                           'url':doc['url'], \
                           'description':doc['description'], \
                           'content_doc':html_page, \
                           'updated_content_doc':datetime.datetime.utcnow(), \
                           'session_dictionary':{}, \
                           'updated_session_dictionary':datetime.datetime.utcnow() \
                           }
                
                # Desde la versió 3.0:
                # new_doc_id = doc_collection.insert_one(new_doc).inserted_id
                doc_collection.insert(new_doc)
                inserted_doc = doc_collection.find({'date':new_doc['date']})
                # http://docs.mongodb.org/manual/tutorial/modify-documents/
                all_doc_collection.update({'_id':doc['_id']},{'$set':{'id':inserted_doc[0]['_id']}},upsert=False, multi=False)

#
all_doc_col = db['all_document']
#
doc_col = db['document']
doc_col.drop()

download_docs_to_DB(all_doc_col, doc_col)
# Out:
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805120157.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805130158.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805140159.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805190160.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199804230153.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199804280154.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199804290155.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199804290155.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199804300156.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805200161.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805200161.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805210162.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710280110.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710290111.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710290111.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710220108.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710230109.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710080106.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710080106.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710090107.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199709250104.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199710070105.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199709230102.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199709240103.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199709240103.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705070081.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705070081.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705080082.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705200083.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705210084.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705210084.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705220085.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705270086.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705280087.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705280087.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705290088.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199706030089.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199706040090.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199706040090.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411290110.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411300111.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411300111.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411160104.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411160104.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411170105.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411030102.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411150103.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411230108.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411240109.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411210106.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411220107.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-63.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200705310259.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201005260168.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201005260168.CODI.#1
# Loading: ... %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-66.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-65.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411020101.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199411020101.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199410270100.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199409280093.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199409280093.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199409270092.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199410040095.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199409290094.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199410060097.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199410050096.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199410050096.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199410260099.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199410260099.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199410250098.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-68.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200109060099.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200107260098.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106210094.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106200093.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106200093.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106270096.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106260095.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106130090.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106130090.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106120089.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106190092.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200106140091.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-135.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-135.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201004220157.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201004210156.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201004210156.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201003180149.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201003170148.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201003240151.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201003240151.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201003230150.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201004130153.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201003250152.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201004200155.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201004140154.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201004140154.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912220134.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912170133.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912160132.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912160132.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912150131.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912030130.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912020129.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912020129.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200912010128.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200911260127.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201002100137.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201002100137.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201002090136.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200012120048.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200011300047.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200012140050.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201105240246.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201105120245.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201105260248.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200012130049.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200012130049.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201105050242.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201105040241.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201105110244.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201105110244.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201105100243.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200706130261.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200706130261.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200511140127.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106080250.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106080250.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106070249.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200012190051.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200303110233.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200303060232.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200302200229.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200302190228.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200302190228.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200303050231.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200303040230.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200302120225.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200302120225.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200302110224.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200302180227.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200302130226.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199911240276.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199911240276.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201205310037.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200205210162.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200510190121.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200510190121.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201007210183.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201007210183.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201007200182.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201007200181.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201007150179.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201007140178.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199903180223.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199903170222.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199903160221.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199903110220.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199903100219.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199903100219.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199903090218.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199902250217.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199902240216.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-70.CODI.#1
# Saving: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-70.CODI.#1
# Loading: ... CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-69-C1+DSCD-10-PL-69.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201205160030.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201205160030.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199903240225.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199903230224.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201205170031.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199911160272.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199911170273.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201205230034.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201205290035.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199811120193.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199811110192.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199811110192.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199810060185.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199810010184.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199810080187.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199810070186.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199810070186.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199810280189.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199810270188.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199811100191.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199810280190.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199902090209.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199812220206.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199812170205.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199812160204.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199812160204.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199902170213.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199902170213.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199902160212.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199902110211.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199902100210.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199902100210.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199902230215.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199902180214.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200602070146.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199702110056.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199612270053.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199702130058.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199702120057.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199702120057.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199612170050.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199612120049.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199612190052.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199612180051.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199612180051.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199702190060.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199702190060.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199702180059.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199511080182.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199511080182.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199511070181.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199510250180.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199510240179.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199510190178.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199510180177.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199510180177.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199510170176.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199510050175.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199510040174.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199510040174.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199510030173.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-201.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-202.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-202.CODI.#1
# Loading: ... 29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-199.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-200.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-200.CODI.#1
# Loading: ... 29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-205.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-206.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-206.CODI.#1
# Loading: ... %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-58.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-203.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-204.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201009090187.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200210310201.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201009080186.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201009080186.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200909080100.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200909090101.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200909090101.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200906250095.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200907080096.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200909150103.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200909160104.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200909160104.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200909090101.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200909090101.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200909100102.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200909170105.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200909220106.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200303180236.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200303250237.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200303120234.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200303130235.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200304010240.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200304020241.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200304020241.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200303260238.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200303270239.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200304030242.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200304080243.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-250.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-250.CODI.#1
# Loading: ... 29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-251.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200104260081.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200105160082.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200105160082.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200104240079.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200104250080.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200104250080.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200105230085.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200105290086.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200105170083.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200105220084.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200105300087.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200105300087.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200105310088.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199904200230.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199904210231.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199904210231.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199904220232.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199904270233.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199903300226.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199904130227.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199904140228.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199904140228.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199904150229.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-75.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-76.CODI.#1
# Saving: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-76.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-77.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-78.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199904280234.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199904280234.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199904290235.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-73.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-74.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199809290182.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199809300183.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199809300183.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199809230180.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199809230180.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199809240181.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199809170178.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199809220179.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199809150176.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199809160177.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199809160177.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199806240173.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199806240173.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199806250174.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199811160194.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199811170195.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199811180196.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199811190197.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199811240198.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199811250199.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199811260200.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199812090201.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199812090201.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199812100202.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199812150203.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199703190069.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199703200070.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199702260063.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199702260063.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199702270064.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199702200061.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199702250062.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199703130067.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199703180068.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199703110065.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199703120066.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199703120066.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199509270171.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199509270171.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199509280172.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199509190167.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199509200168.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199509200168.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199509210169.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199509260170.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199507270163.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199509120164.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199509130165.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199509130165.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199509140166.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200302050222.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200302060223.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200212100212.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200212110213.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200411300053.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200411250052.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200411150047.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200411030046.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200411030046.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200411020045.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200410270044.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200411240051.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200411240051.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200411230050.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200411170049.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200411160048.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200203210149.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200910270116.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200910210115.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200910140112.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200910140112.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200910130111.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200910200114.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200910150113.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200909290108.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200909230107.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200909230107.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200910010110.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200909300109.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-259.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-258.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-254.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-254.CODI.#1
# Loading: ... 29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-253.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-257.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-257.CODI.#1
# Loading: ... 29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-256.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199404120061.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199403240060.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-261.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-260.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-260.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199403100057.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199403090056.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199403090056.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199403230059.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199403230059.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199403220058.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199403020053.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199403020053.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199403010052.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199403080055.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199403030054.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200104170076.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200104050075.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200104040074.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200104040074.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200104030073.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200103220072.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200103210071.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200103210071.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200103200070.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200103150069.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200104190078.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200104180077.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200104180077.CODI.#1
# Loading: ... 29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-262.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199906150245.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199905270244.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-92.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-91.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199905110237.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199905040236.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199905130239.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199905120238.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199905120238.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199905190241.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199905190241.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199905180240.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199905260243.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199905260243.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199905200242.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200506210098.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199611130038.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199611120037.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199610310036.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199610300035.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199610300035.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199610290034.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199610230033.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199610220032.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199610100031.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199610090030.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199610090030.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199610080029.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199506150154.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199506140153.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199506140153.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199506210156.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199506200155.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199506270158.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199506220157.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199506290160.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199506280159.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199506280159.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199507050162.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199507040161.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-226.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-246.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-227.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-228.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200412280062.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199306290001.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-229.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-229.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200412010054.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200412010054.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200412020055.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200412020056.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200412090057.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200412140058.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200412150059.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200412150059.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200412210060.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200412220061.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200412220061.CODI.#1
# Loading: ... 29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-247.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-247.CODI.#1
# Loading: ... 29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-224.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-225.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-225.CODI.#1
# Loading: ... 29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-189.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-189.CODI.#1
# Loading: ... %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-90.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-191.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-192.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-193.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-193.CODI.#1
# Loading: ... 29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-194.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-195.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-89.CODI.#1
# Saving: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-89.CODI.#1
# Loading: ... 29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-197.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-198.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-198.CODI.#1
# Loading: ... %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-88.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-87.CODI.#1
# Saving: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-87.CODI.#1
# Loading: ... %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-84.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-83.CODI.#1
# Saving: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-83.CODI.#1
# Loading: ... %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-82.CODI.#1
# Loading: ...
# ...
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199806100167.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199806100167.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199806090166.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805280165.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805270164.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805270164.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199805260163.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199806230172.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199806180171.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-143.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-142.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-141.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-141.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199709180101.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199709170100.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199709170100.CODI.#1
# Loading: ... 29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-140.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199706110092.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199706050091.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199706240094.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199706120093.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199706260096.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199706250095.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199706250095.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199709160099.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199707170098.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-137.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200903310073.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199704150074.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199704100073.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199704090072.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199704090072.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199704080071.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199704230078.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199704230078.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199704220077.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199704170076.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199704160075.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199704160075.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199705060080.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199704240079.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-266.CODI.#1
# Saving: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-266.CODI.#1
# Loading: ... NGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-267-C1+DSCD-10-PL-267.CODI.#1
# Loading: ...
#  NGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-268-C1+DSCD-10-PL-268.CODI.#1
# Loading: ...
#  29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-269.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200703290246.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200704170247.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200703150240.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200703200241.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200703130238.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200703140239.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200703140239.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200703270244.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200703280245.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200703280245.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200703210242.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200703210242.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200703220243.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199412210117.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199412210117.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199412200116.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199412270119.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199412220118.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199412130113.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199412010112.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199412150115.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199412140114.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199412140114.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199502090122.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199502080121.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200006290020.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200109270108.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200110020109.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200109110100.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200109120101.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200109120101.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200109130102.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200109180103.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200109190104.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200109190104.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200109200105.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200109250106.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200109260107.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201003110146.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201003160147.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201003090144.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201003100145.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201002230142.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201002240143.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201002240143.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201002170140.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201002170140.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201002180141.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201002110138.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201002160139.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200309100274.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200309100274.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200309110275.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200307280269.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200307300271.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200307010266.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200307080267.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200306260264.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200306300265.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200309160276.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200309170277.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200911120121.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200911170122.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200911180123.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200911180123.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200911190124.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200910280117.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200910280117.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200910290118.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200911100119.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200911110120.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200911240125.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200911250126.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200911250126.CODI.#1
# Loading: ... CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-57-C1+DSCD-10-PL-57.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402230050.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402230050.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402240051.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402170048.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402220049.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402150046.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402160047.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402160047.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402090044.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402090044.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402100045.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199401200042.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP199402080043.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201107120260.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201107130261.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201107130261.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106160253.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106210254.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106140251.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106150252.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106150252.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106290257.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106300258.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106220255.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106220255.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201106280256.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200005240009.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200005240009.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200005300010.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201004280159.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201004280159.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200005170007.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200005170007.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200005230008.CODI.#1
# Loading: ...
#  CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-55-C1+DSCD-10-PL-55.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-56.CODI.#1
# Saving: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-56.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201207190051.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201207240053.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201207170049.CODI.#1
# Loading: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201207180050.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP201207180050.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200006140013.CODI.#1
# Saving: ...
#  9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200006140013.CODI.#1
# Loading: ... 9.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+CDP200006200014.CODI.#1
# Loading: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-59.CODI.#1
# Saving: ...
#  %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-59.CODI.#1
# Loading: ... %29.PUBL.+%26+%28CONGRESO%29.SECC.+%26+%28PLENO%29.ORSE.+Y+DSCD-10-PL-60.CODI.#1

# %%
#
doc_col = db['document']

print "num. of rows: ", doc_col.count()
for doc in doc_col.find():
    file_name = doc['date'].strftime("%Y%m%d") + "_doc.html"
    print file_name, ":", doc['description']
    save_text_file(doc['content_doc'], 'docs/' + file_name)
# Out:
# num. of rows:  372
# 19980429_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 155, de 29/04/1998
# 19980520_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 161, de 20/05/1998
# 19971029_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 111, de 29/10/1997
# 19971008_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 106, de 08/10/1997
# 19970924_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 103, de 24/09/1997
# 19970507_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 81, de 07/05/1997
# 19970521_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 84, de 21/05/1997
# 19970528_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 87, de 28/05/1997
# 19970604_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 90, de 04/06/1997
# 19941130_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 111, de 30/11/1994
# 19941116_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 104, de 16/11/1994
# 20100526_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 168, de 26/05/2010
# 19941102_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 101, de 02/11/1994
# 19940928_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 93, de 28/09/1994
# 19941005_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 96, de 05/10/1994
# 19941026_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 99, de 26/10/1994
# 20010620_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 93, de 20/06/2001
# 20010613_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 90, de 13/06/2001
# 20130911_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 135, de 11/09/2013
# 20100421_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 156, de 21/04/2010
# 20100324_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 151, de 24/03/2010
# 20100414_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 154, de 14/04/2010
# 20091216_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 132, de 16/12/2009
# 20091202_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 129, de 02/12/2009
# 20100210_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 137, de 10/02/2010
# 20001213_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 49, de 13/12/2000
# 20110511_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 244, de 11/05/2011
# 20070613_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 261, de 13/06/2007
# 20110608_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 250, de 08/06/2011
# 20030219_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 228, de 19/02/2003
# 20030212_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 225, de 12/02/2003
# 19991124_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 276, de 24/11/1999
# 20051019_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 121, de 19/10/2005
# 20100721_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 183, de 21/07/2010
# 19990310_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 219, de 10/03/1999
# 20121031_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 70, de 31/10/2012
# 20120516_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 30, de 16/05/2012
# 19951004_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 174, de 04/10/1995
# 19981111_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 192, de 11/11/1998
# 19981007_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 186, de 07/10/1998
# 19981216_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 204, de 16/12/1998
# 19990217_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 213, de 17/02/1999
# 19990210_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 210, de 10/02/1999
# 19970212_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 57, de 12/02/1997
# 19961218_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 51, de 18/12/1996
# 19970219_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 60, de 19/02/1997
# 19951108_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 182, de 08/11/1995
# 19951018_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 177, de 18/10/1995
# 20140528_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 202, de 28/05/2014
# 20140514_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 200, de 14/05/2014
# 20140625_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 206, de 25/06/2014
# 20100908_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 186, de 08/09/2010
# 20090909_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 101, de 09/09/2009
# 20090916_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 104, de 16/09/2009
# 20090909_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 101, de 09/09/2009
# 20030402_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 241, de 02/04/2003
# 20141217_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 250, de 17/12/2014
# 20010516_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 82, de 16/05/2001
# 20010425_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 80, de 25/04/2001
# 20010530_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 87, de 30/05/2001
# 19990421_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 231, de 21/04/1999
# 19990414_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 228, de 14/04/1999
# 20121128_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 76, de 28/11/2012
# 19990428_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 234, de 28/04/1999
# 19980930_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 183, de 30/09/1998
# 19980923_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 180, de 23/09/1998
# 19980916_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 177, de 16/09/1998
# 19980624_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 173, de 24/06/1998
# 19981209_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 201, de 09/12/1998
# 19970226_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 63, de 26/02/1997
# 19970312_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 66, de 12/03/1997
# 19950927_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 171, de 27/09/1995
# 19950920_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 168, de 20/09/1995
# 19950913_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 165, de 13/09/1995
# 20041103_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 46, de 03/11/2004
# 20041124_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 51, de 24/11/2004
# 20091014_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 112, de 14/10/2009
# 20090923_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 107, de 23/09/2009
# 20150121_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 254, de 21/01/2015
# 20150211_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 257, de 11/02/2015
# 20150218_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 260, de 18/02/2015
# 19940309_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 56, de 09/03/1994
# 19940323_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 59, de 23/03/1994
# 19940302_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 53, de 02/03/1994
# 20010404_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 74, de 04/04/2001
# 20010321_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 71, de 21/03/2001
# 20010418_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 77, de 18/04/2001
# 19990512_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 238, de 12/05/1999
# 19990519_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 241, de 19/05/1999
# 19990526_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 243, de 26/05/1999
# 19961030_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 35, de 30/10/1996
# 19961009_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 30, de 09/10/1996
# 19950614_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 153, de 14/06/1995
# 19950628_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 159, de 28/06/1995
# 20141015_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 229, de 15/10/2014
# 20041201_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 54, de 01/12/2004
# 20041215_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 59, de 15/12/2004
# 20041222_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 61, de 22/12/2004
# 20141210_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 247, de 10/12/2014
# 20141008_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 225, de 08/10/2014
# 20140319_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 189, de 19/03/2014
# 20140409_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 193, de 09/04/2014
# 20140507_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 198, de 07/05/2014
# 20130213_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 89, de 13/02/2013
# 20130130_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 87, de 30/01/2013
# 20121219_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 83, de 19/12/2012
# 20090429_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 80, de 29/04/2009
# 20010307_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 65, de 07/03/2001
# 20010214_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 60, de 14/02/2001
# 20010221_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 62, de 21/02/2001
# 20100929_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 194, de 29/09/2010
# 20101013_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 196, de 13/10/2010
# 20100922_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 191, de 22/09/2010
# 19990915_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 256, de 15/09/1999
# 19990630_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 251, de 30/06/1999
# 19961211_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 48, de 11/12/1996
# 19961127_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 46, de 27/11/1996
# 19950531_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 150, de 31/05/1995
# 19950517_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 148, de 17/05/1995
# 19950510_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 145, de 10/05/1995
# 20060628_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 189, de 28/06/2006
# 20060621_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 186, de 21/06/2006
# 20050309_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 74, de 09/03/2005
# 20050223_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 71, de 23/02/2005
# 20140312_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 186, de 12/03/2014
# 20041006_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 38, de 06/10/2004
# 20110316_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 231, de 16/03/2011
# 20090624_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 94, de 24/06/2009
# 20090527_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 87, de 27/05/2009
# 20090610_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 89, de 10/06/2009
# 20070627_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 267, de 27/06/2007
# 20070620_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 264, de 20/06/2007
# 20001220_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 52, de 20/12/2000
# 20070530_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 258, de 30/05/2007
# 20020522_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 163, de 22/05/2002
# 20020529_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 166, de 29/05/2002
# 20020612_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 170, de 12/06/2002
# 20100915_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 189, de 15/09/2010
# 20110525_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 247, de 25/05/2011
# 19930922_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 13, de 22/09/1993
# 19930929_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 16, de 29/09/1993
# 19931027_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 21, de 27/10/1993
# 19960529_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 8, de 29/05/1996
# 19960612_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 12, de 12/06/1996
# 19960619_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 14, de 19/06/1996
# 19960626_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 17, de 26/06/1996
# 20060524_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 180, de 24/05/2006
# 20060426_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 171, de 26/04/2006
# 20060510_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 174, de 10/05/2006
# 20060517_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 177, de 17/05/2006
# 20050316_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 77, de 16/03/2005
# 20050406_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 80, de 06/04/2005
# 20040915_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 29, de 15/09/2004
# 20040630_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 22, de 30/06/2004
# 19940413_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 62, de 13/04/1994
# 19940427_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 67, de 27/04/1994
# 20121010_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 64, de 10/10/2012
# 20071121_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 301, de 21/11/2007
# 20071017_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 292, de 17/10/2007
# 20020626_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 177, de 26/06/2002
# 20081217_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 55, de 17/12/2008
# 19960918_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 24, de 18/09/1996
# 19960911_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 22, de 11/09/1996
# 19960925_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 27, de 25/09/1996
# 20060329_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 165, de 29/03/2006
# 20060405_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 168, de 05/04/2006
# 20060322_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 162, de 22/03/2006
# 20050518_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 91, de 18/05/2005
# 20050525_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 94, de 25/05/2005
# 20031210_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 303, de 10/12/2003
# 20031217_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 306, de 17/12/2003
# 20070926_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 286, de 26/09/2007
# 20071003_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 289, de 03/10/2007
# 20070919_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 283, de 19/09/2007
# 20071031_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 296, de 31/10/2007
# 20120627_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 45, de 27/06/2012
# 20000920_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 25, de 20/09/2000
# 20000913_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 23, de 13/09/2000
# 20120620_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 42, de 20/06/2012
# 20000628_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 19, de 28/06/2000
# 20000621_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 16, de 21/06/2000
# 19960522_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 6, de 22/05/1996
# 19951220_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 193, de 20/12/1995
# 20131030_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 152, de 30/10/2013
# 20131016_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 147, de 16/10/2013
# 20060222_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 153, de 22/02/2006
# 20060301_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 156, de 01/03/2006
# 20140709_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 211, de 09/07/2014
# 20060315_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 159, de 15/03/2006
# 20050622_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 99, de 22/06/2005
# 20050629_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 102, de 29/06/2005
# 20050601_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 96, de 01/06/2005
# 20080514_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 7, de 14/05/2008
# 20080521_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 9, de 21/05/2008
# 20080528_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 11, de 28/05/2008
# 20020417_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 154, de 17/04/2002
# 20020410_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 151, de 10/04/2002
# 20131218_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 167, de 18/12/2013
# 20140212_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 175, de 12/02/2014
# 20140122_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 172, de 22/01/2014
# 20001004_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 31, de 04/10/2000
# 20001018_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 34, de 18/10/2000
# 20000927_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 28, de 27/09/2000
# 19931103_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 24, de 03/11/1993
# 20070207_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 230, de 07/02/2007
# 20081029_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 41, de 29/10/2008
# 20070221_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 233, de 21/02/2007
# 20081015_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 35, de 15/10/2008
# 20070228_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 236, de 28/02/2007
# 19951122_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 184, de 22/11/1995
# 19951213_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 190, de 13/12/1995
# 19951129_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 187, de 29/11/1995
# 20050914_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 109, de 14/09/2005
# 20051123_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 131, de 23/11/2005
# 20051130_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 134, de 30/11/2005
# 20051214_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 137, de 14/12/2005
# 20040602_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 14, de 02/06/2004
# 20040616_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 17, de 16/06/2004
# 20040623_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 20, de 23/06/2004
# 19940615_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 79, de 15/06/1994
# 19940525_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 76, de 25/05/1994
# 19940518_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 73, de 18/05/1994
# 20071128_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 304, de 28/11/2007
# 20071219_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 309, de 19/12/2007
# 20071212_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 307, de 12/12/2007
# 20021120_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 207, de 20/11/2002
# 20131211_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 164, de 11/12/2013
# 20131127_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 161, de 27/11/2013
# 20070912_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 280, de 12/09/2007
# 20120208_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 7, de 08/02/2012
# 19971210_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 124, de 10/12/1997
# 19971217_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 127, de 17/12/1997
# 20120328_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 22, de 28/03/2012
# 20120411_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 25, de 11/04/2012
# 20120314_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 19, de 14/03/2012
# 20061213_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 221, de 13/12/2006
# 20061129_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 218, de 29/11/2006
# 20061220_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 224, de 20/12/2006
# 20101027_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 200, de 27/10/2010
# 20051005_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 118, de 05/10/2005
# 20101110_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 202, de 10/11/2010
# 20051221_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 140, de 21/12/2005
# 20060208_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 147, de 08/02/2006
# 20060215_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 150, de 15/02/2006
# 20081001_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 32, de 01/10/2008
# 20080924_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 29, de 24/09/2008
# 20080917_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 27, de 17/09/2008
# 20081126_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 49, de 26/11/2008
# 20081210_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 52, de 10/12/2008
# 20081119_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 46, de 19/11/2008
# 20021218_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 217, de 18/12/2002
# 20141029_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 235, de 29/10/2014
# 20130417_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 105, de 17/04/2013
# 20130424_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 108, de 24/04/2013
# 20120215_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 10, de 15/02/2012
# 20120222_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 13, de 22/02/2012
# 20120307_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 16, de 07/03/2012
# 20101215_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 212, de 15/12/2010
# 20110126_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 219, de 26/01/2011
# 19971126_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 121, de 26/11/1997
# 19971112_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 114, de 12/11/1997
# 20000531_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 11, de 31/05/2000
# 20061004_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 206, de 04/10/2006
# 20061018_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 209, de 18/10/2006
# 20130918_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 138, de 18/09/2013
# 20110209_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 221, de 09/02/2011
# 20030625_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 263, de 25/06/2003
# 20030618_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 260, de 18/06/2003
# 20030611_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 257, de 11/06/2003
# 20080611_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 15, de 11/06/2008
# 20080625_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 19, de 25/06/2008
# 20011219_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 131, de 19/12/2001
# 20020213_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 138, de 13/02/2002
# 20130313_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 96, de 13/03/2013
# 20130227_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 94, de 27/02/2013
# 20130320_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 99, de 20/03/2013
# 19990922_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 259, de 22/09/1999
# 19991020_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 265, de 20/10/1999
# 19990929_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 262, de 29/09/1999
# 20140924_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 222, de 24/09/2014
# 20141126_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 244, de 26/11/2014
# 19931201_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 35, de 01/12/1993
# 19931124_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 32, de 24/11/1993
# 19931215_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 38, de 15/12/1993
# 20020918_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 187, de 18/09/2002
# 20020925_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 189, de 25/09/2002
# 20101201_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 208, de 01/12/2010
# 20141119_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 241, de 19/11/2014
# 19980422_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 152, de 22/04/1998
# 19980401_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 147, de 01/04/1998
# 19980415_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 149, de 15/04/1998
# 19980325_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 144, de 25/03/1998
# 19930915_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 10, de 15/09/1993
# 20131120_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 158, de 20/11/2013
# 20060927_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 203, de 27/09/2006
# 20060920_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 201, de 20/09/2006
# 19950322_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 136, de 22/03/1995
# 19950315_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 133, de 15/03/1995
# 19950405_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 139, de 05/04/1995
# 19950426_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 142, de 26/04/1995
# 20030514_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 252, de 14/05/2003
# 20030507_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 249, de 07/05/2003
# 20030430_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 247, de 30/04/2003
# 19940921_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 91, de 21/09/1994
# 19940629_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 85, de 29/06/1994
# 19940622_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 82, de 22/06/1994
# 19940914_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 88, de 14/09/1994
# 20121212_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 80, de 12/12/2012
# 20130626_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 125, de 26/06/2013
# 20120530_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 36, de 30/05/2012
# 19991110_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 269, de 10/11/1999
# 20021002_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 192, de 02/10/2002
# 19980218_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 136, de 18/02/1998
# 19980211_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 133, de 11/02/1998
# 19980225_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 139, de 25/02/1998
# 19980311_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 141, de 11/03/1998
# 20070509_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 254, de 09/05/2007
# 20070418_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 248, de 18/04/2007
# 20070425_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 251, de 25/04/2007
# 20070516_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 256, de 16/05/2007
# 19950215_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 124, de 15/02/1995
# 19950222_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 127, de 22/02/1995
# 19950308_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 130, de 08/03/1995
# 20011003_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 110, de 03/10/2001
# 20011031_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 116, de 31/10/2001
# 20130522_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 113, de 22/05/2013
# 20130529_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 116, de 29/05/2013
# 20110323_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 234, de 23/03/2011
# 20130612_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 119, de 12/06/2013
# 20130619_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 122, de 19/06/2013
# 20031015_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 286, de 15/10/2003
# 19991201_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 279, de 01/12/1999
# 19991215_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 281, de 15/12/1999
# 20140910_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 216, de 10/09/2014
# 20140917_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 219, de 17/09/2014
# 20110330_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 236, de 30/03/2011
# 19980617_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 170, de 17/06/1998
# 19980610_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 167, de 10/06/1998
# 19980527_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 164, de 27/05/1998
# 20130925_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 141, de 25/09/2013
# 19970917_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 100, de 17/09/1997
# 19970625_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 95, de 25/06/1997
# 19970409_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 72, de 09/04/1997
# 19970423_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 78, de 23/04/1997
# 19970416_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 75, de 16/04/1997
# 20150311_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 266, de 11/03/2015
# 20070314_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 239, de 14/03/2007
# 20070328_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 245, de 28/03/2007
# 20070321_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 242, de 21/03/2007
# 19941221_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 117, de 21/12/1994
# 19941214_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 114, de 14/12/1994
# 20010912_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 101, de 12/09/2001
# 20010919_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 104, de 19/09/2001
# 20100224_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 143, de 24/02/2010
# 20100217_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 140, de 17/02/2010
# 20030910_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 274, de 10/09/2003
# 20091118_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 123, de 18/11/2009
# 20091028_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 117, de 28/10/2009
# 20091125_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 126, de 25/11/2009
# 19940223_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 50, de 23/02/1994
# 19940216_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 47, de 16/02/1994
# 19940209_doc.html
#  : Congreso de los Diputados, Pleno y Dip. Perm., núm. 44, de 09/02/1994
# 20110713_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 261, de 13/07/2011
# 20110615_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 252, de 15/06/2011
# 20110622_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 255, de 22/06/2011
# 20000524_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 9, de 24/05/2000
# 20100428_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 159, de 28/04/2010
# 20000517_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 7, de 17/05/2000
# 20120912_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 56, de 12/09/2012
# 20120718_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 50, de 18/07/2012
# 20000614_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 13, de 14/06/2000
# 20120919_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 59, de 19/09/2012

# %%
'''
Blocs detectats en els diaris de sessions del Congrés dels dimecres (per ordre d'aparició):

"ORDEN DEL DÍA:"
- Trobat sempre

"SUMARIO"
- Trobat sempre


<br /><br />Se levanta la sesión a las ocho y cuarenta minutos de la noche.
<br /><br />Se suspende la sesión a las tres y diez minutos de la tarde.
<br /><br />Se reanuda la sesión a las nueve de la mañana.
    
    
"COMPARECENCIA DEL GOBIERNO ANTE EL PLENO DE LA CÁMARA"
- Trobat a DSCD-10-PL-172-C1.html

"PREGUNTAS:"
- Trobat sempre

"INTERPELACIONES URGENTES:"
- Trobat sempre

"CONVALIDACIÓN O DEROGACIÓN DE REALES DECRETOS-LEYES:"
- Trobat a DSCD-10-PL-172-C1.html



'''

# %%
import re

def document_analyzer(document):

    legislature = get_legislature_DB(legislatures_collection, document['date'])
    print "date: ", document['date'], ", legislature:", legislature
    
    prefix_file_name = doc['date'].strftime("%Y%m%d") + "_doc"
    html_file = document['content_doc']

    # Extraiem el text desde l'última aparició de 'PREGUNTAS:' i '<hr size="1" noshade="" />' (aquest últim element només apareix al final de cada doc)
    preguntas_html = get_text_between(html_file, 'PREGUNTAS:', '<hr size="1" noshade="" />', include_limits = False, first_ocurrences = False)

    # Cleaning the text of html tags:
    # Remove:
    # <p style="text-align:center"><a name="(Página7)"><b>Página7</b></a></p>
    preguntas_html = re.sub(r'<p.*?/p>', '', preguntas_html, flags=re.DOTALL)
    
    # Remove:
    # <center><a name="(Página8259)"><b>Página 8259</b></a></center>
    preguntas_html = re.sub(r'<center>.*?</center>', '', preguntas_html, flags=re.DOTALL)
    
    # Remove:
    # <br />
    preguntas_html = re.sub(r'<br />', '', preguntas_html, flags=re.DOTALL)

    save_text_file(preguntas_html, 'log/' + prefix_file_name + '_preguntas_html.txt', "utf-8")
    #
    # paragraphs = preguntas_html.split("\n\n")
    # paragraphs = preguntas_html.split("<br />")
    paragraphs = preguntas_html.split("\n")
    text_to_analyze = ""
    i = 0
    for paragraph in paragraphs:
        text_to_analyze += "["+ str(i) + "]-----------------------------------------------------" + "\n"
        text_to_analyze += paragraph + "\n"
        i += 1
    # print text_to_analyze
    save_text_file(text_to_analyze, 'log/' + prefix_file_name + '_to_analyze.txt', "utf-8")

    #
    '''
    with Capturing() as output:
        result_dialogue_dict = paragraphs_analyzer(paragraphs, legislature)
    '''
    result_dialogue_dict = paragraphs_analyzer(paragraphs, legislature)
    # Log output
    # print 'output:\n', output
    # save_list_text_file(output, 'log/' + prefix_file_name + '_analyzer_log.txt') 

    return result_dialogue_dict

# %%
def search_group_in_text(text, groups_dict):
    for key in groups_dict:
        description = groups_dict[key]['description'].upper()
        if description in text.upper():
            return groups_dict[key]['code']
    return None

def get_who(surname, legislature):
    dip = search_diputado_in_BD(congres_members_collection, surname, legislature=legislature)
    if dip:
        if len(dip['group']) == 1:
            dip_group = dip['group'].keys()[0]
        else:
            dip_group = get_group(dip['group'], legislature)
        
        who_dict = {'surname': dip['r_surname'], 'name': dip['r_name'], 'group': dip_group}
        return dip['_id'], who_dict
    else:
        who_dict = {'surname': '<unknown>', 'name': '<unknown>', 'group': '<unknown>'}
        return 9999, who_dict

import re
        
# Mètode que analitza una llista de paràgrafs
def paragraphs_analyzer(paragraphs, legislature):

    index = 0
    num_dialogue = 0
    dialogue_started = False
    num_intervention = 0
    dialogue_dict = {}
    who_id = None  # None: not interesting, 9999: unknown, otherwise: diputado id
    sub_text = ""
    sub_text_stared = False

    while index < len(paragraphs):
        
        print "["+ str(index) + "]-----------------------------------------------------"
        
        # Recerca del número d'expedient que té el següent format: 999/999999
        m_q = re.search(r"\D(\d{3}/\d{6})\D", paragraphs[index])
        
        if paragraphs[index].strip() == "":
            print "Empty paragraph"
        elif not sub_text_stared and ("DEL DIPUTADO" in paragraphs[index] or "DE LA DIPUTADA" in paragraphs[index] or "DEL GRUPO PARLAMENTARIO" in paragraphs[index]):
            print u"sub_text_stared = True"
            print u"Adding:", paragraphs[index]
            sub_text = paragraphs[index] + "\n"
            sub_text_stared = True
        elif m_q and sub_text_stared:
            sub_text += paragraphs[index]
            print "sub_text: ", sub_text
            sub_text_stared = False
            
            if "REAL DECRETO-LEY" not in sub_text:
                num_dialogue += 1
                dialogue_started = True
                num_intervention = 0
                who_id = None
                
                num_exp = m_q.group(1)
                group = search_group_in_text_DB(remove_spaces_and_newline(sub_text), congres_groups_collection)
                
                question = get_text_between(sub_text,u'¿',u'?')
                if question == "":
                    question = get_text_between(sub_text, u"SOBRE", u"(Número")
                    if question == "":
                        question = get_text_between(sub_text, u"RELATIVA A", u"(Número")
                        if not group:
                            group = get_text_between(sub_text, u"DEL GRUPO PARLAMENTARIO", u"RELATIVA A")
                    else:
                        if not group:
                            group = get_text_between(sub_text, u"DEL GRUPO PARLAMENTARIO", u" SOBRE")
                    speaker = "<group>"
                else:
                    if not group:
                        group = get_text_between(sub_text, "GRUPO PARLAMENTARIO", ", QUE")
                    m = re.search(ur"(DEL SEÑOR DIPUTADO DON|DEL DIPUTADO DON|DE LA DIPUTADA DOÑA) ([^,]+),", sub_text)
                    if m:
                        speaker = m.group(2)
                    else:
                        speaker = "not found"

                dialogue_dict[num_dialogue] = {'question':question, 'speaker':speaker, 'group':group, 'num_exp':num_exp, 'intervention_dictionary':{}}
                print "num_exp:", num_exp
                print "question:", question
                print "speaker:", speaker
                print "group:", group
        elif m_q and dialogue_started: # num_intervention > 0:
            print "Dialog ends:", paragraphs[index]
            dialogue_started = False            
        elif sub_text_stared:
            print u"Adding:", paragraphs[index]
            sub_text += (paragraphs[index] + "\n")
        elif u"INTERPELACIONES URGENTES:" in paragraphs[index]:
            print "DO NOTHING WITH INTERPELACIONES URGENTES:", paragraphs[index]
        elif u"CONVALIDACIÓN O DEROGACIÓN DE REALES DECRETOS-LEYES:" in paragraphs[index]:
            print "DO NOTHING WITH CONVALIDACIÓN O DEROGACIÓN DE REALES DECRETOS-LEYES:", paragraphs[index]
        elif num_dialogue > 0 and dialogue_started:
            m01 = re.search(ur"^\s*(El señor|La señora) (PRESIDENTE|PRESIDENTA)\:", paragraphs[index])
            m02 = re.search(ur"^\s*(La señora VICEPRESIDENTA \(Villalobos Talero\))\:", paragraphs[index])
            if m01:
                print "KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):", paragraphs[index]
                who_id = None
            elif m02:
                print "KO (La señora VICEPRESIDENTA \(Villalobos Talero\)):", paragraphs[index]
                who_id = None
            else:
                # expressió regular per cognoms de dues paraules
                m1 = re.search(ur"señor\w? ([A-ZÁÉÍÓÚÑ\-]+) ([A-ZÁÉÍÓÚÑ\-]+)\:", paragraphs[index])
                if m1:
                    print "OK 1", paragraphs[index]
                    print "found:", paragraphs[index][m1.start():m1.end()]
                    print "groups:", m1.group(0), ", ", m1.group(1), ", ", m1.group(2)
                    print "speaker:", m1.group(1) + " " + m1.group(2)
                    print "speach:", paragraphs[index][m1.end():]

                    who_id, who_dict = get_who(m1.group(1) + " " + m1.group(2), legislature)
                        
                    dialogue_dict[num_dialogue]['intervention_dictionary'].update({num_intervention:{'who':who_dict,'text':paragraphs[index][m1.end():]}})
                    num_intervention += 1
                else:
                    # expressió regular per els cognoms catalans
                    m2 = re.search(ur"señor\w? ([A-ZÁÉÍÓÚÑ\-]+) I ([A-ZÁÉÍÓÚÑ\-]+)\:", paragraphs[index])
                    if m2:
                        print "OK 2", paragraphs[index]
                        print "found:", paragraphs[index][m2.start():m2.end()]
                        print "groups:", m2.group(0), ", ", m2.group(1), ", ", m2.group(2)
                        print "speaker:", m2.group(1) + " I " + m2.group(2)
                        print "speach:", paragraphs[index][m2.end():]

                        who_id, who_dict = get_who(m2.group(1) + " I " + m2.group(2), legislature)
                        
                        dialogue_dict[num_dialogue]['intervention_dictionary'].update({num_intervention:{'who':who_dict,'text':paragraphs[index][m2.end():]}})
                        num_intervention += 1
                    else:
                        # expressió regular per trobar intervencions del tipus: 
                        #     "   El señor MINISTRO DE INDUSTRIA, ENERGÍA Y TURISMO (Soria López):"
                        m3 = re.search(ur"^\s*(El señor|La señora) ([^:]+)\:", paragraphs[index])
                        if m3:
                            print "OK 3", paragraphs[index]
                            print "found:", paragraphs[index][m3.start():m3.end()]
                            print "groups:", m3.group(0), ", ", m3.group(1), ", ", m3.group(2)
                            print "speaker:", m3.group(2)
                            if '(' in m3.group(2) and ')' in m3.group(2):
                                str_surname = remove_spaces_and_newline(get_text_between(m3.group(2), '(',')'))
                            else:
                                str_surname = m3.group(2)
                            print "speaker2:", str_surname
                            print "speach:", paragraphs[index][m3.end():]

                            who_id, who_dict = get_who(str_surname, legislature)

                            dialogue_dict[num_dialogue]['intervention_dictionary'].update({num_intervention:{'who':who_dict,'text':paragraphs[index][m3.end():]}})
                            num_intervention += 1
                        else:
                            if who_id:
                                print "OK", who_id, ":"
                                # Eliminem la intervenció final del "PRESIDENTE" del congrés detectada en les intervencions de diaris de sessions antics
                                m = re.search(ur"(El señor|La señora) (PRESIDENTE|PRESIDENTA)\:", paragraphs[index])
                                if m:
                                    extracted_text = paragraphs[index][0:m.start()]
                                    print "(El señor|La señora) (PRESIDENTE|PRESIDENTA)\:"
                                    print ">" + extracted_text + "<"
                                else:
                                    extracted_text = paragraphs[index]
                                    print extracted_text
                                
                                dialogue_dict[num_dialogue]['intervention_dictionary'][(num_intervention-1)]['text'] += ("\n" + extracted_text)
                            else:
                                print "KO", paragraphs[index]
                                
                                if index+1 < len(paragraphs):
                                    paragraph_fusion = paragraphs[index] + paragraphs[index+1]

                                    m3_2 = re.search(ur"^\s*(El señor|La señora) ([^:]+)\:", paragraph_fusion)
                                    if m3_2:
                                        print "OK 3_2", paragraph_fusion
                                        print "found:", paragraph_fusion[m3_2.start():m3_2.end()]
                                        print "groups:", m3_2.group(0), ", ", m3_2.group(1), ", ", m3_2.group(2)
                                        print "speaker:", m3_2.group(2)
                                        if '(' in m3_2.group(2) and ')' in m3_2.group(2):
                                            str_surname = remove_spaces_and_newline(get_text_between(m3_2.group(2), '(',')'))
                                        else:
                                            str_surname = m3_2.group(2)
                                        print "speaker2:", str_surname
                                        print "speach:", paragraphs[index][m3_2.end():]

                                        who_id, who_dict = get_who(str_surname, legislature)

                                        dialogue_dict[num_dialogue]['intervention_dictionary'].update({num_intervention:{'who':who_dict,'text':paragraph_fusion[m3_2.end():]}})
                                        num_intervention += 1
                                        index += 1
        else:
            print "num_dialogue:", num_dialogue, ">" + paragraphs[index] + "<"

        index += 1

    return dialogue_dict

# %% [markdown]
# #### Procés d'anàl.lisi dels documents

# %%
# %%capture captured_output

# Col.lecció de documents a la BD
doc_col = db['document']
# Col.lecció de diputats a la BD
congres_members_collection = db['congres_members']
# Col.lecció de legislatures a la BD
legislatures_collection = db['legislatures']
# Col.lecció de grups parlamentaris a la BD
congres_groups_collection = db['congres_groups']

'''
for doc in doc_col.find():
    print "Analyzing:", doc['description']
    result_dialogue_dict = document_analyzer(doc)
'''
'''
doc_date = "19/03/2014"
d_doc_date = datetime.datetime.strptime(doc_date, "%d/%m/%Y")
file_name = d_doc_date.strftime("%Y%m%d")
result = doc_col.find({'date': d_doc_date})
'''

doc_start_date = "01/01/2014"
d_doc_start_date = datetime.datetime.strptime(doc_start_date, "%d/%m/%Y")
doc_end_date = "01/04/2015"
d_doc_end_date = datetime.datetime.strptime(doc_end_date, "%d/%m/%Y")
result = doc_col.find({'date': {'$gte': d_doc_start_date, '$lte': d_doc_end_date}}).sort('date',1)


if result.count() > 0:
    for doc in result:
        print "Analyzing:", doc['description']
        result_dialogue_dict = document_analyzer(doc)

        print "Updating '" + doc['description'] + "' ..."
        # save_dict_json(result_dialogue_dict, 'log/' + file_name + '_dialogue_dict.json')

        # dictionary conversion to session_dictionary
        session_dictionary = [None] * len(result_dialogue_dict)
        print "len(result_dialogue_dict):", len(result_dialogue_dict)
        for key in result_dialogue_dict:
            intervention_dictionary = [None] * len(result_dialogue_dict[key]['intervention_dictionary'])
            for subkey in result_dialogue_dict[key]['intervention_dictionary']:
                intervention_dictionary[int(subkey)] = result_dialogue_dict[key]['intervention_dictionary'][subkey]
            result_dialogue_dict[key]['intervention_dictionary'] = intervention_dictionary
            session_dictionary[int(key)-1] = result_dialogue_dict[key]

        # http://docs.mongodb.org/manual/tutorial/modify-documents/
        doc_col.update({'_id':doc['_id']}, \
                       {'$set':{'session_dictionary':session_dictionary, 'updated_session_dictionary':datetime.datetime.utcnow()}}, \
                       upsert=False, multi=False)

# %%
import datetime
filename = datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + "_log.txt"
print "Save log file:", filename
save_text_file(captured_output.stdout, 'log/' + filename, "utf-8")
# Out:
# Save log file: 20150406_112411_log.txt
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-60-57e51db40545> in <module>()
#       2 filename = datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + "_log.txt"
#       3 print "Save log file:", filename
# ----> 4 save_text_file(captured_output.stdout, 'log/' + filename, "utf-8")
#
# C:\Users\pablo_000\Anaconda\lib\site-packages\IPython\utils\capture.pyc in stdout(self)
#      99         if not self._stdout:
#     100             return ''
# --> 101         return self._stdout.getvalue()
#     102
#     103     @property
#
# C:\Users\pablo_000\Anaconda\lib\StringIO.pyc in getvalue(self)
#     269         _complain_ifclosed(self.closed)
#     270         if self.buflist:
# --> 271             self.buf += ''.join(self.buflist)
#     272             self.buflist = []
#     273         return self.buf
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 9: ordinal not in range(128)

# %% [markdown]
# #### Estadística de l'anàl.lisi dels resultats obtinguts

# %%
# Col.lecció de documents a la BD
doc_col = db['document']
#
doc_start_date = "01/01/2014"
d_doc_start_date = datetime.datetime.strptime(doc_start_date, "%d/%m/%Y")
doc_end_date = "01/04/2015"
d_doc_end_date = datetime.datetime.strptime(doc_end_date, "%d/%m/%Y")

result = doc_col.find({'date': {'$gte': d_doc_start_date, '$lte': d_doc_end_date}}).sort('date',1)

if result.count() > 0 :
    print "Num. of docs:", result.count()
    for doc in result:
        print doc['description']
        dialogue_stats = []
        for dialogue_id, dialogue in enumerate(doc['session_dictionary']):
            dialogue_stats.append(len(dialogue['intervention_dictionary']))
        print dialogue_stats
# Out:
# Num. of docs: 24
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 172, de 22/01/2014
# [4, 4, 4, 5, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 7, 11, 7]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 175, de 12/02/2014
# [6, 2, 4, 4, 4, 4, 4, 4, 4, 5, 4, 3, 4, 4, 4, 4, 4, 5, 6, 5, 7, 16, 17, 20]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 186, de 12/03/2014
# [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 2, 4, 4, 4, 4, 3, 8, 7, 6, 16, 12, 14]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 189, de 19/03/2014
# [5, 4, 4, 5, 4, 4, 4, 4, 6, 4, 4, 4, 5, 4, 2, 11, 9, 11]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 193, de 09/04/2014
# [4, 4, 4, 5, 4, 4, 4, 4, 2, 4, 4, 2, 4, 4, 4, 5, 4, 6, 9, 17, 29]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 198, de 07/05/2014
# [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 5, 2, 5, 10, 6]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 200, de 14/05/2014
# [4, 4, 4, 5, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 9, 6, 7, 5]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 202, de 28/05/2014
# [5, 4, 4, 2, 4, 4, 4, 4, 5, 4, 4, 2, 4, 4, 4, 4, 6, 7, 9, 11, 11]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 206, de 25/06/2014
# [4, 4, 4, 5, 2, 3, 4, 4, 4, 4, 5, 2, 2, 4, 4, 4, 6, 6, 6, 6]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 211, de 09/07/2014
# [4, 4, 4, 4, 4, 4, 4, 3, 6, 4, 4, 2, 4, 4, 4, 10, 7, 5]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 216, de 10/09/2014
# [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 2, 4, 2, 6, 7, 6, 5]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 219, de 17/09/2014
# [5, 3, 4, 4, 4, 4, 4, 4, 4, 5, 4, 5, 4, 4, 4, 4, 4, 11, 18]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 222, de 24/09/2014
# [2, 4, 5, 4, 4, 4, 4, 5, 5, 8, 4, 4, 6, 6, 10, 9, 11]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 225, de 08/10/2014
# [4, 4, 2, 4, 4, 4, 4, 4, 4, 4, 2, 4, 5, 4, 4, 4, 2, 2, 4, 4, 7, 15, 12]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 229, de 15/10/2014
# [4, 4, 5, 4, 4, 4, 4, 4, 3, 4, 4, 4, 4, 4, 4, 7, 4, 18, 7]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 235, de 29/10/2014
# [4, 4, 4, 4, 2, 4, 4, 4, 4, 4, 4, 4, 4, 4, 10, 4, 4, 9]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 241, de 19/11/2014
# [0, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 2, 4, 4, 4, 4, 6, 5, 4, 10, 19]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 244, de 26/11/2014
# [4, 4, 4, 4, 2, 4, 4, 4, 4, 4, 2, 2, 4, 4, 4, 4, 5, 5, 8, 14]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 247, de 10/12/2014
# [4, 4, 4, 4, 4, 2, 5, 4, 4, 2, 4, 4, 4, 6, 6, 7, 8]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 250, de 17/12/2014
# [4, 4, 4, 6, 4, 4, 4, 2, 4, 4, 4, 4, 4, 4, 2, 4, 4, 9, 4, 8, 4, 6, 14, 8, 11]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 254, de 21/01/2015
# [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 2, 4, 4]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 257, de 11/02/2015
# [4, 4, 4, 4, 4, 4, 4, 4, 2, 9, 7, 9, 6, 4, 4, 10, 4, 11, 11, 14, 11]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 260, de 18/02/2015
# [3, 4, 4, 4, 4, 4, 4, 4, 4, 4, 5, 4, 4, 4, 4, 2, 10, 5, 7, 4, 12, 12]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 266, de 11/03/2015
# [4, 2, 5, 6, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 7, 7, 4, 5, 7]

# %% [markdown]
# #### Marcatge dels paràgrafs seleccionats al document HTML

# %%
# constants
tab_mark_start = u'<span title="{}" style="background-color: {};">'
tab_mark_end = u'</span>'

def get_group_color_DB(congres_groups_col, group_code):
    
    result = congres_groups_col.find({'code':group_code})
    if result.count() > 0:
        return result[0]['color']
    else:
        return 'cyan'

def mark_text_in_HTML(html_page, title_text, selected_text, start_index, group_color):
    text_start_index = html_page.find(selected_text, start_index)
    if text_start_index > 0:
        text_end_index = text_start_index + len(selected_text)
        html_page = html_page[:text_end_index] + tab_mark_end + html_page[text_end_index:]
        html_page = html_page[:text_start_index] + tab_mark_start.format(title_text, group_color) + html_page[text_start_index:]
    else:
        text_end_index = start_index

    return html_page, text_end_index

def get_marked_HTML_doc(selected_doc):
    
    selected_content_doc = selected_doc['content_doc']

    text_index = selected_content_doc.rfind('PREGUNTAS:')

    for dialogue_id, dialogue in enumerate(selected_doc['session_dictionary']):
        group_color = get_group_color_DB(congres_groups_collection, dialogue['group'])
        old_text_index = text_index
        question_text = dialogue['question'].strip()
        title_text = "group: " + dialogue['group'] + "\n" \
            + "speaker: " + dialogue['speaker'] + "\n" \
            + "num_exp: " + dialogue['num_exp']
        selected_content_doc, text_index = mark_text_in_HTML(selected_content_doc, title_text, question_text, text_index, group_color)
        if text_index == old_text_index:
            print "text_type:", 'question', "text_index:", text_index, ", num_dialogue:", dialogue_id
            print ">" + question_text + "<"
        for inter_id, inter in enumerate(dialogue['intervention_dictionary']):
            paragraphs = inter['text'].split("\n")

            group_color = get_group_color_DB(congres_groups_collection, inter['who']['group'])

            for paragraph in paragraphs:
                old_text_index = text_index
                paragraph_text = paragraph.strip()
                title_text = "num_inter: " + str(inter_id) + "\n" \
                    + "group: " + inter['who']['group'] + "\n" \
                    + "who: " + inter['who']['surname'] + "; " + inter['who']['name']
                selected_content_doc, text_index = mark_text_in_HTML(selected_content_doc, title_text, paragraph_text, text_index, group_color)
                if text_index == old_text_index:
                    print "text_type:", 'intervention', "text_index:", text_index, ", num_dialogue:", dialogue_id, "num_inter:", inter_id
                    print ">" + paragraph_text + "<"

    return selected_content_doc

# %%
# 
congres_groups_collection = db['congres_groups']

doc_start_date = "01/01/2014"
d_doc_start_date = datetime.datetime.strptime(doc_start_date, "%d/%m/%Y")
doc_end_date = "01/04/2015"
d_doc_end_date = datetime.datetime.strptime(doc_end_date, "%d/%m/%Y")

result = doc_col.find({'date': {'$gte': d_doc_start_date, '$lte': d_doc_end_date}}).sort('date',1)

if result.count() > 0:
    for result_obj in result:

        file_name = result_obj['date'].strftime("%Y%m%d")
        selected_content_doc = get_marked_HTML_doc(result_obj)

        print "Saving 'docs/" + file_name + "_doc_marked.html'..."
        save_text_file(selected_content_doc, 'docs/marked/' + file_name + '_doc_marked.html',"utf-8")
# Out:
# Saving 'docs/20140122_doc_marked.html'...
# text_type:
#  intervention text_index: 280384 , num_dialogue: 15 num_inter: 3
# ><
# Saving 'docs/20140212_doc_marked.html'...
# Saving 'docs/20140312_doc_marked.html'...
# Saving 'docs/20140319_doc_marked.html'...
# Saving 'docs/20140409_doc_marked.html'...
# text_type:
#  question text_index: 254107 , num_dialogue: 14
# ><
# Saving 'docs/20140507_doc_marked.html'...
# Saving 'docs/20140514_doc_marked.html'...
# text_type:
#  intervention text_index: 199951 , num_dialogue: 10 num_inter: 3
# ><
# text_type:
#  intervention text_index: 546725 , num_dialogue: 19 num_inter: 0
# ><
# Saving 'docs/20140528_doc_marked.html'...
# Saving 'docs/20140625_doc_marked.html'...
# text_type:
#  intervention text_index: 461096 , num_dialogue: 12 num_inter: 3
# ><
# Saving 'docs/20140709_doc_marked.html'...
# text_type:
#  intervention text_index: 158789 , num_dialogue: 8 num_inter: 1
# ><
# text_type:
#  intervention text_index: 282376 , num_dialogue: 16 num_inter: 1
# ><
# text_type:
#  intervention text_index: 581706 , num_dialogue: 20 num_inter: 2
# ><
# Saving 'docs/20140910_doc_marked.html'...
# text_type:
#  question text_index: 350763 , num_dialogue: 16
# ><
# Saving 'docs/20140917_doc_marked.html'...
# text_type:
#  intervention text_index: 66398 , num_dialogue: 2 num_inter: 1
# ><
# text_type:
#  question text_index: 411232 , num_dialogue: 14
# ><
# text_type:
#  question text_index: 556439 , num_dialogue: 16
# ><
# Saving 'docs/20140924_doc_marked.html'...
# text_type:
#  intervention text_index: 281336 , num_dialogue: 16 num_inter: 1
# ><
# text_type:
#  question text_index: 568730 , num_dialogue: 21
# ><
# Saving 'docs/20141008_doc_marked.html'...
# text_type:
#  intervention text_index: 150881 , num_dialogue: 7 num_inter: 1
# ><
# Saving 'docs/20141015_doc_marked.html'...
# text_type:
#  question text_index: 355816 , num_dialogue: 4
# ><
# Saving 'docs/20141029_doc_marked.html'...
# Saving 'docs/20141119_doc_marked.html'...
# Saving 'docs/20141126_doc_marked.html'...
# text_type:
#  intervention text_index: 221441 , num_dialogue: 12 num_inter: 1
# ><
# Saving 'docs/20141210_doc_marked.html'...
# Saving 'docs/20141217_doc_marked.html'...
# Saving 'docs/20150121_doc_marked.html'...
# text_type:
#  intervention text_index: 101522 , num_dialogue: 4 num_inter: 1
# ><
# Saving 'docs/20150211_doc_marked.html'...
# Saving 'docs/20150218_doc_marked.html'...
# Saving 'docs/20150311_doc_marked.html'...

# %% [markdown]
# #### Query documents, embedded documents

# %%
# http://docs.mongodb.org/manual/reference/method/db.collection.update/
# http://docs.mongodb.org/manual/tutorial/query-documents/#read-operations-embedded-documents

# %% [markdown]
# #### Import and Export MongoDB Data

# %%
# Import and Export MongoDB Data
# http://docs.mongodb.org/manual/core/import-export/

# http://stackoverflow.com/questions/13988479/loading-and-saving-mongodb-database-from-to-disk-with-pymongo

# Copying a Database
# http://api.mongodb.org/python/current/examples/copydb.html

# Export / Import
# http://stackoverflow.com/questions/11255630/how-to-export-all-collection-in-mongodb
# mongodump -d <our database name> -o <directory_backup>
# mongorestore <our database name>

# %% [markdown]
# #### Proves

# %%
dip = search_diputado_in_BD(congres_members_collection, u"RODRÍGUEZ SÁNCHEZ", legislature=10, verbose=True)
print dip
'''
    if dip:
        if len(dip['group']) == 1:
            dip_group = dip['group'].keys()[0]
        else:
            dip_group = get_group(dip['group'], legislature)
        
        who_dict = {'surname': dip['r_surname'], 'name': dip['r_name'], 'group': dip_group}
        return dip['_id'], who_dict
'''
'''
who_id, who_dict = get_who(u"RODRÍGUEZ SÁNCHEZ", 10)
print who_dict
'''
# Out:
# WARN en search_diputado_in_BD: S'ha trobat més d'un resultat per:  RODRÍGUEZ SÁNCHEZ ;
# 	{u'group': {u'GS': [10]}, u'name': u'GERMAN', u'r_name': u'Germ\xe1n', u'surname': u'RODRIGUEZ SANCHEZ', u'_id': ObjectId('551f91597c4c671d6037b06c'), u'r_surname': u'Rodr\xedguez S\xe1nchez'}
# 	{u'group': {u'GP': [10]}, u'name': u'MARIA FELICIDAD', u'r_name': u'Mar\xeda Felicidad', u'surname': u'RODRIGUEZ SANCHEZ', u'_id': ObjectId('551f91597c4c671d6037b06b'), u'r_surname': u'Rodr\xedguez S\xe1nchez'}
# {u'group': {u'GS': [10]}, u'name': u'GERMAN', u'r_name': u'Germ\xe1n', u'surname': u'RODRIGUEZ SANCHEZ', u'_id': ObjectId('551f91597c4c671d6037b06c'), u'r_surname': u'Rodr\xedguez S\xe1nchez'}
# '\nwho_id, who_dict = get_who(u"RODR\xc3\x8dGUEZ S\xc3\x81NCHEZ", 10)\nprint who_dict\n'

# %%
import re

text = '''
El señor PRESIDENTE DEL GOBIERNO (Aznar López): Sí, señor presidente.
'''
# paragraphs = text.split("\n\n")
# paragraphs = preguntas_html.split("\n\n")
# paragraphs = [text]

loaded_text_file = load_text_file('docs/19980429_doc.html',"")
preguntas_html = get_text_between(loaded_text_file, 'PREGUNTAS:', '<hr size="1" noshade="" />')
paragraphs = preguntas_html.split("<br />")

# print remove_text_between(text, '(',')')

index = 0
while index < len(paragraphs):
    m = re.search(r"^\s*(El señor|La señora) (PRESIDENTE|PRESIDENTA|VICEPRESIDENTA)\:", paragraphs[index])
    if m:
        print "KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):", paragraphs[index]
        who = None
    else:
        # expressió regular per cognoms de dues paraules
        m = re.search(r"señor\w? ([A-ZÁÉÍÓÚÑ\-]+) ([A-ZÁÉÍÓÚÑ\-]+)\:", paragraphs[index])
        if m:
            print "OK", paragraphs[index]
            print "found:", paragraphs[index][m.start():m.end()]
            print "groups:", m.group(0), ", ", m.group(1), ", ", m.group(2)
            print "speaker:", m.group(1) + " " + m.group(2)
            print "speach:", paragraphs[index][m.end():]

            id = search_diputado_in_dict(loaded_diputados_dict, m.group(1) + " " + m.group(2))
            # dip = search_diputado_in_BD(congres_members_collection, m.group(1) + " " + m.group(2))
            if id:
                who = id
            else:
                who = 9999
        else:
            # expressió regular per els cognoms catalans
            m = re.search(r"señor\w? ([A-ZÁÉÍÓÚÑ\-]+) I ([A-ZÁÉÍÓÚÑ\-]+)\:", paragraphs[index])
            if m:
                print "OK 2", paragraphs[index]
                print "found:", paragraphs[index][m.start():m.end()]
                print "groups:", m.group(0), ", ", m.group(1), ", ", m.group(2)
                print "speaker:", m.group(1) + " " + m.group(2)
                print "speach:", paragraphs[index][m.end():]

                id = search_diputado_in_dict(loaded_diputados_dict, m.group(1) + " I " + m.group(2))
                # dip = search_diputado_in_BD(congres_members_collection, m.group(1) + " I " + m.group(2))
                if id:
                    who = id
                else:
                    who = 9999           
            else:
                # expressió regular per trobar intervencions del tipus: 
                #     "   El señor MINISTRO DE INDUSTRIA, ENERGÍA Y TURISMO (Soria López):"
                m = re.search(r"^\s+(El señor|La señora) ([^:]+)\:", paragraphs[index])
                if m:
                    print "OK 3", paragraphs[index]
                    print "found:", paragraphs[index][m.start():m.end()]
                    print "groups:", m.group(0), ", ", m.group(1), ", ", m.group(2)
                    print "speaker:", m.group(2)
                    if '(' in m.group(2) and ')' in m.group(2):
                        str_surname = remove_spaces_and_newline(get_text_between(m.group(2), '(',')'))
                    else:
                        str_surname = m.group(2)
                    print "speaker2:", str_surname
                    print "speach:", paragraphs[index][m.end():]

                    id = search_diputado_in_dict(loaded_diputados_dict, str_surname)
                    # dip = search_diputado_in_BD(congres_members_collection, str_surname)
                    if id:
                        who = id
                    else:
                        who = 9999
    
    index += 1
# Out:
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Se reanuda la sesión.
# OK El señor HERNANDEZ MOLTO: Muchas gracias.
# found: señor HERNANDEZ MOLTO:
# groups: señor HERNANDEZ MOLTO: ,  HERNANDEZ ,  MOLTO
# speaker: HERNANDEZ MOLTO
# speach:  Muchas gracias.
# ERROR en search_diputado_in_dict. No s'ha trobat: HERNANDEZ MOLTO
# OK El señor HERNANDEZ MOLTO: Muchas gracias, señor presidente.
# found: señor HERNANDEZ MOLTO:
# groups: señor HERNANDEZ MOLTO: ,  HERNANDEZ ,  MOLTO
# speaker: HERNANDEZ MOLTO
# speach:  Muchas gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: HERNANDEZ MOLTO
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Señora Rubiales, silencio.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señor presidente del Gobierno.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Pregunta número 22, que formula al Gobierno el
#     diputado don José Ignacio Echániz Salgado, del Grupo Popular.
# OK El señor ECHANIZ SALGADO: Muchas gracias, señor presidente.
# found: señor ECHANIZ SALGADO:
# groups: señor ECHANIZ SALGADO: ,  ECHANIZ ,  SALGADO
# speaker: ECHANIZ SALGADO
# speach:  Muchas gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: ECHANIZ SALGADO
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señor presidente.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Pregunta número 32, que formula al Gobierno el
#     diputado don Francisco Frutos Gras, del Grupo Federal de Izquierda Unida.
# OK El señor FRUTOS GRAS: Muchas gracias, señor presidente.
# found: señor FRUTOS GRAS:
# groups: señor FRUTOS GRAS: ,  FRUTOS ,  GRAS
# speaker: FRUTOS GRAS
# speach:  Muchas gracias, señor presidente.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señor Frutos.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señor presidente.
# OK El señor FRUTOS GRAS: Creía, señor presidente, que sería más locuaz.
# found: señor FRUTOS GRAS:
# groups: señor FRUTOS GRAS: ,  FRUTOS ,  GRAS
# speaker: FRUTOS GRAS
# speach:  Creía, señor presidente, que sería más locuaz.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Muchas gracias.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Pregunta número 14, que formula al Gobierno la
#     diputada doña Arantxa Mendizábal Gorostiaga, del Grupo Socialista.
# OK La señora MENDIZABAL GOROSTIAGA: Muchas gracias, señor presidente.
# found: señora MENDIZABAL GOROSTIAGA:
# groups: señora MENDIZABAL GOROSTIAGA: ,  MENDIZABAL ,  GOROSTIAGA
# speaker: MENDIZABAL GOROSTIAGA
# speach:  Muchas gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: MENDIZABAL GOROSTIAGA
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señora Mendizábal.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señor vicepresidente.
# OK
#     La señora MENDIZABAL GOROSTIAGA: Gracias, señor presidente.
# found: señora MENDIZABAL GOROSTIAGA:
# groups: señora MENDIZABAL GOROSTIAGA: ,  MENDIZABAL ,  GOROSTIAGA
# speaker: MENDIZABAL GOROSTIAGA
# speach:  Gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: MENDIZABAL GOROSTIAGA
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señora Mendizábal.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señor vicepresidente.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Pregunta número 23, que formula al Gobierno al
#     diputado don Javier Gómez Darmendrail, del Grupo Popular.
# OK El señor GOMEZ DARMENDRAIL: Muchas gracias, señor presidente.
# found: señor GOMEZ DARMENDRAIL:
# groups: señor GOMEZ DARMENDRAIL: ,  GOMEZ ,  DARMENDRAIL
# speaker: GOMEZ DARMENDRAIL
# speach:  Muchas gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: GOMEZ DARMENDRAIL
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señor Gómez Darmendrail.
# OK El señor GONZALEZ REVENGA: Gracias, señor presidente.
# found: señor GONZALEZ REVENGA:
# groups: señor GONZALEZ REVENGA: ,  GONZALEZ ,  REVENGA
# speaker: GONZALEZ REVENGA
# speach:  Gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: GONZALEZ REVENGA
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Muchas gracias, señor González Revenga.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señora ministra.
# OK El señor GONZALEZ REVENGA: Señora ministra, su respuesta no me es nada
#     satisfactoria porque denota
#
#
# found: señor GONZALEZ REVENGA:
# groups: señor GONZALEZ REVENGA: ,  GONZALEZ ,  REVENGA
# speaker: GONZALEZ REVENGA
# speach:  Señora ministra, su respuesta no me es nada
#     satisfactoria porque denota
#
#
# ERROR en search_diputado_in_dict. No s'ha trobat: GONZALEZ REVENGA
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Muchas gracias, señor González Revenga.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señora ministra de Educación y Cultura.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Pasamos a las preguntas a la ministra de Justicia.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señora Fernández de la Vega.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señora ministra.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Pregunta número 19 que formula al Gobierno la
#     diputada doña Amparo Rubiales Torrejón, del Grupo Socialista.
# OK La señora RUBIALES TORREJON: Gracias, señor presidente.
# found: señora RUBIALES TORREJON:
# groups: señora RUBIALES TORREJON: ,  RUBIALES ,  TORREJON
# speaker: RUBIALES TORREJON
# speach:  Gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: RUBIALES TORREJON
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señora Rubiales.
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señora ministra.
# OK La señora RUBIALES TORREJON: Señora ministra, ¿qué ley? ¿Esa que ustedes
#     no aceptaban, que hoy sí les gusta pero que no quieren reformar?
#     (Rumores.) Señora ministra,... ¿me dejan hablar, señorías? Señora
#     ministra, es nuestra, queremos reformarla y vosotros sois los que no nos
#     dejáis que la reformemos. (Continúan los rumores.) El señor PRESIDENTE:
#     Silencio, señorías. Dejen que continúe la interpelante. Adelante, señora
#     Rubiales.
# found: señora RUBIALES TORREJON:
# groups: señora RUBIALES TORREJON: ,  RUBIALES ,  TORREJON
# speaker: RUBIALES TORREJON
# speach:  Señora ministra, ¿qué ley? ¿Esa que ustedes
#     no aceptaban, que hoy sí les gusta pero que no quieren reformar?
#     (Rumores.) Señora ministra,... ¿me dejan hablar, señorías? Señora
#     ministra, es nuestra, queremos reformarla y vosotros sois los que no nos
#     dejáis que la reformemos. (Continúan los rumores.) El señor PRESIDENTE:
#     Silencio, señorías. Dejen que continúe la interpelante. Adelante, señora
#     Rubiales.
# ERROR en search_diputado_in_dict. No s'ha trobat: RUBIALES TORREJON
# OK La señora RUBIALES TORREJON: Me habrá quitado el tiempo, señor
#     presidente.
# found: señora RUBIALES TORREJON:
# groups: señora RUBIALES TORREJON: ,  RUBIALES ,  TORREJON
# speaker: RUBIALES TORREJON
# speach:  Me habrá quitado el tiempo, señor
#     presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: RUBIALES TORREJON
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Ya está descontado, no se preocupe.
# OK La señora RUBIALES TORREJON: Gracias, señor presidente.
# found: señora RUBIALES TORREJON:
# groups: señora RUBIALES TORREJON: ,  RUBIALES ,  TORREJON
# speaker: RUBIALES TORREJON
# speach:  Gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: RUBIALES TORREJON
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Pasamos a las preguntas dirigidas al ministro de
#     Defensa. En primer lugar la formulada por el diputado Manuel José Silva i
#     Sánchez, del Grupo Parlamentario Catalán (Convergència i Unió).
# OK 2 El señor SILVA I SANCHEZ: Muchas gracias, señor presidente.
# found: señor SILVA I SANCHEZ:
# groups: señor SILVA I SANCHEZ: ,  SILVA ,  SANCHEZ
# speaker: SILVA SANCHEZ
# speach:  Muchas gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: SILVA I SANCHEZ
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE: Gracias, señor Silva.
# OK El señor SILVA SANCHEZ: Muchas gracias, señor presidente.
# found: señor SILVA SANCHEZ:
# groups: señor SILVA SANCHEZ: ,  SILVA ,  SANCHEZ
# speaker: SILVA SANCHEZ
# speach:  Muchas gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: SILVA SANCHEZ
# OK El señor MORENO BUSTOS: Gracias, señor presidente.
# found: señor MORENO BUSTOS:
# groups: señor MORENO BUSTOS: ,  MORENO ,  BUSTOS
# speaker: MORENO BUSTOS
# speach:  Gracias, señor presidente.
# ERROR en search_diputado_in_dict. S'ha trobat més d'un resultat:
# 533: Moreno Bustos, Ramón Antonio
# 732: Moreno Bustos, Ramón
#
# OK El señor CABALLERO BASAÑEZ: Gracias, señor Presidente.
# found: señor CABALLERO BASAÑEZ:
# groups: señor CABALLERO BASAÑEZ: ,  CABALLERO ,  BASAÑEZ
# speaker: CABALLERO BASAÑEZ
# speach:  Gracias, señor Presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat:
#  CABALLERO BASAÑEZ
# OK El señor CABALLERO BASAÑEZ: Gracias, señor ministro.
# found: señor CABALLERO BASAÑEZ:
# groups: señor CABALLERO BASAÑEZ: ,  CABALLERO ,  BASAÑEZ
# speaker: CABALLERO BASAÑEZ
# speach:  Gracias, señor ministro.
# ERROR en search_diputado_in_dict. No s'ha trobat: CABALLERO BASAÑEZ
# OK 2 El señor SILVA I SANCHEZ: Muchas gracias, señor presidente.
# found: señor SILVA I SANCHEZ:
# groups: señor SILVA I SANCHEZ: ,  SILVA ,  SANCHEZ
# speaker: SILVA SANCHEZ
# speach:  Muchas gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: SILVA I SANCHEZ
# OK 2 El señor SILVA I SANCHEZ: Señor ministro, no querría valorar el grado de
#     utilización del catalán, lengua propia y oficial de Cataluña, por su
#     Ministerio acudiendo a criterios de renta per cápita. Yo creo que la
#     manifestación que ha hecho el señor ministro pone de manifiesto que hay
#     direcciones generales que tienen perfectamente asumido el carácter
#     plurilingüe del Estado y posiblemente hay alguna otra dirección general
#     que bien no lo tiene asumido o bien no lo plasma en la práctica. Según
#     los datos que obran en nuestro poder, en la última campaña de la
#     Dirección General de Tráfico (la Campaña Vive, con un presupuesto de
#     2.100 millones de pesetas, con cuñas en radio, televisión, entreactos en
#     los cines, y medios impresos de comunicación) no se ha destinado ni una
#     sola peseta a efectuar esta difusión en lengua catalana. Por tanto, no
#     nos gustaría hablar en estos casos de media, sino que solicitaríamos del
#     señor ministro que en esta función que le incumbe de impulsar la
#     actuación política de su departamento tome nota de la proposición no de
#     ley aprobada en este Congreso de los Diputados el 16 de diciembre del año
#     pasado, en la cual se insta a las instituciones a que asuman e impulsen
#     la realidad plurilingüe del Estado y, por consiguiente, más que hablar de
#     aceptabilidad, yo creo que en este caso nos correspondería hablar de
#     claroscuros.
# found: señor SILVA I SANCHEZ:
# groups: señor SILVA I SANCHEZ: ,  SILVA ,  SANCHEZ
# speaker: SILVA SANCHEZ
# speach:  Señor ministro, no querría valorar el grado de
#     utilización del catalán, lengua propia y oficial de Cataluña, por su
#     Ministerio acudiendo a criterios de renta per cápita. Yo creo que la
#     manifestación que ha hecho el señor ministro pone de manifiesto que hay
#     direcciones generales que tienen perfectamente asumido el carácter
#     plurilingüe del Estado y posiblemente hay alguna otra dirección general
#     que bien no lo tiene asumido o bien no lo plasma en la práctica. Según
#     los datos que obran en nuestro poder, en la última campaña de la
#     Dirección General de Tráfico (la Campaña Vive, con un presupuesto de
#     2.100 millones de pesetas, con cuñas en radio, televisión, entreactos en
#     los cines, y medios impresos de comunicación) no se ha destinado ni una
#     sola peseta a efectuar esta difusión en lengua catalana. Por tanto, no
#     nos gustaría hablar en estos casos de media, sino que solicitaríamos del
#     señor ministro que en esta función que le incumbe de impulsar la
#     actuación política de su departamento tome nota de la proposición no de
#     ley aprobada en este Congreso de los Diputados el 16 de diciembre del año
#     pasado, en la cual se insta a las instituciones a que asuman e impulsen
#     la realidad plurilingüe del Estado y, por consiguiente, más que hablar de
#     aceptabilidad, yo creo que en este caso nos correspondería hablar de
#     claroscuros.
# ERROR en search_diputado_in_dict. No s'ha trobat: SILVA I SANCHEZ
# OK El señor PEREZ RUBALCABA: Muchas gracias, señor presidente.
# found: señor PEREZ RUBALCABA:
# groups: señor PEREZ RUBALCABA: ,  PEREZ ,  RUBALCABA
# speaker: PEREZ RUBALCABA
# speach:  Muchas gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: PEREZ RUBALCABA
# OK El señor PEREZ RUBALCABA: Muchas gracias, señor presidente.
# found: señor PEREZ RUBALCABA:
# groups: señor PEREZ RUBALCABA: ,  PEREZ ,  RUBALCABA
# speaker: PEREZ RUBALCABA
# speach:  Muchas gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: PEREZ RUBALCABA
# OK El señor CHIVITE CORNAGO: Gracias, señor presidente.
# found: señor CHIVITE CORNAGO:
# groups: señor CHIVITE CORNAGO: ,  CHIVITE ,  CORNAGO
# speaker: CHIVITE CORNAGO
# speach:  Gracias, señor presidente.
# OK
#     El señor CHIVITE CORNAGO: Señora ministra, esperaba esa respuesta.
# found: señor CHIVITE CORNAGO:
# groups: señor CHIVITE CORNAGO: ,  CHIVITE ,  CORNAGO
# speaker: CHIVITE CORNAGO
# speach:  Señora ministra, esperaba esa respuesta.
# OK El señor PINTADO BARBANOJ: Muchas gracias, señor presidente.
# found: señor PINTADO BARBANOJ:
# groups: señor PINTADO BARBANOJ: ,  PINTADO ,  BARBANOJ
# speaker: PINTADO BARBANOJ
# speach:  Muchas gracias, señor presidente.
# ERROR en search_diputado_in_dict. S'ha trobat més d'un resultat:
# 551: Pintado Barbanoj, Angel
# 759: Pintado Barbanoj, Ángel
#
# OK
#     El señor JORDANO SALINAS: Gracias, señor presidente.
# found: señor JORDANO SALINAS:
# groups: señor JORDANO SALINAS: ,  JORDANO ,  SALINAS
# speaker: JORDANO SALINAS
# speach:  Gracias, señor presidente.
# OK El señor AGUIRIANO FORNIES: Gracias, señor presidente.
# found: señor AGUIRIANO FORNIES:
# groups: señor AGUIRIANO FORNIES: ,  AGUIRIANO ,  FORNIES
# speaker: AGUIRIANO FORNIES
# speach:  Gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: AGUIRIANO FORNIES
# OK El señor AGUIRIANO FORNIES: Señor presidente, señor ministro, me preocupa
#     su talante. (Rumores.) Usted, que es conocido, al igual que un antepasado
#     suyo, como la sonrisa del régimen, me desilusiona en este trámite. He
#     pretendido hacer una intervención constructiva en función de lo más
#     importante en este caso: la seguridad de unos escoltas que ustedes han
#     puesto en peligro.
# found: señor AGUIRIANO FORNIES:
# groups: señor AGUIRIANO FORNIES: ,  AGUIRIANO ,  FORNIES
# speaker: AGUIRIANO FORNIES
# speach:  Señor presidente, señor ministro, me preocupa
#     su talante. (Rumores.) Usted, que es conocido, al igual que un antepasado
#     suyo, como la sonrisa del régimen, me desilusiona en este trámite. He
#     pretendido hacer una intervención constructiva en función de lo más
#     importante en este caso: la seguridad de unos escoltas que ustedes han
#     puesto en peligro.
# ERROR en search_diputado_in_dict. No s'ha trobat: AGUIRIANO FORNIES
# OK El señor MORLAN GRACIA: Muchas gracias, señor presidente.
# found: señor MORLAN GRACIA:
# groups: señor MORLAN GRACIA: ,  MORLAN ,  GRACIA
# speaker: MORLAN GRACIA
# speach:  Muchas gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: MORLAN GRACIA
# OK El señor MORLAN GRACIA: Señor ministro, tengo aquí el calendario oficial
#     de fiestas que ustedes aprobaron en octubre de 1997, y haciendo
#     referencia a la pregunta que contestó su compañero de Gobierno, que
#     hablaba de que determinadas fiestas autonómicas no tenían nada que ver
#     con la aplicación o no de tarifas telefónicas, le tengo que decir que
#     cuando se trata de una fiesta que es la única que se guarda en todas las
#     comunidades autónomas la Compañía Telefónica no ha tenido el detalle de
#     decir que esa fiesta tenía las mismas características que otro tipo de
#     fiestas que pudiera haber en cada una de las comunidades autónomas, o al
#     menos igual que las fiestas que tienen un carácter nacional.
# found: señor MORLAN GRACIA:
# groups: señor MORLAN GRACIA: ,  MORLAN ,  GRACIA
# speaker: MORLAN GRACIA
# speach:  Señor ministro, tengo aquí el calendario oficial
#     de fiestas que ustedes aprobaron en octubre de 1997, y haciendo
#     referencia a la pregunta que contestó su compañero de Gobierno, que
#     hablaba de que determinadas fiestas autonómicas no tenían nada que ver
#     con la aplicación o no de tarifas telefónicas, le tengo que decir que
#     cuando se trata de una fiesta que es la única que se guarda en todas las
#     comunidades autónomas la Compañía Telefónica no ha tenido el detalle de
#     decir que esa fiesta tenía las mismas características que otro tipo de
#     fiestas que pudiera haber en cada una de las comunidades autónomas, o al
#     menos igual que las fiestas que tienen un carácter nacional.
# ERROR en search_diputado_in_dict. No s'ha trobat:
#  MORLAN GRACIA
# OK El señor IZQUIERDO JUAREZ: Gracias, señor presidente.
# found: señor IZQUIERDO JUAREZ:
# groups: señor IZQUIERDO JUAREZ: ,  IZQUIERDO ,  JUAREZ
# speaker: IZQUIERDO JUAREZ
# speach:  Gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: IZQUIERDO JUAREZ
# OK El señor ALCARAZ RAMOS: Muchas gracias, señor presidente.
# found: señor ALCARAZ RAMOS:
# groups: señor ALCARAZ RAMOS: ,  ALCARAZ ,  RAMOS
# speaker: ALCARAZ RAMOS
# speach:  Muchas gracias, señor presidente.
# OK El señor ALCARAZ RAMOS: Gracias, señor presidente.
# found: señor ALCARAZ RAMOS:
# groups: señor ALCARAZ RAMOS: ,  ALCARAZ ,  RAMOS
# speaker: ALCARAZ RAMOS
# speach:  Gracias, señor presidente.
# OK 2 El señor RECODER I MIRALLES: Muchas gracias, señor presidente.
# found: señor RECODER I MIRALLES:
# groups: señor RECODER I MIRALLES: ,  RECODER ,  MIRALLES
# speaker: RECODER MIRALLES
# speach:  Muchas gracias, señor presidente.
# OK La señora SABANES NADAL: Muchas gracias, señor presidente.
# found: señora SABANES NADAL:
# groups: señora SABANES NADAL: ,  SABANES ,  NADAL
# speaker: SABANES NADAL
# speach:  Muchas gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: SABANES NADAL
# OK El señor GARCIA-SANTESMASES MARTIN-TESORERO: Tengo que decir que el
#     consenso de nuestro grupo es completo con lo que ha dicho el señor
#     Alcaraz, pero también con lo manifestado por el señor Recoder y por la
#     señora Sabanés, es decir, hay un consenso de todos los grupos
#     parlamentarios sobre este tema, manifestado en la Comisión de Asuntos
#     Exteriores
#          --como sabe el señor ministro-- el pasado mes de diciembre. Lo que
#     se recuerda hoy aquí tiene quizá más actualidad por la cumbre
#     hispano-marroquí, pero, en definitiva, el señor Recoder --aunque llevamos
#     esta semana de tensión con los nacionalistas catalanes, en este punto
#     coincidimos completamente-- lo ha resumido perfectamente. Hay una
#     responsabilidad histórica, hay una situación que nos llena de vergüenza,
#     hay un deber moral y hay un cierto optimismo en relación con los acuerdos
#     que se han producido en Houston, que nos permiten salir del escepticismo
#     en el que estábamos.
# found: señor GARCIA-SANTESMASES MARTIN-TESORERO:
# groups: señor GARCIA-SANTESMASES MARTIN-TESORERO: ,  GARCIA-SANTESMASES ,  MARTIN-TESORERO
# speaker: GARCIA-SANTESMASES MARTIN-TESORERO
# speach:  Tengo que decir que el
#     consenso de nuestro grupo es completo con lo que ha dicho el señor
#     Alcaraz, pero también con lo manifestado por el señor Recoder y por la
#     señora Sabanés, es decir, hay un consenso de todos los grupos
#     parlamentarios sobre este tema, manifestado en la Comisión de Asuntos
#     Exteriores
#          --como sabe el señor ministro-- el pasado mes de diciembre. Lo que
#     se recuerda hoy aquí tiene quizá más actualidad por la cumbre
#     hispano-marroquí, pero, en definitiva, el señor Recoder --aunque llevamos
#     esta semana de tensión con los nacionalistas catalanes, en este punto
#     coincidimos completamente-- lo ha resumido perfectamente. Hay una
#     responsabilidad histórica, hay una situación que nos llena de vergüenza,
#     hay un deber moral y hay un cierto optimismo en relación con los acuerdos
#     que se han producido en Houston, que nos permiten salir del escepticismo
#     en el que estábamos.
# ERROR en search_diputado_in_dict. No s'ha trobat: GARCIA-SANTESMASES MARTIN-TESORERO
# OK La señora PULGAR FRAILE: Muchas gracias, señor presidente.
# found: señora PULGAR FRAILE:
# groups: señora PULGAR FRAILE: ,  PULGAR ,  FRAILE
# speaker: PULGAR FRAILE
# speach:  Muchas gracias, señor presidente.
# OK 2 La señora PALMA I MUÑOZ: Gracias, señor presidente.
# found: señora PALMA I MUÑOZ:
# groups: señora PALMA I MUÑOZ: ,  PALMA ,  MUÑOZ
# speaker: PALMA MUÑOZ
# speach:  Gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: PALMA I MUÑOZ
# OK 3
#     El señor VICEPRESIDENTE (Fernández-Miranda y Lozana): Señora Palma, le
#     ruego que vaya concluyendo.
# found:
#     El señor VICEPRESIDENTE (Fernández-Miranda y Lozana):
# groups:
#     El señor VICEPRESIDENTE (Fernández-Miranda y Lozana): ,  El señor ,  VICEPRESIDENTE (Fernández-Miranda y Lozana)
# speaker: VICEPRESIDENTE (Fernández-Miranda y Lozana)
# speaker2: Fernández-Miranda y Lozana
# speach:  Señora Palma, le
#     ruego que vaya concluyendo.
# ERROR en search_diputado_in_dict. No s'ha trobat: Fernández-Miranda y Lozana
# OK 2 La señora PALMA I MUÑOZ: Voy terminando, señor presidente.
# found: señora PALMA I MUÑOZ:
# groups: señora PALMA I MUÑOZ: ,  PALMA ,  MUÑOZ
# speaker: PALMA MUÑOZ
# speach:  Voy terminando, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: PALMA I MUÑOZ
# OK 2 La señora PALMA I MUÑOZ: Gracias, señor presidente; gracias, señor
#     ministro.
# found: señora PALMA I MUÑOZ:
# groups: señora PALMA I MUÑOZ: ,  PALMA ,  MUÑOZ
# speaker: PALMA MUÑOZ
# speach:  Gracias, señor presidente; gracias, señor
#     ministro.
# ERROR en search_diputado_in_dict. No s'ha trobat: PALMA I MUÑOZ
# OK 2
#  La señora PALMA I MUÑOZ: Concluyo enseguida, señor presidente.
# found: señora PALMA I MUÑOZ:
# groups: señora PALMA I MUÑOZ: ,  PALMA ,  MUÑOZ
# speaker: PALMA MUÑOZ
# speach:  Concluyo enseguida, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: PALMA I MUÑOZ
# OK 3
#     El señor VICEPRESIDENTE (Fernández-Miranda y Lozana): Muchas gracias,
#     señor ministro.
# found:
#     El señor VICEPRESIDENTE (Fernández-Miranda y Lozana):
# groups:
#     El señor VICEPRESIDENTE (Fernández-Miranda y Lozana): ,  El señor ,  VICEPRESIDENTE (Fernández-Miranda y Lozana)
# speaker: VICEPRESIDENTE (Fernández-Miranda y Lozana)
# speaker2: Fernández-Miranda y Lozana
# speach:  Muchas gracias,
#     señor ministro.
# ERROR en search_diputado_in_dict. No s'ha trobat: Fernández-Miranda y Lozana
# OK El señor ALCARAZ RAMOS: Muchas gracias, señor presidente.
# found: señor ALCARAZ RAMOS:
# groups: señor ALCARAZ RAMOS: ,  ALCARAZ ,  RAMOS
# speaker: ALCARAZ RAMOS
# speach:  Muchas gracias, señor presidente.
# OK La señora LASAGABASTER OLAZABAL: Señor presidente, sin perjuicio de la
#     posición que mantengamos en la moción que se presentará en el Pleno
#     próximo, querríamos señalar algunas ideas. En primer lugar, una cuestión
#     clave: la política universitaria destaca por su indefinición, ya se ha
#     dicho en esta Cámara y en estos momentos. Los cambios sucesivos en el
#     equipo de la ministra han alterado el normal funcionamiento del
#     Ministerio y de los organismos que dependen de él, sea el Consejo de
#     Universidades, la Comisión Nacional Evaluadora de la Actividad
#     Investigadora, etcétera. Prueba de ello es que hoy en día sigue
#     reclamándose una política, un proyecto sobre el cual podamos
#     pronunciarnos. Creemos que detrás de la manifiesta indefinición se erige
#     la carencia de un diagnóstico claro, preciso y de futuro sobre la
#     situación de la universidad. Esta indefinición tiene graves consecuencias
#     en la reforma de los planes de estudio y en la financiación de las
#     universidades. No estamos diciendo que la universidad necesite más
#     dinero, que obviamente lo necesita, sino que hay que modificar el actual
#     sistema de financiación porque en los umbrales del siglo XXI no puede ser
#     el mismo que el establecido en la Ley de 1983.
# found: señora LASAGABASTER OLAZABAL:
# groups: señora LASAGABASTER OLAZABAL: ,  LASAGABASTER ,  OLAZABAL
# speaker: LASAGABASTER OLAZABAL
# speach:  Señor presidente, sin perjuicio de la
#     posición que mantengamos en la moción que se presentará en el Pleno
#     próximo, querríamos señalar algunas ideas. En primer lugar, una cuestión
#     clave: la política universitaria destaca por su indefinición, ya se ha
#     dicho en esta Cámara y en estos momentos. Los cambios sucesivos en el
#     equipo de la ministra han alterado el normal funcionamiento del
#     Ministerio y de los organismos que dependen de él, sea el Consejo de
#     Universidades, la Comisión Nacional Evaluadora de la Actividad
#     Investigadora, etcétera. Prueba de ello es que hoy en día sigue
#     reclamándose una política, un proyecto sobre el cual podamos
#     pronunciarnos. Creemos que detrás de la manifiesta indefinición se erige
#     la carencia de un diagnóstico claro, preciso y de futuro sobre la
#     situación de la universidad. Esta indefinición tiene graves consecuencias
#     en la reforma de los planes de estudio y en la financiación de las
#     universidades. No estamos diciendo que la universidad necesite más
#     dinero, que obviamente lo necesita, sino que hay que modificar el actual
#     sistema de financiación porque en los umbrales del siglo XXI no puede ser
#     el mismo que el establecido en la Ley de 1983.
# ERROR en search_diputado_in_dict. No s'ha trobat: LASAGABASTER OLAZABAL
# OK La señora SABANES NADAL: Gracias, señor presidente.
# found: señora SABANES NADAL:
# groups: señora SABANES NADAL: ,  SABANES ,  NADAL
# speaker: SABANES NADAL
# speach:  Gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: SABANES NADAL
# OK El señor GUERRA ZUNZUNEGUI: Señor presidente, señorías, la interpelación
#     que presenta hoy la señora Palma, en nombre del Grupo Socialista, es muy
#     interesante; es para que en una comisión habláramos largo y tendido sobre
#     todo el tema universitario.
# found: señor GUERRA ZUNZUNEGUI:
# groups: señor GUERRA ZUNZUNEGUI: ,  GUERRA ,  ZUNZUNEGUI
# speaker: GUERRA ZUNZUNEGUI
# speach:  Señor presidente, señorías, la interpelación
#     que presenta hoy la señora Palma, en nombre del Grupo Socialista, es muy
#     interesante; es para que en una comisión habláramos largo y tendido sobre
#     todo el tema universitario.
# OK El señor GUERRA ZUNZUNEGUI: Muchas gracias, señor presidente.
# found: señor GUERRA ZUNZUNEGUI:
# groups: señor GUERRA ZUNZUNEGUI: ,  GUERRA ,  ZUNZUNEGUI
# speaker: GUERRA ZUNZUNEGUI
# speach:  Muchas gracias, señor presidente.
# OK El señor GUERRA ZUNZUNEGUI: Termino, señor presidente, Pido disculpas a
#     la Cámara por haberme alargado, pero es un tema tan atractivo y tan
#     fundamental para el futuro de nuestras juventudes que indudablemente
#     merece que le dediquemos nuestro tiempo.
# found: señor GUERRA ZUNZUNEGUI:
# groups: señor GUERRA ZUNZUNEGUI: ,  GUERRA ,  ZUNZUNEGUI
# speaker: GUERRA ZUNZUNEGUI
# speach:  Termino, señor presidente, Pido disculpas a
#     la Cámara por haberme alargado, pero es un tema tan atractivo y tan
#     fundamental para el futuro de nuestras juventudes que indudablemente
#     merece que le dediquemos nuestro tiempo.
# OK 3
#     El señor VAQUERO DEL POZO: Gracias, señor presidente.
# found:
#     El señor VAQUERO DEL POZO:
# groups:
#     El señor VAQUERO DEL POZO: ,  El señor ,  VAQUERO DEL POZO
# speaker: VAQUERO DEL POZO
# speaker2: VAQUERO DEL POZO
# speach:  Gracias, señor presidente.
# OK 3
#     El señor VAQUERO DEL POZO: Es por ello que ahí tiene su engarce la
#     problemática que a veces se aborda con un sospechoso simplismo. Por
#     ejemplo, cuando se realiza una reforma fiscal que agrava la situación
#     financiera que el Estado tiene para mantener lo que hay, sin tener en
#     cuenta si lo que hay es suficiente. Por ejemplo, las diferentes
#     interpretaciones del Pacto de Toledo, como ya tuvimos ocasión de ver y
#     poner de manifiesto en el debate de la Ley de Pensiones. Y, por ejemplo,
#     cuando se dice que hay que recortar políticas pasivas para financiar
#     políticas activas. La semántica nos traiciona.
# found:
#     El señor VAQUERO DEL POZO:
# groups:
#     El señor VAQUERO DEL POZO: ,  El señor ,  VAQUERO DEL POZO
# speaker: VAQUERO DEL POZO
# speaker2: VAQUERO DEL POZO
# speach:  Es por ello que ahí tiene su engarce la
#     problemática que a veces se aborda con un sospechoso simplismo. Por
#     ejemplo, cuando se realiza una reforma fiscal que agrava la situación
#     financiera que el Estado tiene para mantener lo que hay, sin tener en
#     cuenta si lo que hay es suficiente. Por ejemplo, las diferentes
#     interpretaciones del Pacto de Toledo, como ya tuvimos ocasión de ver y
#     poner de manifiesto en el debate de la Ley de Pensiones. Y, por ejemplo,
#     cuando se dice que hay que recortar políticas pasivas para financiar
#     políticas activas. La semántica nos traiciona.
# OK El señor DIAZ SOL: Gracias, señor presidente. Voy a intervenir
#     brevemente.
# found: señor DIAZ SOL:
# groups: señor DIAZ SOL: ,  DIAZ ,  SOL
# speaker: DIAZ SOL
# speach:  Gracias, señor presidente. Voy a intervenir
#     brevemente.
# ERROR en search_diputado_in_dict. No s'ha trobat: DIAZ SOL
# -c:17: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal

# %% [markdown]
# #### Proves d'anàl.lisi de text

# %%
def search_group_in_text(text, groups_dict):
    for key in groups_dict:
        description = groups_dict[key]['description'].upper()
        if description in text.decode('utf-8').upper():
            return groups_dict[key]['code']
    return None

import re

# Mètode que analitza una llista de paràgrafs
def my_paragraphs_analyzer(paragraphs):

    index = 0
    num_dialogue = 0
    num_intervention = 0
    dialogue_dict = {}
    who = None  # None: not interesting, 9999: unknown, otherwise: diputado id
    sub_text = ""
    sub_text_stared = False

    while index < len(paragraphs):
        
        print "["+ str(index) + "]-----------------------------------------------------"
        
        # Recerca del número d'expedient que té el següent format: 999/999999
        m_q = re.search(r"\D(\d{3}/\d{6})\D", paragraphs[index])
        
        if paragraphs[index].strip() == "":
            print "Empty paragraph"
        elif not sub_text_stared and ("DEL DIPUTADO" in paragraphs[index] or "DE LA DIPUTADA" in paragraphs[index] or "DEL GRUPO PARLAMENTARIO" in paragraphs[index]):
            print "sub_text_stared = True"
            print "Adding:", paragraphs[index]
            sub_text = paragraphs[index] + "\n"
            sub_text_stared = True
        elif m_q and sub_text_stared:
            sub_text += paragraphs[index]
            print "sub_text: ", sub_text
            sub_text_stared = False
            
            if "REAL DECRETO-LEY" not in sub_text:
                num_dialogue += 1
                num_intervention = 0
                who = None
                
                num_exp = m_q.group(1)
                group = search_group_in_text(sub_text, loaded_groups_dict)
                
                question = get_text_between(sub_text,'¿','?')
                if question == "":
                    question = get_text_between(sub_text, "SOBRE", "(Número")
                    if not group:
                        group = get_text_between(sub_text, "DEL GRUPO PARLAMENTARIO", " SOBRE")
                    speaker = "<group>"
                else:
                    if not group:
                        group = get_text_between(sub_text, "GRUPO PARLAMENTARIO", ", QUE")
                    m = re.search(r"(DEL SEÑOR DIPUTADO DON|DEL DIPUTADO DON|DE LA DIPUTADA DOÑA) ([^,]+),", sub_text)
                    if m:
                        speaker = m.group(2)
                    else:
                        speaker = "not found"

                dialogue_dict[num_dialogue] = {'question':question, 'speaker':speaker, 'group':group, 'num_exp':num_exp, 'intervention_dictonary':{}}
                print "num_exp:", num_exp
                print "question:", question
                print "speaker:", speaker
                print "group:", group
        elif sub_text_stared:
            print "Adding:", paragraphs[index]
            sub_text += (paragraphs[index] + "\n")
        elif "INTERPELACIONES URGENTES:" in paragraphs[index]:
            print "DO NOTHING WITH INTERPELACIONES URGENTES:", paragraphs[index]
        elif "CONVALIDACIÓN O DEROGACIÓN DE REALES DECRETOS-LEYES:" in paragraphs[index]:
            print "DO NOTHING WITH CONVALIDACIÓN O DEROGACIÓN DE REALES DECRETOS-LEYES:", paragraphs[index]
        # elif "PRESIDENTE:" in paragraphs[index]:
        #    print "KO PRESIDENTE:", paragraphs[index]
        #    who = None
        elif num_dialogue > 0:
            m01 = re.search(r"^\s*(El señor|La señora) (PRESIDENTE|PRESIDENTA)\:", paragraphs[index])
            m02 = re.search(r"^\s*(La señora VICEPRESIDENTA \(Villalobos Talero\))\:", paragraphs[index])
            if m01:
                print "KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):", paragraphs[index]
                who = None
            elif m02:
                print "KO (La señora VICEPRESIDENTA \(Villalobos Talero\)):", paragraphs[index]
                who = None
            else:
                # expressió regular per cognoms de dues paraules
                m1 = re.search(r"señor\w? ([A-ZÁÉÍÓÚÑ\-]+) ([A-ZÁÉÍÓÚÑ\-]+)\:", paragraphs[index])
                if m1:
                    print "OK 1", paragraphs[index]
                    print "found:", paragraphs[index][m1.start():m1.end()]
                    print "groups:", m1.group(0), ", ", m1.group(1), ", ", m1.group(2)
                    print "speaker:", m1.group(1) + " " + m1.group(2)
                    print "speach:", paragraphs[index][m1.end():]

                    id = search_diputado_in_dict(loaded_diputados_dict, m1.group(1) + " " + m1.group(2), ignore_accents = True)
                    # dip = search_diputado_in_BD(congres_members_collection, m.group(1) + " " + m.group(2))
                    if id:
                        who = id
                    else:
                        who = 9999
                    # dialogue_dict[num_dialogue]['inter_dict'].update({num_intervention:{'who':who,'text':remove_spaces_and_newline(paragraphs[index][m.end():])}})
                    dialogue_dict[num_dialogue]['intervention_dictonary'].update({num_intervention:{'who':who,'text':paragraphs[index][m1.end():]}})
                    num_intervention += 1
                else:
                    # expressió regular per els cognoms catalans
                    m2 = re.search(r"señor\w? ([A-ZÁÉÍÓÚÑ\-]+) I ([A-ZÁÉÍÓÚÑ\-]+)\:", paragraphs[index])
                    if m2:
                        print "OK 2", paragraphs[index]
                        print "found:", paragraphs[index][m2.start():m2.end()]
                        print "groups:", m2.group(0), ", ", m2.group(1), ", ", m2.group(2)
                        print "speaker:", m2.group(1) + " " + m2.group(2)
                        print "speach:", paragraphs[index][m2.end():]

                        id = search_diputado_in_dict(loaded_diputados_dict, m2.group(1) + " I " + m2.group(2), ignore_accents = True)
                        # dip = search_diputado_in_BD(congres_members_collection, m.group(1) + " I " + m.group(2))
                        if id:
                            who = id
                        else:
                            who = 9999           
                        # dialogue_dict[num_dialogue]['inter_dict'].update({num_intervention:{'who':who,'text':remove_spaces_and_newline(paragraphs[index][m.end():])}})
                        dialogue_dict[num_dialogue]['intervention_dictonary'].update({num_intervention:{'who':who,'text':paragraphs[index][m2.end():]}})
                        num_intervention += 1
                    else:
                        # expressió regular per trobar intervencions del tipus: 
                        #     "   El señor MINISTRO DE INDUSTRIA, ENERGÍA Y TURISMO (Soria López):"
                        m3 = re.search(r"^\s*(El señor|La señora) ([^:]+)\:", paragraphs[index])
                        if m3:
                            print "OK 3", paragraphs[index]
                            print "found:", paragraphs[index][m3.start():m3.end()]
                            print "groups:", m3.group(0), ", ", m3.group(1), ", ", m3.group(2)
                            print "speaker:", m3.group(2)
                            if '(' in m3.group(2) and ')' in m3.group(2):
                                str_surname = remove_spaces_and_newline(get_text_between(m3.group(2), '(',')'))
                            else:
                                str_surname = m3.group(2)
                            print "speaker2:", str_surname
                            print "speach:", paragraphs[index][m3.end():]

                            id = search_diputado_in_dict(loaded_diputados_dict, str_surname, ignore_accents = True)
                            # dip = search_diputado_in_BD(congres_members_collection, str_surname)
                            if id:
                                who = id
                            else:
                                who = 9999
                            # dialogue_dict[num_dialogue]['inter_dict'].update({num_intervention:{'who':who,'text':remove_spaces_and_newline(paragraphs[index][m.end():])}})
                            dialogue_dict[num_dialogue]['intervention_dictonary'].update({num_intervention:{'who':who,'text':paragraphs[index][m3.end():]}})
                            num_intervention += 1
                        else:
                            if who:
                                print "OK", who, ":"
                                # Eliminem la intervenció final del "PRESIDENTE" del congrés detectada en les intervencions de diaris de sessions antics
                                m = re.search(r"(El señor|La señora) (PRESIDENTE|PRESIDENTA)\:", paragraphs[index])
                                if m:
                                    extracted_text = paragraphs[index][0:m.start()]
                                    print "(El señor|La señora) (PRESIDENTE|PRESIDENTA)\:"
                                    print ">" + extracted_text + "<"
                                else:
                                    extracted_text = paragraphs[index]
                                    print extracted_text
                                
                                dialogue_dict[num_dialogue]['intervention_dictonary'][(num_intervention-1)]['text'] += ("\n" + extracted_text)
                            else:
                                print "KO", paragraphs[index]
                                
                                if index+1 < len(paragraphs):
                                    paragraph_fusion = paragraphs[index] + paragraphs[index+1]

                                    m3_2 = re.search(r"^\s*(El señor|La señora) ([^:]+)\:", paragraph_fusion)
                                    if m3_2:
                                        print "OK 3_2", paragraph_fusion
                                        print "found:", paragraph_fusion[m3_2.start():m3_2.end()]
                                        print "groups:", m3_2.group(0), ", ", m3_2.group(1), ", ", m3_2.group(2)
                                        print "speaker:", m3_2.group(2)
                                        if '(' in m3_2.group(2) and ')' in m3_2.group(2):
                                            str_surname = remove_spaces_and_newline(get_text_between(m3_2.group(2), '(',')'))
                                        else:
                                            str_surname = m3_2.group(2)
                                        print "speaker2:", str_surname
                                        print "speach:", paragraphs[index][m3_2.end():]

                                        id = search_diputado_in_dict(loaded_diputados_dict, str_surname, ignore_accents = True)
                                        # dip = search_diputado_in_BD(congres_members_collection, str_surname)
                                        if id:
                                            who = id
                                        else:
                                            who = 9999

                                        dialogue_dict[num_dialogue]['intervention_dictonary'].update({num_intervention:{'who':who,'text':paragraph_fusion[m3_2.end():]}})
                                        num_intervention += 1
                                        index += 1
        else:
            print "num_dialogue:", num_dialogue, ">" + paragraphs[index] + "<"

        index += 1

    return dialogue_dict

# %%
import re

def file_document_analyzer(text, date):

    prefix_file_name = date + "_doc"

    # Extraiem el text desde l'última aparició de 'PREGUNTAS:' i '<hr size="1" noshade="" />' (aquest últim element només apareix al final de cada doc)
    preguntas_html = get_text_between(text, 'PREGUNTAS:', '<hr size="1" noshade="" />', include_limits = False, first_ocurrences = False)

    # Cleaning the text of html tags:
    # Remove:
    # <p style="text-align:center"><a name="(Página7)"><b>Página7</b></a></p>
    preguntas_html = re.sub(r'<p.*?/p>', '', preguntas_html, flags=re.DOTALL)
    
    # Remove:
    # <center><a name="(Página8259)"><b>Página 8259</b></a></center>
    preguntas_html = re.sub(r'<center>.*?</center>', '', preguntas_html, flags=re.DOTALL)
    
    # Remove:
    # <br />
    preguntas_html = re.sub(r'<br />', '', preguntas_html, flags=re.DOTALL)

    save_text_file(preguntas_html, 'log/' + prefix_file_name + '_preguntas_html.txt', "")
    #
    # paragraphs = preguntas_html.split("\n\n")
    # paragraphs = preguntas_html.split("<br />")
    paragraphs = preguntas_html.split("\n")
    text_to_analyze = ""
    i = 0
    for paragraph in paragraphs:
        text_to_analyze += "["+ str(i) + "]-----------------------------------------------------" + "\n"
        text_to_analyze += paragraph + "\n"
        i += 1
    # print text_to_analyze
    save_text_file(text_to_analyze, 'log/' + prefix_file_name + '_to_analyze.txt', "")

    #
    '''
    with Capturing() as output:
        result_dialogue_dict = paragraphs_analyzer(paragraphs)
    '''
    result_dialogue_dict = my_paragraphs_analyzer(paragraphs)

    # Log output
    # print 'output:\n', output
    # save_list_text_file(output, 'log/' + prefix_file_name + '_analyzer_log.txt') 

    return result_dialogue_dict

# %%
# Load documents
loaded_groups_dict = load_dict_json('groups_dict.json')

'''
loaded_text_file = load_text_file('docs/19980429_doc.html',"")
result_dialogue_dict = file_document_analyzer(loaded_text_file, "19980429")
'''
loaded_text_file = load_text_file('docs/20150311_doc.html',"")
result_dialogue_dict = file_document_analyzer(loaded_text_file, "20150311")
# Out:
# [0]-----------------------------------------------------
# Empty paragraph
# [1]-----------------------------------------------------
# Empty paragraph
# [2]-----------------------------------------------------
# sub_text_stared = True
# Adding:     ? DEL DIPUTADO DON ALFRED BOSCH I PASCUAL, DEL GRUPO PARLAMENTARIO MIXTO,
# [3]-----------------------------------------------------
# Adding:     QUE FORMULA AL SEÑOR PRESIDENTE DEL GOBIERNO: ¿CONSIDERA EL GOBIERNO
# [4]-----------------------------------------------------
# Adding:     ADECUADO PARA ERRADICAR LA POBREZA INFANTIL EN CATALUÑA LOS 2,25 EUROS
# [5]-----------------------------------------------------
# Adding:     POR NIÑO QUE DESTINÓ PARA COMBATIRLA MEDIANTE EL FONDO CORRESPONDIENTE?
# [6]-----------------------------------------------------
# sub_text:      ? DEL DIPUTADO DON ALFRED BOSCH I PASCUAL, DEL GRUPO PARLAMENTARIO MIXTO,
#     QUE FORMULA AL SEÑOR PRESIDENTE DEL GOBIERNO: ¿CONSIDERA EL GOBIERNO
#     ADECUADO PARA ERRADICAR LA POBREZA INFANTIL EN CATALUÑA LOS 2,25 EUROS
#     POR NIÑO QUE DESTINÓ PARA COMBATIRLA MEDIANTE EL FONDO CORRESPONDIENTE?
#     (Número de expediente 180/001217).
# num_exp: 180/001217
# question: CONSIDERA EL GOBIERNO
#     ADECUADO PARA ERRADICAR LA POBREZA INFANTIL EN CATALUÑA LOS 2,25 EUROS
#     POR NIÑO QUE DESTINÓ PARA COMBATIRLA MEDIANTE EL FONDO CORRESPONDIENTE
# speaker: ALFRED BOSCH I PASCUAL
# group: GMx
# [7]-----------------------------------------------------
# Empty paragraph
# [8]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Comenzamos con las preguntas dirigidas al señor
# [9]-----------------------------------------------------
# KO     presidente del Gobierno. Pregunta, en primer lugar, el diputado don
# [10]-----------------------------------------------------
# KO     Alfredo Bosch, del Grupo Parlamentario Mixto.
# [11]-----------------------------------------------------
# Empty paragraph
# [12]-----------------------------------------------------
# OK 2     El señor BOSCH I PASCUAL: ¿Considera el Gobierno adecuados para erradicar
# found: señor BOSCH I PASCUAL:
# groups: señor BOSCH I PASCUAL: ,  BOSCH ,  PASCUAL
# speaker: BOSCH PASCUAL
# speach:  ¿Considera el Gobierno adecuados para erradicar
# [13]-----------------------------------------------------
# OK 1207 :
#     la pobreza infantil los 2,25 euros por niño pobre que se dedican en
# [14]-----------------------------------------------------
# OK 1207 :
#     Cataluña mediante el fondo correspondiente?
# [15]-----------------------------------------------------
# Empty paragraph
# [16]-----------------------------------------------------
# OK 1207 :
#     Muchas gracias.
# [17]-----------------------------------------------------
# Empty paragraph
# [18]-----------------------------------------------------
# Empty paragraph
# [19]-----------------------------------------------------
# Empty paragraph
# [20]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Muchas gracias, señor Bosch.
# [21]-----------------------------------------------------
# Empty paragraph
# [22]-----------------------------------------------------
# KO     Señor presidente.
# [23]-----------------------------------------------------
# Empty paragraph
# [24]-----------------------------------------------------
# OK 3     El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey): Muchas gracias.
# found:     El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey):
# groups:     El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey): ,  El señor ,  PRESIDENTE DEL GOBIERNO (Rajoy Brey)
# speaker: PRESIDENTE DEL GOBIERNO (Rajoy Brey)
# speaker2: Rajoy Brey
# speach:  Muchas gracias.
# [25]-----------------------------------------------------
# Empty paragraph
# [26]-----------------------------------------------------
# OK 315 :
#     Si esa cifra fuera cierta, señor Bosch, me parecería absolutamente
# [27]-----------------------------------------------------
# OK 315 :
#     inadecuada, por suerte es falsa, y yo puedo decir que a pesar de las
# [28]-----------------------------------------------------
# OK 315 :
#     dificultades que hemos vivido en Cataluña y en el conjunto de España a lo
# [29]-----------------------------------------------------
# OK 315 :
#     largo de estos tiempos, somos un país que hemos logrado que los españoles
# [30]-----------------------------------------------------
# OK 315 :
#     pudieran llevar una vida digna, en ocasiones difícil, pero siempre digna.
# [31]-----------------------------------------------------
# Empty paragraph
# [32]-----------------------------------------------------
# OK 315 :
#     Gracias. (Aplausos).
# [33]-----------------------------------------------------
# Empty paragraph
# [34]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Muchas gracias, señor presidente.
# [35]-----------------------------------------------------
# Empty paragraph
# [36]-----------------------------------------------------
# KO     Señor Bosch.
# [37]-----------------------------------------------------
# Empty paragraph
# [38]-----------------------------------------------------
# OK 2     El señor BOSCH I PASCUAL: ¿Sabe lo que pasa, presidente? Que no se lo digo
# found: señor BOSCH I PASCUAL:
# groups: señor BOSCH I PASCUAL: ,  BOSCH ,  PASCUAL
# speaker: BOSCH PASCUAL
# speach:  ¿Sabe lo que pasa, presidente? Que no se lo digo
# [39]-----------------------------------------------------
# OK 1207 :
#     yo, se lo dice todo el mundo; todo el mundo le da tirones de orejas. Se
# [40]-----------------------------------------------------
# OK 1207 :
#     lo dice Unicef, que manifiesta que más de una cuarta parte de la
# [41]-----------------------------------------------------
# OK 1207 :
#     población infantil está en situación de pobreza, que no se hace lo
# [42]-----------------------------------------------------
# OK 1207 :
#     suficiente y que hay necesidad de un sistema de protección como tienen en
# [43]-----------------------------------------------------
# OK 1207 :
#     otros países, que sí han conseguido reducir la pobreza infantil. Se lo
# [44]-----------------------------------------------------
# OK 1207 :
#     dijo la Comisión Europea hace cinco días en su informe, en el cual
# [45]-----------------------------------------------------
# OK 1207 :
#     exponían que los 17 millones de euros ?que es la cifra que dan ellos? que
# [46]-----------------------------------------------------
# OK 1207 :
#     destinaron a la pobreza infantil en 2014 son claramente insuficientes, y
# [47]-----------------------------------------------------
# OK 1207 :
#     le dicen que son políticas regresivas que penalizan o castigan a las
# [48]-----------------------------------------------------
# OK 1207 :
#     familias con las rentas más bajas. Eso es lo que le dicen, y le dicen
# [49]-----------------------------------------------------
# OK 1207 :
#     también que la sociedad española desgraciadamente es el líder en pobreza
# [50]-----------------------------------------------------
# OK 1207 :
#     infantil en la Unión Europea, y ese es el problema. Oiga, ¿se puede
# [51]-----------------------------------------------------
# OK 1207 :
#     comprometer usted realmente a luchar contra la pobreza infantil? ¿Puede
# [52]-----------------------------------------------------
# OK 1207 :
#     dedicar, por ejemplo ?propuesta?, en este ejercicio el Fondo de
# [53]-----------------------------------------------------
# OK 1207 :
#     contingencia a la pobreza infantil en vez de dedicarlo, como hacen cada
# [54]-----------------------------------------------------
# OK 1207 :
#     año ?1.700 millones de euros cada año?, a comprar armas, a gasto militar?
# [55]-----------------------------------------------------
# OK 1207 :
#     ¿Pueden dedicarlo a pobreza infantil? Es posible, se hace en otros
# [56]-----------------------------------------------------
# OK 1207 :
#     lugares. Señor Rajoy, le pido que hable con el corazón en la mano, le
# [57]-----------------------------------------------------
# OK 1207 :
#     pido que sea sincero, que diga lo que piensa, que diga lo que siente. ¿Le
# [58]-----------------------------------------------------
# OK 1207 :
#     parece que se está haciendo lo suficiente contra la pobreza infantil? ¿Le
# [59]-----------------------------------------------------
# OK 1207 :
#     parece que se está haciendo bien o le da igual, o le entra por una oreja
# [60]-----------------------------------------------------
# OK 1207 :
#     y le sale por la otra? ¡Qué triste pena, señor Rajoy! ¡Qué triste pena!
# [61]-----------------------------------------------------
# OK 1207 :
#     (Pronuncia palabras en catalán).
# [62]-----------------------------------------------------
# Empty paragraph
# [63]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Gracias, señor Bosch.
# [64]-----------------------------------------------------
# Empty paragraph
# [65]-----------------------------------------------------
# KO     Señor presidente.
# [66]-----------------------------------------------------
# Empty paragraph
# [67]-----------------------------------------------------
# OK 3     El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey): Puestos a citar frases,
# found:     El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey):
# groups:     El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey): ,  El señor ,  PRESIDENTE DEL GOBIERNO (Rajoy Brey)
# speaker: PRESIDENTE DEL GOBIERNO (Rajoy Brey)
# speaker2: Rajoy Brey
# speach:  Puestos a citar frases,
# [68]-----------------------------------------------------
# OK 315 :
#     señor Bosch, la campaña Pobreza cero, que agrupa a más de 4.200
# [69]-----------------------------------------------------
# OK 315 :
#     organizaciones en el ámbito de la acción social en Cataluña, emitió el
# [70]-----------------------------------------------------
# OK 315 :
#     pasado mes de enero un comunicado en el que decía que no ve en los
# [71]-----------------------------------------------------
# OK 315 :
#     presupuestos de la Generalitat para el año 2015 ningún avance en la lucha
# [72]-----------------------------------------------------
# OK 315 :
#     contra la pobreza y las desigualdades; esos presupuestos fueron apoyados
# [73]-----------------------------------------------------
# OK 315 :
#     por su grupo político.
# [74]-----------------------------------------------------
# Empty paragraph
# [75]-----------------------------------------------------
# OK 315 :
#     Yo le voy a decir lo que estamos haciendo en un tema en el que,
# [76]-----------------------------------------------------
# OK 315 :
#     precisamente porque puede ser dramático, conviene ser ecuánime y actuar
# [77]-----------------------------------------------------
# OK 315 :
#     con sensatez y dejar de lado la demagogia. Quiero hacer las siguientes
# [78]-----------------------------------------------------
# OK 315 :
#     consideraciones. La primera es que el principal factor que explica la
# [79]-----------------------------------------------------
# OK 315 :
#     pobreza infantil es el paro de los padres, por tanto la política más
# [80]-----------------------------------------------------
# OK 315 :
#     importante en esta materia, como en tantas, es hacer un esfuerzo para
# [81]-----------------------------------------------------
# OK 315 :
#     generar empleo en nuestro país y terminar con el paro. Por suerte, se han
# [82]-----------------------------------------------------
# OK 315 :
#     producido avances sustanciales en el año 2014 y yo espero que entre el
# [83]-----------------------------------------------------
# OK 315 :
#     año 2014 y el año 2015 se creen un millón de puestos de trabajo en
# [84]-----------------------------------------------------
# OK 315 :
#     nuestro país. Dicho esto, lo que acabo de señalar no es en absoluto
# [85]-----------------------------------------------------
# OK 315 :
#     suficiente y por eso hemos hecho más cosas y estamos dispuestos a hacer
# [86]-----------------------------------------------------
# OK 315 :
#     todo aquello que sea necesario para mejorar la situación de los niños.
# [87]-----------------------------------------------------
# OK 315 :
#     Hemos aprobado un plan de inclusión social, ese plan al que usted se
# [88]-----------------------------------------------------
# OK 315 :
#     refiere está dotado este año con 32 millones de euros. Asimismo, un plan
# [89]-----------------------------------------------------
# OK 315 :
#     concertado dirigido a los servicios sociales y a las corporaciones
# [90]-----------------------------------------------------
# OK 315 :
#     locales por importe de 27 millones de euros. Hemos destinado a
# [91]-----------------------------------------------------
# OK 315 :
#     subvenciones de programas sociales del IRPF más de 600 millones en esta
# [92]-----------------------------------------------------
# OK 315 :
#     legislatura y al Fondo de pago de alimentos, 40 millones de euros.
# [93]-----------------------------------------------------
# OK 315 :
#     También el FLA y el Plan de pago a proveedores sirven para atender la
# [94]-----------------------------------------------------
# OK 315 :
#     sanidad, la educación y los servicios sociales de los ayuntamientos y de
# [95]-----------------------------------------------------
# OK 315 :
#     las comunidades autónomas. Hemos creado un nuevo mecanismo de
# [96]-----------------------------------------------------
# OK 315 :
#     financiación, el Fondo social, para que los municipios cobren las
# [97]-----------------------------------------------------
# OK 315 :
#     atenciones que dedican a fines sociales mediante convenios con
# [98]-----------------------------------------------------
# OK 315 :
#     comunidades autónomas. Hemos aprobado un fondo específico para familias
# [99]-----------------------------------------------------
# OK 315 :
#     en situación de especial dificultad. Hemos prorrogado el Prepara. Hemos
# [100]-----------------------------------------------------
# OK 315 :
#     firmado con los sindicatos un programa extraordinario para formar a la
# [101]-----------------------------------------------------
# OK 315 :
#     gente para que pueda trabajar. Hemos
# [102]-----------------------------------------------------
# Empty paragraph
# [103]-----------------------------------------------------
# Empty paragraph
# [104]-----------------------------------------------------
# Empty paragraph
# [105]-----------------------------------------------------
# OK 315 :
#     acordado programas de urgencia social, ayudas al Fondo social de la
# [106]-----------------------------------------------------
# OK 315 :
#     vivienda y se ha hecho un gran esfuerzo en el impuesto de la renta. Se
# [107]-----------------------------------------------------
# OK 315 :
#     puede hacer mucho más, y haremos cuanto sea necesario, pero no es justo
# [108]-----------------------------------------------------
# OK 315 :
#     decir que no se aborda este problema. (Aplausos).
# [109]-----------------------------------------------------
# Empty paragraph
# [110]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Gracias, señor presidente.
# [111]-----------------------------------------------------
# Empty paragraph
# [112]-----------------------------------------------------
# sub_text_stared = True
# Adding:     ? DEL DIPUTADO DON PERE MACIAS I ARAU, EN SUSTITUCIÓN DE DON JOSEP ANTONI
# [113]-----------------------------------------------------
# Adding:     DURAN I LLEIDA, DEL GRUPO PARLAMENTARIO CATALÁN (CONVERGÈNCIA I UNIÓ),
# [114]-----------------------------------------------------
# Adding:     QUE FORMULA AL SEÑOR PRESIDENTE DEL GOBIERNO: ¿QUÉ PRIORIDADES TIENE EL
# [115]-----------------------------------------------------
# sub_text:      ? DEL DIPUTADO DON PERE MACIAS I ARAU, EN SUSTITUCIÓN DE DON JOSEP ANTONI
#     DURAN I LLEIDA, DEL GRUPO PARLAMENTARIO CATALÁN (CONVERGÈNCIA I UNIÓ),
#     QUE FORMULA AL SEÑOR PRESIDENTE DEL GOBIERNO: ¿QUÉ PRIORIDADES TIENE EL
#     GOBIERNO EN POLÍTICA INDUSTRIAL? (Número de expediente 180/001230).
# num_exp: 180/001230
# question: QUÉ PRIORIDADES TIENE EL
#     GOBIERNO EN POLÍTICA INDUSTRIAL
# speaker: PERE MACIAS I ARAU
# group: GC-CiU
# [116]-----------------------------------------------------
# Empty paragraph
# [117]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Pregunta que formula el diputado don Pere Macias, del
# [118]-----------------------------------------------------
# KO     Grupo Catalán de Convergència i Unió.
# [119]-----------------------------------------------------
# Empty paragraph
# [120]-----------------------------------------------------
# OK 2     El señor MACIAS I ARAU: Muchas gracias, señor presidente.
# found: señor MACIAS I ARAU:
# groups: señor MACIAS I ARAU: ,  MACIAS ,  ARAU
# speaker: MACIAS ARAU
# speach:  Muchas gracias, señor presidente.
# [121]-----------------------------------------------------
# Empty paragraph
# [122]-----------------------------------------------------
# OK 1290 :
#     Quisiera, en primer lugar, expresar nuestra emocionada solidaridad con el
# [123]-----------------------------------------------------
# OK 1290 :
#     pueblo de Madrid, siendo hoy el día 11 de marzo, de triste recuerdo.
# [124]-----------------------------------------------------
# Empty paragraph
# [125]-----------------------------------------------------
# OK 1290 :
#     Señor presidente, para salir de la crisis hace falta política industrial.
# [126]-----------------------------------------------------
# OK 1290 :
#     Europa quiere que el 20 % del PIB de todos los países sea generado por la
# [127]-----------------------------------------------------
# OK 1290 :
#     industria. Nosotros hemos perdido un millón de puestos de trabajo. Usted
# [128]-----------------------------------------------------
# OK 1290 :
#     sabe, señor presidente, el efecto arrastre que tiene la industria sobre
# [129]-----------------------------------------------------
# OK 1290 :
#     los otros sectores económicos. La recuperación solo será sostenible con
# [130]-----------------------------------------------------
# OK 1290 :
#     industria. Esto se lo formuló, con otras palabras, nuestro portavoz en el
# [131]-----------------------------------------------------
# OK 1290 :
#     debate del estado de la Nación, donde oímos muchas descalificaciones y
# [132]-----------------------------------------------------
# OK 1290 :
#     pocas propuestas, y, de hecho, ninguna respuesta a nuestro portavoz en
# [133]-----------------------------------------------------
# OK 1290 :
#     materia de política industrial. Por esto, le reformulamos algunas de las
# [134]-----------------------------------------------------
# OK 1290 :
#     cuestiones más relevantes que, a nuestro juicio, deben presidir la
# [135]-----------------------------------------------------
# OK 1290 :
#     política industrial. Vamos a tratar cuatro temas. En primer lugar, vamos
# [136]-----------------------------------------------------
# OK 1290 :
#     a hablar de impulsar la innovación, de ser competitivos en energía, de
# [137]-----------------------------------------------------
# OK 1290 :
#     minorar costes logísticos de transporte y de una política fiscal que
# [138]-----------------------------------------------------
# OK 1290 :
#     atraiga la inversión industrial. En algunos sectores industriales, como
# [139]-----------------------------------------------------
# OK 1290 :
#     el de la industria química ?la de Tarragona y otros polígonos en toda
# [140]-----------------------------------------------------
# OK 1290 :
#     España?, están muy preocupados por estos aspectos. Señor presidente,
# [141]-----------------------------------------------------
# OK 1290 :
#     respecto a la política energética, nuestras industrias no son
# [142]-----------------------------------------------------
# OK 1290 :
#     competitivas con una reforma energética que solo se ha hecho por motivos
# [143]-----------------------------------------------------
# OK 1290 :
#     presupuestarios. En materia de innovación, entre los años 2010 y 2015 en
# [144]-----------------------------------------------------
# OK 1290 :
#     los presupuestos ha disminuido un 50 % la inversión pública en
# [145]-----------------------------------------------------
# OK 1290 :
#     innovación, y esto no es de recibo en estos momentos. Si hablamos de
# [146]-----------------------------------------------------
# OK 1290 :
#     logística y transporte, dos temas. Autorización de vehículos de más
# [147]-----------------------------------------------------
# OK 1290 :
#     capacidad de carga: en Portugal, 60 toneladas; en España, 40. ¿Cómo vamos
# [148]-----------------------------------------------------
# OK 1290 :
#     a ser competitivos, señor presidente? Si hablamos de logística, el
# [149]-----------------------------------------------------
# OK 1290 :
#     corredor mediterráneo. Según usted, debía estar en funcionamiento en
# [150]-----------------------------------------------------
# OK 1290 :
#     febrero de 2015; aún tienen que empezar las obras. Si hablamos de
# [151]-----------------------------------------------------
# OK 1290 :
#     política fiscal, acabamos de retirar las ayudas a la inversión en
# [152]-----------------------------------------------------
# OK 1290 :
#     modernización medioambiental. Europa nos exige aplicar mejores técnicas
# [153]-----------------------------------------------------
# OK 1290 :
#     disponibles. ¿Qué hacemos para ayudar a la industria? Le retiramos las
# [154]-----------------------------------------------------
# OK 1290 :
#     ayudas. Las industrias, señor presidente, van a irse. Por esto, le pido,
# [155]-----------------------------------------------------
# OK 1290 :
#     señor presidente, que afine su puntería en materia de política
# [156]-----------------------------------------------------
# OK 1290 :
#     industrial.
# [157]-----------------------------------------------------
# Empty paragraph
# [158]-----------------------------------------------------
# OK 1290 :
#     Muchas gracias.
# [159]-----------------------------------------------------
# Empty paragraph
# [160]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Muchas gracias, señor Macias.
# [161]-----------------------------------------------------
# Empty paragraph
# [162]-----------------------------------------------------
# KO     Señor presidente.
# [163]-----------------------------------------------------
# Empty paragraph
# [164]-----------------------------------------------------
# OK 3     El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey): Me sumo a sus palabras
# found:     El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey):
# groups:     El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey): ,  El señor ,  PRESIDENTE DEL GOBIERNO (Rajoy Brey)
# speaker: PRESIDENTE DEL GOBIERNO (Rajoy Brey)
# speaker2: Rajoy Brey
# speach:  Me sumo a sus palabras
# [165]-----------------------------------------------------
# OK 315 :
#     iniciales, señor Macias, y a la iniciativa del señor presidente de la
# [166]-----------------------------------------------------
# OK 315 :
#     Cámara.
# [167]-----------------------------------------------------
# Empty paragraph
# [168]-----------------------------------------------------
# OK 315 :
#     Coincido con usted en la importancia de la política industrial para
# [169]-----------------------------------------------------
# OK 315 :
#     generar crecimiento económico y empleo. Estamos hablando, además, de un
# [170]-----------------------------------------------------
# OK 315 :
#     sector que, como todo el mundo conoce, genera empleo estable, genera
# [171]-----------------------------------------------------
# OK 315 :
#     empleo cualificado, concentra la mayoría de nuestras exportaciones, el 80
# [172]-----------------------------------------------------
# OK 315 :
#     %, es muy importante en la actividad de I+D+i que el sector privado lleva
# [173]-----------------------------------------------------
# OK 315 :
#     a cabo y está asociado a un importante volumen de actividad del sector
# [174]-----------------------------------------------------
# OK 315 :
#     servicios. Por tanto, tiene usted toda la razón al decir que la política
# [175]-----------------------------------------------------
# OK 315 :
#     industrial es muy importante en nuestro país. ¿Qué hemos hecho a lo largo
# [176]-----------------------------------------------------
# OK 315 :
#     de todo este tiempo? En primer lugar, todas las reformas necesarias, y
# [177]-----------------------------------------------------
# OK 315 :
#     también las que haremos en el futuro, tienen como objetivo fundamental la
# [178]-----------------------------------------------------
# OK 315 :
#     política industrial. La reforma laboral es útil para la política
# [179]-----------------------------------------------------
# OK 315 :
#     industrial, también lo es la reforma energética, la reforma financiera y
# [180]-----------------------------------------------------
# OK 315 :
#     la vuelta al crédito, el programa de unidad de mercado, la reforma
# [181]-----------------------------------------------------
# OK 315 :
#     tributaria que hemos puesto en marcha. Podría citarle otras muchas, pero
# [182]-----------------------------------------------------
# OK 315 :
#     además de esto, por su carácter específico, quiero hacer referencia a la
# [183]-----------------------------------------------------
# OK 315 :
#     agenda para el fortalecimiento del sector industrial español. Son medidas
# [184]-----------------------------------------------------
# OK 315 :
#     más específicas que contribuyen a la mejora del entorno empresarial en el
# [185]-----------------------------------------------------
# OK 315 :
#     que el
# [186]-----------------------------------------------------
# Empty paragraph
# [187]-----------------------------------------------------
# Empty paragraph
# [188]-----------------------------------------------------
# Empty paragraph
# [189]-----------------------------------------------------
# OK 315 :
#     tejido productivo industrial desarrolla su actividad. Hay muchas medidas
# [190]-----------------------------------------------------
# OK 315 :
#     concretas; medidas de apoyo financiero, medidas de inversión industrial,
# [191]-----------------------------------------------------
# OK 315 :
#     programas para sectores como el automóvil, como el naval, como el
# [192]-----------------------------------------------------
# OK 315 :
#     aerospacial. Se ha puesto en marcha el PIVE, el PIMA, la Ley de la cadena
# [193]-----------------------------------------------------
# OK 315 :
#     alimentaria, normas en materia de financiación de buques, construcción
# [194]-----------------------------------------------------
# OK 315 :
#     naval, ayudas a I+D+i, sector aeronáutico. Por tanto, se han tomado
# [195]-----------------------------------------------------
# OK 315 :
#     decisiones importantes para un sector industrial que está creciendo ahora
# [196]-----------------------------------------------------
# OK 315 :
#     y está siendo útil para crear empleo en la economía española.
# [197]-----------------------------------------------------
# Empty paragraph
# [198]-----------------------------------------------------
# OK 315 :
#     Muchas gracias. (Aplausos).
# [199]-----------------------------------------------------
# Empty paragraph
# [200]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Muchas gracias, señor presidente.
# [201]-----------------------------------------------------
# Empty paragraph
# [202]-----------------------------------------------------
# sub_text_stared = True
# Adding:     ? DEL DIPUTADO DON PEDRO SÁNCHEZ PÉREZ-CASTEJÓN, DEL GRUPO PARLAMENTARIO
# [203]-----------------------------------------------------
# Adding:     SOCIALISTA, QUE FORMULA AL SEÑOR PRESIDENTE DEL GOBIERNO: ¿CONSIDERA EL
# [204]-----------------------------------------------------
# Adding:     PRESIDENTE QUE LA ACTUACIÓN DEL GOBIERNO ANTE LAS INUNDACIONES DE LAS
# [205]-----------------------------------------------------
# sub_text:      ? DEL DIPUTADO DON PEDRO SÁNCHEZ PÉREZ-CASTEJÓN, DEL GRUPO PARLAMENTARIO
#     SOCIALISTA, QUE FORMULA AL SEÑOR PRESIDENTE DEL GOBIERNO: ¿CONSIDERA EL
#     PRESIDENTE QUE LA ACTUACIÓN DEL GOBIERNO ANTE LAS INUNDACIONES DE LAS
#     ÚLTIMAS SEMANAS HA SIDO LA ADECUADA? (Número de expediente 180/001220).
# num_exp: 180/001220
# question: CONSIDERA EL
#     PRESIDENTE QUE LA ACTUACIÓN DEL GOBIERNO ANTE LAS INUNDACIONES DE LAS
#     ÚLTIMAS SEMANAS HA SIDO LA ADECUADA
# speaker: PEDRO SÁNCHEZ PÉREZ-CASTEJÓN
# group:
#     SOCIALISTA
# [206]-----------------------------------------------------
# Empty paragraph
# [207]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Pregunta dirigida al señor presidente del Gobierno
# [208]-----------------------------------------------------
# KO     que formula el diputado don Pedro Sánchez, del Grupo Socialista.
# [209]-----------------------------------------------------
# Empty paragraph
# [210]-----------------------------------------------------
# OK 1     El señor SÁNCHEZ PÉREZ-CASTEJÓN: Gracias, señor presidente.
# found: señor SÁNCHEZ PÉREZ-CASTEJÓN:
# groups: señor SÁNCHEZ PÉREZ-CASTEJÓN: ,  SÁNCHEZ ,  PÉREZ-CASTEJÓN
# speaker: SÁNCHEZ PÉREZ-CASTEJÓN
# speach:  Gracias, señor presidente.
# [211]-----------------------------------------------------
# Empty paragraph
# [212]-----------------------------------------------------
# OK 1155 :
#     Señor Rajoy, ¿considera usted adecuada su gestión ante los efectos de la
# [213]-----------------------------------------------------
# OK 1155 :
#     riada del Ebro?
# [214]-----------------------------------------------------
# Empty paragraph
# [215]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Muchas gracias, señor Sánchez.
# [216]-----------------------------------------------------
# Empty paragraph
# [217]-----------------------------------------------------
# KO     Señor presidente.
# [218]-----------------------------------------------------
# Empty paragraph
# [219]-----------------------------------------------------
# OK 3     El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey): Muchas gracias, señor
# found:     El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey):
# groups:     El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey): ,  El señor ,  PRESIDENTE DEL GOBIERNO (Rajoy Brey)
# speaker: PRESIDENTE DEL GOBIERNO (Rajoy Brey)
# speaker2: Rajoy Brey
# speach:  Muchas gracias, señor
# [220]-----------------------------------------------------
# OK 315 :
#     presidente.
# [221]-----------------------------------------------------
# Empty paragraph
# [222]-----------------------------------------------------
# OK 315 :
#     Quiero empezar trasladando mi solidaridad y mi apoyo, y el de todo el
# [223]-----------------------------------------------------
# OK 315 :
#     Gobierno, a todas las personas afectadas por los acontecimientos que se
# [224]-----------------------------------------------------
# OK 315 :
#     produjeron la pasada semana, como ya hice el último viernes en la ciudad
# [225]-----------------------------------------------------
# OK 315 :
#     de Zaragoza. Desde el primer momento hemos trabajado de forma coordinada
# [226]-----------------------------------------------------
# OK 315 :
#     con las comunidades autónomas y con los ayuntamientos, con la Guardia
# [227]-----------------------------------------------------
# OK 315 :
#     Civil, la UME, la policía, los bomberos de la diputación, el personal de
# [228]-----------------------------------------------------
# OK 315 :
#     la Diputación General de Aragón; todos han estado a la altura de las
# [229]-----------------------------------------------------
# OK 315 :
#     circunstancias. Los técnicos también han hecho una labor esencial en
# [230]-----------------------------------------------------
# OK 315 :
#     materia de laminación de los embalses. El Gobierno ha estado ahí. Ya el
# [231]-----------------------------------------------------
# OK 315 :
#     11 febrero, antes de que se produjeran los acontecimientos, estuvo la
# [232]-----------------------------------------------------
# OK 315 :
#     vicepresidenta reunida con varios delegados del Gobierno. El viernes, día
# [233]-----------------------------------------------------
# OK 315 :
#     27, la presidenta de la Diputación General de Aragón estuvo en el puesto
# [234]-----------------------------------------------------
# OK 315 :
#     de mando avanzado y visitó todos los municipios. Hablamos con el Gobierno
# [235]-----------------------------------------------------
# OK 315 :
#     de Aragón a lo largo del fin de semana. El domingo estuvo presente el
# [236]-----------------------------------------------------
# OK 315 :
#     secretario de Estado de Medio Ambiente; el lunes, el ministro del
# [237]-----------------------------------------------------
# OK 315 :
#     Interior y, el martes, la ministra de Agricultura. A lo largo de la
# [238]-----------------------------------------------------
# OK 315 :
#     semana preparamos el real decreto para resarcir los daños y estuve en
# [239]-----------------------------------------------------
# OK 315 :
#     contacto en distintas ocasiones con la presidenta de la comunidad. El
# [240]-----------------------------------------------------
# OK 315 :
#     viernes presenté a los alcaldes de los municipios afectados las medidas
# [241]-----------------------------------------------------
# OK 315 :
#     acordadas en el real decreto-ley que estudiamos en el Consejo de
# [242]-----------------------------------------------------
# OK 315 :
#     Ministros del mismo día, y planteamos también empezar a tomar decisiones
# [243]-----------------------------------------------------
# OK 315 :
#     para tratar de evitar ?cosa que no es fácil, porque no es la primera vez
# [244]-----------------------------------------------------
# OK 315 :
#     que sucede? que estos graves acontecimientos se vuelvan a producir en el
# [245]-----------------------------------------------------
# OK 315 :
#     futuro. Como es natural, lo ideal sería que no se hubiera producido este
# [246]-----------------------------------------------------
# OK 315 :
#     tipo de acontecimientos, pero creo que se hizo lo que había que hacer.
# [247]-----------------------------------------------------
# Empty paragraph
# [248]-----------------------------------------------------
# OK 315 :
#     Muchas gracias. (Aplausos).
# [249]-----------------------------------------------------
# Empty paragraph
# [250]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Muchas gracias, señor presidente.
# [251]-----------------------------------------------------
# Empty paragraph
# [252]-----------------------------------------------------
# KO     Señor Sánchez.
# [253]-----------------------------------------------------
# Empty paragraph
# [254]-----------------------------------------------------
# OK 1     El señor SÁNCHEZ PÉREZ-CASTEJÓN: Gracias, señor presidente.
# found: señor SÁNCHEZ PÉREZ-CASTEJÓN:
# groups: señor SÁNCHEZ PÉREZ-CASTEJÓN: ,  SÁNCHEZ ,  PÉREZ-CASTEJÓN
# speaker: SÁNCHEZ PÉREZ-CASTEJÓN
# speach:  Gracias, señor presidente.
# [255]-----------------------------------------------------
# Empty paragraph
# [256]-----------------------------------------------------
# OK 1155 :
#     Señor Rajoy, el pasado 6 de marzo, cuando visitó de una forma precipitada
# [257]-----------------------------------------------------
# OK 1155 :
#     la ciudad de Zaragoza, resumió en una sola frase su filosofía de acción
# [258]-----------------------------------------------------
# OK 1155 :
#     política; usted dijo: yo voy donde me llevan. Usted dijo textualmente
# [259]-----------------------------------------------------
# OK 1155 :
#     eso: yo voy donde me llevan. Señorías, este es el problema. El problema
# [260]-----------------------------------------------------
# OK 1155 :
#     es que tenemos un presidente que no empatiza con el sufrimiento de la
# [261]-----------------------------------------------------
# OK 1155 :
#     gente. (Rumores y protestas).
# [262]-----------------------------------------------------
# Empty paragraph
# [263]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Silencio.
# [264]-----------------------------------------------------
# Empty paragraph
# [265]-----------------------------------------------------
# OK 1     El señor SÁNCHEZ PÉREZ-CASTEJÓN: Tenemos un presidente del Gobierno que no
# found: señor SÁNCHEZ PÉREZ-CASTEJÓN:
# groups: señor SÁNCHEZ PÉREZ-CASTEJÓN: ,  SÁNCHEZ ,  PÉREZ-CASTEJÓN
# speaker: SÁNCHEZ PÉREZ-CASTEJÓN
# speach:  Tenemos un presidente del Gobierno que no
# [266]-----------------------------------------------------
# OK 1155 :
#     sabe dónde va; y lo que es más grave, señorías, tenemos un presidente del
# [267]-----------------------------------------------------
# OK 1155 :
#     Gobierno que ni está ni le interesa ni le importa
# [268]-----------------------------------------------------
# Empty paragraph
# [269]-----------------------------------------------------
# Empty paragraph
# [270]-----------------------------------------------------
# Empty paragraph
# [271]-----------------------------------------------------
# OK 1155 :
#     el sufrimiento de la gente. (Rumores). Por eso, usted todavía no se ha
# [272]-----------------------------------------------------
# OK 1155 :
#     reunido ni con los agricultores ni con los ganaderos ni con las vecinas y
# [273]-----------------------------------------------------
# OK 1155 :
#     vecinos afectados de la ribera del Ebro, que no solamente están en la
# [274]-----------------------------------------------------
# OK 1155 :
#     ciudad de Zaragoza, están en toda la provincia de Zaragoza, señor Rajoy;
# [275]-----------------------------------------------------
# OK 1155 :
#     y están también en Navarra, en La Rioja y en Castilla y León, y le están
# [276]-----------------------------------------------------
# OK 1155 :
#     esperando a usted y a su Gobierno, señor Rajoy. El hecho cierto es que
# [277]-----------------------------------------------------
# OK 1155 :
#     hay algunas cosas que su Gobierno podría haber evitado: por ejemplo, la
# [278]-----------------------------------------------------
# OK 1155 :
#     inexactitud en el caudal del río; por ejemplo, los recortes sistemáticos
# [279]-----------------------------------------------------
# OK 1155 :
#     en todo lo que tiene que ver con las inversiones públicas en el
# [280]-----------------------------------------------------
# OK 1155 :
#     mantenimiento del cauce del río; y también el no pagar las
# [281]-----------------------------------------------------
# OK 1155 :
#     indemnizaciones, pues todavía tienen ustedes pendiente el pago a todos
# [282]-----------------------------------------------------
# OK 1155 :
#     los afectados por las riadas del año 2013, aunque esa debe ser la tónica
# [283]-----------------------------------------------------
# OK 1155 :
#     habitual por parte de su Gobierno, porque ocurre también con otras
# [284]-----------------------------------------------------
# OK 1155 :
#     indemnizaciones, por ejemplo en Puerto Lumbreras o en la catástrofe de
# [285]-----------------------------------------------------
# OK 1155 :
#     Lorca, señor Rajoy. Ahora ustedes presentan un real decreto deprisa y
# [286]-----------------------------------------------------
# OK 1155 :
#     corriendo que es, a todas luces, insuficiente. (Rumores). Les diré una
# [287]-----------------------------------------------------
# OK 1155 :
#     cosa, señorías del Grupo Parlamentario Popular, presidente del Gobierno,
# [288]-----------------------------------------------------
# OK 1155 :
#     señor Rajoy, en esa riada ustedes se han dejado muchas cosas por delante,
# [289]-----------------------------------------------------
# OK 1155 :
#     y una de ellas es su credibilidad como presidente del Gobierno, señor
# [290]-----------------------------------------------------
# OK 1155 :
#     Rajoy. (Rumores). Sí, usted se esconde cada vez que hay un problema y,
# [291]-----------------------------------------------------
# OK 1155 :
#     por eso, usted se ha negado aquí a responder a las preguntas que tienen
# [292]-----------------------------------------------------
# OK 1155 :
#     que ver con la trama Gürtel (Rumores) y que implican a su partido
# [293]-----------------------------------------------------
# OK 1155 :
#     directamente, señor Rajoy. (Rumores y protestas.?Aplausos). Sí, sí. ¿Pero
# [294]-----------------------------------------------------
# OK 1155 :
#     sabe cuál es el problema? El problema es que mientras usted calla tenemos
# [295]-----------------------------------------------------
# OK 1155 :
#     un ministro de Justicia que amedrenta y amenaza al juez instructor de la
# [296]-----------------------------------------------------
# OK 1155 :
#     Gürtel, tenemos a un ministro de Hacienda que lo que hace es no colaborar
# [297]-----------------------------------------------------
# OK 1155 :
#     con la justicia y utilizar de manera partidista a la Agencia Tributaria.
# [298]-----------------------------------------------------
# OK 1155 :
#     (Rumores). Yo le pregunto una cosa, señor Rajoy: ¿como presidente del
# [299]-----------------------------------------------------
# OK 1155 :
#     Partido Popular ha pagado los 245.000 euros de fianza que le exige la
# [300]-----------------------------------------------------
# OK 1155 :
#     Audiencia Nacional por la trama Gürtel? (Rumores y protestas). Deje de
# [301]-----------------------------------------------------
# OK 1155 :
#     esconderse, acuda aquí al Congreso de los Diputados y asuma sus
# [302]-----------------------------------------------------
# OK 1155 :
#     responsabilidades como presidente del Partido Popular? (Aplausos).
# [303]-----------------------------------------------------
# Empty paragraph
# [304]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Gracias, señor Sánchez.
# [305]-----------------------------------------------------
# Empty paragraph
# [306]-----------------------------------------------------
# KO     Señor presidente, le recuerdo que solo tiene obligación de contestar a la
# [307]-----------------------------------------------------
# KO     pregunta que figura en el orden del día. (Protestas).
# [308]-----------------------------------------------------
# Empty paragraph
# [309]-----------------------------------------------------
# KO     Señor presidente.
# [310]-----------------------------------------------------
# Empty paragraph
# [311]-----------------------------------------------------
# OK 3     El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey): Así lo haré, señor
# found:     El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey):
# groups:     El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey): ,  El señor ,  PRESIDENTE DEL GOBIERNO (Rajoy Brey)
# speaker: PRESIDENTE DEL GOBIERNO (Rajoy Brey)
# speaker2: Rajoy Brey
# speach:  Así lo haré, señor
# [312]-----------------------------------------------------
# OK 315 :
#     presidente, y no le pediré al señor Sánchez explicaciones por los 850
# [313]-----------------------------------------------------
# OK 315 :
#     millones de los ERE de Andalucía que todavía no hemos conocido en esta
# [314]-----------------------------------------------------
# OK 315 :
#     Cámara a qué lo destinaron (Aplausos), ni sobre los más de 250 imputados
# [315]-----------------------------------------------------
# OK 315 :
#     que se han producido, ni por la falta de explicaciones por parte de la
# [316]-----------------------------------------------------
# OK 315 :
#     presidenta de la Junta de Andalucía. (Protestas). A ello no me referiré,
# [317]-----------------------------------------------------
# OK 315 :
#     me referiré a lo que hizo usted cuando fue a Zaragoza. Fue allí cuando el
# [318]-----------------------------------------------------
# OK 315 :
#     Gobierno ya había ido. Fue allí a criticar a todos: al presidente del
# [319]-----------------------------------------------------
# OK 315 :
#     Gobierno, a la ministra de Agricultura, al ministro del Interior y al
# [320]-----------------------------------------------------
# OK 315 :
#     secretario de Medio Ambiente. Dio la sensación de que fue allí a ver si
# [321]-----------------------------------------------------
# OK 315 :
#     pescaba algo. Quiso retirar la pregunta que me ha hecho hoy aquí porque
# [322]-----------------------------------------------------
# OK 315 :
#     veía que ya no podía hacer nada. Olvidó decirle al conjunto de la Cámara
# [323]-----------------------------------------------------
# OK 315 :
#     que pararon las grandes obras como Yesa y Biscarrués, que probablemente
# [324]-----------------------------------------------------
# OK 315 :
#     hubieran evitado muchos de estos problemas. (Protestas). Realmente, la
# [325]-----------------------------------------------------
# OK 315 :
#     sensación que yo tengo, señor Sánchez, es que usted no debería hacer
# [326]-----------------------------------------------------
# OK 315 :
#     campañas a costa del sufrimiento de la gente ni debería desautorizar a
# [327]-----------------------------------------------------
# OK 315 :
#     los técnicos. (Un señor diputado: ¡Bravo!?Rumores.?Aplausos).
# [328]-----------------------------------------------------
# Empty paragraph
# [329]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Gracias, señor presidente. (La señora López i Chamosa
# [330]-----------------------------------------------------
# KO     pronuncia palabras que no se perciben.?Rumores y protestas).
# [331]-----------------------------------------------------
# Empty paragraph
# [332]-----------------------------------------------------
# KO     Señora López i Chamosa, le llamo al orden por primera vez. (Rumores).
# [333]-----------------------------------------------------
# Empty paragraph
# [334]-----------------------------------------------------
# sub_text_stared = True
# Adding:     ? DEL DIPUTADO DON ANTONIO HERNANDO VERA, DEL GRUPO PARLAMENTARIO
# [335]-----------------------------------------------------
# Adding:     SOCIALISTA, QUE FORMULA A LA SEÑORA VICEPRESIDENTA DEL GOBIERNO Y
# [336]-----------------------------------------------------
# Adding:     MINISTRA DE LA PRESIDENCIA: ¿COORDINA LA VICEPRESIDENTA LAS ACTUACIONES
# [337]-----------------------------------------------------
# Adding:     DEL GOBIERNO PARA GARANTIZAR EL RESPETO A LA INDEPENDENCIA DE OTROS
# [338]-----------------------------------------------------
# sub_text:      ? DEL DIPUTADO DON ANTONIO HERNANDO VERA, DEL GRUPO PARLAMENTARIO
#     SOCIALISTA, QUE FORMULA A LA SEÑORA VICEPRESIDENTA DEL GOBIERNO Y
#     MINISTRA DE LA PRESIDENCIA: ¿COORDINA LA VICEPRESIDENTA LAS ACTUACIONES
#     DEL GOBIERNO PARA GARANTIZAR EL RESPETO A LA INDEPENDENCIA DE OTROS
#     PODERES DEL ESTADO? (Número de expediente 180/001221).
# num_exp: 180/001221
# question: COORDINA LA VICEPRESIDENTA LAS ACTUACIONES
#     DEL GOBIERNO PARA GARANTIZAR EL RESPETO A LA INDEPENDENCIA DE OTROS
#     PODERES DEL ESTADO
# speaker: ANTONIO HERNANDO VERA
# group:
#     SOCIALISTA
# [339]-----------------------------------------------------
# Empty paragraph
# [340]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Pregunta del diputado don Antonio Hernando, del Grupo
# [341]-----------------------------------------------------
# KO     Socialista, dirigida a la señora vicepresidenta del Gobierno y ministra
# [342]-----------------------------------------------------
# KO     de la Presidencia.
# [343]-----------------------------------------------------
# Empty paragraph
# [344]-----------------------------------------------------
# OK 1     El señor HERNANDO VERA: Gracias, señor presidente.
# found: señor HERNANDO VERA:
# groups: señor HERNANDO VERA: ,  HERNANDO ,  VERA
# ...
# OK 9999 :
#     creación de empleo, sino también en resolver problemas sociales que otros
# [4055]-----------------------------------------------------
# OK 9999 :
#     habían dejado allí. Lo empezó a hacer nada más tomar posesión. Una de las
# [4056]-----------------------------------------------------
# OK 9999 :
#     primeras medidas que desde el Ministerio de Economía se tomaron fue el
# [4057]-----------------------------------------------------
# OK 9999 :
#     saneamiento de los balances de bancos y cajas de ahorros. A continuación
# [4058]-----------------------------------------------------
# OK 9999 :
#     se hizo un ejercicio de máxima transparencia auditando la totalidad del
# [4059]-----------------------------------------------------
# OK 9999 :
#     sector financiero para saber exactamente dónde estábamos y cómo
# [4060]-----------------------------------------------------
# OK 9999 :
#     estábamos, con ello se pretendía y se ha conseguido recuperar la
# [4061]-----------------------------------------------------
# OK 9999 :
#     credibilidad y la confianza en el mismo. Recuerdo que aquella medida
# [4062]-----------------------------------------------------
# OK 9999 :
#     recibió críticas airadas por parte de algunos portavoces de la oposición,
# [4063]-----------------------------------------------------
# OK 9999 :
#     que entendieron que al descubrir la realidad del sector lo que se estaba
# [4064]-----------------------------------------------------
# OK 9999 :
#     era poniendo en riesgo la recuperación, y sin embargo no ha sido así: la
# [4065]-----------------------------------------------------
# OK 9999 :
#     transparencia ha mejorado la confianza. Por último, y muy
# [4066]-----------------------------------------------------
# OK 9999 :
#     particularmente, este Gobierno se empeñó en adoptar medidas que ayudaran
# [4067]-----------------------------------------------------
# OK 9999 :
#     a resolver los problemas sociales ?insisto?, medidas como el arbitraje,
# [4068]-----------------------------------------------------
# OK 9999 :
#     que ha sacado a más de 300.000 preferentistas del limbo en el que otros
# [4069]-----------------------------------------------------
# OK 9999 :
#     habían dejado su inversión.
# [4070]-----------------------------------------------------
# Empty paragraph
# [4071]-----------------------------------------------------
# OK 9999 :
#     Estas iniciativas, señorías, se adoptaron no para rescatar a los bancos,
# [4072]-----------------------------------------------------
# OK 9999 :
#     como algunos se empeñan en repetir, sino para evitar que los impositores,
# [4073]-----------------------------------------------------
# OK 9999 :
#     los titulares de cuentas corrientes, los titulares de cartillas de
# [4074]-----------------------------------------------------
# OK 9999 :
#     ahorros, perdieran su dinero; y ahí no estamos hablando de 24.000
# [4075]-----------------------------------------------------
# OK 9999 :
#     millones de Bankia, sino que podríamos estar hablando de más de 200.000,
# [4076]-----------------------------------------------------
# OK 9999 :
#     y eso parece que hay algunos que lo obvian. El objetivo último era y es,
# [4077]-----------------------------------------------------
# OK 9999 :
#     está siendo, recuperar la confianza en nuestro sistema financiero, y se
# [4078]-----------------------------------------------------
# OK 9999 :
#     ha conseguido; además, en el
# [4079]-----------------------------------------------------
# Empty paragraph
# [4080]-----------------------------------------------------
# Empty paragraph
# [4081]-----------------------------------------------------
# Empty paragraph
# [4082]-----------------------------------------------------
# OK 9999 :
#     caso de Bankia se ha conseguido sanear la entidad y se ha conseguido que
# [4083]-----------------------------------------------------
# OK 9999 :
#     tenga beneficios y que esté en condiciones de responder a cualquier
# [4084]-----------------------------------------------------
# OK 9999 :
#     responsabilidad presente y futura, señorías. Gracias a este ejercicio de
# [4085]-----------------------------------------------------
# OK 9999 :
#     saneamiento, Bankia responderá de sus responsabilidades presentes o
# [4086]-----------------------------------------------------
# OK 9999 :
#     futuras.
# [4087]-----------------------------------------------------
# Empty paragraph
# [4088]-----------------------------------------------------
# OK 9999 :
#     Coincido con el señor Coscubiela en que hay cierto adanismo; en realidad
# [4089]-----------------------------------------------------
# OK 9999 :
#     lo que hay es cierto creacionismo. Parece ser que la crisis empezó cuando
# [4090]-----------------------------------------------------
# OK 9999 :
#     llegó este Gobierno, cuando tomó posesión en diciembre de 2011 y parece
# [4091]-----------------------------------------------------
# OK 9999 :
#     que a continuación todo estalló. No, señorías. Hubo otros que antes,
# [4092]-----------------------------------------------------
# OK 9999 :
#     gobernando el Partido Socialista, negaron que hubiera crisis, lo negaron
# [4093]-----------------------------------------------------
# OK 9999 :
#     durante años y no adoptaron medida alguna para poder solucionarlo.
# [4094]-----------------------------------------------------
# OK 9999 :
#     Aseguraba el presidente del Gobierno que nuestro sistema financiero
# [4095]-----------------------------------------------------
# OK 9999 :
#     estaba en la Champions League de la economía mundial. Eso fue titular de
# [4096]-----------------------------------------------------
# OK 9999 :
#     periódicos. Se llegó a llamar antipatriotas a quienes alertaron del
# [4097]-----------------------------------------------------
# OK 9999 :
#     riesgo existente. Se alimentó una burbuja inmobiliaria que llevó a que en
# [4098]-----------------------------------------------------
# OK 9999 :
#     el año 2008 se construyeran en este país más de setecientas mil
# [4099]-----------------------------------------------------
# OK 9999 :
#     viviendas, lo que son más viviendas en ese mismo año que la totalidad de
# [4100]-----------------------------------------------------
# OK 9999 :
#     la producción de viviendas de Francia, Alemania e Inglaterra juntas. Y
# [4101]-----------------------------------------------------
# OK 9999 :
#     también se alimentó una burbuja hipotecaria. Y ante la falta de recursos
# [4102]-----------------------------------------------------
# OK 9999 :
#     financieros, señorías ?lo voy a recordar yo también?, se permitió la
# [4103]-----------------------------------------------------
# OK 9999 :
#     colocación de preferentes a centenares de miles de pequeños ahorradores,
# [4104]-----------------------------------------------------
# OK 9999 :
#     atrapándolos en un auténtico corralito. Esta es la realidad a la que nos
# [4105]-----------------------------------------------------
# OK 9999 :
#     tuvimos que enfrentar, y me sorprende la memoria selectiva de algunos,
# [4106]-----------------------------------------------------
# OK 9999 :
#     que hablan de algunas personas o personalidades y se olvidan, unos por
# [4107]-----------------------------------------------------
# OK 9999 :
#     territorio y otros por orientación política, de Caixa Catalunya y de
# [4108]-----------------------------------------------------
# OK 9999 :
#     Narcís Serra, imputado junto con 52 consejeros. Ha sido este Gobierno el
# [4109]-----------------------------------------------------
# OK 9999 :
#     que ha llevado esos temas a los tribunales para que se investiguen, igual
# [4110]-----------------------------------------------------
# OK 9999 :
#     que las tarjetas black de Bankia. Ha sido el Gobierno en un ejercicio de
# [4111]-----------------------------------------------------
# OK 9999 :
#     transparencia.
# [4112]-----------------------------------------------------
# Empty paragraph
# [4113]-----------------------------------------------------
# OK 9999 :
#     En cuanto a la moción de UPyD ?que no la vamos a apoyar, evidentemente,
# [4114]-----------------------------------------------------
# OK 9999 :
#     señor Anchuelo?, no hace más que reflejar la dualidad, las
# [4115]-----------------------------------------------------
# OK 9999 :
#     contradicciones de esa doble estrategia que UPyD mantiene, una estrategia
# [4116]-----------------------------------------------------
# OK 9999 :
#     procesal y otra estrategia parlamentaria, y por tanto no la vamos a
# [4117]-----------------------------------------------------
# OK 9999 :
#     apoyar. En defensa del interés público, el FROB está personado en el
# [4118]-----------------------------------------------------
# OK 9999 :
#     proceso de Bankia; lo está como perjudicado y ustedes han pedido que sea
# [4119]-----------------------------------------------------
# OK 9999 :
#     apartado del proceso, y estamos convencidos de que si estuviera personado
# [4120]-----------------------------------------------------
# OK 9999 :
#     como acusación particular también habrían pedido que se apartara del
# [4121]-----------------------------------------------------
# OK 9999 :
#     proceso.
# [4122]-----------------------------------------------------
# Empty paragraph
# [4123]-----------------------------------------------------
# OK 9999 :
#     En segundo lugar ?y lo ha aclarado aquí mismo, en esta tribuna
# [4124]-----------------------------------------------------
# OK 9999 :
#     parlamentaria?, pretenden anticipar el resultado de las resoluciones
# [4125]-----------------------------------------------------
# OK 9999 :
#     judiciales. Usted ya ha señalado con nombres y apellidos quiénes son los
# [4126]-----------------------------------------------------
# OK 9999 :
#     responsables y me parece que ese es un ejercicio de justicia popular que
# [4127]-----------------------------------------------------
# OK 9999 :
#     no me parece ?otros portavoces lo han señalado? que sea muy conveniente;
# [4128]-----------------------------------------------------
# OK 9999 :
#     no viene al caso ni de la situación política, ni siquiera de lo que es la
# [4129]-----------------------------------------------------
# OK 9999 :
#     responsabilidad de los tribunales.
# [4130]-----------------------------------------------------
# Empty paragraph
# [4131]-----------------------------------------------------
# OK 9999 :
#     Por último, piden en su moción ?en un momento en el que están pendientes
# [4132]-----------------------------------------------------
# OK 9999 :
#     de dilucidar las posibles responsabilidades de los gestores de Bankia en
# [4133]-----------------------------------------------------
# OK 9999 :
#     su salida a Bolsa? un procedimiento de arbitraje para los accionistas, a
# [4134]-----------------------------------------------------
# OK 9999 :
#     la vez que piden una solución general para los preferentistas. Con ello
# [4135]-----------------------------------------------------
# OK 9999 :
#     lo que vienen a decir es que obtengan o no razón en los tribunales o en
# [4136]-----------------------------------------------------
# OK 9999 :
#     los procedimientos de arbitraje, sean todos los contribuyentes quienes
# [4137]-----------------------------------------------------
# OK 9999 :
#     paguen esas pérdidas. Eso es lo que están diciendo. Si no es en el
# [4138]-----------------------------------------------------
# OK 9999 :
#     tribunal, si no es en el arbitraje, déseles la razón y que los
# [4139]-----------------------------------------------------
# OK 9999 :
#     contribuyentes lo paguen. Eso es lo que dice su moción.
# [4140]-----------------------------------------------------
# Empty paragraph
# [4141]-----------------------------------------------------
# OK 9999 :
#     Señorías de UPyD, les pido que reconozcan ustedes algo. Si no son capaces
# [4142]-----------------------------------------------------
# OK 9999 :
#     de reconocer sus propias contradicciones ?y también se lo digo a algún
# [4143]-----------------------------------------------------
# OK 9999 :
#     otro grupo político?, por lo menos sean capaces de reconocer los frutos
# [4144]-----------------------------------------------------
# OK 9999 :
#     del saneamiento del sistema financiero que ha llevado a cabo este
# [4145]-----------------------------------------------------
# OK 9999 :
#     Gobierno; o sean capaces de reconocer que se ha dado una solución a los
# [4146]-----------------------------------------------------
# OK 9999 :
#     preferentistas; o sean capaces de reconocer lo que reconoce todo el
# [4147]-----------------------------------------------------
# OK 9999 :
#     mundo, que gracias a las políticas del Gobierno del Partido Popular
# [4148]-----------------------------------------------------
# OK 9999 :
#     estamos creando empleo y estamos recuperando la economía. Señorías, si no
# [4149]-----------------------------------------------------
# OK 9999 :
#     son ustedes ?y otros? capaces de reconocer esto, acabarán no
# [4150]-----------------------------------------------------
# OK 9999 :
#     reconociéndose a sí mismos, que es lo que les está pasando.
# [4151]-----------------------------------------------------
# Empty paragraph
# [4152]-----------------------------------------------------
# OK 9999 :
#     Muchísimas gracias, señor presidente. (Aplausos).
# [4153]-----------------------------------------------------
# Empty paragraph
# [4154]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Muchas gracias, señor López Garrido.
# [4155]-----------------------------------------------------
# Empty paragraph
# [4156]-----------------------------------------------------
# KO     Señor Anchuelo, hay una enmienda presentada, ¿qué va a hacer usted con esa
# [4157]-----------------------------------------------------
# KO     enmienda?
# [4158]-----------------------------------------------------
# Empty paragraph
# [4159]-----------------------------------------------------
# OK 1     El señor ANCHUELO CREGO: Agradecemos la enmienda socialista, pero no
# found: señor ANCHUELO CREGO:
# groups: señor ANCHUELO CREGO: ,  ANCHUELO ,  CREGO
# speaker: ANCHUELO CREGO
# speach:  Agradecemos la enmienda socialista, pero no
# [4160]-----------------------------------------------------
# OK 1188 :
#     cambia sustancialmente lo que ya proponemos y preferimos que nuestra
# [4161]-----------------------------------------------------
# OK 1188 :
#     moción se vote en sus propios términos.
# [4162]-----------------------------------------------------
# Empty paragraph
# [4163]-----------------------------------------------------
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):     El señor PRESIDENTE: Muchas gracias, señor Anchuelo. Esa votación se hará
# [4164]-----------------------------------------------------
# KO     mañana jueves.
# [4165]-----------------------------------------------------
# Empty paragraph
# [4166]-----------------------------------------------------
# KO     Se suspende la sesión.
# [4167]-----------------------------------------------------
# Empty paragraph
# [4168]-----------------------------------------------------
# KO     Era la una y veinte minutos de la tarde.
# [4169]-----------------------------------------------------
# Empty paragraph
# [4170]-----------------------------------------------------
# KO     http://www.congreso.es Calle Floridablanca, s/n. 28071 Madrid
# [4171]-----------------------------------------------------
# Empty paragraph
# [4172]-----------------------------------------------------
# KO     D. L.: M-12.580/1961 CONGRESO DE LOS DIPUTADOS Teléf.: 91 390 60 00
# [4173]-----------------------------------------------------
# Empty paragraph
# [4174]-----------------------------------------------------
# KO     Edición electrónica preparada por la Agencia Estatal Boletín Oficial del
# [4175]-----------------------------------------------------
# KO     Estado ? http://boe.es
# [4176]-----------------------------------------------------
# KO     </div>
# [4177]-----------------------------------------------------
# Empty paragraph

# %% [markdown]
# #### Proves de marcatge dels paràgrafs seleccionats al document HTML

# %%
def get_group_color(groups_dict, group_code):
    if group_code:
        for key in groups_dict:
            if group_code == groups_dict[key]['code']:
                return groups_dict[key]['color']
    return 'cyan'

def mark_text_in_HTML(html_page, title_text, selected_text, start_index, group_color):
    text_start_index = html_page.find(selected_text, start_index)
    if text_start_index > 0:
        text_end_index = text_start_index + len(selected_text)
        html_page = html_page[:text_end_index] + tab_mark_end + html_page[text_end_index:]
        html_page = html_page[:text_start_index] + tab_mark_start.format(title_text.encode('utf-8'), group_color) + html_page[text_start_index:]
    else:
        text_end_index = start_index

    return html_page, text_end_index


tab_mark_start = '<span title="{}" style="background-color: {};">'
tab_mark_end = '</span>'

loaded_text_file = load_text_file('docs/20150311_doc.html',"")
# loaded_text_file = load_text_file('docs/19980429_doc.html',"")
loaded_groups_dict = load_dict_json('groups_dict.json')

text_index = loaded_text_file.rfind('PREGUNTAS:')

for num_dialogue in result_dialogue_dict:
    group_color = get_group_color(loaded_groups_dict, result_dialogue_dict[num_dialogue]['group'])
    old_text_index = text_index
    question_text = result_dialogue_dict[num_dialogue]['question'].strip()
    title_text = "group: " + result_dialogue_dict[num_dialogue]['group'].decode('utf-8') + "\n" \
        + "speaker: " + result_dialogue_dict[num_dialogue]['speaker'].decode('utf-8') + "\n" \
        + "num_exp: " + result_dialogue_dict[num_dialogue]['num_exp'].decode('utf-8')
    loaded_text_file, text_index = mark_text_in_HTML(loaded_text_file, title_text, question_text, text_index, group_color)
    if text_index == old_text_index:
        print "text_type:", 'question', "text_index:", text_index, ", num_dialogue:", num_dialogue
        print ">" + question_text + "<"
    for num_inter in result_dialogue_dict[num_dialogue]['intervention_dictonary']:
        paragraphs = result_dialogue_dict[num_dialogue]['intervention_dictonary'][num_inter]['text'].split("\n")
        
        id = result_dialogue_dict[num_dialogue]['intervention_dictonary'][num_inter]['who']
        if id != 9999:
            group = get_member_group_by_id(loaded_diputados_dict, id, 10)
            group_color = get_group_color(loaded_groups_dict, group)
        else:
            group = "<unknown>"
            group_color = get_group_color(loaded_groups_dict, None)
            
        for paragraph in paragraphs:
            old_text_index = text_index
            paragraph_text = paragraph.strip()
            title_text = "num_inter: " + str(num_inter) + "\n" \
                + "group: " + group + "\n" \
                + "who: " + str(result_dialogue_dict[num_dialogue]['intervention_dictonary'][num_inter]['who'])
            loaded_text_file, text_index = mark_text_in_HTML(loaded_text_file, title_text, paragraph_text, text_index, group_color)
            if text_index == old_text_index:
                print "text_type:", 'intervention', "text_index:", text_index, ", num_dialogue:", num_dialogue, "num_inter:", num_inter
                print ">" + paragraph_text + "<"

print "Saving 'docs/20150311_doc_marked.html'..."
save_text_file(loaded_text_file, 'docs/20150311_doc_marked.html',"")
# save_text_file(loaded_text_file, 'docs/19980429_doc_marked.html',"")
# Out:
# Saving 'docs/20150311_doc_marked.html'...

# %% [markdown]
# #### Proves d'eliminació d'elements HTML amb expressions regulars

# %%
import re

text_html = '''
    <br /><br />El señor BOSCH I PASCUAL: ¿Considera el Gobierno adecuados para erradicar
    la pobreza infantil los 2,25 euros por niño pobre que se dedican en
    Cataluña mediante el fondo correspondiente?

    <br /><br />Muchas gracias.

    <br /><br /><br /><p style="text-align:center"><a name="(Página6)"><b>Página
    6</b></a></p><br />

    <br /><br />El señor PRESIDENTE: Muchas gracias, señor Bosch.

    <br /><br />Señor presidente.

    <br /><br />El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey): Muchas gracias.
    
    
    
    <br /><br />El señor PRESIDENTE DEL GOBIERNO (Aznar López): Señor diputado, yo vengo
    aquí todos los miércoles y SS. SS. pueden preguntarme sobre cualquier
    aspecto de mi gestión política con toda tranquilidad,

    <br /><br /><center><a name="(Página8259)"><b>Página 8259</b></a></center>

    <br /><br />pero renunciar a ello y dedicarse a amparar o dar cobertura a
    afirmaciones injuriosas o caer directamente en afirmaciones que pueden    
'''

for m in re.finditer('ll', text):
    print('ll found', m.start(), m.end())


text_html = re.sub(r'<p.*?/p>', '', text_html, flags=re.DOTALL)
text_html = re.sub(r'<center>.*?</center>', '', text_html, flags=re.DOTALL)

print text_html
# Out:
#     <br /><br />El señor BOSCH I PASCUAL: ¿Considera el Gobierno adecuados para erradicar
#     la pobreza infantil los 2,25 euros por niño pobre que se dedican en
#     Cataluña mediante el fondo correspondiente?
#
#     <br /><br />Muchas gracias.
#
#     <br /><br /><br /><br />
#
#     <br /><br />El señor PRESIDENTE: Muchas gracias, señor Bosch.
#
#     <br /><br />Señor presidente.
#
#     <br /><br />El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey): Muchas gracias.
#
#
#
#     <br /><br />El señor PRESIDENTE DEL GOBIERNO (Aznar López): Señor diputado, yo vengo
#     aquí todos los miércoles y SS. SS. pueden preguntarme sobre cualquier
#     aspecto de mi gestión política con toda tranquilidad,
#
#     <br /><br />
#
#     <br /><br />pero renunciar a ello y dedicarse a amparar o dar cobertura a
#     afirmaciones injuriosas o caer directamente en afirmaciones que pueden
