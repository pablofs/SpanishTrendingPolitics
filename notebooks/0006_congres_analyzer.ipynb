# %% [markdown]
# # Analyzer

# %% [markdown]
# ### Mètodes i utilitats

# %%
# http://stackoverflow.com/questions/7100125/storing-python-dictionaries

import json
from bson import json_util
import yaml

# http://api.mongodb.org/python/1.10.1/api/bson/json_util.html
# Mètodes per grabar y carregar fitxers en format json
def save_dict_json(dict, filename):
    with open(filename, 'wb') as fp:
        json.dump(dict, fp, default=json_util.default)

def load_dict_json(filename):
    with open(filename, 'rb') as fp:
        return json.load(fp, object_hook=json_util.object_hook)

# http://stackoverflow.com/questions/956867/how-to-get-string-objects-instead-of-unicode-ones-from-json-in-python
def load_dict_yaml(filename):
    with open(filename, 'rb') as fp:
        return yaml.load(fp)
    
# Mètode per grabar un fitxer de texte
def save_text_file(text, file_name, encoding = 'utf-8'):
    with open(file_name, "w") as text_file:
        if encoding:
            text_file.write(text.encode(encoding))
        else:
            text_file.write(text)

import ast
# Mètode per grabar un fitxer de texte
def save_list_text_file(text_list, file_name):
    print "Saving:", file_name, "lines:", len(text_list)
    with open(file_name, "w") as text_file:
        for item in text_list:
            text_file.write((r''.join(ast.literal_eval(item))+"\n").encode('utf-8'))
            # text_file.write(item+"\n")
        
# Mètode per carregar un fitxer de texte
def load_text_file(file_name, encoding = 'utf-8'):
    with open(file_name, "r") as text_file:
        if encoding:
            return text_file.read().decode(encoding)
        else:
            return text_file.read()
        
# Mètode per eliminar caracters incorrectes als noms de fitxers (potser millor utilitzar: https://pypi.python.org/pypi/goldfinch/0.4)
invalid_filename_chars_windows = '\/:*?"<>|'
def del_invalid_chars(value, deletechars):
    for c in deletechars:
        value = value.replace(c,'')
    return value;

import datetime

# Mètode per cambiar de format de data de format_1 a format_2
def format_date(strFecha, format_1, format_2):
    dtDate = datetime.datetime.strptime(strFecha, format_1)
    return dtDate.strftime(format_2)

# Mètode que ens diu si una data cau en dimecres
# https://docs.python.org/2/library/datetime.html#datetime.date.weekday
def isWednesday(my_date):
    if my_date.date().weekday() == 2:  # 0: Monday, 1: Tuesday, 2: Wednesday, ...
        return True
    else:
        return False
    
# print "24/03/2015", "isWednesday:", isWednesday("24/03/2015")
# print "11/03/2015", "isWednesday:", isWednesday("11/03/2015")

# %%
def get_text_between( s, first, last, include_limits = False, first_ocurrences = True, case_sensitive = True ):
    
    if not case_sensitive:
        ncs_s, ncs_first, ncs_last = s.lower(), first.lower(), last.lower()
    else:
        ncs_s, ncs_first, ncs_last = s, first, last
    
    try:
        if first_ocurrences:
            if include_limits:
                start = ncs_s.index( ncs_first )
                end = ncs_s.rindex( ncs_last, start ) + len(ncs_last)
            else:
                start = ncs_s.index( ncs_first ) + len( ncs_first )
                end = ncs_s.rindex( ncs_last, start ) 
        else: 
            # look for last ocurrences of first and last
            if include_limits:
                start = ncs_s.rindex( ncs_first )
                end = ncs_s.index( ncs_last ) + len(ncs_last)
            else:
                start = ncs_s.rindex( ncs_first ) + len( ncs_first )
                end = ncs_s.index( ncs_last ) 
            
        return s[start:end]            
    except ValueError:
        return ""
    
def remove_text_between( s, first, last, include_limits = False ):
    try:
        if include_limits:
            start = s.index( first ) + len( first )
            end = s.index( last, start ) 
            return s[:start] + s[end:] 
        else:
            start = s.index( first )
            end = s.index( last, start ) + len(last)
            return s[:start] + s[end:]
    except ValueError:
        return ""
    
def remove_spaces_and_newline(s):
    return re.sub(r'\s+', ' ', s.replace('\n',''))

# %%
# de 0010_logging.ipynb
# http://stackoverflow.com/questions/16571150/how-to-capture-stdout-output-from-a-python-function-call
# http://stackoverflow.com/questions/28660700/stringio-getvalue-raising-unicodedecodeerror-when-printing-traceback

# https://docs.python.org/2/library/stringio.html#module-cStringIO
# cStringIO is faster than StringIO but:
# "Unlike the StringIO module, this module is not able to accept Unicode strings that cannot be encoded as plain ASCII strings.
import cStringIO
import traceback
import sys

class Capturing(list):
    def __enter__(self):
        # Save the stdout original value
        self._stdout = sys.stdout
        # Redirect the stdout to StringIO()
        sys.stdout = self._stringio = cStringIO.StringIO()
        return self
    def __exit__(self, *args):
        try:
            self.extend(self._stringio.getvalue().splitlines())
        except UnicodeDecodeError as e:
            print "[From Capturing]-------------------------------------------"
            print traceback.format_exc()
        finally:
            # Empty the buffer
            self._stringio.truncate(0)
            # Return to stdout original value
            sys.stdout = self._stdout

import ast
# Mètode per grabar un fitxer de texte
def save_list_text_file(text_list, file_name):
    print "Saving:", file_name, "lines:", len(text_list)
    with open(file_name, "w") as text_file:
        for item in text_list:
            text_file.write((r''.join(ast.literal_eval(item))+"\n").encode('utf-8'))
            # text_file.write(item+"\n")

def rprint(*obj):
    print u' '.join([repr('%s'%x) for x in obj])

# %%
# Reset to original sys.__stdout__
# sys.stdout = sys.__stdout__

#
with Capturing() as output:
    rprint(u"Hola...  pruebas y más pruebas")
    rprint(u'unicode')
    rprint(u'áéíóúÁÉÍÓÚñÑ')
    rprint(u"Adios.")

# Log output
print "Prueba"
print 'output:\n', output

save_list_text_file(output, "log/prueba.txt")
# Out:
# Prueba
# output:
# ["u'Hola...  pruebas y m\\xe1s pruebas'", "u'unicode'", "u'\\xe1\\xe9\\xed\\xf3\\xfa\\xc1\\xc9\\xcd\\xd3\\xda\\xf1\\xd1'", "u'Adios.'"]
# Saving: log/prueba.txt lines: 4

# %% [markdown]
# ## Scraping de la web de documents del Congrés

# %% [markdown]
# #### Mètodes per cercar els diputats al diccionari.

# %%
import unicodedata
import sys

# Mètode que treu els accents a un string (en format unicode)
def remove_accents(input_str):
    nkfd_form = unicodedata.normalize('NFKD', input_str)
    return u"".join([c for c in nkfd_form if not unicodedata.combining(c)])

#
def get_group(member_group_dict, legislature):
    if legislature:
        for key in member_group_dict:
            if legislature in member_group_dict[key]:
                return key
    else:
        legislature = 0
        for key in member_group_dict:
            if legislature < max(member_group_dict[key]):
                legislature = max(member_group_dict[key])
        return get_group(member_group_dict, legislature)

#
def get_member_group_by_id(diputados_dict, id, legislature):
    if len(diputados_dict[id]['group']) == 1:
        return diputados_dict[id]['group'].keys()[0]
    else:
        return get_group(loaded_diputados_dict[id]['group'], legislature)

def search_diputado_in_dict(my_dict, dip_surname, dip_name = "", verbose=False):
    result = []
    
    if dip_name != "":
        for key in my_dict:
            if remove_accents(dip_surname.upper()) == my_dict[key]['surname'] and remove_accents(dip_name.upper()) == my_dict[key]['name']:
                result.append(key)            
    else:
        for key in my_dict:
            if remove_accents(dip_surname.upper()) == my_dict[key]['surname']:
                result.append(key)

    if len(result) == 0:
        if verbose:
            print "ERROR en search_diputado_in_dict. No s'ha trobat:", dip_surname, ",", dip_name
        return None
    elif len(result) == 1:
        return result[0]
    else: # len(result) > 1:
        if verbose:
            str_result = ""
            for i in result:
                str_result += str(i) + ": " + my_dict[i]['surname'] + ", " + my_dict[i]['name'] + "\n"
            print "ERROR en search_diputado_in_dict. S'ha trobat més d'un resultat:\n", str_result.encode('utf-8')
        return result[0]
        
''' '''
loaded_diputados_dict = load_dict_json('diputados_dict.json')

s = u"Aznar López"
n = u"José María"
id = search_diputado_in_dict(loaded_diputados_dict,s,n, True)
if id:
    print id, ":", loaded_diputados_dict[id]
    print "group:", get_member_group_by_id(loaded_diputados_dict, id, 10)
else:
    print "ERROR en search_diputado_in_dict. No s'ha trobat:", s, n
# Out:
# 36 : {u'surname': u'AZNAR LOPEZ', u'group': {u'GP': [5, 6, 7]}, u'r_surname': u'Aznar L\xf3pez', u'r_name': u'Jos\xe9 Mar\xeda', u'name': u'JOSE MARIA'}
# group: GP

# %% [markdown]
# ### Base de dades del Congrés

# %% [markdown]
# #### Obrir conexió a la BD 'congres'

# %%
import pymongo

# Create the connection to MongoDB
try:
    connection=pymongo.MongoClient()
    print "Connection to Mongo Daemon successful!!!"
except pymongo.errors.ConnectionFailure, e:
    print "Could not connect to MongoDB: %s" % e
    
# Obtenim la BD del Congrés
db = connection['congres']
#
print "Collections:", db.collection_names()
# Out:
# Connection to Mongo Daemon successful!!!
# Collections: [u'system.indexes', u'legislatures', u'all_document', u'document', u'congres_groups', u'congres_members']

# %% [markdown]
# Check the database status
# http://127.0.0.1:28017/

# %% [markdown]
# #### Tancar la conexió a la BD

# %%
connection.close()

# %% [markdown]
# #### Cerca de legislatures per data

# %%
def get_legislature_DB(legislatures_col, d_doc_date):
    result = legislatures_col.find({'start':{'$lte':d_doc_date}, 'end':{'$gte':d_doc_date}})
    
    if result.count() == 1:
        return result[0]['_id']
    else:
        print "ERROR, get_legislature: date out of range:", doc_date
        return -1

# Test
legislatures_collection = db['legislatures']
    
my_date = datetime.datetime.strptime("03/06/2007", "%d/%m/%Y")
print "my_date:", my_date, ", legislature:", get_legislature_DB(legislatures_collection, my_date)
my_date = datetime.datetime.strptime("03/06/2012", "%d/%m/%Y")
print "my_date:", my_date, ", legislature:", get_legislature_DB(legislatures_collection, my_date)
my_date = datetime.datetime.strptime("03/06/1996", "%d/%m/%Y")
print "my_date:", my_date, ", legislature:", get_legislature_DB(legislatures_collection, my_date)
# Out:
# my_date: 2007-06-03 00:00:00 , legislature: 8
# my_date: 2012-06-03 00:00:00 , legislature: 10
# my_date: 1996-06-03 00:00:00 , legislature: 6

# %% [markdown]
# #### Cerca de diputats a la BD

# %%
# Metode per buscar un diputat a la BD
# TODO: canviar la query per afegir el parametre 'legislature'
def search_diputado_in_BD(collection, s, n="", type='exact', legislature=0, verbose=False):
    if n=="":
        if type=='exact':
            result = collection.find({'surname': remove_accents(s.upper())})
        else:
            # search 'like'
            result = collection.find({'surname': {"$regex":remove_accents(s.upper())}})
    else:
        if type=='exact':
            result = collection.find({'surname': remove_accents(s.upper()), "name": remove_accents(n.upper())})
        else:
            # search 'like'
            result = collection.find({'surname': {"$regex":remove_accents(s.upper())}, "name": {"$regex":remove_accents(n.upper())}})
            
    if result.count() == 0:
        if verbose:
            print "WARN en search_diputado_in_BD_like: No s'han trobat resultats per:", s, "; ", n
        return None
    elif result.count() == 1:
        return result[0]
    else: # result.count() > 1:
        if verbose:
            print "WARN en search_diputado_in_BD_like: S'ha trobat més d'un resultat per: ", s, "; ", n
        if legislature > 0:
            f_result = []
            for result_obj in result:
                if verbose:
                    print "\t", result_obj
                found = False
                for group in result_obj['group']:
                    if legislature in result_obj['group'][group]:
                        found = True
                if found:
                    f_result.append(result_obj)

            if len(f_result) == 0:
                if verbose:
                    print "WARN en search_diputado_in_BD_like: No s'han trobat resultats per:", s, "; ", n, ", legislature:", legislature
                result.rewind()
                return result[0]
            elif len(f_result) == 1:
                return f_result[0]
            else:
                if verbose:
                    print "WARN en search_diputado_in_BD_like: S'ha trobat més d'un resultat per: ", s, "; ", n
                    for f_result_obj in f_result:
                        print "\t", f_result_obj
                return f_result[0]
        else:
            if verbose:
                print "WARN en search_diputado_in_BD_like: S'ha trobat més d'un resultat per: ", s, "; ", n
                for result_obj in result:
                    print "\t", result_obj
                # http://stackoverflow.com/questions/9872891/is-it-possible-to-iterate-a-mongo-cursor-twice
                result.rewind()
            return result[0]

# %%
def get_group(group_dict, legislature):
    for key in group_dict:
        if legislature in group_dict[key]:
            return key
    return group_dict.keys()[0]

''' '''
#
congres_members_collection = db['congres_members']

# El paràmetre de recerca en unicode
s = u"Llamazares Trigo"
n = u"Gaspar"
dip = search_diputado_in_BD(congres_members_collection,s,n)
if dip:
    print dip
    if len(dip['group']) == 1:
        print "Group:", dip['group'].keys()[0]
    else:
        print "Groups:", dip['group']
        group = get_group(dip['group'], 10)
        if group:
            print s, ",", n, "-->", group
else:
    print "ERROR en search_diputado_in_BD. No s'ha trobat:", s, n

s = u"Fernández Díaz"
dip = search_diputado_in_BD(congres_members_collection, s, legislature=10, verbose=True)
if dip:
    print dip
    if len(dip['group']) == 1:
        print "Group:", dip['group'].keys()[0]
    else:
        print "Groups:", dip['group']
        group = get_group(dip['group'], 10)
        if group:
            print s, ",", n, "-->", group
else:
    print "ERROR en search_diputado_in_BD. No s'ha trobat:", s
    
s = u"ERKOREKA GERVASIO"
dip = search_diputado_in_BD(congres_members_collection, s, legislature=10, verbose=True)
if dip:
    print dip
    if len(dip['group']) == 1:
        print "Group:", dip['group'].keys()[0]
    else:
        print "Groups:", dip['group']
        group = get_group(dip['group'], 10)
        if group:
            print s, ",", n, "-->", group
else:
    print "ERROR en search_diputado_in_BD. No s'ha trobat:", s
# Out:
# {u'group': {u'GIU': [7], u'GIP': [10], u'GER-IU-ICV': [9], u'GIU-ICV': [8]}, u'name': u'GASPAR', u'r_name': u'Gaspar', u'surname': u'LLAMAZARES TRIGO', u'_id': ObjectId('552594aa7c4c6704fc26710f'), u'r_surname': u'Llamazares Trigo'}
# Groups: {u'GIU': [7], u'GIP': [10], u'GER-IU-ICV': [9], u'GIU-ICV': [8]}
# Llamazares Trigo , Gaspar --> GIP
# WARN en search_diputado_in_BD_like: S'ha trobat més d'un resultat per:  Fernández Díaz ;
# 	{u'group': {u'GP': [5]}, u'name': u'ELVIRA', u'r_name': u'Elvira', u'surname': u'FERNANDEZ DIAZ', u'_id': ObjectId('552594ab7c4c6704fc267576'), u'r_surname': u'Fern\xe1ndez D\xedaz'}
# 	{u'group': {u'GP': [5, 6, 7, 8, 9, 10]}, u'name': u'JORGE', u'r_name': u'Jorge', u'surname': u'FERNANDEZ DIAZ', u'_id': ObjectId('552594ab7c4c6704fc267577'), u'r_surname': u'Fern\xe1ndez D\xedaz'}
# {u'group': {u'GP': [5, 6, 7, 8, 9, 10]}, u'name': u'JORGE', u'r_name': u'Jorge', u'surname': u'FERNANDEZ DIAZ', u'_id': ObjectId('552594ab7c4c6704fc267577'), u'r_surname': u'Fern\xe1ndez D\xedaz'}
# Group: GP
# {u'group': {u'GV (EAJ-PNV)': [8, 9, 10], u'GV-PNV': [7]}, u'name': u'JOSU INAKI', u'r_name': u'Josu I\xf1aki', u'surname': u'ERKOREKA GERVASIO', u'_id': ObjectId('552594ab7c4c6704fc267501'), u'r_surname': u'Erkoreka Gervasio'}
# Groups: {u'GV (EAJ-PNV)': [8, 9, 10], u'GV-PNV': [7]}
# ERKOREKA GERVASIO , Gaspar --> GV (EAJ-PNV)

# %%
conjunctions = ['I', 'Y', 'DEL', 'DE']

def get_surname_name_from_string(speaker):
    speaker_list = speaker.upper().split()

    if len(speaker_list) > 1:
        if speaker_list[-2] in conjunctions:
            if len(speaker_list) > 4:
                surname = speaker_list[-3] + " " + speaker_list[-2] + " " + speaker_list[-1]
                name = speaker_list[0]
            else:
                surname = speaker_list[-3] + " " + speaker_list[-2] + " " + speaker_list[-1]
                name = speaker_list[-4]
        else:
            if len(speaker_list) > 2:
                if speaker_list[-3] == 'DE':
                    if len(speaker_list) > 4:
                        surname = speaker_list[-2] + " " + speaker_list[-1]
                        name = speaker_list[0]
                    else:
                        surname = speaker_list[-2] + " " + speaker_list[-1]
                        name = speaker_list[-4] + " DE"
                else:
                    if len(speaker_list) > 3:
                        surname = speaker_list[-2] + " " + speaker_list[-1]
                        name = speaker_list[0]
                    else:
                        surname = speaker_list[-2] + " " + speaker_list[-1]
                        name = speaker_list[-3]
            else: # len(speaker_list) == 2:
                surname = speaker_list[1]
                name = speaker_list[0]
    elif len(speaker_list) == 1:
        surname = speaker_list[0]
        name = ""
    else: # len(speaker_list) == 0:
        surname = ""
        name = ""

    return surname, name


def search_diputado_from_string(congres_members_col, speaker, legislature, verbose = False):
    surname, name = get_surname_name_from_string(speaker)
    return search_diputado_in_BD(congres_members_col, surname, name, type='like', legislature=legislature, verbose=verbose)

# %%
# Test del mètode search_diputado_from_string
#
congres_members_collection = db['congres_members']

for congres_member in congres_members_collection.find():
    ns = congres_member['r_name'] + " " + congres_member['r_surname']
    dip = search_diputado_from_string(congres_members_collection, ns, legislature=10, verbose=True)
    if not dip:
        print "ERROR: no results."
        print "ns:", ns, "-->", congres_member['r_name'] + " || " + congres_member['r_surname']
        print surname, ";", name
        print "--------------------------------------------"
# Out:
# WARN en search_diputado_in_BD_like: S'ha trobat més d'un resultat per:
}
# 	{u'group': {u'GP': [6, 7]}, u'name': u'ANA MARIA', u'r_name': u'Ana Mar\xeda', u'surname': u'TORME PARDO', u'_id': ObjectId('552594ab7c4c6704fc267544'), u'r_surname': u'Torme Pardo'}
# WARN en search_diputado_in_BD_like: No s'han trobat resultats per: TORME PARDO ;  ANA , legislature: 10
# WARN en search_diputado_in_BD_like: S'ha trobat més d'un resultat per:  SÁNCHEZ DÍAZ ;  MARÍA
# 	{u'group': {u'GS': [7, 8, 9, 10]}, u'name': u'MARIA CARMEN', u'r_name': u'Mar\xeda Carmen', u'surname': u'SANCHEZ DIAZ', u'_id': ObjectId('552594aa7c4c6704fc267404'), u'r_surname': u'S\xe1nchez D\xedaz'}
# 	{u'group': {u'GS': [5]}, u'name': u'MARIA DOLORES', u'r_name': u'Mar\xeda Dolores', u'surname': u'SANCHEZ DIAZ', u'_id': ObjectId('552594ab7c4c6704fc2675a7'), u'r_surname': u'S\xe1nchez D\xedaz'}
# WARN en search_diputado_in_BD_like: S'ha trobat més d'un resultat per:  TORME PARDO ;  ANA
# 	{u'group': {u'GP': [8, 9]}, u'name': u'ANA', u'r_name': u'Ana', u'surname': u'TORME PARDO', u'_id': ObjectId('552594ab7c4c6704fc2675c9'), u'r_surname': u'Torme Pardo'}
# 	{u'group': {u'GP': [6, 7]}, u'name': u'ANA MARIA', u'r_name': u'Ana Mar\xeda', u'surname': u'TORME PARDO', u'_id': ObjectId('552594ab7c4c6704fc267544'), u'r_surname': u'Torme Pardo'}
# WARN en search_diputado_in_BD_like: No s'han trobat resultats per: TORME PARDO ;  ANA , legislature: 10
# WARN en search_diputado_in_BD_like: S'ha trobat més d'un resultat per:  AGIRRETXEA URRESTI ;  JOSEBA
# 	{u'group': {u'GV (EAJ-PNV)': [9]}, u'name': u'JOSEBA', u'r_name': u'Joseba', u'surname': u'AGIRRETXEA URRESTI', u'_id': ObjectId('552594aa7c4c6704fc267289'), u'r_surname': u'Agirretxea Urresti'}
# 	{u'group': {u'GV (EAJ-PNV)': [10]}, u'name': u'JOSEBA ANDONI', u'r_name': u'Joseba Andoni', u'surname': u'AGIRRETXEA URRESTI', u'_id': ObjectId('552594ab7c4c6704fc2675e7'), u'r_surname': u'Agirretxea Urresti'}

# %%
# Test 2: errors de transcripció. P.e. al doc 19980617_doc.html: "JERÓNIMO SAAVEDRAACEVEDO" hauria de ser "JERÓNIMO SAAVEDRA ACEVEDO"
#
congres_members_collection = db['congres_members']
legislatures_collection = db['legislatures']

my_date = datetime.datetime.strptime("17/06/1998", "%d/%m/%Y")
legislature = get_legislature_DB(legislatures_collection, my_date)
print search_diputado_from_string(congres_members_collection, u"JER\xd3NIMO SAAVEDRAACEVEDO", legislature, verbose = True)

my_date = datetime.datetime.strptime("20/12/2000", "%d/%m/%Y")
legislature = get_legislature_DB(legislatures_collection, my_date)
print search_diputado_from_string(congres_members_collection, u"MARIAASUNCIÓN OLTRA TORRES", legislature, verbose = True)
# Out:
# WARN en search_diputado_in_BD_like: No s'han trobat resultats per: SAAVEDRAACEVEDO ;  JERÓNIMO
# None
# WARN en search_diputado_in_BD_like: No s'han trobat resultats per: OLTRA TORRES ;  MARIAASUNCIÓN
# None

# %% [markdown]
# La cerca de diputats no funciona amb errors de transcripció. Provarem amb una cerca fent servir 'String distance algorithms', per exemple, la distància de Levenshtein:

# %%
# http://es.wikipedia.org/wiki/Distancia_de_Levenshtein#Python
def distance_Levenshtein(str1, str2):
    n = len(str1)
    m = len(str2)
    d=dict()
    for i in range(len(str1)+1):
        d[i]=dict()
        d[i][0]=i
    for i in range(len(str2)+1):
        d[0][i] = i
    for i in range(1, len(str1)+1):
        for j in range(1, len(str2)+1):
            d[i][j] = min(d[i][j-1]+1, d[i-1][j]+1, d[i-1][j-1]+(not str1[i-1] == str2[j-1]))
    # return d[n][m]
    return 1.0 - float(d[n][m])/max(n,m)

# http://en.wikipedia.org/wiki/S%C3%B8rensen%E2%80%93Dice_coefficient
# http://en.wikibooks.org/wiki/Algorithm_Implementation/Strings/Dice's_coefficient#Python
 
""" duplicate bigrams in a word should be counted distinctly
(per discussion), otherwise 'AA' and 'AAAA' would have a 
dice coefficient of 1...
"""
def dice_coefficient(a,b):
    if not len(a) or not len(b): return 0.0
    """ quick case for true duplicates """
    if a == b: return 1.0
    """ if a != b, and a or b are single chars, then they can't possibly match """
    if len(a) == 1 or len(b) == 1: return 0.0
 
    """ use python list comprehension, preferred over list.append() """
    a_bigram_list = [a[i:i+2] for i in range(len(a)-1)]
    b_bigram_list = [b[i:i+2] for i in range(len(b)-1)]
 
    a_bigram_list.sort()
    b_bigram_list.sort()
 
    # assignments to save function calls
    lena = len(a_bigram_list)
    lenb = len(b_bigram_list)
    # initialize match counters
    matches = i = j = 0
    while (i < lena and j < lenb):
        if a_bigram_list[i] == b_bigram_list[j]:
            matches += 2
            i += 1
            j += 1
        elif a_bigram_list[i] < b_bigram_list[j]:
            i += 1
        else:
            j += 1
 
    score = float(matches)/float(lena + lenb)
    return score

def search_diputado_in_BD_with_string_metric(collection, ns="", s="", n="", metric='distance_Levenshtein', verbose=False):
    
    dip_col = collection.find()
    
    cleaned_ns = ""
    if ns:
        cleaned_ns = remove_accents(ns.upper())
    elif n=="":
        cleaned_ns = remove_accents(s.upper())
    else:
        cleaned_ns = remove_accents(n.upper()) + ' ' + remove_accents(s.upper())
    
    result = [0,None]
    if cleaned_ns:
        if dip_col.count() > 0:
            for dip in dip_col:
                if ns or not n:
                    dip_ns = dip['name'] + ' ' + dip['surname']
                else:
                    dip_ns = dip['surname']

                if metric == 'dice_coefficient':
                    dist = dice_coefficient(cleaned_ns, dip_ns)
                else:
                    dist = distance_Levenshtein(cleaned_ns, dip_ns)

                if dist > result[0]:
                    result[0] = dist
                    result[1] = dip
                    # print result[0], ":", result[1]

    if verbose:
        print result[0], ":", result[1]

    return result[1]

# %%
# Test

#
congres_members_collection = db['congres_members']
legislatures_collection = db['legislatures']

my_date = datetime.datetime.strptime("17/06/1998", "%d/%m/%Y")
legislature = get_legislature_DB(legislatures_collection, my_date)

speaker = u"JER\xd3NIMO SAAVEDRAACEVEDO"
print remove_accents(speaker)
surname, name = get_surname_name_from_string(speaker)
print speaker, "-->", surname, ";", name
print search_diputado_in_BD_with_string_metric(congres_members_collection, ns=speaker, verbose = True)
print "----------------------------------------"
print search_diputado_in_BD_with_string_metric(congres_members_collection, s=surname, verbose = True)
print "----------------------------------------"
print search_diputado_in_BD_with_string_metric(congres_members_collection, s=surname, n=name, verbose = True)
print "----------------------------------------"
print search_diputado_in_BD_with_string_metric(congres_members_collection, ns=speaker, metric='dice_coefficient', verbose = True)
print "----------------------------------------"
print search_diputado_in_BD_with_string_metric(congres_members_collection, s=surname, metric='dice_coefficient', verbose = True)
print "----------------------------------------"
print search_diputado_in_BD_with_string_metric(congres_members_collection, s=surname, n=name, metric='dice_coefficient', verbose = True)
print "\n"
speaker = u"JOAN RIDAO 1 MARTÍN" # Trobat a 20101110_doc.html
surname, name = get_surname_name_from_string(speaker)
print speaker, "-->", surname, ";", name
print search_diputado_in_BD_with_string_metric(congres_members_collection, ns=speaker, verbose = True)
print "----------------------------------------"
print search_diputado_in_BD_with_string_metric(congres_members_collection, s=surname, verbose = True)
print "----------------------------------------"
print search_diputado_in_BD_with_string_metric(congres_members_collection, s=surname, n=name, verbose = True)
print "----------------------------------------"
print search_diputado_in_BD_with_string_metric(congres_members_collection, ns=speaker, metric='dice_coefficient', verbose = True)
print "----------------------------------------"
print search_diputado_in_BD_with_string_metric(congres_members_collection, s=surname, metric='dice_coefficient', verbose = True)
print "----------------------------------------"
print search_diputado_in_BD_with_string_metric(congres_members_collection, s=surname, n=name, metric='dice_coefficient', verbose = True)
print "\n"
speaker = u"MARIAASUNCIÓN OLTRA TORRES" # Trobat a 20001220_doc.html
surname, name = get_surname_name_from_string(speaker)
print speaker, "-->", surname, ";", name
print search_diputado_in_BD_with_string_metric(congres_members_collection, ns=speaker, verbose = True)
print "----------------------------------------"
print search_diputado_in_BD_with_string_metric(congres_members_collection, s=surname, verbose = True)
print "----------------------------------------"
print search_diputado_in_BD_with_string_metric(congres_members_collection, s=surname, n=name, verbose = True)
print "----------------------------------------"
print search_diputado_in_BD_with_string_metric(congres_members_collection, ns=speaker, metric='dice_coefficient', verbose = True)
print "----------------------------------------"
print search_diputado_in_BD_with_string_metric(congres_members_collection, s=surname, metric='dice_coefficient', verbose = True)
print "----------------------------------------"
print search_diputado_in_BD_with_string_metric(congres_members_collection, s=surname, n=name, metric='dice_coefficient', verbose = True)
# Out:
# JERONIMO SAAVEDRAACEVEDO
# JERÓNIMO SAAVEDRAACEVEDO --> SAAVEDRAACEVEDO ; JERÓNIMO
# 0.96 : {u'group': {u'GS': [6]}, u'name': u'JERONIMO', u'r_name': u'Jer\xf3nimo', u'surname': u'SAAVEDRA ACEVEDO', u'_id': ObjectId('552594ab7c4c6704fc2675dd'), u'r_surname': u'Saavedra Acevedo'}
# {u'group': {u'GS': [6]}, u'name': u'JERONIMO', u'r_name': u'Jer\xf3nimo', u'surname': u'SAAVEDRA ACEVEDO', u'_id': ObjectId('552594ab7c4c6704fc2675dd'), u'r_surname': u'Saavedra Acevedo'}
# ----------------------------------------
# 0.6 : {u'group': {u'GS': [6]}, u'name': u'JERONIMO', u'r_name': u'Jer\xf3nimo', u'surname': u'SAAVEDRA ACEVEDO', u'_id': ObjectId('552594ab7c4c6704fc2675dd'), u'r_surname': u'Saavedra Acevedo'}
# {u'group': {u'GS': [6]}, u'name': u'JERONIMO', u'r_name': u'Jer\xf3nimo', u'surname': u'SAAVEDRA ACEVEDO', u'_id': ObjectId('552594ab7c4c6704fc2675dd'), u'r_surname': u'Saavedra Acevedo'}
# ----------------------------------------
# 0.583333333333 : {u'group': {u'GS': [6]}, u'name': u'JERONIMO', u'r_name': u'Jer\xf3nimo', u'surname': u'SAAVEDRA ACEVEDO', u'_id': ObjectId('552594ab7c4c6704fc2675dd'), u'r_surname': u'Saavedra Acevedo'}
# {u'group': {u'GS': [6]}, u'name': u'JERONIMO', u'r_name': u'Jer\xf3nimo', u'surname': u'SAAVEDRA ACEVEDO', u'_id': ObjectId('552594ab7c4c6704fc2675dd'), u'r_surname': u'Saavedra Acevedo'}
# ----------------------------------------
# 0.936170212766 : {u'group': {u'GS': [6]}, u'name': u'JERONIMO', u'r_name': u'Jer\xf3nimo', u'surname': u'SAAVEDRA ACEVEDO', u'_id': ObjectId('552594ab7c4c6704fc2675dd'), u'r_surname': u'Saavedra Acevedo'}
# {u'group': {u'GS': [6]}, u'name': u'JERONIMO', u'r_name': u'Jer\xf3nimo', u'surname': u'SAAVEDRA ACEVEDO', u'_id': ObjectId('552594ab7c4c6704fc2675dd'), u'r_surname': u'Saavedra Acevedo'}
# ----------------------------------------
# 0.684210526316 : {u'group': {u'GS': [6]}, u'name': u'JERONIMO', u'r_name': u'Jer\xf3nimo', u'surname': u'SAAVEDRA ACEVEDO', u'_id': ObjectId('552594ab7c4c6704fc2675dd'), u'r_surname': u'Saavedra Acevedo'}
# {u'group': {u'GS': [6]}, u'name': u'JERONIMO', u'r_name': u'Jer\xf3nimo', u'surname': u'SAAVEDRA ACEVEDO', u'_id': ObjectId('552594ab7c4c6704fc2675dd'), u'r_surname': u'Saavedra Acevedo'}
# ----------------------------------------
# 0.684210526316 : {u'group': {u'GS': [6]}, u'name': u'JERONIMO', u'r_name': u'Jer\xf3nimo', u'surname': u'SAAVEDRA ACEVEDO', u'_id': ObjectId('552594ab7c4c6704fc2675dd'), u'r_surname': u'Saavedra Acevedo'}
# {u'group': {u'GS': [6]}, u'name': u'JERONIMO', u'r_name': u'Jer\xf3nimo', u'surname': u'SAAVEDRA ACEVEDO', u'_id': ObjectId('552594ab7c4c6704fc2675dd'), u'r_surname': u'Saavedra Acevedo'}
#
#
# JOAN RIDAO 1 MARTÍN --> 1 MARTÍN ; JOAN
# 0.947368421053 : {u'group': {u'GER-IU-ICV': [9]}, u'name': u'JOAN', u'r_name': u'Joan', u'surname': u'RIDAO I MARTIN', u'_id': ObjectId('552594aa7c4c6704fc267160'), u'r_surname': u'Ridao i Mart\xedn'}
# {u'group': {u'GER-IU-ICV': [9]}, u'name': u'JOAN', u'r_name': u'Joan', u'surname': u'RIDAO I MARTIN', u'_id': ObjectId('552594aa7c4c6704fc267160'), u'r_surname': u'Ridao i Mart\xedn'}
# ----------------------------------------
# 0.411764705882 : {u'group': {u'GS': [9, 10]}, u'name': u'PABLO', u'r_name': u'Pablo', u'surname': u'MARTIN PERE', u'_id': ObjectId('552594aa7c4c6704fc2672f9'), u'r_surname': u'Mart\xedn Per\xe9'}
# {u'group': {u'GS': [9, 10]}, u'name': u'PABLO', u'r_name': u'Pablo', u'surname': u'MARTIN PERE', u'_id': ObjectId('552594aa7c4c6704fc2672f9'), u'r_surname': u'Mart\xedn Per\xe9'}
# ----------------------------------------
# 0.642857142857 : {u'group': {u'GER-IU-ICV': [9]}, u'name': u'JOAN', u'r_name': u'Joan', u'surname': u'RIDAO I MARTIN', u'_id': ObjectId('552594aa7c4c6704fc267160'), u'r_surname': u'Ridao i Mart\xedn'}
# {u'group': {u'GER-IU-ICV': [9]}, u'name': u'JOAN', u'r_name': u'Joan', u'surname': u'RIDAO I MARTIN', u'_id': ObjectId('552594aa7c4c6704fc267160'), u'r_surname': u'Ridao i Mart\xedn'}
# ----------------------------------------
# 0.941176470588 : {u'group': {u'GP': [7, 8]}, u'name': u'MARIA ASUNCION', u'r_name': u'Mar\xeda Asunci\xf3n', u'surname': u'OLTRA TORRES', u'_id': ObjectId('552594ab7c4c6704fc26758b'), u'r_surname': u'Oltra Torres'}
# {u'group': {u'GP': [7, 8]}, u'name': u'MARIA ASUNCION', u'r_name': u'Mar\xeda Asunci\xf3n', u'surname': u'OLTRA TORRES', u'_id': ObjectId('552594ab7c4c6704fc26758b'), u'r_surname': u'Oltra Torres'}
# ----------------------------------------
# 0.594594594595 : {u'group': {u'GP': [7, 8]}, u'name': u'MARIA ASUNCION', u'r_name': u'Mar\xeda Asunci\xf3n', u'surname': u'OLTRA TORRES', u'_id': ObjectId('552594ab7c4c6704fc26758b'), u'r_surname': u'Oltra Torres'}
# {u'group': {u'GP': [7, 8]}, u'name': u'MARIA ASUNCION', u'r_name': u'Mar\xeda Asunci\xf3n', u'surname': u'OLTRA TORRES', u'_id': ObjectId('552594ab7c4c6704fc26758b'), u'r_surname': u'Oltra Torres'}
# ----------------------------------------
# 0.611111111111 : {u'group': {u'GP': [7, 8]}, u'name': u'MARIA ASUNCION', u'r_name': u'Mar\xeda Asunci\xf3n', u'surname': u'OLTRA TORRES', u'_id': ObjectId('552594ab7c4c6704fc26758b'), u'r_surname': u'Oltra Torres'}
# {u'group': {u'GP': [7, 8]}, u'name': u'MARIA ASUNCION', u'r_name': u'Mar\xeda Asunci\xf3n', u'surname': u'OLTRA TORRES', u'_id': ObjectId('552594ab7c4c6704fc26758b'), u'r_surname': u'Oltra Torres'}

# %%
speaker = u"MARIAASUNCIÓN OLTRA TORRES" # Trobat a 20001220_doc.html
surname, name = get_surname_name_from_string(speaker)
print speaker, "-->", surname, ";", name
print search_diputado_in_BD_with_string_metric(congres_members_collection, ns=speaker)
# Out:
# MARIAASUNCIÓN OLTRA TORRES --> OLTRA TORRES ; MARIAASUNCIÓN
# {u'group': {u'GP': [7, 8]}, u'name': u'MARIA ASUNCION', u'r_name': u'Mar\xeda Asunci\xf3n', u'surname': u'OLTRA TORRES', u'_id': ObjectId('552594ab7c4c6704fc26758b'), u'r_surname': u'Oltra Torres'}

# %% [markdown]
# #### Cerca de grups parlamentaris

# %%
def search_group_in_text_DB(text, congres_groups_col):
    
    for congres_group in congres_groups_col.find():
        description = congres_group['description'].upper()
        if description in text.upper():
            return congres_group['code']
    return None

# Test

doc_text= u'''
    ? DEL DIPUTADO DON ALFRED BOSCH I PASCUAL, DEL GRUPO PARLAMENTARIO MIXTO,
    QUE FORMULA AL SEÑOR PRESIDENTE DEL GOBIERNO: ¿CONSIDERA EL GOBIERNO
    ADECUADO PARA ERRADICAR LA POBREZA INFANTIL EN CATALUÑA LOS 2,25 EUROS
    POR NIÑO QUE DESTINÓ PARA COMBATIRLA MEDIANTE EL FONDO CORRESPONDIENTE?
    (Número de expediente 180/001217).
'''

congres_groups_collection = db['congres_groups']

print search_group_in_text_DB(doc_text, congres_groups_collection)
# Out:
# GMx

# %% [markdown]
# ### Estructura del diccionari de documents del Congrès

# %%
'''
all_document_dictionary = {
    'date': <data del document (Diario de sesiones del congreso de los diputados)>,
    'url': <url del document>,
    'description': <descripció del document>
    'id': <id del document a document_dictionary>
}

document_dictionary = {
    'date': <data del document (Diario de sesiones del congreso de los diputados)>,
    'url': <url del document>,
    'content_doc': <contingut del document en format html (sense tractar)>
    'updated_content_doc': <data d'actualització del camp 'content_doc'>
    <session_dictionary, lista amb les preguntes i intervencions de la sessió de control>
    'updated_session_dictionary': <data d'actualització del camp 'session_dictionary'>
}

session_dictionary = [{
    'question': <texte de la pregunta realitzada>,
    'speaker': <nom i cognoms de qui realitza la pregunta>,
    'group': <grup parlamentari que fa la pregunta o al que pertany qui realitza la pregunta>,
    'expedient_number': <número d'expedient de la pregunta>, 
    'intervention_dictonary' : [], llista amb les intervencions de la sessió de control i les persones que les van realitzar>
    }, ..., ]

intervention_dictonary = [{
    'text': <text de la intervenció>,
    'who': {  
        'surname': <cognoms de la persona que realitza la intervenció>,
        'name': <nom de la persona que realitza la intervenció>,
        'group': <grup al que pertany la persona: 'GP' (Grupo Popular), 'GS' (Grupo Socialista), ...>
    }, ..., ]
}
'''
# Out:
# "\nall_document_dictionary = {\n    'date': <data del document (Diario de sesiones del congreso de los diputados)>,\n    'url': <url del document>,\n    'description': <descripci\xc3\xb3 del document>\n    'id': <id del document a document_dictionary>\n}\n\ndocument_dictionary = {\n    'date': <data del document (Diario de sesiones del congreso de los diputados)>,\n    'url': <url del document>,\n    'content_doc': <contingut del document en format html (sense tractar)>\n    'updated_content_doc': <data d'actualitzaci\xc3\xb3 del camp 'content_doc'>\n    <session_dictionary, lista amb les preguntes i intervencions de la sessi\xc3\xb3 de control>\n    'updated_session_dictionary': <data d'actualitzaci\xc3\xb3 del camp 'session_dictionary'>\n}\n\nsession_dictionary = [{\n    'question': <texte de la pregunta realitzada>,\n    'speaker': <nom i cognoms de qui realitza la pregunta>,\n    'group': <grup parlamentari que fa la pregunta o al que pertany qui realitza la pregunta>,\n    'expedient_number': <n\xc3\xbamero d'expedient de la pregunta>, \n    'intervention_dictonary' : [], llista amb les intervencions de la sessi\xc3\xb3 de control i les persones que les van realitzar>\n    }, ..., ]\n\nintervention_dictonary = [{\n    'text': <text de la intervenci\xc3\xb3>,\n    'who': {  \n        'surname': <cognoms de la persona que realitza la intervenci\xc3\xb3>,\n        'name': <nom de la persona que realitza la intervenci\xc3\xb3>,\n        'group': <grup al que pertany la persona: 'GP' (Grupo Popular), 'GS' (Grupo Socialista), ...>\n    }, ..., ]\n}\n"

# %% [markdown]
# #### LListat dels documents seleccionats (sessions de control dels dimecres)

# %%
#
doc_col = db['document']

print "num. of rows: ", doc_col.count()
for doc in doc_col.find():
    file_name = doc['date'].strftime("%Y%m%d") + "_doc.html"
    print file_name, ":", doc['description']
    save_text_file(doc['content_doc'], 'docs/' + file_name)
# Out:
# num. of rows:  372
# 19980520_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 161, de 20/05/1998
# 19971029_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 111, de 29/10/1997
# 19971008_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 106, de 08/10/1997
# 19970924_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 103, de 24/09/1997
# 19970521_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 84, de 21/05/1997
# 19970528_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 87, de 28/05/1997
# 19970604_doc.html : Congreso de los Diputados, Pleno y Dip. Perm., núm. 90, de
ONVALIDACIÓN O DEROGACIÓN DE REALES DECRETOS-LEYES:"
- Trobat a DSCD-10-PL-172-C1.html



'''
# Out:
# '\nBlocs detectats en els diaris de sessions del Congr\xc3\xa9s dels dimecres (per ordre d\'aparici\xc3\xb3):\n\n"ORDEN DEL D\xc3\x8dA:"\n- Trobat sempre\n\n"SUMARIO"\n- Trobat sempre\n\n\n<br /><br />Se levanta la sesi\xc3\xb3n a las ocho y cuarenta minutos de la noche.\n<br /><br />Se suspende la sesi\xc3\xb3n a las tres y diez minutos de la tarde.\n<br /><br />Se reanuda la sesi\xc3\xb3n a las nueve de la ma\xc3\xb1ana.\n    \n    \n"COMPARECENCIA DEL GOBIERNO ANTE EL PLENO DE LA C\xc3\x81MARA"\n- Trobat a DSCD-10-PL-172-C1.html\n\n"PREGUNTAS:"\n- Trobat sempre\n\n"INTERPELACIONES URGENTES:"\n- Trobat sempre\n\n"CONVALIDACI\xc3\x93N O DEROGACI\xc3\x93N DE REALES DECRETOS-LEYES:"\n- Trobat a DSCD-10-PL-172-C1.html\n\n\n\n'

# %%
import re

def remove_html_tags(html_text):
    # Cleaning the text of html tags:
    # Remove:
    # <p style="text-align:center"><a name="(Página7)"><b>Página7</b></a></p>
    html_text = re.sub(r'<p.*?/p>', '', html_text, flags=re.DOTALL)
    
    # Remove:
    # <center><a name="(Página8259)"><b>Página 8259</b></a></center>
    html_text = re.sub(r'<center>.*?</center>', '', html_text, flags=re.DOTALL)
    
    # Remove:
    # <br />
    html_text = re.sub(r'<br />', '', html_text, flags=re.DOTALL)
    
    return html_text


log_to_file = True

def document_analyzer(document):

    legislature = get_legislature_DB(legislatures_collection, document['date'])
    print "date: ", document['date'], ", legislature:", legislature
    
    prefix_file_name = doc['date'].strftime("%Y%m%d") + "_doc"
    html_file = document['content_doc']
    
    #
    if u"EXCLUSIÓN DEL ORDEN DEL DÍA" in html_file:
        print "EXCLUSIÓN DEL ORDEN DEL DÍA: True"
        question_exclusion = True
    else:
        question_exclusion = False

    # Extraiem el text desde l'última aparició de 'PREGUNTAS:' i '<hr size="1" noshade="" />' (aquest últim element només apareix al final de cada doc)
    preguntas_html = get_text_between(html_file, 'PREGUNTAS:', '<hr size="1" noshade="" />', include_limits = False, first_ocurrences = False)

    preguntas_html = remove_html_tags(preguntas_html)

    # save_text_file(preguntas_html, 'log/' + prefix_file_name + '_preguntas_html.txt', "utf-8")
    
    paragraphs = preguntas_html.split("\n")
    
    #
    if log_to_file:
        text_to_analyze = ""
        i = 0
        for paragraph in paragraphs:
            text_to_analyze += "["+ str(i) + "]-----------------------------------------------------" + "\n"
            text_to_analyze += paragraph + "\n"
            i += 1
        # print text_to_analyze
        save_text_file(text_to_analyze, 'log/' + prefix_file_name + '_to_analyze.txt', "utf-8")

    #
    if log_to_file:
        with Capturing() as output:
            result_dialogue_dict = paragraphs_analyzer(paragraphs, preguntas_html, legislature, question_exclusion)
            # Log output
            # print 'output:\n', output
            
        #
        '''
        for item in output:
            print ast.literal_eval(item)
        '''
        save_list_text_file(output, 'log/' + prefix_file_name + '_analyzer_log.txt')

    else:
        result_dialogue_dict = paragraphs_analyzer(paragraphs, legislature)

    return result_dialogue_dict

# %%
def search_group_in_text(text, groups_dict):
    for key in groups_dict:
        description = groups_dict[key]['description'].upper()
        if description in text.upper():
            return groups_dict[key]['code']
    return None

def get_who(surname, legislature):
    dip = search_diputado_in_BD(congres_members_collection, surname, legislature=legislature)
    if not dip:
        dip = search_diputado_in_BD_with_string_metric(congres_members_collection, surname)

    if dip:
        if len(dip['group']) == 1:
            dip_group = dip['group'].keys()[0]
        else:
            dip_group = get_group(dip['group'], legislature)
        
        who_dict = {'surname': dip['r_surname'], 'name': dip['r_name'], 'group': dip_group}
        return dip['_id'], who_dict
    else:
        who_dict = {'surname': '<unknown>', 'name': '<unknown>', 'group': '<unknown>'}
        return 9999, who_dict
    
def get_prev_non_empty_paragraph(paragraphs, from_index):
    i = from_index - 1
    while(i>=0):
        if paragraphs[i].split():
            return paragraphs[i]
        i+=-1
    return None

def get_next_non_empty_paragraph(paragraphs, from_index):
    i = from_index + 1
    while(i<len(paragraphs)):
        if paragraphs[i].split():
            return i,paragraphs[i]
        i+=1
    return 0, None
        
question_checkers = [u"DEL DIPUTADO", u"DE LA DIPUTADA", u"DEL GRUPO PARLAMENTARIO", u"DE DOÑA"]
question_starters = [u"SOBRE", u"RELATIVA A", u"RELATIVA", u"ACERCA DE", u"PARA CONOCER SI", u"CLARIFIQUE",
                     u"EN MATERIA DE", u"DE CONOCER",u"RELACIÓN CON",u"PARA INFORMAR",u"EXPLIQUE",u"ACLARE",
                     u"INFORME",u"DEBATIR",u"EXPONGA",u"PARA",u":",u","]
    
def question_analyzer(sub_text, legislature):
    group = search_group_in_text_DB(remove_spaces_and_newline(sub_text), congres_groups_collection)

    # Remove the non-alphanumeric first characters
    m = re.search(r"\w", sub_text)
    if m:
        sub_text = sub_text[m.start():]

    if u'¿' in sub_text or u'?' in sub_text:
        question = get_text_between(sub_text,u'¿',u'?')
        if question == "":
            if u'¿' in sub_text:
                question = get_text_between(sub_text, u"¿", u"(Número", case_sensitive = False)
            elif u'?' in sub_text:
                # question = get_text_between(sub_text, u":", u"?")
                m = re.search('[\.|\:](.*?)\?', sub_text, re.DOTALL)
                if m:
                    question = sub_text[m.start():m.end()]

        if question == "":
            rprint("TO BE CATCHED -->", get_text_between(sub_text, u"GRUPO PARLAMENTARIO", u"(Número", case_sensitive = False))
            # question = get_text_between(sub_text, u"GRUPO PARLAMENTARIO", u"(Número")                    

        if not group:
            group = get_text_between(sub_text, "GRUPO PARLAMENTARIO", ", QUE")

        # m = re.search(ur"(DIPUTADO SEÑOR|DIPUTADO DON|DIPUTADA DOÑA|SEÑORA DOÑA|DE DOÑA) ([^,]+),", sub_text)
        m = regex.search(ur"(DIPUTADO SEÑOR|DIPUTADO DON|DIPUTADO D.|SEÑOR DON|DIPUTADA DOÑA|SEÑORA DOÑA|DE DOÑA){e<=1} ([^,]+),", sub_text)
        if m:
            speaker = m.group(2)
        else:
            m = re.search(ur"(DIPUTADO|DON|DIPUTADA) ([^,]+),", sub_text)
            if m:
                speaker = m.group(2)
            else:
                catched_speaker = ""
                coma_index = sub_text.find(",")
                if coma_index > 0:
                    catched_speaker = sub_text[0:coma_index]
                else:
                    space_index = sub_text.find(" ", 40)
                    catched_speaker = sub_text[0:space_index]
                rprint("CATCHED -->", catched_speaker)
                
                s_words = question_checkers + [u"DIPUTADO", u"DIPUTADA", u"GRUPO", u"PARLAMENTARIO", u"DON", u"DOÑA",u"DE LA"]
                for s_word in s_words:
                    catched_speaker = catched_speaker.replace(s_word, " ")
                catched_speaker = remove_spaces_and_newline(catched_speaker)
                rprint("CATCHED (CLEANED) -->", catched_speaker)

                if not catched_speaker:
                    speaker = "not found"
                else:
                    speaker = catched_speaker
    else:
        for question_starter in question_starters:
            if question_starter in sub_text:
                question = get_text_between(sub_text, question_starter, u"(Número", case_sensitive = False)
                if not group:
                    group = get_text_between(sub_text, u"DEL GRUPO PARLAMENTARIO", question_starter)
                break;

        if question=="":
            rprint("TO BE CATCHED -->", get_text_between(sub_text, u"DEL GRUPO PARLAMENTARIO", u"(Número", case_sensitive = False))
            # question = get_text_between(sub_text, u"DEL GRUPO PARLAMENTARIO", u"(Número")

        speaker = "<group>"

    rprint("group:", group)
    rprint("speaker:", speaker)
    if speaker!="<group>" and speaker!="not found":
        s_speaker = search_diputado_from_string(congres_members_collection, speaker, legislature=legislature)
        if not s_speaker:
            s_speaker = search_diputado_in_BD_with_string_metric(congres_members_collection, ns=speaker)
    else:
        s_speaker = speaker
        
    return question, group, speaker, s_speaker


def intervention_analyzer(paragraphs, dialogue_dict, paragraph, fushioned, reparagraph, index, inc_index, who_id, p_offset, num_intervention, num_dialogue):
    m01 = re.search(ur"^\s*(El señor|La señora) (PRESIDENTE|PRESIDENTA)\:", paragraph)
    m02 = re.search(ur"^\s*(El señor|La señora) (VICEPRESIDENTE|VICEPRESIDENTA)\:", paragraph)
    m03 = re.search(ur"^\s*(El señor|La señora) (VICEPRESIDENTE|VICEPRESIDENTA) (\([^:]+\))\:", paragraph)
    m04 = re.search(ur"^\s*\(La señora vicepresidenta", paragraph)
    if m01:
        rprint(u"KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):", paragraph)
        p_offset += len(paragraph)
        who_id = None
    elif m02 or m03 or m04:
        rprint(u"KO (El señor|La señora) (VICEPRESIDENTE|VICEPRESIDENTA):", paragraph)
        p_offset += len(paragraph)
        who_id = None
    else:
        # https://pypi.python.org/pypi/regex [ regex 2015.03.18 ]
        
        # expressió regular per cognoms de dues paraules
        m1 = re.search(ur"señor\w? ([A-ZÁÉÍÓÚÑ\-]+) ([A-ZÁÉÍÓÚÑ\-]+)(\:|\.)", paragraph)
        if m1:
            rprint(u"OK 1", paragraph)
            rprint(u"found:", paragraph[m1.start():m1.end()])
            rprint(u"groups:", m1.group(0), ", ", m1.group(1), ", ", m1.group(2))
            rprint(u"speaker:", m1.group(1) + " " + m1.group(2))
            rprint(u"speach:", paragraph[m1.end():])

            who_id, who_dict = get_who(m1.group(1) + " " + m1.group(2), legislature)
                
            dialogue_dict[num_dialogue]['intervention_dictionary'].update({num_intervention:{'who':who_dict,'text':paragraph[m1.end():],'offset':p_offset}})
            p_offset = 0
            num_intervention += 1
        else:
            # expressió regular per els cognoms catalans
            m2 = re.search(ur"señor\w? ([A-ZÁÉÍÓÚÑ\-]+) I ([A-ZÁÉÍÓÚÑ\-]+)(\:|\.)", paragraph)
            if m2:
                rprint(u"OK 2", paragraph)
                rprint(u"found:", paragraph[m2.start():m2.end()])
                rprint(u"groups:", m2.group(0), ", ", m2.group(1), ", ", m2.group(2))
                rprint(u"speaker:", m2.group(1) + " I " + m2.group(2))
                rprint(u"speach:", paragraph[m2.end():])

                who_id, who_dict = get_who(m2.group(1) + " I " + m2.group(2), legislature)
                
                dialogue_dict[num_dialogue]['intervention_dictionary'].update({num_intervention:{'who':who_dict,'text':paragraph[m2.end():], 'offset':p_offset}})
                p_offset = 0
                num_intervention += 1
            else:
                # expressió regular per trobar intervencions del tipus: 
                #     "   El señor MINISTRO DE INDUSTRIA, ENERGÍA Y TURISMO (Soria López):"
                # m3 = re.search(ur"^\s*(El señor|La señora) ([^:]+)\:", paragraphs[index])
                m3 = regex.search(ur"^\s*(El señor|La señora){e<=1} ([^:]+)\:", paragraph)
                if m3:
                    rprint(u"OK 3", paragraph)
                    rprint(u"found:", paragraph[m3.start():m3.end()])
                    rprint(u"groups:", m3.group(0), ", ", m3.group(1), ", ", m3.group(2))
                    rprint(u"speaker:", m3.group(2))
                    if '(' in m3.group(2) and ')' in m3.group(2):
                        str_surname = remove_spaces_and_newline(get_text_between(m3.group(2), '(',')'))
                        # El señor LÓPEZ GARRIDO (don Diego):
                        if 'don' in str_surname:
                            str_surname = m3.group(2).split(' (')[0]
                    else:
                        str_surname = m3.group(2)
                    rprint(u"speaker2:", str_surname)
                    rprint(u"speach:", paragraph[m3.end():])

                    who_id, who_dict = get_who(str_surname, legislature)

                    dialogue_dict[num_dialogue]['intervention_dictionary'].update({num_intervention:{'who':who_dict,'text':paragraph[m3.end():], 'offset':p_offset}})
                    p_offset = 0
                    num_intervention += 1
                    if fushioned:
                        index += inc_index
                        
                else:
                    '''
                    m4 = regex.search(ur"(El señor|La señora) ([^:]+)\:", paragraph)
                    if m4 and not fushioned:
                        rprint(u"OK 4", paragraph)
                        rprint(u"found:", paragraph[m4.start():m4.end()])
                        rprint(u"groups:", m4.group(0), ", ", m4.group(1), ", ", m4.group(2))
                        rprint(u"speaker:", m4.group(2))
                        if '(' in m4.group(2) and ')' in m4.group(2):
                            str_surname = remove_spaces_and_newline(get_text_between(m4.group(2), '(',')'))
                            # El señor LÓPEZ GARRIDO (don Diego):
                            if 'don' in str_surname:
                                str_surname = m4.group(2).split(' (')[0]
                        else:
                            str_surname = m4.group(2)
                        rprint(u"speaker2:", str_surname)
                        rprint(u"speach:", paragraph[m4.end():])

                        who_id, who_dict = get_who(str_surname, legislature)

                        dialogue_dict[num_dialogue]['intervention_dictionary'].update({num_intervention:{'who':who_dict,'text':paragraph[m4.end():], 'offset':p_offset}})
                        p_offset = 0
                        num_intervention += 1
                        if fushioned:
                            index += inc_index
                    '''

                    index_mr = paragraph.find(u"El señor")
                    index_mrs = paragraph.find(u"La señora")
                    index_par = paragraph.find(u"(")
                    new_paragraph = ""
                    
                    if not reparagraph:
                        if index_mrs > 0 and index_par > 0:
                            new_paragraph = paragraph[index_mrs:index_par] + paragraph[0:index_mrs].lstrip() + paragraph[index_par:]
                        elif index_mr > 0 and index_par > 0:
                            new_paragraph = paragraph[index_mr:index_par] + paragraph[0:index_mr].lstrip() + paragraph[index_par:]
                    
                    if new_paragraph and not fushioned:
                        index, p_offset, num_intervention, who_id = intervention_analyzer(paragraphs, dialogue_dict, new_paragraph, fushioned, True, index, inc_index, who_id, p_offset, num_intervention, num_dialogue)

                    else:

                        if not fushioned:
                            next_index, next_non_empty_paragraph = get_next_non_empty_paragraph(paragraphs, index)
                            if next_non_empty_paragraph:
                                inc_index = next_index - index
                                paragraph_fusion = paragraphs[index] + next_non_empty_paragraph
                            else:
                                inc_index = 0
                                paragraph_fusion=""

                            index, p_offset, num_intervention, who_id = intervention_analyzer(paragraphs, dialogue_dict, paragraph_fusion, True, reparagraph, index, inc_index, who_id, p_offset, num_intervention, num_dialogue)

                        elif who_id:
                            rprint(u"OK ", who_id, ":")
                            # Eliminem la intervenció final del "PRESIDENTE" del congrés detectada en les intervencions de diaris de sessions antics
                            m = re.search(ur"(El señor|La señora) (PRESIDENTE|PRESIDENTA)\:", paragraphs[index])
                            if m:
                                extracted_text = paragraphs[index][0:m.start()]
                                rprint(u"(El señor|La señora) (PRESIDENTE|PRESIDENTA)\:")
                                rprint(u">" + extracted_text + u"<")
                            else:
                                extracted_text = paragraphs[index]
                                rprint(extracted_text)

                            dialogue_dict[num_dialogue]['intervention_dictionary'][(num_intervention-1)]['text'] += ("\n" + extracted_text)
                        else:
                            rprint(u"KO ", paragraphs[index])
                            p_offset += len(paragraphs[index])
                        
    return index, p_offset, num_intervention, who_id


# El número d'expedient que té el següent format: 999/999999, amb excepcions:
                  # 20141015_doc.html -->  (Número de expediente 172/00263)
                  # 20101013_doc.htlm -->  (Número de expediente 180/0001223.)
                  # 20051214_doc.html -->  de expediente 180/ 001015.)
num_exp_regexs = [r"\D(\d{3}\s?/\s?\d{5,7})\D",
                  # 20030430_doc.html -->  (Número de expediente 180/1887.)
                  r"expediente (\d{3}\s?/\s?\d{4})\D",
                  # 20130417_doc.html -->  (Número de expediente 180000491)
                  # 20051019_doc.html -->  (Número de expediente 1807000927.)
                  # 20001220_doc.html -->  (Número de expediente\n1807000393.)
                  r"expediente\s*(\d{9,10})\D"]

def eval_regex_list(regex_list, paragraph):
    for regex_item in regex_list:
        m_q = re.search(regex_item, paragraph)
        if m_q:
            return m_q
    return m_q

# Extracció del número d'expedient
def get_num_exp(paragraph, paragraph_prev, num_exp_prev):

    m_q = eval_regex_list(num_exp_regexs, paragraph)
    if m_q:
        return m_q
    elif paragraph_prev:
        # 20000927_doc --> "INSTRUMENTOS DE CORRECCIÓN DE LOS MISMOS. (Número de expediente 172/\n000034.)
        p_paragraph = paragraph_prev.strip() + " " + paragraph.strip()
        # rprint("p_paragraph:",p_paragraph)
        m_q = eval_regex_list(num_exp_regexs, p_paragraph)
        if m_q and m_q.group(1) != num_exp_prev:
            return m_q
        else:
            return None
    return m_q

# 20081029_doc --> "  retirada la pregunta. (Rumores.)"
# 20070509_doc --> "    decae esta interpelación"
# 20000628_doc --> " obviamente, se da por decaída. (Rumores.)"
remove_words = [u"aplazará",u"retirada",u"decae",u"Decae",u"decaída"]
        
        
import re
# https://pypi.python.org/pypi/regex
import regex
        
# Mètode que analitza una llista de paràgrafs
def paragraphs_analyzer(paragraphs, raw_text, legislature, question_exclusion):

    index = 0
    num_dialogue = 0
    dialogue_started = False
    num_intervention = 0
    dialogue_dict = {}
    who_id = None  # None: not interesting, 9999: unknown, otherwise: diputado id
    num_exp = ""
    sub_text = ""
    sub_text_started = False
    p_offset = 0
    
    continue_analyzing = True

    while index < len(paragraphs) and continue_analyzing:
        
        rprint("["+ str(index) + "]-----------------------------------------------------")
        
        # Extracció del número d'expedient
        m_q = get_num_exp(paragraphs[index],paragraphs[index-1],num_exp)
       
        if paragraphs[index].strip() == "":
            p_offset += len(paragraphs[index])
            rprint("Empty paragraph")
        elif not sub_text_started and any(question_checker in paragraphs[index] for question_checker in question_checkers):
            
            if dialogue_started:
                rprint("Dialog ends (1):", paragraphs[index])
                dialogue_started = False
                if num_intervention == 0:
                    prev_paragraph = get_text_between(raw_text, dialogue_dict[num_dialogue]['num_exp'], paragraphs[index])
                    if question_exclusion or any(remove_word in prev_paragraph for remove_word in remove_words):
                        rprint("Removing:",dialogue_dict[num_dialogue], "\nexclusion:", question_exclusion, "\nprev_paragraph:", prev_paragraph)
                        p_offset += len(dialogue_dict[num_dialogue]['question'])
                        dialogue_dict.pop(num_dialogue, None)
                        num_dialogue -= 1
                                
            rprint(u"sub_text_started = True")
            rprint(u"Adding:", paragraphs[index])
            sub_text = paragraphs[index] + "\n"
            sub_text_started = True
            
        elif m_q and sub_text_started:
            sub_text += paragraphs[index]
            rprint(u"sub_text: ", sub_text)
            sub_text_started = False
            
            num_dialogue += 1
            dialogue_started = True
            question = ""
            num_intervention = 0
            who_id = None

            num_exp = m_q.group(1)
            
            question, group, speaker, s_speaker = question_analyzer(sub_text, legislature)

            dialogue_dict[num_dialogue] = {'question':question, 'offset': p_offset, 'speaker':speaker, 'group':group, 'num_exp':num_exp, 'intervention_dictionary':{}}
            p_offset = 0
            rprint("num_exp:", num_exp)
            rprint("question:", question)
            rprint("s_speaker:", s_speaker)
        elif m_q and dialogue_started:
            rprint("Dialog ends (2):", paragraphs[index])
            dialogue_started = False
            if num_intervention == 0 and question_exclusion:
                rprint("Removing:",dialogue_dict[num_dialogue], "len dict:", len(dialogue_dict))
                p_offset += len(dialogue_dict[num_dialogue]['question'])
                dialogue_dict.pop(num_dialogue, None)
                rprint("Removed...  len dict:", len(dialogue_dict))
                num_dialogue -= 1
                
        elif sub_text_started:
            rprint(u"Adding:", paragraphs[index])
            sub_text += (paragraphs[index] + "\n")
        elif u"INTERPELACIONES URGENTES:" in paragraphs[index]:
            rprint(u"DO NOTHING WITH INTERPELACIONES URGENTES:", paragraphs[index])
            dialogue_started = False
            if num_intervention == 0 and question_exclusion:
                rprint("Removing:",dialogue_dict[num_dialogue])
                p_offset += len(dialogue_dict[num_dialogue]['question'])
                dialogue_dict.pop(num_dialogue, None)
                num_dialogue -= 1
                
        elif u"CONVALIDACIÓN O DEROGACIÓN DE REALES DECRETOS-LEYES" in paragraphs[index]:
            rprint(u"DO NOTHING WITH CONVALIDACIÓN O DEROGACIÓN DE REALES DECRETOS-LEYES:", paragraphs[index])
            dialogue_started = False
            if num_intervention == 0 and question_exclusion:
                rprint("Removing:",dialogue_dict[num_dialogue])
                p_offset += len(dialogue_dict[num_dialogue]['question'])
                dialogue_dict.pop(num_dialogue, None)
                num_dialogue -= 1
                
        elif u"JURAMENTO O PROMESA DE ACATAMIENTO DE LA CONSTITUCIÓN" in paragraphs[index]:
            rprint(u"DO NOTHING WITH JURAMENTO O PROMESA DE ACATAMIENTO DE LA CONSTITUCIÓN:", paragraphs[index])
            dialogue_started = False
            if num_intervention == 0 and question_exclusion:
                rprint("Removing:",dialogue_dict[num_dialogue])
                p_offset += len(dialogue_dict[num_dialogue]['question'])
                dialogue_dict.pop(num_dialogue, None)
                num_dialogue -= 1
                
        elif u"PROPOSICIONES NO DE LEY" in paragraphs[index]:
            rprint(u"ANALYSIS END: 'PROPOSICIONES NO DE LEY", paragraphs[index])
            continue_analyzing = False
        elif u"MOCIONES CONSECUENCIA DE INTERPELACIONES URGENTES" in paragraphs[index]:
            rprint(u"ANALYSIS END: 'MOCIONES CONSECUENCIA DE INTERPELACIONES URGENTES':", paragraphs[index])
            continue_analyzing = False
        elif num_dialogue > 0 and dialogue_started:
            
            index, p_offset, num_intervention, who_id = intervention_analyzer(paragraphs, dialogue_dict, paragraphs[index], False, False, index, 0, who_id, p_offset, num_intervention, num_dialogue)
            
        else:
            rprint(u"[DO NOTHING] num_dialogue:", num_dialogue, u" >" + paragraphs[index] + u"<")

        index += 1
        
    if len(dialogue_dict[num_dialogue]['intervention_dictionary'])==0:
        last_paragraph = get_prev_non_empty_paragraph(paragraphs,index)
        prev_paragraph = get_text_between(raw_text, dialogue_dict[num_dialogue]['num_exp'], last_paragraph)
        if question_exclusion or any(remove_word in prev_paragraph for remove_word in remove_words):
            rprint("Removing:",dialogue_dict[num_dialogue], "\nexclusion:", question_exclusion, "\nprev_paragraph:", prev_paragraph)
            p_offset += len(dialogue_dict[num_dialogue]['question'])
            dialogue_dict.pop(num_dialogue, None)

    return dialogue_dict

# %% [markdown]
# #### Procés d'anàl.lisi dels documents

# %%
import time

# Col.lecció de documents a la BD
doc_col = db['document']
# Col.lecció de diputats a la BD
congres_members_collection = db['congres_members']
# Col.lecció de legislatures a la BD
legislatures_collection = db['legislatures']
# Col.lecció de grups parlamentaris a la BD
congres_groups_collection = db['congres_groups']


# All
doc_start_date = "01/01/2000"
d_doc_start_date = datetime.datetime.strptime(doc_start_date, "%d/%m/%Y")
d_doc_end_date = datetime.datetime.utcnow()
result = doc_col.find({'date': {'$gte': d_doc_start_date, '$lte': d_doc_end_date}}).sort('date',1)

'''
doc_date = "11/03/2015"
d_doc_date = datetime.datetime.strptime(doc_date, "%d/%m/%Y")
file_name = d_doc_date.strftime("%Y%m%d")
result = doc_col.find({'date': d_doc_date})
'''
'''
# Legislatura X
doc_start_date = "14/12/2011"
d_doc_start_date = datetime.datetime.strptime(doc_start_date, "%d/%m/%Y")
d_doc_end_date = datetime.datetime.utcnow()
result = doc_col.find({'date': {'$gte': d_doc_start_date, '$lte': d_doc_end_date}}).sort('date',1)
'''
'''
# Legislaturas V-IX
doc_start_date = "29/06/1993"
d_doc_start_date = datetime.datetime.strptime(doc_start_date, "%d/%m/%Y")
doc_end_date = "14/12/2011"
d_doc_end_date = datetime.datetime.strptime(doc_end_date, "%d/%m/%Y")
result = doc_col.find({'date': {'$gte': d_doc_start_date, '$lte': d_doc_end_date}}).sort('date',1)
'''

if result.count() > 0:
    
    t_total_init = time.clock()
    
    for doc in result:
        t_init = time.clock()
        print "Analyzing:", doc['description']
        result_dialogue_dict = document_analyzer(doc)

        print "Updating '" + doc['description'] + "' ..."
        # save_dict_json(result_dialogue_dict, 'log/' + file_name + '_dialogue_dict.json')

        # dictionary conversion to session_dictionary
        session_dictionary = [None] * len(result_dialogue_dict)
        print "len(result_dialogue_dict):", len(result_dialogue_dict)
        for key in result_dialogue_dict:
            intervention_dictionary = [None] * len(result_dialogue_dict[key]['intervention_dictionary'])
            for subkey in result_dialogue_dict[key]['intervention_dictionary']:
                intervention_dictionary[int(subkey)] = result_dialogue_dict[key]['intervention_dictionary'][subkey]
            result_dialogue_dict[key]['intervention_dictionary'] = intervention_dictionary
            session_dictionary[int(key)-1] = result_dialogue_dict[key]

        # http://docs.mongodb.org/manual/tutorial/modify-documents/
        doc_col.update({'_id':doc['_id']}, \
                       {'$set':{'session_dictionary':session_dictionary, 'updated_session_dictionary':datetime.datetime.utcnow()}}, \
                       upsert=False, multi=False)
        t_end = time.clock()
        print "Done in {0:.2f} seconds".format(t_end-t_init)
        
    t_total_end = time.clock()
    print "\n" + ("-"*120)
    print "Analysis finished in {0:.2f} seconds".format(t_total_end-t_total_init)
# Out:
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 7, de 17/05/2000
# date:  2000-05-17 00:00:00 , legislature: 7
# Saving: log/20000517_doc_analyzer_log.txt lines: 13123
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 7, de 17/05/2000' ...
# len(result_dialogue_dict): 26
# Done in 16.81 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 9, de 24/05/2000
# date:  2000-05-24 00:00:00 , legislature: 7
# Saving: log/20000524_doc_analyzer_log.txt lines: 14128
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 9, de 24/05/2000' ...
# len(result_dialogue_dict): 26
# Done in 11.70 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 11, de 31/05/2000
# date:  2000-05-31 00:00:00 , legislature: 7
# Saving: log/20000531_doc_analyzer_log.txt lines: 15768
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 11, de 31/05/2000' ...
# len(result_dialogue_dict): 27
# Done in 14.82 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 13, de 14/06/2000
# date:  2000-06-14 00:00:00 , legislature: 7
# Saving: log/20000614_doc_analyzer_log.txt lines: 12358
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 13, de 14/06/2000' ...
# len(result_dialogue_dict): 25
# Done in 15.44 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 16, de 21/06/2000
# date:  2000-06-21 00:00:00 , legislature: 7
# Saving: log/20000621_doc_analyzer_log.txt lines: 13295
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 16, de 21/06/2000' ...
# len(result_dialogue_dict): 27
# Done in 17.14 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 19, de 28/06/2000
# date:  2000-06-28 00:00:00 , legislature: 7
# Saving: log/20000628_doc_analyzer_log.txt lines: 10600
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 19, de 28/06/2000' ...
# len(result_dialogue_dict): 26
# Done in 19.53 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 23, de 13/09/2000
# date:  2000-09-13 00:00:00 , legislature: 7
# Saving: log/20000913_doc_analyzer_log.txt lines: 10626
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 23, de 13/09/2000' ...
# len(result_dialogue_dict): 24
# Done in 14.54 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 25, de 20/09/2000
# date:  2000-09-20 00:00:00 , legislature: 7
# Saving: log/20000920_doc_analyzer_log.txt lines: 14723
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 25, de 20/09/2000' ...
# len(result_dialogue_dict): 27
# Done in 17.55 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 28, de 27/09/2000
# date:  2000-09-27 00:00:00 , legislature: 7
# Saving: log/20000927_doc_analyzer_log.txt lines: 13076
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 28, de 27/09/2000' ...
# len(result_dialogue_dict): 25
# Done in 14.89 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 31, de 04/10/2000
# date:  2000-10-04 00:00:00 , legislature: 7
# Saving: log/20001004_doc_analyzer_log.txt lines: 13067
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 31, de 04/10/2000' ...
# len(result_dialogue_dict): 22
# Done in 12.79 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 34, de 18/10/2000
# date:  2000-10-18 00:00:00 , legislature: 7
# Saving: log/20001018_doc_analyzer_log.txt lines: 13674
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 34, de 18/10/2000' ...
# len(result_dialogue_dict): 28
# Done in 25.20 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 49, de 13/12/2000
# date:  2000-12-13 00:00:00 , legislature: 7
# Saving: log/20001213_doc_analyzer_log.txt lines: 13686
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 49, de 13/12/2000' ...
# len(result_dialogue_dict): 28
# Done in 14.14 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 52, de 20/12/2000
# date:  2000-12-20 00:00:00 , legislature: 7
# Saving: log/20001220_doc_analyzer_log.txt lines: 6279
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 52, de 20/12/2000' ...
# len(result_dialogue_dict): 22
# Done in 12.08 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 60, de 14/02/2001
# date:  2001-02-14 00:00:00 , legislature: 7
# Saving: log/20010214_doc_analyzer_log.txt lines: 15583
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 60, de 14/02/2001' ...
# len(result_dialogue_dict): 26
# Done in 16.23 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 62, de 21/02/2001
# date:  2001-02-21 00:00:00 , legislature: 7
# Saving: log/20010221_doc_analyzer_log.txt lines: 15034
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 62, de 21/02/2001' ...
# len(result_dialogue_dict): 27
# Done in 15.46 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 65, de 07/03/2001
# date:  2001-03-07 00:00:00 , legislature: 7
# Saving: log/20010307_doc_analyzer_log.txt lines: 14623
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 65, de 07/03/2001' ...
# len(result_dialogue_dict): 25
# Done in 10.08 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 71, de 21/03/2001
# date:  2001-03-21 00:00:00 , legislature: 7
# Saving: log/20010321_doc_analyzer_log.txt lines: 11356
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 71, de 21/03/2001' ...
# len(result_dialogue_dict): 25
# Done in 10.97 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 74, de 04/04/2001
# date:  2001-04-04 00:00:00 , legislature: 7
# Saving: log/20010404_doc_analyzer_log.txt lines: 16094
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 74, de 04/04/2001' ...
# len(result_dialogue_dict): 28
# Done in 11.17 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 77, de 18/04/2001
# date:  2001-04-18 00:00:00 , legislature: 7
# Saving: log/20010418_doc_analyzer_log.txt lines: 11863
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 77, de 18/04/2001' ...
# len(result_dialogue_dict): 26
# Done in 24.08 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 80, de 25/04/2001
# date:  2001-04-25 00:00:00 , legislature: 7
# Saving: log/20010425_doc_analyzer_log.txt lines: 10887
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 80, de 25/04/2001' ...
# len(result_dialogue_dict): 27
# Done in 20.04 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 82, de 16/05/2001
# date:  2001-05-16 00:00:00 , legislature: 7
# Saving: log/20010516_doc_analyzer_log.txt lines: 10772
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 82, de 16/05/2001' ...
# len(result_dialogue_dict): 24
# Done in 9.94 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 87, de 30/05/2001
# date:  2001-05-30 00:00:00 , legislature: 7
# Saving: log/20010530_doc_analyzer_log.txt lines: 11264
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 87, de 30/05/2001' ...
# len(result_dialogue_dict): 26
# Done in 14.51 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 90, de 13/06/2001
# date:  2001-06-13 00:00:00 , legislature: 7
# Saving: log/20010613_doc_analyzer_log.txt lines: 9414
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 90, de 13/06/2001' ...
# len(result_dialogue_dict): 25
# Done in 13.85 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 93, de 20/06/2001
# date:  2001-06-20 00:00:00 , legislature: 7
# Saving: log/20010620_doc_analyzer_log.txt lines: 12696
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 93, de 20/06/2001' ...
# len(result_dialogue_dict): 28
# Done in 12.22 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 101, de 12/09/2001
# date:  2001-09-12 00:00:00 , legislature: 7
# Saving: log/20010912_doc_analyzer_log.txt lines: 10036
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 101, de 12/09/2001' ...
# len(result_dialogue_dict): 22
# Done in 8.65 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 104, de 19/09/2001
# date:  2001-09-19 00:00:00 , legislature: 7
# Saving: log/20010919_doc_analyzer_log.txt lines: 12724
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 104, de 19/09/2001' ...
# len(result_dialogue_dict): 30
# Done in 13.92 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 110, de 03/10/2001
# date:  2001-10-03 00:00:00 , legislature: 7
# Saving: log/20011003_doc_analyzer_log.txt lines: 11246
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 110, de 03/10/2001' ...
# len(result_dialogue_dict): 26
# Done in 15.34 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 116, de 31/10/2001
# date:  2001-10-31 00:00:00 , legislature: 7
# Saving: log/20011031_doc_analyzer_log.txt lines: 11157
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 116, de 31/10/2001' ...
# len(result_dialogue_dict): 26
# Done in 21.01 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 131, de 19/12/2001
# date:  2001-12-19 00:00:00 , legislature: 7
# Saving: log/20011219_doc_analyzer_log.txt lines: 11559
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 131, de 19/12/2001' ...
# len(result_dialogue_dict): 27
# Done in 18.14 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 138, de 13/02/2002
# date:  2002-02-13 00:00:00 , legislature: 7
# Saving: log/20020213_doc_analyzer_log.txt lines: 10418
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 138, de 13/02/2002' ...
# len(result_dialogue_dict): 24
# Done in 15.03 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 151, de 10/04/2002
# date:  2002-04-10 00:00:00 , legislature: 7
# Saving: log/20020410_doc_analyzer_log.txt lines: 11576
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 151, de 10/04/2002' ...
# len(result_dialogue_dict): 27
# Done in 9.18 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 154, de 17/04/2002
# date:  2002-04-17 00:00:00 , legislature: 7
# Saving: log/20020417_doc_analyzer_log.txt lines: 10990
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 154, de 17/04/2002' ...
# len(result_dialogue_dict): 26
# Done in 14.49 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 163, de 22/05/2002
# date:  2002-05-22 00:00:00 , legislature: 7
# Saving: log/20020522_doc_analyzer_log.txt lines: 12103
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 163, de 22/05/2002' ...
# len(result_dialogue_dict): 27
# Done in 13.94 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 166, de 29/05/2002
# date:  2002-05-29 00:00:00 , legislature: 7
# Saving: log/20020529_doc_analyzer_log.txt lines: 6104
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 166, de 29/05/2002' ...
# len(result_dialogue_dict): 11
# Done in 5.99 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 170, de 12/06/2002
# date:  2002-06-12 00:00:00 , legislature: 7
# Saving: log/20020612_doc_analyzer_log.txt lines: 11867
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 170, de 12/06/2002' ...
# len(result_dialogue_dict): 27
# Done in 14.10 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 177, de 26/06/2002
# date:  2002-06-26 00:00:00 , legislature: 7
# Saving: log/20020626_doc_analyzer_log.txt lines: 11872
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 177, de 26/06/2002' ...
# len(result_dialogue_dict): 27
# Done in 11.28 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 187, de 18/09/2002
# date:  2002-09-18 00:00:00 , legislature: 7
# Saving: log/20020918_doc_analyzer_log.txt lines: 10445
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 187, de 18/09/2002' ...
# len(result_dialogue_dict): 24
# Done in 10.37 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 189, de 25/09/2002
# date:  2002-09-25 00:00:00 , legislature: 7
# Saving: log/20020925_doc_analyzer_log.txt lines: 6935
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 189, de 25/09/2002' ...
# len(result_dialogue_dict): 16
# Done in 4.20 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 192, de 02/10/2002
# date:  2002-10-02 00:00:00 , legislature: 7
# Saving: log/20021002_doc_analyzer_log.txt lines: 13586
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 192, de 02/10/2002' ...
# len(result_dialogue_dict): 32
# Done in 14.11 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 207, de 20/11/2002
# date:  2002-11-20 00:00:00 , legislature: 7
# Saving: log/20021120_doc_analyzer_log.txt lines: 10888
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 207, de 20/11/2002' ...
# len(result_dialogue_dict): 26
# Done in 7.25 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 217, de 18/12/2002
# date:  2002-12-18 00:00:00 , legislature: 7
# Saving: log/20021218_doc_analyzer_log.txt lines: 11529
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 217, de 18/12/2002' ...
# len(result_dialogue_dict): 26
# Done in 9.59 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 225, de 12/02/2003
# date:  2003-02-12 00:00:00 , legislature: 7
# Saving: log/20030212_doc_analyzer_log.txt lines: 12346
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 225, de 12/02/2003' ...
# len(result_dialogue_dict): 29
# Done in 15.06 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 228, de 19/02/2003
# date:  2003-02-19 00:00:00 , legislature: 7
# Saving: log/20030219_doc_analyzer_log.txt lines: 10303
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 228, de 19/02/2003' ...
# len(result_dialogue_dict): 25
# Done in 8.32 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 241, de 02/04/2003
# date:  2003-04-02 00:00:00 , legislature: 7
# Saving: log/20030402_doc_analyzer_log.txt lines: 11037
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 241, de 02/04/2003' ...
# len(result_dialogue_dict): 24
# Done in 5.14 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 247, de 30/04/2003
# date:  2003-04-30 00:00:00 , legislature: 7
# Saving: log/20030430_doc_analyzer_log.txt lines: 11218
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 247, de 30/04/2003' ...
# len(result_dialogue_dict): 24
# Done in 7.34 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 249, de 07/05/2003
# date:  2003-05-07 00:00:00 , legislature: 7
# Saving: log/20030507_doc_analyzer_log.txt lines: 9683
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 249, de 07/05/2003' ...
# len(result_dialogue_dict): 24
# Done in 10.30 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 252, de 14/05/2003
# date:  2003-05-14 00:00:00 , legislature: 7
# Saving: log/20030514_doc_analyzer_log.txt lines: 11459
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 252, de 14/05/2003' ...
# len(result_dialogue_dict): 28
# Done in 6.43 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 257, de 11/06/2003
# date:  2003-06-11 00:00:00 , legislature: 7
# Saving: log/20030611_doc_analyzer_log.txt lines: 12545
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 257, de 11/06/2003' ...
# len(result_dialogue_dict): 27
# Done in 6.34 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 260, de 18/06/2003
# date:  2003-06-18 00:00:00 , legislature: 7
# Saving: log/20030618_doc_analyzer_log.txt lines: 11073
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 260, de 18/06/2003' ...
# len(result_dialogue_dict): 23
# Done in 2.54 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 263, de 25/06/2003
# date:  2003-06-25 00:00:00 , legislature: 7
# Saving: log/20030625_doc_analyzer_log.txt lines: 9227
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 263, de 25/06/2003' ...
# len(result_dialogue_dict): 18
# Done in 15.99 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 274, de 10/09/2003
# date:  2003-09-10 00:00:00 , legislature: 7
# Saving: log/20030910_doc_analyzer_log.txt lines: 11365
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 274, de 10/09/2003' ...
# len(result_dialogue_dict): 25
# Done in 3.75 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 286, de 15/10/2003
# date:  2003-10-15 00:00:00 , legislature: 7
# Saving: log/20031015_doc_analyzer_log.txt lines: 11495
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 286, de 15/10/2003' ...
# len(result_dialogue_dict): 25
# Done in 12.09 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 303, de 10/12/2003
# date:  2003-12-10 00:00:00 , legislature: 7
# Saving: log/20031210_doc_analyzer_log.txt lines: 11367
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 303, de 10/12/2003' ...
# len(result_dialogue_dict): 25
# Done in 5.04 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 306, de 17/12/2003
# date:  2003-12-17 00:00:00 , legislature: 7
# Saving: log/20031217_doc_analyzer_log.txt lines: 10934
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 306, de 17/12/2003' ...
# len(result_dialogue_dict): 26
# Done in 7.34 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 14, de 02/06/2004
# date:  2004-06-02 00:00:00 , legislature: 8
# Saving: log/20040602_doc_analyzer_log.txt lines: 9596
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 14, de 02/06/2004' ...
# len(result_dialogue_dict): 25
# Done in 4.21 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 17, de 16/06/2004
# date:  2004-06-16 00:00:00 , legislature: 8
# Saving: log/20040616_doc_analyzer_log.txt lines: 10885
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 17, de 16/06/2004' ...
# len(result_dialogue_dict): 28
# Done in 11.80 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 20, de 23/06/2004
# date:  2004-06-23 00:00:00 , legislature: 8
# Saving: log/20040623_doc_analyzer_log.txt lines: 10542
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 20, de 23/06/2004' ...
# len(result_dialogue_dict): 25
# Done in 3.62 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 22, de 30/06/2004
# date:  2004-06-30 00:00:00 , legislature: 8
# Saving: log/20040630_doc_analyzer_log.txt lines: 13395
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 22, de 30/06/2004' ...
# len(result_dialogue_dict): 29
# Done in 4.19 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 29, de 15/09/2004
# date:  2004-09-15 00:00:00 , legislature: 8
# Saving: log/20040915_doc_analyzer_log.txt lines: 12116
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 29, de 15/09/2004' ...
# len(result_dialogue_dict): 26
# Done in 6.04 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 38, de 06/10/2004
# date:  2004-10-06 00:00:00 , legislature: 8
# Saving: log/20041006_doc_analyzer_log.txt lines: 12700
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 38, de 06/10/2004' ...
# len(result_dialogue_dict): 28
# Done in 13.73 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 46, de 03/11/2004
# date:  2004-11-03 00:00:00 , legislature: 8
# Saving: log/20041103_doc_analyzer_log.txt lines: 14286
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 46, de 03/11/2004' ...
# len(result_dialogue_dict): 30
# Done in 4.09 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 51, de 24/11/2004
# date:  2004-11-24 00:00:00 , legislature: 8
# Saving: log/20041124_doc_analyzer_log.txt lines: 11375
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 51, de 24/11/2004' ...
# len(result_dialogue_dict): 27
# Done in 9.52 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 54, de 01/12/2004
# date:  2004-12-01 00:00:00 , legislature: 8
# Saving: log/20041201_doc_analyzer_log.txt lines: 11208
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 54, de 01/12/2004' ...
# len(result_dialogue_dict): 25
# Done in 5.68 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 59, de 15/12/2004
# date:  2004-12-15 00:00:00 , legislature: 8
# Saving: log/20041215_doc_analyzer_log.txt lines: 9006
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 59, de 15/12/2004' ...
# len(result_dialogue_dict): 24
# Done in 5.77 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 61, de 22/12/2004
# date:  2004-12-22 00:00:00 , legislature: 8
# Saving: log/20041222_doc_analyzer_log.txt lines: 8418
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 61, de 22/12/2004' ...
# len(result_dialogue_dict): 24
# Done in 5.17 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 71, de 23/02/2005
# date:  2005-02-23 00:00:00 , legislature: 8
# Saving: log/20050223_doc_analyzer_log.txt lines: 10969
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 71, de 23/02/2005' ...
# len(result_dialogue_dict): 26
# Done in 5.10 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 74, de 09/03/2005
# date:  2005-03-09 00:00:00 , legislature: 8
# Saving: log/20050309_doc_analyzer_log.txt lines: 11566
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 74, de 09/03/2005' ...
# len(result_dialogue_dict): 27
# Done in 4.97 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 77, de 16/03/2005
# date:  2005-03-16 00:00:00 , legislature: 8
# Saving: log/20050316_doc_analyzer_log.txt lines: 10730
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 77, de 16/03/2005' ...
# len(result_dialogue_dict): 24
# Done in 4.72 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 80, de 06/04/2005
# date:  2005-04-06 00:00:00 , legislature: 8
# Saving: log/20050406_doc_analyzer_log.txt lines: 9085
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 80, de 06/04/2005' ...
# len(result_dialogue_dict): 24
# Done in 7.09 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 91, de 18/05/2005
# date:  2005-05-18 00:00:00 , legislature: 8
# Saving: log/20050518_doc_analyzer_log.txt lines: 9440
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 91, de 18/05/2005' ...
# len(result_dialogue_dict): 22
# Done in 6.49 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 94, de 25/05/2005
# date:  2005-05-25 00:00:00 , legislature: 8
# Saving: log/20050525_doc_analyzer_log.txt lines: 10570
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 94, de 25/05/2005' ...
# len(result_dialogue_dict): 26
# Done in 9.22 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 96, de 01/06/2005
# date:  2005-06-01 00:00:00 , legislature: 8
# Saving: log/20050601_doc_analyzer_log.txt lines: 14029
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 96, de 01/06/2005' ...
# len(result_dialogue_dict): 30
# Done in 16.55 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 99, de 22/06/2005
# date:  2005-06-22 00:00:00 , legislature: 8
# Saving: log/20050622_doc_analyzer_log.txt lines: 8083
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 99, de 22/06/2005' ...
# len(result_dialogue_dict): 18
# Done in 2.45 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 102, de 29/06/2005
# date:  2005-06-29 00:00:00 , legislature: 8
# Saving: log/20050629_doc_analyzer_log.txt lines: 21106
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 102, de 29/06/2005' ...
# len(result_dialogue_dict): 33
# Done in 16.35 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 109, de 14/09/2005
# date:  2005-09-14 00:00:00 , legislature: 8
# Saving: log/20050914_doc_analyzer_log.txt lines: 12475
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 109, de 14/09/2005' ...
# len(result_dialogue_dict): 28
# Done in 6.99 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 118, de 05/10/2005
# date:  2005-10-05 00:00:00 , legislature: 8
# Saving: log/20051005_doc_analyzer_log.txt lines: 11399
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 118, de 05/10/2005' ...
# len(result_dialogue_dict): 26
# Done in 5.07 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 121, de 19/10/2005
# date:  2005-10-19 00:00:00 , legislature: 8
# Saving: log/20051019_doc_analyzer_log.txt lines: 11431
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 121, de 19/10/2005' ...
# len(result_dialogue_dict): 29
# Done in 4.12 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 131, de 23/11/2005
# date:  2005-11-23 00:00:00 , legislature: 8
# Saving: log/20051123_doc_analyzer_log.txt lines: 12037
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 131, de 23/11/2005' ...
# len(result_dialogue_dict): 25
# Done in 7.96 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 134, de 30/11/2005
# date:  2005-11-30 00:00:00 , legislature: 8
# Saving: log/20051130_doc_analyzer_log.txt lines: 9858
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 134, de 30/11/2005' ...
# len(result_dialogue_dict): 26
# Done in 6.58 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 137, de 14/12/2005
# date:  2005-12-14 00:00:00 , legislature: 8
# Saving: log/20051214_doc_analyzer_log.txt lines: 12459
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 137, de 14/12/2005' ...
# len(result_dialogue_dict): 28
# Done in 5.71 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 140, de 21/12/2005
# date:  2005-12-21 00:00:00 , legislature: 8
# Saving: log/20051221_doc_analyzer_log.txt lines: 10672
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 140, de 21/12/2005' ...
# len(result_dialogue_dict): 24
# Done in 5.03 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 147, de 08/02/2006
# date:  2006-02-08 00:00:00 , legislature: 8
# Saving: log/20060208_doc_analyzer_log.txt lines: 10658
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 147, de 08/02/2006' ...
# len(result_dialogue_dict): 24
# Done in 1.95 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 150, de 15/02/2006
# date:  2006-02-15 00:00:00 , legislature: 8
# Saving: log/20060215_doc_analyzer_log.txt lines: 12522
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 150, de 15/02/2006' ...
# len(result_dialogue_dict): 26
# Done in 4.21 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 153, de 22/02/2006
# date:  2006-02-22 00:00:00 , legislature: 8
# Saving: log/20060222_doc_analyzer_log.txt lines: 10465
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 153, de 22/02/2006' ...
# len(result_dialogue_dict): 27
# Done in 4.88 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 156, de 01/03/2006
# date:  2006-03-01 00:00:00 , legislature: 8
# Saving: log/20060301_doc_analyzer_log.txt lines: 11668
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 156, de 01/03/2006' ...
# len(result_dialogue_dict): 27
# Done in 4.28 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 159, de 15/03/2006
# date:  2006-03-15 00:00:00 , legislature: 8
# Saving: log/20060315_doc_analyzer_log.txt lines: 11980
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 159, de 15/03/2006' ...
# len(result_dialogue_dict): 27
# Done in 4.03 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 162, de 22/03/2006
# date:  2006-03-22 00:00:00 , legislature: 8
# Saving: log/20060322_doc_analyzer_log.txt lines: 11403
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 162, de 22/03/2006' ...
# len(result_dialogue_dict): 27
# Done in 2.68 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 165, de 29/03/2006
# date:  2006-03-29 00:00:00 , legislature: 8
# Saving: log/20060329_doc_analyzer_log.txt lines: 3271
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 165, de 29/03/2006' ...
# len(result_dialogue_dict): 6
# Done in 0.94 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 168, de 05/04/2006
# date:  2006-04-05 00:00:00 , legislature: 8
# Saving: log/20060405_doc_analyzer_log.txt lines: 12583
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 168, de 05/04/2006' ...
# len(result_dialogue_dict): 31
# Done in 5.08 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 171, de 26/04/2006
# date:  2006-04-26 00:00:00 , legislature: 8
# Saving: log/20060426_doc_analyzer_log.txt lines: 8521
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 171, de 26/04/2006' ...
# len(result_dialogue_dict): 21
# Done in 5.18 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 174, de 10/05/2006
# date:  2006-05-10 00:00:00 , legislature: 8
# EXCLUSIÓN DEL ORDEN DEL DÍA: True
# Saving: log/20060510_doc_analyzer_log.txt lines: 9739
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 174, de 10/05/2006' ...
# len(result_dialogue_dict): 23
# Done in 6.08 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 177, de 17/05/2006
# date:  2006-05-17 00:00:00 , legislature: 8
# Saving: log/20060517_doc_analyzer_log.txt lines: 14770
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 177, de 17/05/2006' ...
# len(result_dialogue_dict): 30
# Done in 11.73 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 180, de 24/05/2006
# date:  2006-05-24 00:00:00 , legislature: 8
# Saving: log/20060524_doc_analyzer_log.txt lines: 10511
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 180, de 24/05/2006' ...
# len(result_dialogue_dict): 28
# Done in 6.01 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 186, de 21/06/2006
# date:  2006-06-21 00:00:00 , legislature: 8
# Saving: log/20060621_doc_analyzer_log.txt lines: 9512
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 186, de 21/06/2006' ...
# len(result_dialogue_dict): 21
# Done in 1.80 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 189, de 28/06/2006
# date:  2006-06-28 00:00:00 , legislature: 8
# Saving: log/20060628_doc_analyzer_log.txt lines: 13413
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 189, de 28/06/2006' ...
# len(result_dialogue_dict): 28
# Done in 4.13 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 201, de 20/09/2006
# date:  2006-09-20 00:00:00 , legislature: 8
# Saving: log/20060920_doc_analyzer_log.txt lines: 10959
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 201, de 20/09/2006' ...
# len(result_dialogue_dict): 25
# Done in 1.98 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 203, de 27/09/2006
# date:  2006-09-27 00:00:00 , legislature: 8
# Saving: log/20060927_doc_analyzer_log.txt lines: 13288
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 203, de 27/09/2006' ...
# len(result_dialogue_dict): 28
# Done in 7.27 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 206, de 04/10/2006
# date:  2006-10-04 00:00:00 , legislature: 8
# Saving: log/20061004_doc_analyzer_log.txt lines: 9946
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 206, de 04/10/2006' ...
# len(result_dialogue_dict): 26
# Done in 1.57 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 209, de 18/10/2006
# date:  2006-10-18 00:00:00 , legislature: 8
# Saving: log/20061018_doc_analyzer_log.txt lines: 11806
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 209, de 18/10/2006' ...
# len(result_dialogue_dict): 28
# Done in 7.01 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 218, de 29/11/2006
# date:  2006-11-29 00:00:00 , legislature: 8
# Saving: log/20061129_doc_analyzer_log.txt lines: 13460
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 218, de 29/11/2006' ...
# len(result_dialogue_dict): 27
# Done in 7.42 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 221, de 13/12/2006
# date:  2006-12-13 00:00:00 , legislature: 8
# Saving: log/20061213_doc_analyzer_log.txt lines: 13772
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 221, de 13/12/2006' ...
# len(result_dialogue_dict): 27
# Done in 4.76 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 224, de 20/12/2006
# date:  2006-12-20 00:00:00 , legislature: 8
# Saving: log/20061220_doc_analyzer_log.txt lines: 4720
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 224, de 20/12/2006' ...
# len(result_dialogue_dict): 15
# Done in 0.73 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 230, de 07/02/2007
# date:  2007-02-07 00:00:00 , legislature: 8
# EXCLUSIÓN DEL ORDEN DEL DÍA: True
# Saving: log/20070207_doc_analyzer_log.txt lines: 10374
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 230, de 07/02/2007' ...
# len(result_dialogue_dict): 26
# Done in 3.35 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 233, de 21/02/2007
# date:  2007-02-21 00:00:00 , legislature: 8
# EXCLUSIÓN DEL ORDEN DEL DÍA: True
# Saving: log/20070221_doc_analyzer_log.txt lines: 9572
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 233, de 21/02/2007' ...
# len(result_dialogue_dict): 25
# Done in 6.63 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 236, de 28/02/2007
# date:  2007-02-28 00:00:00 , legislature: 8
# Saving: log/20070228_doc_analyzer_log.txt lines: 13911
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 236, de 28/02/2007' ...
# len(result_dialogue_dict): 29
# Done in 6.25 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 239, de 14/03/2007
# date:  2007-03-14 00:00:00 , legislature: 8
# Saving: log/20070314_doc_analyzer_log.txt lines: 7306
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 239, de 14/03/2007' ...
# len(result_dialogue_dict): 18
# Done in 1.26 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 242, de 21/03/2007
# date:  2007-03-21 00:00:00 , legislature: 8
# Saving: log/20070321_doc_analyzer_log.txt lines: 15702
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 242, de 21/03/2007' ...
# len(result_dialogue_dict): 28
# Done in 6.45 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 245, de 28/03/2007
# date:  2007-03-28 00:00:00 , legislature: 8
# Saving: log/20070328_doc_analyzer_log.txt lines: 9961
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 245, de 28/03/2007' ...
# len(result_dialogue_dict): 26
# Done in 4.11 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 248, de 18/04/2007
# date:  2007-04-18 00:00:00 , legislature: 8
# Saving: log/20070418_doc_analyzer_log.txt lines: 12567
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 248, de 18/04/2007' ...
# len(result_dialogue_dict): 26
# Done in 4.67 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 251, de 25/04/2007
# date:  2007-04-25 00:00:00 , legislature: 8
# Saving: log/20070425_doc_analyzer_log.txt lines: 10407
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 251, de 25/04/2007' ...
# len(result_dialogue_dict): 22
# Done in 5.62 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 254, de 09/05/2007
# date:  2007-05-09 00:00:00 , legislature: 8
# Saving: log/20070509_doc_analyzer_log.txt lines: 9440
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 254, de 09/05/2007' ...
# len(result_dialogue_dict): 23
# Done in 2.72 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 256, de 16/05/2007
# date:  2007-05-16 00:00:00 , legislature: 8
# Saving: log/20070516_doc_analyzer_log.txt lines: 10215
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 256, de 16/05/2007' ...
# len(result_dialogue_dict): 23
# Done in 1.13 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 258, de 30/05/2007
# date:  2007-05-30 00:00:00 , legislature: 8
# Saving: log/20070530_doc_analyzer_log.txt lines: 10452
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 258, de 30/05/2007' ...
# len(result_dialogue_dict): 26
# Done in 4.20 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 261, de 13/06/2007
# date:  2007-06-13 00:00:00 , legislature: 8
# Saving: log/20070613_doc_analyzer_log.txt lines: 9965
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 261, de 13/06/2007' ...
# len(result_dialogue_dict): 24
# Done in 2.40 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 264, de 20/06/2007
# date:  2007-06-20 00:00:00 , legislature: 8
# Saving: log/20070620_doc_analyzer_log.txt lines: 15049
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 264, de 20/06/2007' ...
# len(result_dialogue_dict): 25
# Done in 6.88 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 267, de 27/06/2007
# date:  2007-06-27 00:00:00 , legislature: 8
# Saving: log/20070627_doc_analyzer_log.txt lines: 8664
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 267, de 27/06/2007' ...
# len(result_dialogue_dict): 16
# Done in 2.43 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 280, de 12/09/2007
# date:  2007-09-12 00:00:00 , legislature: 8
# Saving: log/20070912_doc_analyzer_log.txt lines: 10644
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 280, de 12/09/2007' ...
# len(result_dialogue_dict): 24
# Done in 4.32 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 283, de 19/09/2007
# date:  2007-09-19 00:00:00 , legislature: 8
# Saving: log/20070919_doc_analyzer_log.txt lines: 10616
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 283, de 19/09/2007' ...
# len(result_dialogue_dict): 22
# Done in 2.24 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 286, de 26/09/2007
# date:  2007-09-26 00:00:00 , legislature: 8
# Saving: log/20070926_doc_analyzer_log.txt lines: 11270
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 286, de 26/09/2007' ...
# len(result_dialogue_dict): 25
# Done in 2.47 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 289, de 03/10/2007
# date:  2007-10-03 00:00:00 , legislature: 8
# Saving: log/20071003_doc_analyzer_log.txt lines: 10758
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 289, de 03/10/2007' ...
# len(result_dialogue_dict): 26
# Done in 6.86 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 292, de 17/10/2007
# date:  2007-10-17 00:00:00 , legislature: 8
# Saving: log/20071017_doc_analyzer_log.txt lines: 10039
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 292, de 17/10/2007' ...
# len(result_dialogue_dict): 23
# Done in 1.84 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 296, de 31/10/2007
# date:  2007-10-31 00:00:00 , legislature: 8
# Saving: log/20071031_doc_analyzer_log.txt lines: 3098
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 296, de 31/10/2007' ...
# len(result_dialogue_dict): 10
# Done in 2.32 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 301, de 21/11/2007
# date:  2007-11-21 00:00:00 , legislature: 8
# Saving: log/20071121_doc_analyzer_log.txt lines: 12427
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 301, de 21/11/2007' ...
# len(result_dialogue_dict): 28
# Done in 3.62 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 304, de 28/11/2007
# date:  2007-11-28 00:00:00 , legislature: 8
# Saving: log/20071128_doc_analyzer_log.txt lines: 12384
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 304, de 28/11/2007' ...
# len(result_dialogue_dict): 27
# Done in 3.48 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 307, de 12/12/2007
# date:  2007-12-12 00:00:00 , legislature: 8
# Saving: log/20071212_doc_analyzer_log.txt lines: 10799
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 307, de 12/12/2007' ...
# len(result_dialogue_dict): 24
# Done in 1.27 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 309, de 19/12/2007
# date:  2007-12-19 00:00:00 , legislature: 8
# Saving: log/20071219_doc_analyzer_log.txt lines: 6118
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 309, de 19/12/2007' ...
# len(result_dialogue_dict): 20
# Done in 0.69 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 7, de 14/05/2008
# date:  2008-05-14 00:00:00 , legislature: 9
# Saving: log/20080514_doc_analyzer_log.txt lines: 8764
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 7, de 14/05/2008' ...
# len(result_dialogue_dict): 20
# Done in 2.34 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 9, de 21/05/2008
# date:  2008-05-21 00:00:00 , legislature: 9
# Saving: log/20080521_doc_analyzer_log.txt lines: 10207
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 9, de 21/05/2008' ...
# len(result_dialogue_dict): 26
# Done in 11.73 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 11, de 28/05/2008
# date:  2008-05-28 00:00:00 , legislature: 9
# Saving: log/20080528_doc_analyzer_log.txt lines: 11826
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 11, de 28/05/2008' ...
# len(result_dialogue_dict): 26
# Done in 9.45 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 15, de 11/06/2008
# date:  2008-06-11 00:00:00 , legislature: 9
# Saving: log/20080611_doc_analyzer_log.txt lines: 12267
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 15, de 11/06/2008' ...
# len(result_dialogue_dict): 27
# Done in 8.99 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 19, de 25/06/2008
# date:  2008-06-25 00:00:00 , legislature: 9
# Saving: log/20080625_doc_analyzer_log.txt lines: 11192
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 19, de 25/06/2008' ...
# len(result_dialogue_dict): 23
# Done in 5.89 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 27, de 17/09/2008
# date:  2008-09-17 00:00:00 , legislature: 9
# Saving: log/20080917_doc_analyzer_log.txt lines: 14967
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 27, de 17/09/2008' ...
# len(result_dialogue_dict): 24
# Done in 10.17 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 29, de 24/09/2008
# date:  2008-09-24 00:00:00 , legislature: 9
# Saving: log/20080924_doc_analyzer_log.txt lines: 11217
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 29, de 24/09/2008' ...
# len(result_dialogue_dict): 21
# Done in 7.97 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 32, de 01/10/2008
# date:  2008-10-01 00:00:00 , legislature: 9
# Saving: log/20081001_doc_analyzer_log.txt lines: 9990
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 32, de 01/10/2008' ...
# len(result_dialogue_dict): 22
# Done in 9.91 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 35, de 15/10/2008
# date:  2008-10-15 00:00:00 , legislature: 9
# Saving: log/20081015_doc_analyzer_log.txt lines: 9887
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 35, de 15/10/2008' ...
# len(result_dialogue_dict): 22
# Done in 9.75 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 41, de 29/10/2008
# date:  2008-10-29 00:00:00 , legislature: 9
# Saving: log/20081029_doc_analyzer_log.txt lines: 9437
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 41, de 29/10/2008' ...
# len(result_dialogue_dict): 18
# Done in 8.33 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 46, de 19/11/2008
# date:  2008-11-19 00:00:00 , legislature: 9
# Saving: log/20081119_doc_analyzer_log.txt lines: 10247
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 46, de 19/11/2008' ...
# len(result_dialogue_dict): 24
# Done in 9.64 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 49, de 26/11/2008
# date:  2008-11-26 00:00:00 , legislature: 9
# Saving: log/20081126_doc_analyzer_log.txt lines: 10339
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 49, de 26/11/2008' ...
# len(result_dialogue_dict): 24
# Done in 9.38 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 52, de 10/12/2008
# date:  2008-12-10 00:00:00 , legislature: 9
# Saving: log/20081210_doc_analyzer_log.txt lines: 9081
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 52, de 10/12/2008' ...
# len(result_dialogue_dict): 22
# Done in 11.38 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 55, de 17/12/2008
# date:  2008-12-17 00:00:00 , legislature: 9
# Saving: log/20081217_doc_analyzer_log.txt lines: 12293
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 55, de 17/12/2008' ...
# len(result_dialogue_dict): 24
# Done in 10.41 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 80, de 29/04/2009
# date:  2009-04-29 00:00:00 , legislature: 9
# Saving: log/20090429_doc_analyzer_log.txt lines: 12620
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 80, de 29/04/2009' ...
# len(result_dialogue_dict): 24
# Done in 11.98 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 87, de 27/05/2009
# date:  2009-05-27 00:00:00 , legislature: 9
# Saving: log/20090527_doc_analyzer_log.txt lines: 10596
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 87, de 27/05/2009' ...
# len(result_dialogue_dict): 22
# Done in 8.82 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 89, de 10/06/2009
# date:  2009-06-10 00:00:00 , legislature: 9
# Saving: log/20090610_doc_analyzer_log.txt lines: 13666
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 89, de 10/06/2009' ...
# len(result_dialogue_dict): 21
# Done in 6.49 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 94, de 24/06/2009
# date:  2009-06-24 00:00:00 , legislature: 9
# Saving: log/20090624_doc_analyzer_log.txt lines: 13813
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 94, de 24/06/2009' ...
# len(result_dialogue_dict): 18
# Done in 6.81 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 101, de 09/09/2009
# date:  2009-09-09 00:00:00 , legislature: 9
# EXCLUSIÓN DEL ORDEN DEL DÍA: True
# Saving: log/20090909_doc_analyzer_log.txt lines: 3183
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 101, de 09/09/2009' ...
# len(result_dialogue_dict): 11
# Done in 0.33 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 101, de 09/09/2009
# date:  2009-09-09 00:00:00 , legislature: 9
# EXCLUSIÓN DEL ORDEN DEL DÍA: True
# Saving: log/20090909_doc_analyzer_log.txt lines: 3183
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 101, de 09/09/2009' ...
# len(result_dialogue_dict): 11
# Done in 0.32 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 104, de 16/09/2009
# date:  2009-09-16 00:00:00 , legislature: 9
# Saving: log/20090916_doc_analyzer_log.txt lines: 13618
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 104, de 16/09/2009' ...
# len(result_dialogue_dict): 24
# Done in 7.90 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 107, de 23/09/2009
# date:  2009-09-23 00:00:00 , legislature: 9
# Saving: log/20090923_doc_analyzer_log.txt lines: 8593
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 107, de 23/09/2009' ...
# len(result_dialogue_dict): 21
# Done in 6.14 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 112, de 14/10/2009
# date:  2009-10-14 00:00:00 , legislature: 9
# Saving: log/20091014_doc_analyzer_log.txt lines: 8488
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 112, de 14/10/2009' ...
# len(result_dialogue_dict): 21
# Done in 3.71 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 117, de 28/10/2009
# date:  2009-10-28 00:00:00 , legislature: 9
# Saving: log/20091028_doc_analyzer_log.txt lines: 14812
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 117, de 28/10/2009' ...
# len(result_dialogue_dict): 22
# Done in 5.53 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 123, de 18/11/2009
# date:  2009-11-18 00:00:00 , legislature: 9
# Saving: log/20091118_doc_analyzer_log.txt lines: 10594
# ...
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 64, de 10/10/2012' ...
# len(result_dialogue_dict): 23
# Done in 5.26 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 70, de 31/10/2012
# date:  2012-10-31 00:00:00 , legislature: 10
# Saving: log/20121031_doc_analyzer_log.txt lines: 10430
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 70, de 31/10/2012' ...
# len(result_dialogue_dict): 19
# Done in 5.33 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 76, de 28/11/2012
# date:  2012-11-28 00:00:00 , legislature: 10
# Saving: log/20121128_doc_analyzer_log.txt lines: 15822
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 76, de 28/11/2012' ...
# len(result_dialogue_dict): 23
# Done in 9.38 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 80, de 12/12/2012
# date:  2012-12-12 00:00:00 , legislature: 10
# Saving: log/20121212_doc_analyzer_log.txt lines: 8286
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 80, de 12/12/2012' ...
# len(result_dialogue_dict): 17
# Done in 1.98 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 83, de 19/12/2012
# date:  2012-12-19 00:00:00 , legislature: 10
# Saving: log/20121219_doc_analyzer_log.txt lines: 8882
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 83, de 19/12/2012' ...
# len(result_dialogue_dict): 19
# Done in 2.87 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 87, de 30/01/2013
# date:  2013-01-30 00:00:00 , legislature: 10
# Saving: log/20130130_doc_analyzer_log.txt lines: 18126
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 87, de 30/01/2013' ...
# len(result_dialogue_dict): 17
# Done in 7.80 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 89, de 13/02/2013
# date:  2013-02-13 00:00:00 , legislature: 10
# Saving: log/20130213_doc_analyzer_log.txt lines: 11326
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 89, de 13/02/2013' ...
# len(result_dialogue_dict): 19
# Done in 3.58 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 94, de 27/02/2013
# date:  2013-02-27 00:00:00 , legislature: 10
# Saving: log/20130227_doc_analyzer_log.txt lines: 10400
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 94, de 27/02/2013' ...
# len(result_dialogue_dict): 21
# Done in 3.34 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 96, de 13/03/2013
# date:  2013-03-13 00:00:00 , legislature: 10
# Saving: log/20130313_doc_analyzer_log.txt lines: 10913
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 96, de 13/03/2013' ...
# len(result_dialogue_dict): 22
# Done in 6.81 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 99, de 20/03/2013
# date:  2013-03-20 00:00:00 , legislature: 10
# Saving: log/20130320_doc_analyzer_log.txt lines: 8765
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 99, de 20/03/2013' ...
# len(result_dialogue_dict): 19
# Done in 4.75 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 105, de 17/04/2013
# date:  2013-04-17 00:00:00 , legislature: 10
# Saving: log/20130417_doc_analyzer_log.txt lines: 10374
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 105, de 17/04/2013' ...
# len(result_dialogue_dict): 19
# Done in 3.80 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 108, de 24/04/2013
# date:  2013-04-24 00:00:00 , legislature: 10
# Saving: log/20130424_doc_analyzer_log.txt lines: 9294
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 108, de 24/04/2013' ...
# len(result_dialogue_dict): 16
# Done in 3.67 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 113, de 22/05/2013
# date:  2013-05-22 00:00:00 , legislature: 10
# Saving: log/20130522_doc_analyzer_log.txt lines: 10680
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 113, de 22/05/2013' ...
# len(result_dialogue_dict): 19
# Done in 3.13 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 116, de 29/05/2013
# date:  2013-05-29 00:00:00 , legislature: 10
# Saving: log/20130529_doc_analyzer_log.txt lines: 9986
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 116, de 29/05/2013' ...
# len(result_dialogue_dict): 18
# Done in 2.49 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 119, de 12/06/2013
# date:  2013-06-12 00:00:00 , legislature: 10
# Saving: log/20130612_doc_analyzer_log.txt lines: 10696
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 119, de 12/06/2013' ...
# len(result_dialogue_dict): 21
# Done in 6.37 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 122, de 19/06/2013
# date:  2013-06-19 00:00:00 , legislature: 10
# Saving: log/20130619_doc_analyzer_log.txt lines: 11502
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 122, de 19/06/2013' ...
# len(result_dialogue_dict): 20
# Done in 2.36 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 125, de 26/06/2013
# date:  2013-06-26 00:00:00 , legislature: 10
# Saving: log/20130626_doc_analyzer_log.txt lines: 9795
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 125, de 26/06/2013' ...
# len(result_dialogue_dict): 18
# Done in 2.38 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 135, de 11/09/2013
# date:  2013-09-11 00:00:00 , legislature: 10
# Saving: log/20130911_doc_analyzer_log.txt lines: 8125
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 135, de 11/09/2013' ...
# len(result_dialogue_dict): 17
# Done in 2.38 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 138, de 18/09/2013
# date:  2013-09-18 00:00:00 , legislature: 10
# Saving: log/20130918_doc_analyzer_log.txt lines: 10111
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 138, de 18/09/2013' ...
# len(result_dialogue_dict): 19
# Done in 3.64 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 141, de 25/09/2013
# date:  2013-09-25 00:00:00 , legislature: 10
# Saving: log/20130925_doc_analyzer_log.txt lines: 10045
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 141, de 25/09/2013' ...
# len(result_dialogue_dict): 19
# Done in 1.15 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 147, de 16/10/2013
# date:  2013-10-16 00:00:00 , legislature: 10
# Saving: log/20131016_doc_analyzer_log.txt lines: 10840
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 147, de 16/10/2013' ...
# len(result_dialogue_dict): 19
# Done in 7.87 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 152, de 30/10/2013
# date:  2013-10-30 00:00:00 , legislature: 10
# Saving: log/20131030_doc_analyzer_log.txt lines: 10318
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 152, de 30/10/2013' ...
# len(result_dialogue_dict): 18
# Done in 6.01 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 158, de 20/11/2013
# date:  2013-11-20 00:00:00 , legislature: 10
# Saving: log/20131120_doc_analyzer_log.txt lines: 16210
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 158, de 20/11/2013' ...
# len(result_dialogue_dict): 22
# Done in 4.06 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 161, de 27/11/2013
# date:  2013-11-27 00:00:00 , legislature: 10
# Saving: log/20131127_doc_analyzer_log.txt lines: 16089
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 161, de 27/11/2013' ...
# len(result_dialogue_dict): 21
# Done in 6.59 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 164, de 11/12/2013
# date:  2013-12-11 00:00:00 , legislature: 10
# Saving: log/20131211_doc_analyzer_log.txt lines: 7988
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 164, de 11/12/2013' ...
# len(result_dialogue_dict): 16
# Done in 2.95 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 167, de 18/12/2013
# date:  2013-12-18 00:00:00 , legislature: 10
# Saving: log/20131218_doc_analyzer_log.txt lines: 11843
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 167, de 18/12/2013' ...
# len(result_dialogue_dict): 22
# Done in 4.13 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 172, de 22/01/2014
# date:  2014-01-22 00:00:00 , legislature: 10
# Saving: log/20140122_doc_analyzer_log.txt lines: 16112
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 172, de 22/01/2014' ...
# len(result_dialogue_dict): 17
# Done in 4.50 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 175, de 12/02/2014
# date:  2014-02-12 00:00:00 , legislature: 10
# Saving: log/20140212_doc_analyzer_log.txt lines: 17989
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 175, de 12/02/2014' ...
# len(result_dialogue_dict): 24
# Done in 6.67 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 186, de 12/03/2014
# date:  2014-03-12 00:00:00 , legislature: 10
# Saving: log/20140312_doc_analyzer_log.txt lines: 16838
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 186, de 12/03/2014' ...
# len(result_dialogue_dict): 23
# Done in 6.49 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 189, de 19/03/2014
# date:  2014-03-19 00:00:00 , legislature: 10
# Saving: log/20140319_doc_analyzer_log.txt lines: 10854
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 189, de 19/03/2014' ...
# len(result_dialogue_dict): 17
# Done in 2.70 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 193, de 09/04/2014
# date:  2014-04-09 00:00:00 , legislature: 10
# EXCLUSIÓN DEL ORDEN DEL DÍA: True
# Saving: log/20140409_doc_analyzer_log.txt lines: 13716
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 193, de 09/04/2014' ...
# len(result_dialogue_dict): 21
# Done in 1.86 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 198, de 07/05/2014
# date:  2014-05-07 00:00:00 , legislature: 10
# Saving: log/20140507_doc_analyzer_log.txt lines: 9651
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 198, de 07/05/2014' ...
# len(result_dialogue_dict): 17
# Done in 2.43 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 200, de 14/05/2014
# date:  2014-05-14 00:00:00 , legislature: 10
# Saving: log/20140514_doc_analyzer_log.txt lines: 17553
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 200, de 14/05/2014' ...
# len(result_dialogue_dict): 21
# Done in 4.74 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 202, de 28/05/2014
# date:  2014-05-28 00:00:00 , legislature: 10
# Saving: log/20140528_doc_analyzer_log.txt lines: 10111
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 202, de 28/05/2014' ...
# len(result_dialogue_dict): 19
# Done in 2.72 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 206, de 25/06/2014
# date:  2014-06-25 00:00:00 , legislature: 10
# Saving: log/20140625_doc_analyzer_log.txt lines: 9697
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 206, de 25/06/2014' ...
# len(result_dialogue_dict): 19
# Done in 2.48 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 211, de 09/07/2014
# date:  2014-07-09 00:00:00 , legislature: 10
# Saving: log/20140709_doc_analyzer_log.txt lines: 8467
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 211, de 09/07/2014' ...
# len(result_dialogue_dict): 18
# Done in 1.25 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 216, de 10/09/2014
# date:  2014-09-10 00:00:00 , legislature: 10
# Saving: log/20140910_doc_analyzer_log.txt lines: 11738
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 216, de 10/09/2014' ...
# len(result_dialogue_dict): 21
# Done in 1.32 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 219, de 17/09/2014
# date:  2014-09-17 00:00:00 , legislature: 10
# Saving: log/20140917_doc_analyzer_log.txt lines: 8336
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 219, de 17/09/2014' ...
# len(result_dialogue_dict): 17
# Done in 5.10 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 222, de 24/09/2014
# date:  2014-09-24 00:00:00 , legislature: 10
# Saving: log/20140924_doc_analyzer_log.txt lines: 12476
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 222, de 24/09/2014' ...
# len(result_dialogue_dict): 18
# Done in 2.41 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 225, de 08/10/2014
# date:  2014-10-08 00:00:00 , legislature: 10
# Saving: log/20141008_doc_analyzer_log.txt lines: 10533
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 225, de 08/10/2014' ...
# len(result_dialogue_dict): 21
# Done in 5.17 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 229, de 15/10/2014
# date:  2014-10-15 00:00:00 , legislature: 10
# Saving: log/20141015_doc_analyzer_log.txt lines: 10078
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 229, de 15/10/2014' ...
# len(result_dialogue_dict): 18
# Done in 4.06 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 235, de 29/10/2014
# date:  2014-10-29 00:00:00 , legislature: 10
# Saving: log/20141029_doc_analyzer_log.txt lines: 9306
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 235, de 29/10/2014' ...
# len(result_dialogue_dict): 17
# Done in 3.83 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 241, de 19/11/2014
# date:  2014-11-19 00:00:00 , legislature: 10
# EXCLUSIÓN DEL ORDEN DEL DÍA: True
# Saving: log/20141119_doc_analyzer_log.txt lines: 13691
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 241, de 19/11/2014' ...
# len(result_dialogue_dict): 20
# Done in 2.86 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 244, de 26/11/2014
# date:  2014-11-26 00:00:00 , legislature: 10
# Saving: log/20141126_doc_analyzer_log.txt lines: 8531
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 244, de 26/11/2014' ...
# len(result_dialogue_dict): 18
# Done in 3.51 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 247, de 10/12/2014
# date:  2014-12-10 00:00:00 , legislature: 10
# Saving: log/20141210_doc_analyzer_log.txt lines: 8902
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 247, de 10/12/2014' ...
# len(result_dialogue_dict): 16
# Done in 2.10 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 250, de 17/12/2014
# date:  2014-12-17 00:00:00 , legislature: 10
# Saving: log/20141217_doc_analyzer_log.txt lines: 13309
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 250, de 17/12/2014' ...
# len(result_dialogue_dict): 23
# Done in 6.65 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 254, de 21/01/2015
# date:  2015-01-21 00:00:00 , legislature: 10
# Saving: log/20150121_doc_analyzer_log.txt lines: 14317
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 254, de 21/01/2015' ...
# len(result_dialogue_dict): 15
# Done in 3.42 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 257, de 11/02/2015
# date:  2015-02-11 00:00:00 , legislature: 10
# Saving: log/20150211_doc_analyzer_log.txt lines: 7841
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 257, de 11/02/2015' ...
# len(result_dialogue_dict): 17
# Done in 3.09 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 260, de 18/02/2015
# date:  2015-02-18 00:00:00 , legislature: 10
# Saving: log/20150218_doc_analyzer_log.txt lines: 15329
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 260, de 18/02/2015' ...
# len(result_dialogue_dict): 22
# Done in 6.92 seconds
# Analyzing: Congreso de los Diputados, Pleno y Dip. Perm., núm. 266, de 11/03/2015
# date:  2015-03-11 00:00:00 , legislature: 10
# Saving: log/20150311_doc_analyzer_log.txt lines: 10407
# Updating 'Congreso de los Diputados, Pleno y Dip. Perm., núm. 266, de 11/03/2015' ...
# len(result_dialogue_dict): 20
# Done in 1.37 seconds
#
# ------------------------------------------------------------------------------------------------------------------------
# Analysis finished in 1665.55 seconds

# %% [markdown]
# #### Paralelització de l'analisi

# %%
from IPython import parallel
try:
    clients = parallel.Client()
    print clients.ids
except IOError as e:
    print e
# Out:
# [0, 1, 2, 3]

# %%
lview_all = clients.load_balanced_view()
print lview_all
# Out:
# <LoadBalancedView None>

# %%
def parallel_process_doc(doc):
    t_init = time.clock()
    print "Analyzing:", doc['description']
    result_dialogue_dict = document_analyzer(doc)

    print "Updating '" + doc['description'] + "' ..."
    # save_dict_json(result_dialogue_dict, 'log/' + file_name + '_dialogue_dict.json')

    # dictionary conversion to session_dictionary
    session_dictionary = [None] * len(result_dialogue_dict)
    print "len(result_dialogue_dict):", len(result_dialogue_dict)
    for key in result_dialogue_dict:
        intervention_dictionary = [None] * len(result_dialogue_dict[key]['intervention_dictionary'])
        for subkey in result_dialogue_dict[key]['intervention_dictionary']:
            intervention_dictionary[int(subkey)] = result_dialogue_dict[key]['intervention_dictionary'][subkey]
        result_dialogue_dict[key]['intervention_dictionary'] = intervention_dictionary
        session_dictionary[int(key)-1] = result_dialogue_dict[key]

    # http://docs.mongodb.org/manual/tutorial/modify-documents/
    doc_col.update({'_id':doc['_id']}, \
                   {'$set':{'session_dictionary':session_dictionary, 'updated_session_dictionary':datetime.datetime.utcnow()}}, \
                   upsert=False, multi=False)
    t_end = time.clock()
    print "Done in {0:.2f} seconds".format(t_end-t_init)

# %%
import time

# Col.lecció de documents a la BD
doc_col = db['document']
# Col.lecció de diputats a la BD
congres_members_collection = db['congres_members']
# Col.lecció de legislatures a la BD
legislatures_collection = db['legislatures']
# Col.lecció de grups parlamentaris a la BD
congres_groups_collection = db['congres_groups']

'''
# All
doc_start_date = "01/01/1990"
d_doc_start_date = datetime.datetime.strptime(doc_start_date, "%d/%m/%Y")
d_doc_end_date = datetime.datetime.utcnow()
result = doc_col.find({'date': {'$gte': d_doc_start_date, '$lte': d_doc_end_date}}).sort('date',1)
'''

doc_date = "19/10/2005"
d_doc_date = datetime.datetime.strptime(doc_date, "%d/%m/%Y")
file_name = d_doc_date.strftime("%Y%m%d")
result = doc_col.find({'date': d_doc_date})

'''
# Legislatura X
doc_start_date = "14/12/2011"
d_doc_start_date = datetime.datetime.strptime(doc_start_date, "%d/%m/%Y")
d_doc_end_date = datetime.datetime.utcnow()
result = doc_col.find({'date': {'$gte': d_doc_start_date, '$lte': d_doc_end_date}}).sort('date',1)
'''
'''
# Legislaturas V-IX
doc_start_date = "29/06/1993"
d_doc_start_date = datetime.datetime.strptime(doc_start_date, "%d/%m/%Y")
doc_end_date = "14/12/2011"
d_doc_end_date = datetime.datetime.strptime(doc_end_date, "%d/%m/%Y")
result = doc_col.find({'date': {'$gte': d_doc_start_date, '$lte': d_doc_end_date}}).sort('date',1)
'''

if result.count() > 0:
    
    t_total_init = time.clock()
    
    async = lview_all.map(parallel_process_doc, result, block = False)
            
    t_total_end = time.clock()
    print "\n" + ("-"*120)
    print "Analysis finished in {0:.2f} seconds".format(t_total_end-t_total_init)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-22e6bc1b8a55> in <module>()
#      43     t_total_init = time.clock()
#      44
# ---> 45     async = lview_all.map(parallel_process_doc, result, block = False)
#      46
#      47     t_total_end = time.clock()
#
# NameError: name 'lview_all' is not defined

# %% [markdown]
# #### Estadística de l'anàl.lisi dels resultats obtinguts

# %%
# Col.lecció de documents a la BD
doc_col = db['document']

#
# All
doc_start_date = "01/01/1990"
d_doc_start_date = datetime.datetime.strptime(doc_start_date, "%d/%m/%Y")
d_doc_end_date = datetime.datetime.utcnow()
result = doc_col.find({'date': {'$gte': d_doc_start_date, '$lte': d_doc_end_date}}).sort('date',1)
'''
# Legislatura X
doc_start_date = "14/12/2011"
d_doc_start_date = datetime.datetime.strptime(doc_start_date, "%d/%m/%Y")
d_doc_end_date = datetime.datetime.utcnow()
result = doc_col.find({'date': {'$gte': d_doc_start_date, '$lte': d_doc_end_date}}).sort('date',1)
'''
'''
# Legislaturas V-IX
doc_start_date = "29/06/1993"
d_doc_start_date = datetime.datetime.strptime(doc_start_date, "%d/%m/%Y")
doc_end_date = "14/12/2011"
d_doc_end_date = datetime.datetime.strptime(doc_end_date, "%d/%m/%Y")
result = doc_col.find({'date': {'$gte': d_doc_start_date, '$lte': d_doc_end_date}}).sort('date',1)
'''

if result.count() > 0 :
    print "Num. of docs:", result.count()
    for doc in result:
        print doc['description']
        dialogue_stats = []
        for dialogue_id, dialogue in enumerate(doc['session_dictionary']):
            num_interventions = len(dialogue['intervention_dictionary'])
            dialogue_stats.append(num_interventions)
            if dialogue['question'].strip()=="":
                print "WARN: The question", dialogue['num_exp'] ,"is empty"
            if dialogue['question'].strip().count('\n')>10:
                print "WARN: The question", dialogue['num_exp'] ,"seems too long:", dialogue['question'].strip().count('\n'),"lines"
            if dialogue['speaker']=="not found":
                print "WARN: speaker of question", dialogue['num_exp'] ,"not found"
            if num_interventions < 2:
                print "WARN: The question", dialogue['num_exp'] ," has few interventions"
            else:
                for intervention_id, intervention in enumerate(dialogue['intervention_dictionary']):
                    if intervention['text'].strip()=="":
                        print "WARN: intervention", intervention_id, "of question", dialogue['num_exp'] ,"is empty"
                    if intervention['who']['surname']=='<unknown>':
                        print "WARN: who of intervention", intervention_id, "of question", dialogue['num_exp'] ,"is unknown"
                
        print len(doc['session_dictionary']), ":", dialogue_stats
# Out:
# Num. of docs: 372
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 10, de 15/09/1993
# WARN: intervention 2 of question 180/000021 is empty
# WARN: The question 180/000033  has few interventions
# WARN: The question 180/000014  has few interventions
# WARN: intervention 3 of question 180/000019 is empty
# WARN: intervention 1 of question 180/000030 is empty
# WARN: The question 180/000017  has few interventions
# WARN: intervention 2 of question 180/000018 is empty
# WARN: intervention 4 of question 180/000018 is empty
# WARN: intervention 1 of question 180/000022 is empty
# WARN: intervention 2 of question 180/000027 is empty
# WARN: intervention 4 of question 180/000027 is empty
# WARN: intervention 1 of question 180/000023 is empty
# WARN: intervention 2 of question 180/000028 is empty
# WARN: The question 180/000034  has few interventions
# WARN: intervention 2 of question 172/000002 is empty
# WARN: intervention 4 of question 172/000002 is empty
# WARN: The question 172/000003 is empty
# WARN: intervention 2 of question 172/000004 is empty
# 26 : [3, 3, 4, 1, 2, 2, 0, 5, 4, 3, 0, 4, 6, 5, 6, 4, 3, 4, 1, 2, 3, 4, 4, 10, 12, 8]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 13, de 22/09/1993
# WARN: The question 180/000043  has few interventions
# WARN: The question 180/000044  has few interventions
# WARN: intervention 3 of question 180/000038 is empty
# WARN: intervention 0 of question 180/000048 is empty
# WARN: intervention 0 of question 180/000051 is empty
# WARN: intervention 0 of question 180/000057 is empty
# WARN: intervention 3 of question 180/000057 is empty
# WARN: intervention 0 of question 180/000053 is empty
# WARN: The question 180/000045  has few interventions
# WARN: intervention 0 of question 180/000046 is empty
# WARN: intervention 0 of question 180/000036 is empty
# WARN: The question 180/000040  has few interventions
# WARN: intervention 0 of question 180/000041 is empty
# WARN: The question 180/000042  has few interventions
# 27 : [4, 4, 2, 1, 1, 4, 5, 2, 4, 4, 4, 4, 4, 5, 4, 5, 6, 4, 1, 2, 2, 3, 1, 2, 1, 9, 9]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 16, de 29/09/1993
# WARN: intervention 2 of question 180/000064 is empty
# WARN: intervention 1 of question 180/000071 is empty
# WARN: intervention 1 of question 180/000080 is empty
# WARN: The question 180/000069  has few interventions
# WARN: The question 180/000073  has few interventions
# WARN: intervention 2 of question 180/000093 is empty
# WARN: The question 180/000067  has few interventions
# WARN: intervention 3 of question 180/000086 is empty
# WARN: intervention 2 of question 180/000084 is empty
# WARN: intervention 1 of question 180/000082 is empty
# WARN: intervention 4 of question 180/000082 is empty
# WARN: intervention 1 of question 180/000078 is empty
# WARN: intervention 3 of question 180/000075 is empty
# 24 : [5, 3, 5, 2, 3, 1, 2, 1, 3, 5, 1, 2, 5, 2, 3, 4, 3, 6, 3, 6, 4, 11, 10, 6]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 21, de 27/10/1993
# WARN: intervention 0 of question 180/000097 is empty
# WARN: intervention 2 of question 180/000099 is empty
# WARN: intervention 1 of question 180/000102 is empty
# WARN: intervention 2 of question 180/000113 is empty
# WARN: intervention 3 of question 180/000118 is empty
# WARN: intervention 1 of question 180/000096 is empty
# WARN: intervention 3 of question 180/000096 is empty
# WARN: intervention 5 of question 180/000096 is empty
# WARN: intervention 1 of question 180/000066 is empty
# WARN: intervention 3 of question 180/000066 is empty
# WARN: intervention 4 of question 172/000013 is empty
# WARN: intervention 6 of question 172/000013 is empty
# WARN: intervention 9 of question 172/000013 is empty
# WARN: The question 172/000014  has few interventions
# 19 : [4, 7, 2, 2, 4, 3, 4, 5, 7, 6, 5, 5, 4, 4, 4, 4, 5, 14, 0]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 24, de 03/11/1993
# WARN: intervention 0 of question 180/000098 is empty
# WARN: The question 180/000104  has few interventions
# WARN: intervention 0 of question 180/000112 is empty
# WARN: intervention 3 of question 180/000112 is empty
# WARN: intervention 2 of question 180/000115 is empty
# WARN: intervention 0 of question 180/000122 is empty
# WARN: The question 180/000123  has few interventions
# WARN: intervention 1 of question 180/000125 is empty
# WARN: The question 180/000130  has few interventions
# WARN: intervention 1 of question 180/000143 is empty
# WARN: intervention 0 of question 180/000139 is empty
# WARN: intervention 2 of question 180/000139 is empty
# WARN: intervention 4 of question 180/000139 is empty
# WARN: intervention 2 of question 180/000119 is empty
# WARN: intervention 4 of question 180/000119 is empty
# WARN: intervention 1 of question 180/000142 is empty
# WARN: intervention 3 of question 180/000142 is empty
# WARN: intervention 2 of question 180/000131 is empty
# WARN: The question 180/000134 seems too long: 89 lines
# WARN: intervention 2 of question 180/000134 is empty
# WARN: intervention 10 of question 172/000015 is empty
# WARN: intervention 4 of question 172/000016 is empty
# 31 : [3, 1, 5, 2, 4, 2, 2, 3, 1, 3, 4, 2, 2, 3, 4, 2, 2, 1, 2, 4, 7, 6, 6, 5, 5, 4, 4, 4, 2, 14, 7]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 32, de 24/11/1993
# WARN: intervention 0 of question 180/000158 is empty
# WARN: The question 180/000150  has few interventions
# WARN: intervention 0 of question 180/000156 is empty
# WARN: intervention 6 of question 180/000156 is empty
# WARN: intervention 1 of question 180/000160 is empty
# WARN: intervention 3 of question 180/000155 is empty
# WARN: The question 172/000017  has few interventions
# WARN: The question 172/000020  has few interventions
# WARN: intervention 9 of question 172/000019 is empty
# 25 : [2, 2, 2, 3, 4, 2, 5, 2, 2, 1, 4, 2, 7, 4, 8, 5, 7, 4, 5, 4, 3, 13, 0, 0, 21]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 35, de 01/12/1993
# WARN: intervention 1 of question 180/000195 is empty
# WARN: intervention 2 of question 180/000202 is empty
# WARN: intervention 2 of question 180/000175 is empty
# WARN: intervention 1 of question 180/000176 is empty
# WARN: intervention 1 of question 180/000181 is empty
# WARN: intervention 2 of question 180/000178 is empty
# WARN: intervention 2 of question 180/000184 is empty
# WARN: intervention 2 of question 180/000185 is empty
# WARN: The question 180/000201  has few interventions
# 25 : [4, 4, 3, 2, 4, 5, 3, 2, 3, 4, 4, 5, 4, 3, 4, 3, 2, 2, 3, 4, 3, 8, 4, 1, 11]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 38, de 15/12/1993
# WARN: intervention 0 of question 180/000205 is empty
# WARN: intervention 5 of question 180/000205 is empty
# WARN: intervention 3 of question 180/000210 is empty
# WARN: intervention 1 of question 180/000211 is empty
# WARN: intervention 0 of question 180/000206 is empty
# WARN: intervention 0 of question 181/000230 is empty
# 23 : [4, 7, 5, 5, 4, 4, 3, 4, 4, 4, 4, 6, 2, 2, 2, 2, 2, 2, 2, 2, 2, 6, 3]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 44, de 09/02/1994
# WARN: intervention 3 of question 180/000251 is empty
# WARN: intervention 3 of question 180/000260 is empty
# WARN: The question 180/000237  has few interventions
# WARN: intervention 0 of question 180/000253 is empty
# WARN: The question 180/000257  has few interventions
# WARN: intervention 8 of question 172/000026 is empty
# WARN: intervention 19 of question 172/000026 is empty
# 25 : [2, 2, 3, 2, 5, 4, 3, 2, 4, 5, 2, 1, 4, 3, 2, 4, 2, 2, 3, 2, 0, 21, 12, 9, 5]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 47, de 16/02/1994
# WARN: intervention 2 of question 180/000279 is empty
# WARN: intervention 4 of question 180/000279 is empty
# WARN: intervention 1 of question 180/000280 is empty
# WARN: intervention 3 of question 180/000280 is empty
# WARN: The question 180/000262  has few interventions
# WARN: The question 180/000283  has few interventions
# WARN: intervention 3 of question 180/000271 is empty
# WARN: intervention 1 of question 180/000282 is empty
# WARN: intervention 2 of question 180/000265 is empty
# WARN: intervention 3 of question 172/000030 is empty
# 29 : [2, 2, 6, 6, 4, 2, 2, 1, 4, 1, 4, 4, 4, 5, 2, 2, 2, 4, 4, 3, 2, 2, 5, 4, 4, 3, 2, 7, 8]
# Congreso de los Diputados, Pleno y Dip. Perm., núm.
 16]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 67, de 27/04/1994
# WARN: The question 180/000435  has few interventions
# WARN: The question 180/000436  has few interventions
# WARN: intervention 0 of question 180/000456 is empty
# WARN: The question 180/000441  has few interventions
# WARN: The question 180/000447  has few interventions
# WARN: intervention 0 of question 180/000438 is empty
# WARN: intervention 5 of question 172/000048 is empty
# WARN: intervention 8 of question 172/000048 is empty
# WARN: intervention 5 of question 172/000049 is empty
# 25 : [6, 1, 1, 3, 2, 4, 2, 2, 0, 4, 2, 4, 4, 4, 4, 4, 2, 2, 3, 1, 2, 3, 4, 15, 9]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 73, de 18/05/1994
# WARN: intervention 1 of question 180/000475 is empty
# WARN: intervention 3 of question 180/000475 is empty
# WARN: intervention 5 of question 180/000475 is empty
# WARN: intervention 1 of question 180/000462 is empty
# WARN: intervention 3 of question 180/000462 is empty
# WARN: intervention 1 of question 180/000464 is empty
# WARN: intervention 3 of question 180/000464 is empty
# WARN: intervention 1 of question 180/000467 is empty
# WARN: intervention 3 of question 180/000467 is empty
# WARN: intervention 5 of question 180/000467 is empty
# WARN: intervention 1 of question 180/000469 is empty
# WARN: intervention 3 of question 180/000469 is empty
# WARN: intervention 6 of question 180/000469 is empty
# WARN: intervention 10 of question 180/000469 is empty
# WARN: intervention 1 of question 180/000483 is empty
# WARN: The question 180/000485  has few interventions
# WARN: intervention 0 of question 172/000050 is empty
# WARN: intervention 12 of question 172/000050 is empty
# 26 : [4, 5, 6, 4, 7, 3, 7, 6, 9, 7, 4, 7, 13, 6, 2, 4, 3, 4, 1, 4, 5, 4, 3, 2, 17, 6]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 76, de 25/05/1994
# WARN: intervention 2 of question 180/000499 is empty
# WARN: intervention 4 of question 180/000499 is empty
# WARN: intervention 1 of question 180/000492 is empty
# WARN: intervention 3 of question 180/000492 is empty
# WARN: intervention 5 of question 180/000492 is empty
# WARN: intervention 1 of question 180/000494 is empty
# WARN: intervention 3 of question 180/000494 is empty
# WARN: intervention 5 of question 180/000494 is empty
# WARN: intervention 1 of question 180/000495 is empty
# WARN: The question 180/000497  has few interventions
# WARN: The question 180/000512  has few interventions
# WARN: The question 180/000517  has few interventions
# WARN: The question 180/000518  has few interventions
# WARN: intervention 0 of question 180/000493 is empty
# WARN: The question 180/000498  has few interventions
# WARN: The question 180/000516  has few interventions
# WARN: intervention 5 of question 172/000053 is empty
# 25 : [4, 6, 7, 7, 5, 4, 4, 2, 0, 2, 2, 2, 1, 1, 1, 6, 0, 2, 4, 3, 1, 4, 2, 5, 12]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 79, de 15/06/1994
# WARN: intervention 2 of question 180/000523 is empty
# WARN: The question 180/000532  has few interventions
# WARN: The question 180/000525  has few interventions
# 24 : [2, 2, 2, 2, 4, 3, 2, 4, 5, 1, 2, 3, 2, 2, 4, 2, 4, 5, 4, 2, 1, 2, 8, 13]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 82, de 22/06/1994
# WARN: intervention 1 of question 180/000569 is empty
# WARN: intervention 3 of question 180/000569 is empty
# WARN: intervention 5 of question 180/000569 is empty
# WARN: intervention 1 of question 180/000550 is empty
# WARN: intervention 3 of question 180/000550 is empty
# WARN: intervention 5 of question 180/000550 is empty
# WARN: intervention 4 of question 172/000058 is empty
# 19 : [2, 2, 7, 7, 2, 2, 2, 2, 4, 5, 4, 13, 6, 4, 4, 2, 4, 17, 8]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 85, de 29/06/1994
# WARN: intervention 1 of question 180/000589 is empty
# WARN: intervention 1 of question 180/000553 is empty
# WARN: The question 180/000559  has few interventions
# WARN: The question 180/000560  has few interventions
# WARN: The question 180/000596  has few interventions
# WARN: The question 180/000593  has few interventions
# WARN: The question 180/000594  has few interventions
# WARN: intervention 1 of question 172/000061 is empty
# WARN: intervention 3 of question 172/000062 is empty
# WARN: intervention 7 of question 172/000062 is empty
# 34 : [3, 3, 5, 4, 2, 4, 2, 2, 1, 1, 1, 2, 2, 4, 4, 2, 1, 1, 2, 2, 4, 3, 4, 4, 4, 4, 2, 2, 4, 4, 7, 18, 8, 9]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 88, de 14/09/1994
# WARN: intervention 1 of question 180/000622 is empty
# WARN: intervention 2 of question 180/000632 is empty
# WARN: intervention 4 of question 180/000632 is empty
# WARN: The question 180/000627  has few interventions
# WARN: The question 180/000648  has few interventions
# WARN: The question 180/000651  has few interventions
# WARN: The question 180/000643  has few interventions
# WARN: The question 180/000645  has few interventions
# WARN: The question 180/000640  has few interventions
# 21 : [5, 6, 2, 4, 0, 3, 3, 1, 1, 2, 2, 1, 1, 4, 2, 3, 2, 2, 1, 7, 8]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 91, de 21/09/1994
# WARN: intervention 2 of question 180/000670 is empty
# WARN: intervention 1 of question 180/000661 is empty
# WARN: intervention 1 of question 180/000678 is empty
# WARN: intervention 3 of question 180/000678 is empty
# WARN: intervention 0 of question 180/000676 is empty
# WARN: The question 172/000065  has few interventions
# 25 : [4, 2, 5, 6, 4, 2, 2, 2, 4, 3, 2, 4, 2, 3, 2, 2, 3, 3, 4, 6, 2, 4, 5, 0, 13]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 93, de 28/09/1994
# WARN: intervention 1 of question 180/000692 is empty
# WARN: intervention 3 of question 180/000692 is empty
# WARN: The question 180/000708  has few interventions
# WARN: intervention 3 of question 180/000701 is empty
# WARN: intervention 1 of question 180/000703 is empty
# WARN: intervention 0 of question 180/000700 is empty
# WARN: The question 172/000067  has few interventions
# 18 : [6, 4, 2, 1, 5, 3, 2, 4, 4, 5, 5, 2, 5, 8, 2, 4, 2, 0]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 96, de 05/10/1994
# WARN: intervention 1 of question 180/000720 is empty
# WARN: intervention 3 of question 180/000720 is empty
# WARN: intervention 1 of question 180/000716 is empty
# WARN: intervention 3 of question 180/000716 is empty
# WARN: intervention 1 of question 180/000737 is empty
# WARN: intervention 1 of question 180/000718 is empty
# WARN: intervention 2 of question 180/000726 is empty
# WARN: intervention 4 of question 180/000726 is empty
# WARN: intervention 2 of question 180/000685 is empty
# WARN: The question 180/000714  has few interventions
# WARN: The question 180/000740  has few interventions
# 31 : [6, 2, 4, 2, 4, 6, 2, 2, 2, 2, 2, 4, 4, 3, 2, 3, 5, 6, 2, 5, 4, 2, 4, 3, 4, 2, 1, 1, 8, 10, 6]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 99, de 26/10/1994
# WARN: The question 180/000760  has few interventions
# WARN: intervention 2 of question 180/000746 is empty
# WARN: The question 180/000761  has few interventions
# WARN: The question 180/000762  has few interventions
# WARN: intervention 1 of question 180/000743 is empty
# WARN: intervention 0 of question 173/000054 is empty
# WARN: intervention 6 of question 173/000054 is empty
# 28 : [2, 6, 2, 4, 4, 2, 4, 2, 2, 3, 1, 4, 2, 5, 3, 1, 1, 2, 5, 4, 6, 2, 2, 13, 9, 13, 10, 14]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 101, de 02/11/1994
# WARN: intervention 1 of question 180/000769 is empty
# WARN: intervention 2 of question 180/000781 is empty
# WARN: intervention 4 of question 180/000781 is empty
# WARN: intervention 1 of question 180/000774 is empty
# WARN: intervention 3 of question 180/000774 is empty
# WARN: intervention 5 of question 180/000774 is empty
# WARN: intervention 1 of question 180/000773 is empty
# WARN: intervention 3 of question 180/000773 is empty
# WARN: intervention 5 of question 180/000773 is empty
# WARN: intervention 1 of question 180/000780 is empty
# WARN: intervention 3 of question 180/000780 is empty
# WARN: The question 180/000789  has few interventions
# WARN: intervention 3 of question 180/000768 is empty
# WARN: intervention 1 of question 180/000784 is empty
# WARN: intervention 3 of question 180/000784 is empty
# WARN: intervention 1 of question 180/000787 is empty
# WARN: The question 180/000786  has few interventions
# WARN: The question 180/000791  has few interventions
# WARN: The question 172/000075  has few interventions
# WARN: intervention 7 of question 173/000056 is empty
# WARN: intervention 14 of question 173/000056 is empty
# 25 : [5, 6, 2, 4, 2, 4, 7, 4, 2, 7, 6, 2, 1, 5, 6, 2, 3, 2, 1, 2, 3, 1, 0, 7, 16]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 104, de 16/11/1994
# WARN: intervention 1 of question 180/000793 is empty
# WARN: intervention 13 of question 180/000793 is empty
# WARN: The question 180/000798  has few interventions
# WARN: The question 180/000802  has few interventions
# WARN: intervention 2 of question 180/000775 is empty
# WARN: The question 180/000801  has few interventions
# WARN: intervention 3 of question 180/000806 is empty
# WARN: intervention 1 of question 180/000807 is empty
# WARN: intervention 3 of question 180/000807 is empty
# WARN: intervention 1 of question 180/000804 is empty
# WARN: intervention 1 of question 180/000805 is empty
# WARN: The question 180/000813 seems too long: 101 lines
# WARN: intervention 0 of question 172/000078 is empty
# WARN: intervention 5 of question 172/000078 is empty
# WARN: intervention 4 of question 172/000079 is empty
# 23 : [7, 17, 4, 1, 1, 3, 4, 1, 2, 4, 5, 5, 4, 4, 3, 3, 2, 4, 4, 4, 4, 16, 7]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 111, de 30/11/1994
# WARN: intervention 3 of question 180/000815 is empty
# WARN: intervention 1 of question 180/000834 is empty
# WARN: intervention 3 of question 180/000834 is empty
# WARN: intervention 5 of question 180/000834 is empty
# WARN: The question 180/000852  has few interventions
# WARN: The question 180/000855  has few interventions
# WARN: The question 180/000859  has few interventions
# WARN: intervention 1 of question 180/000842 is empty
# WARN: intervention 1 of question 180/000848 is empty
# WARN: intervention 1 of question 180/000858 is empty
# WARN: The question 180/000832  has few interventions
# WARN: intervention 4 of question 172/000080 is empty
# WARN: intervention 7 of question 172/000080 is empty
# WARN: intervention 5 of question 172/000081 is empty
# 20 : [5, 7, 0, 2, 1, 1, 3, 3, 2, 2, 3, 4, 4, 0, 4, 4, 4, 14, 16, 13]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 114, de
 8]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 168, de 20/09/1995
# WARN: The question 180/001345  has few interventions
# WARN: intervention 1 of question 180/001339 is empty
# WARN: intervention 3 of question 180/001339 is empty
# WARN: The question 180/001362  has few interventions
# WARN: The question 180/001363  has few interventions
# 18 : [4, 0, 2, 4, 6, 4, 4, 4, 2, 2, 1, 1, 2, 4, 6, 2, 2, 10]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 171, de 27/09/1995
# WARN: The question 180/001393  has few interventions
# 25 : [4, 4, 4, 4, 2, 3, 3, 4, 5, 4, 2, 2, 2, 2, 4, 2, 3, 4, 4, 4, 2, 0, 2, 2, 13]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 174, de 04/10/1995
# WARN: intervention 1 of question 180/001415 is empty
# WARN: intervention 2 of question 180/001413 is empty
# WARN: speaker of question 180/001414 not found
# WARN: intervention 1 of question 180/001414 is empty
# WARN: intervention 3 of question 180/001414 is empty
# WARN: intervention 5 of question 180/001414 is empty
# WARN: The question 180/001408 seems too long: 67 lines
# WARN: The question 180/001408  has few interventions
# 19 : [4, 4, 5, 2, 2, 4, 4, 4, 5, 2, 5, 4, 2, 3, 2, 7, 0, 4, 5]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 177, de 18/10/1995
# WARN: intervention 1 of question 180/001434 is empty
# WARN: intervention 1 of question 180/001448 is empty
# WARN: intervention 3 of question 180/001448 is empty
# WARN: The question 180/001437  has few interventions
# WARN: intervention 2 of question 180/001463 is empty
# 28 : [2, 5, 2, 2, 2, 6, 4, 4, 4, 3, 2, 3, 6, 4, 8, 4, 2, 3, 0, 2, 2, 2, 4, 2, 2, 5, 13, 4]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 182, de 08/11/1995
# WARN: intervention 1 of question 180/001478 is empty
# WARN: intervention 3 of question 180/001478 is empty
# WARN: intervention 5 of question 180/001478 is empty
# WARN: intervention 1 of question 180/001481 is empty
# WARN: intervention 1 of question 180/001472 is empty
# WARN: intervention 1 of question 180/001474 is empty
# WARN: intervention 3 of question 180/001487 is empty
# WARN: intervention 0 of question 180/001492 is empty
# 22 : [7, 2, 2, 4, 5, 4, 4, 2, 2, 6, 5, 3, 4, 4, 2, 2, 2, 2, 2, 2, 2, 4]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 184, de 22/11/1995
# WARN: The question 180/001509  has few interventions
# WARN: The question 180/001511  has few interventions
# WARN: The question 180/001516  has few interventions
# WARN: The question 180/001529  has few interventions
# WARN: intervention 1 of question 180/001510 is empty
# WARN: intervention 1 of question 180/001526 is empty
# WARN: intervention 2 of question 180/001527 is empty
# WARN: intervention 3 of question 180/001521 is empty
# WARN: intervention 2 of question 172/000130 is empty
# 26 : [4, 2, 3, 2, 1, 0, 1, 2, 0, 2, 4, 2, 2, 2, 2, 4, 4, 7, 3, 3, 5, 6, 4, 7, 8, 6]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 187, de 29/11/1995
# WARN: The question 180/001552  has few interventions
# WARN: The question 180/001553  has few interventions
# WARN: The question 180/001558  has few interventions
# WARN: The question 180/001544  has few interventions
# WARN: The question 180/001551  has few interventions
# WARN: intervention 2 of question 180/001537 is empty
# WARN: intervention 1 of question 180/001543 is empty
# WARN: intervention 1 of question 180/001542 is empty
# 20 : [2, 2, 2, 2, 1, 1, 2, 1, 0, 0, 5, 3, 4, 5, 4, 4, 5, 2, 10, 7]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 190, de 13/12/1995
# WARN: The question 180/001566  has few interventions
# WARN: The question 180/001568  has few interventions
# WARN: The question 180/001571  has few interventions
# WARN: intervention 2 of question 180/001590 is empty
# WARN: intervention 4 of question 180/001590 is empty
# WARN: intervention 2 of question 180/001586 is empty
# WARN: intervention 4 of question 180/001586 is empty
# WARN: intervention 2 of question 180/001587 is empty
# WARN: The question 180/001593  has few interventions
# 29 : [4, 4, 2, 2, 2, 2, 3, 5, 1, 2, 1, 0, 6, 4, 6, 7, 0, 4, 4, 4, 3, 2, 4, 2, 4, 4, 2, 10, 11]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 193, de 20/12/1995
# WARN: intervention 1 of question 180/001614 is empty
# WARN: intervention 0 of question 180/001598 is empty
# WARN: intervention 2 of question 180/001598 is empty
# WARN: intervention 4 of question 180/001598 is empty
# WARN: intervention 3 of question 180/001601 is empty
# WARN: intervention 1 of question 180/001609 is empty
# WARN: intervention 1 of question 180/001610 is empty
# WARN: The question 172/000135  has few interventions
# 14 : [5, 2, 4, 4, 4, 2, 3, 7, 3, 6, 3, 3, 0, 15]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 6, de 22/05/1996
# WARN: The question 180/000021  has few interventions
# WARN: intervention 5 of question 180/000002 is empty
# WARN: intervention 3 of question 180/000012 is empty
# WARN: intervention 2 of question 172/000001 is empty
# 23 : [4, 5, 2, 2, 2, 1, 4, 4, 4, 4, 4, 7, 4, 4, 2, 3, 2, 2, 2, 3, 2, 5, 16]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 8, de 29/05/1996
# WARN: intervention 0 of question 180/000034 is empty
# WARN: intervention 2 of question 180/000034 is empty
# WARN: intervention 4 of question 180/000034 is empty
# WARN: intervention 6 of question 180/000034 is empty
# WARN: intervention 0 of question 180/000050 is empty
# WARN: intervention 4 of question 180/000050 is empty
# WARN: intervention 3 of question 180/000007 is empty
# WARN: The question 180/000051  has few interventions
# WARN: The question 180/000052  has few interventions
# WARN: intervention 2 of question 180/000036 is empty
# WARN: intervention 4 of question 180/000036 is empty
# WARN: intervention 0 of question 180/000042 is empty
# WARN: intervention 1 of question 180/000056 is empty
# WARN: intervention 0 of question 180/000046 is empty
# WARN: intervention 1 of question 180/000039 is empty
# WARN: intervention 3 of question 180/000039 is empty
# WARN: intervention 5 of question 180/000039 is empty
# WARN: intervention 1 of question 180/000043 is empty
# 25 : [8, 6, 6, 2, 2, 6, 2, 4, 2, 5, 5, 2, 1, 0, 2, 2, 4, 6, 6, 3, 5, 3, 7, 5, 9]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 12, de 12/06/1996
# WARN: The question 180/000074  has few interventions
# WARN: The question 180/000075 seems too long: 102 lines
# WARN: The question 180/000079  has few interventions
# WARN: intervention 0 of question 180/000078 is empty
# WARN: intervention 2 of question 180/000078 is empty
# WARN: intervention 0 of question 180/000083 is empty
# WARN: intervention 0 of question 180/000067 is empty
# WARN: intervention 0 of question 180/000059 is empty
# WARN: intervention 2 of question 180/000059 is empty
# WARN: intervention 0 of question 180/000069 is empty
# WARN: intervention 2 of question 180/000069 is empty
# WARN: intervention 4 of question 180/000069 is empty
# WARN: intervention 2 of question 180/000068 is empty
# WARN: intervention 4 of question 180/000068 is empty
# WARN: intervention 0 of question 180/000072 is empty
# WARN: intervention 3 of question 172/000006 is empty
# 21 : [0, 2, 3, 4, 1, 5, 4, 3, 2, 3, 5, 2, 4, 7, 6, 5, 4, 2, 2, 2, 14]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 14, de 19/06/1996
# WARN: The question 180/000121  has few interventions
# WARN: The question 180/000119  has few interventions
# WARN: intervention 3 of question 180/000076 is empty
# WARN: intervention 0 of question 180/000077 is empty
# WARN: intervention 2 of question 180/000077 is empty
# WARN: intervention 3 of question 180/000095 is empty
# WARN: intervention 0 of question 180/000091 is empty
# WARN: intervention 2 of question 180/000091 is empty
# WARN: intervention 4 of question 180/000091 is empty
# WARN: The question 180/000102  has few interventions
# WARN: intervention 3 of question 180/000099 is empty
# WARN: intervention 0 of question 180/000100 is empty
# WARN: intervention 2 of question 180/000100 is empty
# WARN: intervention 5 of question 180/000100 is empty
# WARN: intervention 0 of question 180/000101 is empty
# WARN: intervention 3 of question 180/000101 is empty
# WARN: intervention 0 of question 180/000109 is empty
# WARN: intervention 4 of question 172/000009 is empty
# 31 : [4, 4, 2, 5, 5, 1, 1, 5, 6, 2, 2, 5, 7, 2, 4, 4, 4, 2, 2, 0, 2, 5, 7, 6, 4, 4, 4, 4, 5, 2, 8]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 17, de 26/06/1996
# WARN: The question 180/000129  has few interventions
# WARN: The question 180/000130  has few interventions
# WARN: intervention 1 of question 180/000150 is empty
# WARN: intervention 1 of question 180/000133 is empty
# WARN: intervention 0 of question 180/000134 is empty
# WARN: intervention 2 of question 180/000134 is empty
# WARN: intervention 0 of question 180/000147 is empty
# WARN: intervention 2 of question 180/000147 is empty
# 22 : [4, 5, 2, 2, 1, 1, 2, 3, 2, 3, 4, 6, 4, 2, 4, 3, 2, 2, 5, 2, 4, 3]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 22, de 11/09/1996
# WARN: intervention 0 of question 180/000163 is empty
# WARN: intervention 3 of question 180/000172 is empty
# WARN: intervention 1 of question 180/000157 is empty
# WARN: The question 180/000165  has few interventions
# WARN: The question 180/000167  has few interventions
# WARN: intervention 2 of question 180/000177 is empty
# WARN: intervention 4 of question 180/000177 is empty
# WARN: intervention 2 of question 172/000010 is empty
# 24 : [2, 3, 2, 3, 5, 4, 4, 4, 4, 2, 4, 4, 5, 5, 6, 2, 2, 1, 1, 3, 6, 2, 13, 9]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 24, de 18/09/1996
# WARN: intervention 0 of question 180/000187 is empty
# WARN: intervention 2 of question 180/000187 is empty
# WARN: intervention 0 of question 180/000201 is empty
# WARN: intervention 1 of question 180/000198 is empty
# WARN: intervention 4 of question 180/000198 is empty
# WARN: intervention 1 of question 180/000188 is empty
# WARN: intervention 0 of question 180/000189 is empty
# WARN: intervention 3 of question 180/000208 is empty
# WARN: intervention 1 of question 180/000185 is empty
# WARN: intervention 3 of question 180/000199 is empty
# WARN: intervention 0 of question 180/000205 is empty
# WARN: intervention 3 of question 180/000205 is empty
# WARN: intervention 9 of question 172/000014 is empty
# 23 : [4, 6, 4, 2, 4, 7, 2, 2, 4, 3, 3, 2, 2, 4, 4, 5, 5, 2, 5, 6, 3, 5, 18]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 27, de 25/09/1996
# WARN: intervention 0 of question 180/000220 is empty
# WARN: intervention 2 of question 180/000220 is empty
# WARN: intervention 0 of question 180/000214 is empty
# WARN: intervention 5 of question 172/000016 is empty
# 23 : [5, 2, 3, 4, 4, 4, 2, 4, 5, 2, 2, 3, 5, 4, 2, 2, 2, 3, 4, 2, 2, 2, 22]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 30, de 09/10/1996
# WARN: intervention 2 of question 180/000255 is empty
# WARN: intervention 1 of question 180/000259 is empty
# WARN: intervention 0 of question 180/000260 is empty
# WARN: intervention 2 of question 180/000260 is empty
# WARN: intervention 4 of question 180/000260 is empty
# WARN: intervention 0 of question 180/000239 is empty
# WARN: intervention 2 of question 180/000239 is empty
# WARN: intervention 4 of question 180/000239 is empty
# WARN: intervention 0 of question 180/000211 is empty
# WARN: intervention 3 of question 180/000211 is empty
# WARN: The question 180/000261  has few interventions
# WARN: The question 180/000262  has few interventions
# WARN: intervention 2 of question 172/000017 is empty
# 20 : [5, 2, 2, 5, 2, 3, 6, 7, 2, 6, 4, 1, 1, 2, 4, 7, 2, 4, 6, 19]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 35, de 30/10/1996
# WARN: intervention 1 of question 180/000272 is empty
# WARN: intervention 0 of question 180/000265 is empty
# WARN: intervention 0 of question 180/000249 is empty
# WARN: intervention 2 of question 180/000249 is empty
# WARN: intervention 2 of question 180/000254 is empty
# WARN: intervention 4 of question 180/000254 is empty
# WARN: intervention 0 of question 180/000267 is empty
# WARN: intervention 2 of question 180/000267 is empty
# WARN: intervention 0 of question 180/000268 is empty
# WARN: intervention 2 of question 180/000268 is empty
# WARN: intervention 5 of question 180/000268 is empty
# WARN: intervention 1 of question 180/000285 is empty
# WARN: intervention 3 of question 180/000285 is empty
# 27 : [4, 4, 4, 5, 4, 2, 3, 6, 4, 6, 7, 7, 7, 3, 2, 2, 2, 2, 2, 5, 5, 2, 2, 3, 2, 5, 12]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 46, de 27/11/1996
# WARN: The question 180/000310  has few interventions
# WARN: intervention 0 of question 180/000298 is empty
# WARN: intervention 2 of question 180/000298 is empty
# WARN: intervention 4 of question 180/000298 is empty
# WARN: intervention 1 of question 180/000316 is empty
# WARN: intervention 3 of question 180/000316 is empty
# 20 : [1, 4, 2, 4, 4, 4, 2, 2, 2, 5, 7, 3, 7, 2, 6, 4, 2, 2, 6, 12]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 48, de 11/12/1996
# WARN: intervention 0 of question 180/000337 is empty
# WARN: intervention 1 of question 180/000322 is empty
# WARN: intervention 3 of question 180/000322 is empty
# WARN: intervention 5 of question 180/000322 is empty
# WARN: The question 180/000314  has few interventions
# WARN: The question 180/000315  has few interventions
# WARN: The question 180/000338  has few interventions
# 23 : [4, 4, 3, 4, 4, 4, 3, 2, 4, 2, 4, 4, 7, 4, 4, 2, 2, 1, 1, 1, 4, 2, 21]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 51, de 18/12/1996
# WARN: The question 180/000324  has few interventions
# WARN: The question 180/000370  has few interventions
# WARN: intervention 3 of question 180/000350 is empty
# WARN: intervention 0 of question 180/000362 is empty
# WARN: intervention 1 of question 180/000344 is empty
# WARN: intervention 3 of question 180/000344 is empty
# WARN: intervention 5 of question 180/000344 is empty
# 11 : [2, 0, 2, 1, 2, 4, 4, 4, 5, 3, 7]
# Congreso de los Diputados, Pleno y Dip. Perm., núm.
 8]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 211, de 09/07/2014
# 18 : [6, 6, 6, 6, 6, 6, 4, 6, 10, 6, 6, 3, 6, 6, 6, 17, 10, 5]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 216, de 10/09/2014
# 21 : [6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 3, 6, 3, 9, 11, 6, 6]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 219, de 17/09/2014
# 17 : [7, 5, 6, 6, 6, 6, 4, 6, 6, 7, 4, 7, 6, 6, 6, 6, 6]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 222, de 24/09/2014
# 18 : [3, 6, 7, 6, 6, 6, 6, 7, 7, 6, 6, 6, 4, 9, 9, 15, 17, 18]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 225, de 08/10/2014
# 21 : [6, 6, 3, 6, 6, 6, 4, 5, 6, 6, 3, 6, 7, 6, 6, 6, 3, 3, 6, 6, 11]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 229, de 15/10/2014
# 18 : [6, 6, 8, 6, 6, 6, 6, 4, 4, 6, 6, 6, 6, 6, 6, 7, 6, 4]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 235, de 29/10/2014
# 17 : [6, 6, 6, 6, 3, 6, 6, 4, 6, 6, 6, 6, 6, 6, 16, 6, 6]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 241, de 19/11/2014
# 20 : [6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 3, 4, 6, 6, 6, 6, 6, 6, 16, 21]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 244, de 26/11/2014
# 18 : [6, 6, 6, 6, 3, 4, 6, 5, 6, 6, 3, 3, 6, 6, 6, 6, 7, 7]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 247, de 10/12/2014
# 16 : [6, 6, 6, 5, 6, 3, 7, 6, 6, 3, 6, 6, 4, 6, 4, 10]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 250, de 17/12/2014
# 23 : [5, 6, 6, 8, 6, 6, 6, 3, 6, 6, 6, 6, 5, 6, 3, 5, 6, 13, 6, 12, 6, 9, 21]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 254, de 21/01/2015
# 15 : [6, 5, 6, 6, 6, 4, 6, 6, 6, 6, 6, 6, 3, 6, 6]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 257, de 11/02/2015
# 17 : [6, 6, 6, 6, 6, 6, 6, 6, 3, 6, 6, 6, 4, 6, 4, 11, 6]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 260, de 18/02/2015
# 22 : [5, 6, 6, 6, 6, 6, 6, 6, 6, 4, 8, 6, 6, 6, 6, 3, 7, 4, 10, 6, 20, 19]
# Congreso de los Diputados, Pleno y Dip. Perm., núm. 266, de 11/03/2015
# 20 : [6, 3, 7, 8, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 10, 8, 6, 7]

# %% [markdown]
# #### Marcatge dels paràgrafs seleccionats al document HTML

# %%
# constants de marcatge
form_tab_mark_start = u'<span title="{}" style="background-color: {};">'
form_tab_mark_end = u'</span>'

def get_group_color_DB(congres_groups_col, group_code):
    
    result = congres_groups_col.find({'code':group_code})
    if result.count() > 0:
        return result[0]['color']
    else:
        return 'cyan'

def mark_text_in_HTML(html_page, title_text, selected_text, start_index, group_color):
    
    tab_mark_start = form_tab_mark_start.format(title_text, group_color)
    tab_mark_end = form_tab_mark_end
    
    text_start_index = html_page.find(selected_text, start_index)
    if text_start_index > 0:
        # print "-"*20
        # print "1. html_page len:", len(html_page)
        text_end_index = text_start_index + len(selected_text)
        html_page = html_page[:text_end_index] + tab_mark_end + html_page[text_end_index:]
        html_page = html_page[:text_start_index] + tab_mark_start + html_page[text_start_index:]
        # text_end_index += (len(tab_mark_start) + len(tab_mark_end))
        # print "2. html_page len:", len(html_page), "t_inc:", (len(tab_mark_start) + len(tab_mark_end))
    else:
        # print "S-->", selected_text
        # print "T-->", html_page[start_index:start_index+30]
        # Si la cerca del texte sencer no funciona, cerquem l'inici (fins '\n') i el final del texte
        first_break = selected_text.find("\n")
        last_break = selected_text.rfind("\n")
        # print first_break, ":", last_break
        text_start_index = html_page.find(selected_text[:first_break], start_index)
        if text_start_index > 0:
            text_end_index = html_page.find(selected_text[last_break:], start_index) + len(selected_text[last_break:])
            html_page = html_page[:text_end_index] + tab_mark_end + html_page[text_end_index:]
            html_page = html_page[:text_start_index] + tab_mark_start + html_page[text_start_index:]
            # text_end_index += (len(tab_mark_start) + len(tab_mark_end))
        else:
            text_end_index = start_index

    return html_page, text_end_index

def get_marked_HTML_doc(selected_doc, use_offset = True):
    
    selected_content_doc = selected_doc['content_doc']

    text_index = selected_content_doc.rfind('PREGUNTAS:')

    for dialogue_id, dialogue in enumerate(selected_doc['session_dictionary']):
        group_color = get_group_color_DB(congres_groups_collection, dialogue['group'])
        if use_offset:
            text_index += dialogue['offset']
        question_text = dialogue['question'].strip()
        old_text_index = text_index
        if question_text=="":
            print "question: ", dialogue['num_exp'], "is empty."
        else:
            title_text = "dialogue: " + str(dialogue_id) + "\n" \
                + "group: " + dialogue['group'] + "\n" \
                + "speaker: " + dialogue['speaker'] + "\n" \
                + "num_exp: " + dialogue['num_exp']
            selected_content_doc, text_index = mark_text_in_HTML(selected_content_doc, title_text, question_text, text_index, group_color)
            if text_index == old_text_index:
                print "text_type:", 'question', "text_index:", text_index, ", num_dialogue:", dialogue_id
                print ">" + question_text + "<"
        for inter_id, inter in enumerate(dialogue['intervention_dictionary']):
            paragraphs = inter['text'].split("\n")
            if use_offset:
                text_index += inter['offset']
            group_color = get_group_color_DB(congres_groups_collection, inter['who']['group'])

            for paragraph in paragraphs:
                old_text_index = text_index
                paragraph_text = paragraph.strip()
                if not paragraph_text=="":
                    title_text = "dialogue: " + str(dialogue_id) + "\n" \
                        + "num_inter: " + str(inter_id) + "\n" \
                        + "group: " + inter['who']['group'] + "\n" \
                        + "who: " + inter['who']['surname'] + "; " + inter['who']['name']
                    selected_content_doc, text_index = mark_text_in_HTML(selected_content_doc, title_text, paragraph_text, text_index, group_color)
                    if text_index == old_text_index:
                        print "text_type:", 'intervention', "text_index:", text_index, ", num_dialogue:", dialogue_id, "num_inter:", inter_id
                        print ">" + paragraph_text + "<"

    return selected_content_doc

# %%
# Col.lecció de documents a la BD
doc_col = db['document']
# Col.lecció de diputats a la BD
congres_members_collection = db['congres_members']
# Col.lecció de legislatures a la BD
legislatures_collection = db['legislatures']
# Col.lecció de grups parlamentaris a la BD
congres_groups_collection = db['congres_groups']


# All
doc_start_date = "01/01/1990"
d_doc_start_date = datetime.datetime.strptime(doc_start_date, "%d/%m/%Y")
d_doc_end_date = datetime.datetime.utcnow()
result = doc_col.find({'date': {'$gte': d_doc_start_date, '$lte': d_doc_end_date}}).sort('date',1)

'''
doc_date = "11/03/2015"
d_doc_date = datetime.datetime.strptime(doc_date, "%d/%m/%Y")
file_name = d_doc_date.strftime("%Y%m%d")
result = doc_col.find({'date': d_doc_date})
'''
'''
# Legislatura X
doc_start_date = "14/12/2011"
d_doc_start_date = datetime.datetime.strptime(doc_start_date, "%d/%m/%Y")
d_doc_end_date = datetime.datetime.utcnow()
result = doc_col.find({'date': {'$gte': d_doc_start_date, '$lte': d_doc_end_date}}).sort('date',1)
'''
'''
# Legislaturas V-IX
doc_start_date = "29/06/1993"
d_doc_start_date = datetime.datetime.strptime(doc_start_date, "%d/%m/%Y")
doc_end_date = "14/12/2011"
d_doc_end_date = datetime.datetime.strptime(doc_end_date, "%d/%m/%Y")
result = doc_col.find({'date': {'$gte': d_doc_start_date, '$lte': d_doc_end_date}}).sort('date',1)
'''

if result.count() > 0:
    for result_obj in result:

        file_name = result_obj['date'].strftime("%Y%m%d")
        selected_content_doc = get_marked_HTML_doc(result_obj, False)

        print "Saving 'docs/" + file_name + "_doc_marked.html'..."
        save_text_file(selected_content_doc, 'docs/marked/' + file_name + '_doc_marked.html',"utf-8")
# Out:
# 11 : 78
# question:  172/000003 is empty.
# Saving 'docs/19930915_doc_marked.html'...
# 9 : 79
# Saving 'docs/19930922_doc_marked.html'...
# Saving 'docs/19930929_doc_marked.html'...
# Saving 'docs/19931027_doc_marked.html'...
# 51 : 5078
# 27 : 375
# Saving 'docs/19931103_doc_marked.html'...
# 6 : 192
# 37 : 213
# Saving 'docs/19931124_doc_marked.html'...
# Saving 'docs/19931201_doc_marked.html'...
# 51 : 138
# Saving 'docs/19931215_doc_marked.html'...
# 9 : 133
# 18 : 308
# 49 : 190
# Saving 'docs/19940209_doc_marked.html'...
# 15 : 264
# Saving 'docs/19940216_doc_marked.html'...
# 6 : 213
# 14 : 439
# Saving 'docs/19940223_doc_marked.html'...
# 16 : 81
# Saving 'docs/19940302_doc_marked.html'...
# 16 : 209
# Saving 'docs/19940309_doc_marked.html'...
# Saving 'docs/19940323_doc_marked.html'...
# 7 : 69
# Saving 'docs/19940413_doc_marked.html'...
# 60 : 175
# Saving 'docs/19940427_doc_marked.html'...
# 24 : 263
# 21 : 67
# 59 : 68
# Saving 'docs/19940518_doc_marked.html'...
# 24 : 143
# Saving 'docs/19940525_doc_marked.html'...
# Saving 'docs/19940615_doc_marked.html'...
# Saving 'docs/19940622_doc_marked.html'...
# 24 : 277
# Saving 'docs/19940629_doc_marked.html'...
# 25 : 174
# 58 : 123
# Saving 'docs/19940914_doc_marked.html'...
# Saving 'docs/19940921_doc_marked.html'...
# Saving 'docs/19940928_doc_marked.html'...
# 45 : 117
# 23 : 210
# Saving 'docs/19941005_doc_marked.html'...
# 22 : 203
# Saving 'docs/19941026_doc_marked.html'...
# Saving 'docs/19941102_doc_marked.html'...
# 25 : 316
# 18 : 5902
# Saving 'docs/19941116_doc_marked.html'...
# Saving 'docs/19941130_doc_marked.html'...
# Saving 'docs/19941214_doc_marked.html'...
# 6 : 289
# Saving 'docs/19941221_doc_marked.html'...
# Saving 'docs/19950215_doc_marked.html'...
# Saving 'docs/19950222_doc_marked.html'...
# Saving 'docs/19950308_doc_marked.html'...
# Saving 'docs/19950315_doc_marked.html'...
# Saving 'docs/19950322_doc_marked.html'...
# 38 : 313
# 29 : 207
# Saving 'docs/19950405_doc_marked.html'...
# 24 : 301
# Saving 'docs/19950426_doc_marked.html'...
# 29 : 5781
# 3 : 5116
# 50 : 13610
# 3 : 6142
# 14 : 5666
# Saving 'docs/19950510_doc_marked.html'...
# Saving 'docs/19950517_doc_marked.html'...
# question:  180/001224 is empty.
# Saving 'docs/19950531_doc_marked.html'...
# 17 : 209
# Saving 'docs/19950614_doc_marked.html'...
# Saving 'docs/19950628_doc_marked.html'...
# 10 : 161
# Saving 'docs/19950913_doc_marked.html'...
# Saving 'docs/19950920_doc_marked.html'...
# 36 : 255
# Saving 'docs/20130925_doc_marked.html'...
# Saving 'docs/20131016_doc_marked.html'...
# Saving 'docs/20131030_doc_marked.html'...
# Saving 'docs/20131120_doc_marked.html'...
# Saving 'docs/20131127_doc_marked.html'...
# Saving 'docs/20131211_doc_marked.html'...
# Saving 'docs/20131218_doc_marked.html'...
# Saving 'docs/20140122_doc_marked.html'...
# Saving 'docs/20140212_doc_marked.html'...
# Saving 'docs/20140312_doc_marked.html'...
# Saving 'docs/20140319_doc_marked.html'...
# Saving 'docs/20140409_doc_marked.html'...
# Saving 'docs/20140507_doc_marked.html'...
# Saving 'docs/20140514_doc_marked.html'...
# Saving 'docs/20140528_doc_marked.html'...
# Saving 'docs/20140625_doc_marked.html'...
# Saving 'docs/20140709_doc_marked.html'...
# Saving 'docs/20140910_doc_marked.html'...
# Saving 'docs/20140917_doc_marked.html'...
# Saving 'docs/20140924_doc_marked.html'...
# Saving 'docs/20141008_doc_marked.html'...
# Saving 'docs/20141015_doc_marked.html'...
# Saving 'docs/20141029_doc_marked.html'...
# Saving 'docs/20141119_doc_marked.html'...
# Saving 'docs/20141126_doc_marked.html'...
# Saving 'docs/20141210_doc_marked.html'...
# Saving 'docs/20141217_doc_marked.html'...
# Saving 'docs/20150121_doc_marked.html'...
# Saving 'docs/20150211_doc_marked.html'...
# Saving 'docs/20150218_doc_marked.html'...
# Saving 'docs/20150311_doc_marked.html'...

# %% [markdown]
# #### Query documents, embedded documents

# %%
# http://docs.mongodb.org/manual/reference/method/db.collection.update/
# http://docs.mongodb.org/manual/tutorial/query-documents/#read-operations-embedded-documents

# %% [markdown]
# #### Import and Export MongoDB Data

# %%
# Import and Export MongoDB Data
# http://docs.mongodb.org/manual/core/import-export/

# http://stackoverflow.com/questions/13988479/loading-and-saving-mongodb-database-from-to-disk-with-pymongo

# Copying a Database
# http://api.mongodb.org/python/current/examples/copydb.html

# Export / Import
# http://stackoverflow.com/questions/11255630/how-to-export-all-collection-in-mongodb
# mongodump -d <our database name> -o <directory_backup>
# mongorestore <our database name>

# %% [markdown]
# ## Proves

# %%
num_exp_regexs = [r"\D(\d{3}/\d{6})\D",
                  # 20141015_doc.html -->  (Número de expediente 172/00263)
                  r"\D(\d{3}/\d{5})\D", 
                  # 20130417_doc.html -->  (Número de expediente 180000491)
                  r"\D(\d{9})\D"]

# Recerca del número d'expedient que té el següent format: 999/999999
def get_num_exp(paragraph):

    for num_exp_regex in num_exp_regexs:
        m_q = re.search(num_exp_regex, paragraph)
        if m_q:
            return m_q
    return m_q
    
paragraf = "    AL VIRUS DEL ÉBOLA. (Número de expediente 172/00263)."

print get_num_exp(paragraf).group(1)
# Out:
# 172/00263

# %%
def question_analyzer(sub_text, legislature):
    group = search_group_in_text_DB(remove_spaces_and_newline(sub_text), congres_groups_collection)

    # Remove the non-alphanumeric first characters
    m = re.search(r"\w", sub_text)
    if m:
        sub_text = sub_text[m.start():]

    if u'¿' in sub_text or u'?' in sub_text:
        question = get_text_between(sub_text,u'¿',u'?')
        if question == "":
            if u'¿' in sub_text:
                question = get_text_between(sub_text, u"¿", u"(Número", case_sensitive = False)
            elif u'?' in sub_text:
                # question = get_text_between(sub_text, u":", u"?")
                m = re.search('[\.|\:](.*?)\?', sub_text, re.DOTALL)
                if m:
                    question = sub_text[m.start():m.end()]

        if question == "":
            rprint("TO BE CATCHED -->", get_text_between(sub_text, u"GRUPO PARLAMENTARIO", u"(Número", case_sensitive = False))
            # question = get_text_between(sub_text, u"GRUPO PARLAMENTARIO", u"(Número")                    

        if not group:
            group = get_text_between(sub_text, "GRUPO PARLAMENTARIO", ", QUE")
        m = re.search(ur"(DEL SEÑOR DIPUTADO DON|DEL DIPUTADO DON|DE LA DIPUTADA DOÑA|DE LA SEÑORA DOÑA) ([^,]+),", sub_text)
        if m:
            speaker = m.group(2)
        else:
            speaker = "not found"
    else:
        question_starters = [u"SOBRE", u"RELATIVA A", u"RELATIVA", u"ACERCA DE", u"PARA CONOCER SI", u"CLARIFIQUE",u"EN MATERIA DE", u"DE CONOCER",u"RELACIÓN CON",u"PARA INFORMAR",u"EXPLIQUE",u"ACLARE",u"INFORME",u"DEBATIR",u"EXPONGA",u"PARA",u":",u","]
        for question_starter in question_starters:
            if question_starter in sub_text:
                question = get_text_between(sub_text, question_starter, u"(Número", case_sensitive = False)
                if not group:
                    group = get_text_between(sub_text, u"DEL GRUPO PARLAMENTARIO", question_starter)
                break;

        if question=="":
            rprint("TO BE CATCHED -->", get_text_between(sub_text, u"DEL GRUPO PARLAMENTARIO", u"(Número", case_sensitive = False))
            # question = get_text_between(sub_text, u"DEL GRUPO PARLAMENTARIO", u"(Número")

        speaker = "<group>"

    rprint("group:", group)
    rprint("speaker:", speaker)
    if speaker!="<group>" and speaker!="not found":
        s_speaker = search_diputado_from_string(congres_members_collection, speaker, legislature=legislature)
    else:
        s_speaker = speaker
        
    return question, group, speaker, s_speaker

# %%
# import regex 

subtexts = [
u'''
    ? DE DIPUTADO DON ANTONIO CANTÓ GARCÍA DEL MORAL, DEL GRUPO PARLAMENTARIO
    DE UNIÓN PROGRESO Y DEMOCRACIA, QUE FORMULA AL SEÑOR MINISTRO DE ECONOMÍA
    Y COMPETITIVIDAD: ¿QUÉ MEDIDAS HA ADOPTADO EL GOBIERNO PARA GARANTIZAR
    QUE LOS ACCIONISTAS DE BANKIA ESTAFADOS PUEDAN RECUPERAR SU DINERO?
    (Número de expediente 180/001188).''',
u'''
    ? DE LA SEÑORA DOÑA ROSA MARÍA DÍEZ GONZÁLEZ, DEL GRUPO PARLAMENTARIO DE
    UNIÓN PROGRESO Y DEMOCRACIA, QUE FORMULA AL SEÑOR PRESIDENTE DEL
    GOBIERNO: ¿CREE USTED QUE SU GOBIERNO ESTÁ HACIENDO LO NECESARIO PARA
    GARANTIZAR LA IGUALDAD ENTRE ESPAÑOLES? (Número de expediente
    180/001204).''',
u'''
     - DEL DIPUTADO SEÑOR PÉREZ RUBALCABA, DEL GRUPO PARLAMENTARIO SOCIALISTA,
    QUE FORMULA AL SEÑOR PRESIDENTE DEL GOBIERNO: ¿
    ESTÁ LLEVANDO A CABO EL GOBIERNO PARA HACER REALIDAD LA MODERNIZACIÓN DEL
    SERVICIO  PÚBLICO DE LA JUSTICIA? (Número de expediente 180/000689.)''',
u'''
   - EL DIPUTADO DON JUAN CARLOS CORCUERA PLAZA, DEL GRUPO PARLAMENTARIO
    SOCIALISTA, QUE FORMULA AL SEÑOR MINISTRO DEL INTERIOR: ¿QUÉ VALORACIÓN
    HACE EL GOBIERNO DE LA APLICACIÓN DEL CÓDIGO PENAL EN MATERIA DE
    SEGURIDAD VIAL? (Número de expediente 180/000053.)''',
u'''    
       -DEL SEÑOR DON IÑAKI TXUEKA ISASTI, DEL GRUPO PARLAMENTARIO VASCO
    (EAJ-PNV), QUE FORMULA A LA SEÑORA MINISTRA DE AGRICULTURA, PESCA Y
    ALIMENTACIÓN: ¿CÓMO PLANTEA EL GOBIERNO AFRONTAR EL PROCESO DE
    REESTRUCTURACIÓN DEL SECTOR AZUCARERO ANTE LOS CAMBIOS QUE SE HAN IDO
    PRODUCIENDO DESDE QUE SE SUSCRIBIÓ EL ACUERDO MARCO INTERPROFESIONAL?
    (Número de expediente 180/001757.)''',
# 20100224_doc
u'''
       MARTÍNEZ SAIZ, DEL GRUPO PARLAMENTARIO POPULAR EN EL CONGRESO, QUE
    FORMULA AL SEÑOR MINISTRO DE FOMENTO: ¿CONSIDERA QUE LOS RECORTES
    PRESUPUESTARIOS EN EL MINISTERIO DE FOMENTO SE DEBEN TAMBIÉN A UNA
    CONSPIRACIÓN INTERNACIONAL? (Número de expediente 180/000869.)'''
]

for subtext in subtexts:
    print "-"*120
    # m = re.search(ur"(DIPUTADO SEÑOR|DIPUTADO DON|DIPUTADA DOÑA|SEÑORA DOÑA|DE DOÑA) ([^,]+),", subtext)
    m = regex.search(ur"(DIPUTADO SEÑOR|DIPUTADO DON|DIPUTADO D.|SEÑOR DON|DIPUTADA DOÑA|SEÑORA DOÑA|DE DOÑA){e<=1} ([^,]+),", subtext)
    if m:
        speaker = m.group(2)
    else:
        m = re.search(ur"(DIPUTADO|DON) ([^,]+),", subtext)
        if m:
            speaker = m.group(2)
        else:
            speaker = "not found"

    print speaker

    print question_analyzer(subtext, 10)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# ANTONIO CANTÓ GARCÍA DEL MORAL
# 'group:' u'GUPyD'
# 'speaker:' 'not found'
# (u'QU\xc9 MEDIDAS HA ADOPTADO EL GOBIERNO PARA GARANTIZAR\n    QUE LOS ACCIONISTAS DE BANKIA ESTAFADOS PUEDAN RECUPERAR SU DINERO', u'GUPyD', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# ROSA MARÍA DÍEZ GONZÁLEZ
# 'group:' u'GUPyD'
# 'speaker:' u'ROSA MAR\xcdA D\xcdEZ GONZ\xc1LEZ'
# (u'CREE USTED QUE SU GOBIERNO EST\xc1 HACIENDO LO NECESARIO PARA\n    GARANTIZAR LA IGUALDAD ENTRE ESPA\xd1OLES', u'GUPyD', u'ROSA MAR\xcdA D\xcdEZ GONZ\xc1LEZ', {u'group': {u'GUPyD': [10], u'GMx': [9]}, u'name': u'ROSA MARIA', u'r_name': u'Rosa Mar\xeda', u'surname': u'DIEZ GONZALEZ', u'_id': ObjectId('552594aa7c4c6704fc267417'), u'r_surname': u'D\xedez Gonz\xe1lez'})
# ------------------------------------------------------------------------------------------------------------------------
# PÉREZ RUBALCABA
# 'group:' u'GS'
# 'speaker:' 'not found'
# (u'C\xd3MO PIENSA AFRONTAR LA\n    SITUACI\xd3N POL\xcdTICA DE ESPA\xd1A', u'GS', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# GEMA CONDE MARTÍNEZ
# 'group:' u'GP'
# 'speaker:' 'not found'
# (u'QU\xc9 VALORACI\xd3N\n    HACE EL MINISTERIO DEL INTERIOR DE LAS RECIENTES MODIFICACIONES LEGALES\n    RELATIVAS A LA DESTRUCCI\xd3N DE DROGAS T\xd3XICAS Y ESTUPEFACIENTES\n    APREHENDIDOS POR LAS FUERZAS Y CUERPOS DE SEGURIDAD DEL ESTADO', u'GP', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# CARLOS MARTÍNEZ GORRIARÁN
# 'group:' u'GUPyD'
# 'speaker:' 'not found'
# (u'C\xd3MO EXPLICA EL GOBIERNO EL AUMENTO DE LA\n    DEUDA DE LAS DIPUTACIONES PROVINCIALES EN UN 34 % DESDE 2008', u'GUPyD', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# EDUARDO MADINA MUÑOZ
# 'group:' u'GS'
# 'speaker:' 'not found'
# (u'POR QU\xc9 SE EMPE\xd1A\n    EL GOBIERNO EN REFORMAR LA LEY DE INTERRUPCI\xd3N VOLUNTARIA DEL EMBARAZO', u'GS', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# ROSA DELIA BLANCO TERÁN
# 'group:' u'GS'
# 'speaker:' 'not found'
# (u'QU\xc9 MEDIDAS VA A ADOPTAR EL GOBIERNO ANTE EL\n    PROCESO QUE SE EST\xc1 LLEVANDO A CABO EN LA SANIDAD DE LA COMUNIDAD DE\n    MADRID', u'GS', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# SABINO CUADRA LASARTE
# 'group:' u'GMx'
# 'speaker:' 'not found'
# (u'HA CUMPLIMENTADO EL GOBIERNO LOS\n    REQUERIMIENTOS DEL PARLAMENTO FORAL DE NAVARRA ADOPTADO MEDIANTE\n    RESOLUCI\xd3N POR LA QUE SE INST\xd3 A LO GOBIERNO A DEROGAR EL DECRETO EL\n    DECRETO 411/1937, DE 8 DE NOVIEMBRE, POR EL QUE EL DICTADOR FRANCO\n    CONCEDI\xd3 A NAVARRA LA CRUZ LAUREADA "COMO RECUERDO A LAS GESTAS HEROICAS\n    DE NAVARRA EN EL MOVIMIENTO NACIONAL Y HOMENAJE A QUIEN RECIENTEMENTE\n    ATESORA LAS VIRTUDES DE LA RAZA"', u'GMx', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# ANA MARÍA ORAMAS GONZÁLEZ-MORO
# 'group:' u'GMx'
# 'speaker:' 'not found'
# (u'CONSIDERA EL PRESIDENTE DEL GOBIERNO QUE HA CUMPLIDO LOS COMPROMISOS\n    ASUMIDOS CON CANARIAS EN EL DEBATE DE INVESTIDURA', u'GMx', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# TERESA CUNILLERA I MESTRES
# 'group:' u'GS'
# 'speaker:' u'TERESA CUNILLERA I MESTRES'
# (u'QU\xc9 VA A HACER EL\n    GOBIERNO ANTE LOS PRONUNCIAMIENTOS DE UN MILITAR RETIRADO A FAVOR DE LA\n    INTERVENCI\xd3N DE LAS FUERZAS ARMADAS EN COMUNIDADES AUT\xd3NOMAS', u'GS', u'TERESA CUNILLERA I MESTRES', {u'group': {u'GS': [6, 7, 8, 9]}, u'name': u'TERESA', u'r_name': u'Teresa', u'surname': u'CUNILLERA I MESTRES', u'_id': ObjectId('552594aa7c4c6704fc2672f6'), u'r_surname': u'Cunillera i Mestres'})
# ------------------------------------------------------------------------------------------------------------------------
# JOSÉ ANDRÉS AYALA SÁNCHEZ
# 'group:' u'GP'
# 'speaker:' 'not found'
# (u'QU\xc9 OPORTUNIDADES\n    SE HAN PODIDO IDENTIFICAR PARA LAS EMPRESAS ESPA\xd1OLAS DE INFRAESTRUCTURAS\n    DURANTE SU VIAJE A BRASIL DE LA SEMANA PASADA', u'GP', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# CARMEN MONTÓN GIMÉNEZ
# 'group:' u'GS'
# 'speaker:' 'not found'
# (u'POR QU\xc9 LIMITA EL GOBIERNO LAS POL\xcdTICAS DE\n    IGUALDAD', u'GS', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# ALFREDO PÉREZ RUBALCABA
# 'group:' u'GS'
# 'speaker:' 'not found'
# (u'HA VALORADO EL\n    GOBIERNO ADECUADAMENTE TODOS LOS EFECTOS DE SU REFORMA LABORAL', u'GS', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# JOSEP ANTONI DURAN I LLEIDA
# 'group:' u'GC-CiU'
# 'speaker:' 'not found'
# (u'CU\xc1L ES EL PORCENTAJE DE BECAS OTORGADAS POR EL ESTADO QUE HAN\n    SIDO DESTINADAS A CATALU\xd1A EN LOS \xdaLTIMOS CINCO A\xd1OS', u'GC-CiU', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# MARÍA JESÚS BONILLA DOMÍNGUEZ
# 'group:' u'GP'
# 'speaker:' 'not found'
# (u'HA REALIZADO EL VICEPRESIDENTE TERCERO DEL GOBIERNO ALGUNA\n    ACTUACI\xd3N DE COORDINACI\xd3N ENTRE ADMINISTRACIONES PARA ACLARAR LA\n    INTERFERENCIA DE SE\xd1ALES DE TELEVISI\xd3N PATROCINADA POR LA JUNTA DE\n    COMUNIDADES DE CASTILLA-LA MANCHA', u'GP', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# JULIO VILLARRUBIA MEDIAVILLA
# 'group:' u'GS'
# 'speaker:' 'not found'
# (u'QU\xc9 ACTUACIONES\n    EST\xc1 LLEVANDO A CABO EL GOBIERNO PARA HACER REALIDAD LA MODERNIZACI\xd3N DEL\n    SERVICIO  P\xdaBLICO DE LA JUSTICIA', u'GS', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# JUAN CARLOS CORCUERA PLAZA
# 'group:' u'GS'
# 'speaker:' 'not found'
# (u'QU\xc9 VALORACI\xd3N\n    HACE EL GOBIERNO DE LA APLICACI\xd3N DEL C\xd3DIGO PENAL EN MATERIA DE\n    SEGURIDAD VIAL', u'GS', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# IÑAKI TXUEKA ISASTI
# 'group:' u'GV (EAJ-PNV)'
# 'speaker:' 'not found'
# (u'C\xd3MO PLANTEA EL GOBIERNO AFRONTAR EL PROCESO DE\n    REESTRUCTURACI\xd3N DEL SECTOR AZUCARERO ANTE LOS CAMBIOS QUE SE HAN IDO\n    PRODUCIENDO DESDE QUE SE SUSCRIBI\xd3 EL ACUERDO MARCO INTERPROFESIONAL', u'GV (EAJ-PNV)', 'not found', 'not found')
# ------------------------------------------------------------------------------------------------------------------------
# not found
# 'group:' u'GP'
# 'speaker:' 'not found'
# (u'CONSIDERA QUE LOS RECORTES\n    PRESUPUESTARIOS EN EL MINISTERIO DE FOMENTO SE DEBEN TAMBI\xc9N A UNA\n    CONSPIRACI\xd3N INTERNACIONAL', u'GP', 'not found', 'not found')

# %%
import re

text = '''
El señor PRESIDENTE DEL GOBIERNO (Aznar López): Sí, señor presidente.
'''
# paragraphs = text.split("\n\n")
# paragraphs = preguntas_html.split("\n\n")
# paragraphs = [text]

loaded_text_file = load_text_file('docs/19980429_doc.html',"")
preguntas_html = get_text_between(loaded_text_file, 'PREGUNTAS:', '<hr size="1" noshade="" />')
paragraphs = preguntas_html.split("<br />")

# print remove_text_between(text, '(',')')

index = 0
while index < len(paragraphs):
    m = re.search(r"^\s*(El señor|La señora) (PRESIDENTE|PRESIDENTA|VICEPRESIDENTA)\:", paragraphs[index])
    if m:
        print "KO (El señor|La señora) (PRESIDENTE|PRESIDENTA):", paragraphs[index]
        who = None
    else:
        # expressió regular per cognoms de dues paraules
        m = re.search(r"señor\w? ([A-ZÁÉÍÓÚÑ\-]+) ([A-ZÁÉÍÓÚÑ\-]+)\:", paragraphs[index])
        if m:
            print "OK", paragraphs[index]
            print "found:", paragraphs[index][m.start():m.end()]
            print "groups:", m.group(0), ", ", m.group(1), ", ", m.group(2)
            print "speaker:", m.group(1) + " " + m.group(2)
            print "speach:", paragraphs[index][m.end():]

            id = search_diputado_in_dict(loaded_diputados_dict, m.group(1) + " " + m.group(2))
            # dip = search_diputado_in_BD(congres_members_collection, m.group(1) + " " + m.group(2))
            if id:
                who = id
            else:
                who = 9999
        else:
            # expressió regular per els cognoms catalans
            m = re.search(r"señor\w? ([A-ZÁÉÍÓÚÑ\-]+) I ([A-ZÁÉÍÓÚÑ\-]+)\:", paragraphs[index])
            if m:
                print "OK 2", paragraphs[index]
                print "found:", paragraphs[index][m.start():m.end()]
                print "groups:", m.group(0), ", ", m.group(1), ", ", m.group(2)
                print "speaker:", m.group(1) + " " + m.group(2)
                print "speach:", paragraphs[index][m.end():]

                id = search_diputado_in_dict(loaded_diputados_dict, m.group(1) + " I " + m.group(2))
                # dip = search_diputado_in_BD(congres_members_collection, m.group(1) + " I " + m.group(2))
                if id:
                    who = id
                else:
                    who = 9999           
            else:
                # expressió regular per trobar intervencions del tipus: 
                #     "   El señor MINISTRO DE INDUSTRIA, ENERGÍA Y TURISMO (Soria López):"
                m = re.search(r"^\s+(El señor|La señora) ([^:]+)\:", paragraphs[index])
                if m:
                    print "OK 3", paragraphs[index]
                    print "found:", paragraphs[index][m.start():m.end()]
                    print "groups:", m.group(0), ", ", m.group(1), ", ", m.group(2)
                    print "speaker:", m.group(2)
                    if '(' in m.group(2) and ')' in m.group(2):
                        str_surname = remove_spaces_and_newline(get_text_between(m.group(2), '(',')'))
                    else:
                        str_surname = m.group(2)
                    print "speaker2:", str_surname
                    print "speach:", paragraphs[index][m.end():]

                    id = search_diputado_in_dict(loaded_diputados_dict, str_surname)
                    # dip = search_diputado_in_BD(congres_members_collection, str_surname)
                    if id:
                        who = id
                    else:
                        who = 9999
    
    index += 1
# Out:
# KO (El señor|La señora) (PRESIDENTE|PRESIDENTA): El señor PRESIDENTE:

# speach:  Muchas gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: MORLAN GRACIA
# OK El señor MORLAN GRACIA: Señor ministro, tengo aquí el calendario oficial
#     de fiestas que ustedes aprobaron en octubre de 1997, y haciendo
#     referencia a la pregunta que contestó su compañero de Gobierno, que
#     hablaba de que determinadas fiestas autonómicas no tenían nada que ver
#     con la aplicación o no de tarifas telefónicas, le tengo que decir que
#     cuando se trata de una fiesta que es la única que se guarda en todas las
#     comunidades autónomas la Compañía Telefónica no ha tenido el detalle de
#     decir que esa fiesta tenía las mismas características que otro tipo de
#     fiestas que pudiera haber en cada una de las comunidades autónomas, o al
#     menos igual que las fiestas que tienen un carácter nacional.
# found: señor MORLAN GRACIA:
# groups: señor MORLAN GRACIA: ,  MORLAN ,  GRACIA
# speaker: MORLAN GRACIA
# speach:  Señor ministro, tengo aquí el calendario oficial
#     de fiestas que ustedes aprobaron en octubre de 1997, y haciendo
#     referencia a la pregunta que contestó su compañero de Gobierno, que
#     hablaba de que determinadas fiestas autonómicas no tenían nada que ver
#     con la aplicación o no de tarifas telefónicas, le tengo que decir que
#     cuando se trata de una fiesta que es la única que se guarda en todas las
#     comunidades autónomas la Compañía Telefónica no ha tenido el detalle de
#     decir que esa fiesta tenía las mismas características que otro tipo de
#     fiestas que pudiera haber en cada una de las comunidades autónomas, o al
#     menos igual que las fiestas que tienen un carácter nacional.
# ERROR en search_diputado_in_dict. No s'ha trobat: MORLAN GRACIA
# OK El señor IZQUIERDO JUAREZ: Gracias, señor presidente.
# found: señor IZQUIERDO JUAREZ:
# groups: señor IZQUIERDO JUAREZ: ,  IZQUIERDO ,  JUAREZ
# speaker: IZQUIERDO JUAREZ
# speach:  Gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: IZQUIERDO JUAREZ
# OK El señor ALCARAZ RAMOS: Muchas gracias, señor presidente.
# found: señor ALCARAZ RAMOS:
# groups: señor ALCARAZ RAMOS: ,  ALCARAZ ,  RAMOS
# speaker: ALCARAZ RAMOS
# speach:  Muchas gracias, señor presidente.
# OK El señor ALCARAZ RAMOS: Gracias, señor presidente.
# found: señor ALCARAZ RAMOS:
# groups: señor ALCARAZ RAMOS: ,  ALCARAZ ,  RAMOS
# speaker: ALCARAZ RAMOS
# speach:  Gracias, señor presidente.
# OK 2 El señor RECODER I MIRALLES: Muchas gracias, señor presidente.
# found: señor RECODER I MIRALLES:
# groups: señor RECODER I MIRALLES: ,  RECODER ,  MIRALLES
# speaker: RECODER MIRALLES
# speach:  Muchas gracias, señor presidente.
# OK La señora SABANES NADAL: Muchas gracias, señor presidente.
# found: señora SABANES NADAL:
# groups: señora SABANES NADAL: ,  SABANES ,  NADAL
# speaker: SABANES NADAL
# speach:  Muchas gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: SABANES NADAL
# OK El señor GARCIA-SANTESMASES MARTIN-TESORERO: Tengo que decir que el
#     consenso de nuestro grupo es completo con lo que ha dicho el señor
#     Alcaraz, pero también con lo manifestado por el señor Recoder y por la
#     señora Sabanés, es decir, hay un consenso de todos los grupos
#     parlamentarios sobre este tema, manifestado en la Comisión de Asuntos
#     Exteriores
#          --como sabe el señor ministro-- el pasado mes de diciembre. Lo que
#     se recuerda hoy aquí tiene quizá más actualidad por la cumbre
#     hispano-marroquí, pero, en definitiva, el señor Recoder --aunque llevamos
#     esta semana de tensión con los nacionalistas catalanes, en este punto
#     coincidimos completamente-- lo ha resumido perfectamente. Hay una
#     responsabilidad histórica, hay una situación que nos llena de vergüenza,
#     hay un deber moral y hay un cierto optimismo en relación con los acuerdos
#     que se han producido en Houston, que nos permiten salir del escepticismo
#     en el que estábamos.
# found: señor GARCIA-SANTESMASES MARTIN-TESORERO:
# groups: señor GARCIA-SANTESMASES MARTIN-TESORERO: ,  GARCIA-SANTESMASES ,  MARTIN-TESORERO
# speaker: GARCIA-SANTESMASES MARTIN-TESORERO
# speach:  Tengo que decir que el
#     consenso de nuestro grupo es completo con lo que ha dicho el señor
#     Alcaraz, pero también con lo manifestado por el señor Recoder y por la
#     señora Sabanés, es decir, hay un consenso de todos los grupos
#     parlamentarios sobre este tema, manifestado en la Comisión de Asuntos
#     Exteriores
#          --como sabe el señor ministro-- el pasado mes de diciembre. Lo que
#     se recuerda hoy aquí tiene quizá más actualidad por la cumbre
#     hispano-marroquí, pero, en definitiva, el señor Recoder --aunque llevamos
#     esta semana de tensión con los nacionalistas catalanes, en este punto
#     coincidimos completamente-- lo ha resumido perfectamente. Hay una
#     responsabilidad histórica, hay una situación que nos llena de vergüenza,
#     hay un deber moral y hay un cierto optimismo en relación con los acuerdos
#     que se han producido en Houston, que nos permiten salir del escepticismo
#     en el que estábamos.
# ERROR en search_diputado_in_dict. No s'ha trobat: GARCIA-SANTESMASES MARTIN-TESORERO
# OK La señora PULGAR FRAILE: Muchas gracias, señor presidente.
# found: señora PULGAR FRAILE:
# groups: señora PULGAR FRAILE: ,  PULGAR ,  FRAILE
# speaker: PULGAR FRAILE
# speach:  Muchas gracias, señor presidente.
# OK 2 La señora PALMA I MUÑOZ: Gracias, señor presidente.
# found: señora PALMA I MUÑOZ:
# groups: señora PALMA I MUÑOZ: ,  PALMA ,  MUÑOZ
# speaker: PALMA MUÑOZ
# speach:  Gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: PALMA I MUÑOZ
# OK 3
#     El señor VICEPRESIDENTE (Fernández-Miranda y Lozana): Señora Palma, le
#     ruego que vaya concluyendo.
# found:
#     El señor VICEPRESIDENTE (Fernández-Miranda y Lozana):
# groups:
#     El señor VICEPRESIDENTE (Fernández-Miranda y Lozana): ,  El señor ,  VICEPRESIDENTE (Fernández-Miranda y Lozana)
# speaker: VICEPRESIDENTE (Fernández-Miranda y Lozana)
# speaker2: Fernández-Miranda y Lozana
# speach:  Señora Palma, le
#     ruego que vaya concluyendo.
# ERROR en search_diputado_in_dict. No s'ha trobat: Fernández-Miranda y Lozana
# OK 2 La señora PALMA I MUÑOZ: Voy terminando, señor presidente.
# found: señora PALMA I MUÑOZ:
# groups: señora PALMA I MUÑOZ: ,  PALMA ,  MUÑOZ
# speaker: PALMA MUÑOZ
# speach:  Voy terminando, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: PALMA I MUÑOZ
# OK 2 La señora PALMA I MUÑOZ: Gracias, señor presidente; gracias, señor
#     ministro.
# found: señora PALMA I MUÑOZ:
# groups: señora PALMA I MUÑOZ: ,  PALMA ,  MUÑOZ
# speaker: PALMA MUÑOZ
# speach:  Gracias, señor presidente; gracias, señor
#     ministro.
# ERROR en search_diputado_in_dict. No s'ha trobat: PALMA I MUÑOZ
# OK 2 La señora PALMA I MUÑOZ: Concluyo enseguida, señor presidente.
# found: señora PALMA I MUÑOZ:
# groups: señora PALMA I MUÑOZ: ,  PALMA ,  MUÑOZ
# speaker: PALMA MUÑOZ
# speach:  Concluyo enseguida, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: PALMA I MUÑOZ
# OK 3
#     El señor VICEPRESIDENTE (Fernández-Miranda y Lozana): Muchas gracias,
#     señor ministro.
# found:
#     El señor VICEPRESIDENTE (Fernández-Miranda y Lozana):
# groups:
#     El señor VICEPRESIDENTE (Fernández-Miranda y Lozana): ,  El señor ,  VICEPRESIDENTE (Fernández-Miranda y Lozana)
# speaker: VICEPRESIDENTE (Fernández-Miranda y Lozana)
# speaker2: Fernández-Miranda y Lozana
# speach:  Muchas gracias,
#     señor ministro.
# ERROR en search_diputado_in_dict. No s'ha trobat: Fernández-Miranda y Lozana
# OK El señor ALCARAZ RAMOS: Muchas gracias, señor presidente.
# found: señor ALCARAZ RAMOS:
# groups: señor ALCARAZ RAMOS: ,  ALCARAZ ,  RAMOS
# speaker: ALCARAZ RAMOS
# speach:  Muchas gracias, señor presidente.
# OK La señora LASAGABASTER OLAZABAL: Señor presidente, sin perjuicio de la
#     posición que mantengamos en la moción que se presentará en el Pleno
#     próximo, querríamos señalar algunas ideas. En primer lugar, una cuestión
#     clave: la política universitaria destaca por su indefinición, ya se ha
#     dicho en esta Cámara y en estos momentos. Los cambios sucesivos en el
#     equipo de la ministra han alterado el normal funcionamiento del
#     Ministerio y de los organismos que dependen de él, sea el Consejo de
#     Universidades, la Comisión Nacional Evaluadora de la Actividad
#     Investigadora, etcétera. Prueba de ello es que hoy en día sigue
#     reclamándose una política, un proyecto sobre el cual podamos
#     pronunciarnos. Creemos que detrás de la manifiesta indefinición se erige
#     la carencia de un diagnóstico claro, preciso y de futuro sobre la
#     situación de la universidad. Esta indefinición tiene graves consecuencias
#     en la reforma de los planes de estudio y en la financiación de las
#     universidades. No estamos diciendo que la universidad necesite más
#     dinero, que obviamente lo necesita, sino que hay que modificar el actual
#     sistema de financiación porque en los umbrales del siglo XXI no puede ser
#     el mismo que el establecido en la Ley de 1983.
# found: señora LASAGABASTER OLAZABAL:
# groups: señora LASAGABASTER OLAZABAL: ,  LASAGABASTER ,  OLAZABAL
# speaker: LASAGABASTER OLAZABAL
# speach:  Señor presidente, sin perjuicio de la
#     posición que mantengamos en la moción que se presentará en el Pleno
#     próximo, querríamos señalar algunas ideas. En primer lugar, una cuestión
#     clave: la política universitaria destaca por su indefinición, ya se ha
#     dicho en esta Cámara y en estos momentos. Los cambios sucesivos en el
#     equipo de la ministra han alterado el normal funcionamiento del
#     Ministerio y de los organismos que dependen de él, sea el Consejo de
#     Universidades, la Comisión Nacional Evaluadora de la Actividad
#     Investigadora, etcétera. Prueba de ello es que hoy en día sigue
#     reclamándose una política, un proyecto sobre el cual podamos
#     pronunciarnos. Creemos que detrás de la manifiesta indefinición se erige
#     la carencia de un diagnóstico claro, preciso y de futuro sobre la
#     situación de la universidad. Esta indefinición tiene graves consecuencias
#     en la reforma de los planes de estudio y en la financiación de las
#     universidades. No estamos diciendo que la universidad necesite más
#     dinero, que obviamente lo necesita, sino que hay que modificar el actual
#     sistema de financiación porque en los umbrales del siglo XXI no puede ser
#     el mismo que el establecido en la Ley de 1983.
# ERROR en search_diputado_in_dict. No s'ha trobat: LASAGABASTER OLAZABAL
# OK La señora SABANES NADAL: Gracias, señor presidente.
# found: señora SABANES NADAL:
# groups: señora SABANES NADAL: ,  SABANES ,  NADAL
# speaker: SABANES NADAL
# speach:  Gracias, señor presidente.
# ERROR en search_diputado_in_dict. No s'ha trobat: SABANES NADAL
# OK El señor GUERRA ZUNZUNEGUI: Señor presidente, señorías, la interpelación
#     que presenta hoy la señora Palma, en nombre del Grupo Socialista, es muy
#     interesante; es para que en una comisión habláramos largo y tendido sobre
#     todo el tema universitario.
# found: señor GUERRA ZUNZUNEGUI:
# groups: señor GUERRA ZUNZUNEGUI: ,  GUERRA ,  ZUNZUNEGUI
# speaker: GUERRA ZUNZUNEGUI
# speach:  Señor presidente, señorías, la interpelación
#     que presenta hoy la señora Palma, en nombre del Grupo Socialista, es muy
#     interesante; es para que en una comisión habláramos largo y tendido sobre
#     todo el tema universitario.
# OK El señor GUERRA ZUNZUNEGUI: Muchas gracias, señor presidente.
# found: señor GUERRA ZUNZUNEGUI:
# groups: señor GUERRA ZUNZUNEGUI: ,  GUERRA ,  ZUNZUNEGUI
# speaker: GUERRA ZUNZUNEGUI
# speach:  Muchas gracias, señor presidente.
# OK El señor GUERRA ZUNZUNEGUI: Termino, señor presidente, Pido disculpas a
#     la Cámara por haberme alargado, pero es un tema tan atractivo y tan
#     fundamental para el futuro de nuestras juventudes que indudablemente
#     merece que le dediquemos nuestro tiempo.
# found: señor GUERRA ZUNZUNEGUI:
# groups: señor GUERRA ZUNZUNEGUI: ,  GUERRA ,  ZUNZUNEGUI
# speaker: GUERRA ZUNZUNEGUI
# speach:  Termino, señor presidente, Pido disculpas a
#     la Cámara por haberme alargado, pero es un tema tan atractivo y tan
#     fundamental para el futuro de nuestras juventudes que indudablemente
#     merece que le dediquemos nuestro tiempo.
# OK 3
#     El señor VAQUERO DEL POZO: Gracias, señor presidente.
# found:
#     El señor VAQUERO DEL POZO:
# groups:
#     El señor VAQUERO DEL POZO: ,  El señor ,  VAQUERO DEL POZO
# speaker: VAQUERO DEL POZO
# speaker2: VAQUERO DEL POZO
# speach:  Gracias, señor presidente.
# OK 3
#     El señor VAQUERO DEL POZO: Es por ello que ahí tiene su engarce la
#     problemática que a veces se aborda con un sospechoso simplismo. Por
#     ejemplo, cuando se realiza una reforma fiscal que agrava la situación
#     financiera que el Estado tiene para mantener lo que hay, sin tener en
#     cuenta si lo que hay es suficiente. Por ejemplo, las diferentes
#     interpretaciones del Pacto de Toledo, como ya tuvimos ocasión de ver y
#     poner de manifiesto en el debate de la Ley de Pensiones. Y, por ejemplo,
#     cuando se dice que hay que recortar políticas pasivas para financiar
#     políticas activas. La semántica nos traiciona.
# found:
#     El señor VAQUERO DEL POZO:
# groups:
#     El señor VAQUERO DEL POZO: ,  El señor ,  VAQUERO DEL POZO
# speaker: VAQUERO DEL POZO
# speaker2: VAQUERO DEL POZO
# speach:  Es por ello que ahí tiene su engarce la
#     problemática que a veces se aborda con un sospechoso simplismo. Por
#     ejemplo, cuando se realiza una reforma fiscal que agrava la situación
#     financiera que el Estado tiene para mantener lo que hay, sin tener en
#     cuenta si lo que hay es suficiente. Por ejemplo, las diferentes
#     interpretaciones del Pacto de Toledo, como ya tuvimos ocasión de ver y
#     poner de manifiesto en el debate de la Ley de Pensiones. Y, por ejemplo,
#     cuando se dice que hay que recortar políticas pasivas para financiar
#     políticas activas. La semántica nos traiciona.
# OK El señor DIAZ SOL: Gracias, señor presidente. Voy a intervenir
#     brevemente.
# found: señor DIAZ SOL:
# groups: señor DIAZ SOL: ,  DIAZ ,  SOL
# speaker: DIAZ SOL
# speach:  Gracias, señor presidente. Voy a intervenir
#     brevemente.
# ERROR en search_diputado_in_dict. No s'ha trobat: DIAZ SOL
# -c:17: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal

# %% [markdown]
# #### Proves d'eliminació d'elements HTML amb expressions regulars

# %%
import re

text_html = '''
    <br /><br />El señor BOSCH I PASCUAL: ¿Considera el Gobierno adecuados para erradicar
    la pobreza infantil los 2,25 euros por niño pobre que se dedican en
    Cataluña mediante el fondo correspondiente?

    <br /><br />Muchas gracias.

    <br /><br /><br /><p style="text-align:center"><a name="(Página6)"><b>Página
    6</b></a></p><br />

    <br /><br />El señor PRESIDENTE: Muchas gracias, señor Bosch.

    <br /><br />Señor presidente.

    <br /><br />El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey): Muchas gracias.
    
    
    
    <br /><br />El señor PRESIDENTE DEL GOBIERNO (Aznar López): Señor diputado, yo vengo
    aquí todos los miércoles y SS. SS. pueden preguntarme sobre cualquier
    aspecto de mi gestión política con toda tranquilidad,

    <br /><br /><center><a name="(Página8259)"><b>Página 8259</b></a></center>

    <br /><br />pero renunciar a ello y dedicarse a amparar o dar cobertura a
    afirmaciones injuriosas o caer directamente en afirmaciones que pueden    
'''

for m in re.finditer('ll', text):
    print('ll found', m.start(), m.end())


text_html = re.sub(r'<p.*?/p>', '', text_html, flags=re.DOTALL)
text_html = re.sub(r'<center>.*?</center>', '', text_html, flags=re.DOTALL)

print text_html
# Out:
#     <br /><br />El señor BOSCH I PASCUAL: ¿Considera el Gobierno adecuados para erradicar
#     la pobreza infantil los 2,25 euros por niño pobre que se dedican en
#     Cataluña mediante el fondo correspondiente?
#
#     <br /><br />Muchas gracias.
#
#     <br /><br /><br /><br />
#
#     <br /><br />El señor PRESIDENTE: Muchas gracias, señor Bosch.
#
#     <br /><br />Señor presidente.
#
#     <br /><br />El señor PRESIDENTE DEL GOBIERNO (Rajoy Brey): Muchas gracias.
#
#
#
#     <br /><br />El señor PRESIDENTE DEL GOBIERNO (Aznar López): Señor diputado, yo vengo
#     aquí todos los miércoles y SS. SS. pueden preguntarme sobre cualquier
#     aspecto de mi gestión política con toda tranquilidad,
#
#     <br /><br />
#
#     <br /><br />pero renunciar a ello y dedicarse a amparar o dar cobertura a
#     afirmaciones injuriosas o caer directamente en afirmaciones que pueden

# %%
string = '''
     --DEL DIPUTADO DON MANUEL JOSE SILVA I SANCHEZ, DEL GRUPO PARLAMENTARIO
    CATALAN (CONVERGéNCIA I UNIO), QUE FORMULA AL SEÑOR MINISTRO DE DEFENSA.
    CUAL ES EL GRADO DE UTILIZACION DEL CATALAN, LENGUA PROPIA Y OFICIAL DE
    CATALUÑA, EN LAS CAMPAÑAS INSTITUCIONALES DESARROLLADAS POR SU MINISTERIO
    A TRAVES DE LOS DIFERENTES MEDIOS DE COMUNICACION CON DIFUSION EN
    CATALUÑA? (Número de expediente 180/001192)
'''
m = re.search('[\.|\:](.*?)\?', string, re.DOTALL)
print m.start(),m.end(), ">", string[m.start():m.end()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-072e3752c085> in <module>()
#       8 '''
#       9 m = re.search('[\.|\:](.*?)\?', string)
# ---> 10 print m.start(),m.end(), ">", string[m.start():m.end()]
#
# AttributeError: 'NoneType' object has no attribute 'start'

# %%
# https://pypi.python.org/pypi/regex

import regex

def get_speaker(paragraph):
    m3 = regex.search(ur"^\s*(El señor|La señora){e<=1} ([^{:.}]+)(\:|\.)", paragraph)
    if m3:
        print m3.fuzzy_counts
        print "(s substitutions, i insertions, d deletions)"
        print "OK 3", paragraph
        print "found:", paragraph[m3.start():m3.end()]
        print "groups:", m3.group(0), ", ", m3.group(1), ", ", m3.group(2)
        print "speaker:", m3.group(2)
        if '(' in m3.group(2) and ')' in m3.group(2):
            str_surname = remove_spaces_and_newline(get_text_between(m3.group(2), '(',')'))
        else:
            str_surname = m3.group(2)
        print "speaker2:", str_surname
        print "speach:", paragraph[m3.end():]

paragraphs = [u'     El seño BONO ARA: Gracias, señora presidenta.',
              u'     El señor BONO ARA: Gracias, señora presidenta.',
              u'     El señora BONO ARA: Gracias, señora presidenta.',
              u'    EL señor MINISTRO DE ASUNTOS EXTERIORES Y COOPERACIÓN (Moratinos Cuyaubé):',
              u'   (La señora vicepresidenta, Villalobos Talero, ocupa la Presidencia).',
              u'    El señor MINISTRO DE SANIDAD, SERVICIOS SOCIALES E IGUALDAD (Alonso     Aranegui)): Muchas gracias, señor presidente.',
              u'    El señor MINISTRO DE EDUCACIÓN, CULTURA Y DEPORTE (Wert Ortega): Muchas',
              u'   Y TECNOLOGÍA La señora MINISTRA DE CIENCIA (Birulés Bertrán):  ',
              u'   DE FOMENTO El señor MINISTRO (ÁlvarezCascos Fernández): Señora presidenta'
             ]

index = 0 
while index < len(paragraphs):
    print "----------------------------------------------------"
    '''
    m1 = regex.search(ur"(señor\w?){e<=3} ([A-ZÁÉÍÓÚÑ\-]+) ([A-ZÁÉÍÓÚÑ\-]+)\:", paragraphs[index])
    if m1:
        print m1.fuzzy_counts
        print "(s substitutions, i insertions, d deletions)"
        print u"OK 1", paragraphs[index]
        print u"found:", paragraphs[index][m1.start():m1.end()]
        print u"groups:", m1.group(0), ", ", m1.group(1), ", ", m1.group(2)
        print u"speaker:", m1.group(1) + " " + m1.group(2)
        print u"speach:", paragraphs[index][m1.end():]
    else:
        print "No results."
    '''
    m3 = regex.search(ur"^\s*(El señor|La señora){e<=1} ([^{:.}]+)(\:|\.)", paragraphs[index])
    if m3:
        print m3.fuzzy_counts
        print "(s substitutions, i insertions, d deletions)"
        print "OK 3", paragraphs[index]
        print "found:", paragraphs[index][m3.start():m3.end()]
        print "groups:", m3.group(0), ", ", m3.group(1), ", ", m3.group(2)
        print "speaker:", m3.group(2)
        if '(' in m3.group(2) and ')' in m3.group(2):
            str_surname = remove_spaces_and_newline(get_text_between(m3.group(2), '(',')'))
        else:
            str_surname = m3.group(2)
        print "speaker2:", str_surname
        print "speach:", paragraphs[index][m3.end():]
    else:
        print "No results."
        print "-"*120
        m4 = regex.search(ur"(El señor|La señora) ([^{:.}]+)(\:|\.)", paragraphs[index])
        if m4:
            print m4.fuzzy_counts
            print "(s substitutions, i insertions, d deletions)"
            print "OK 4", paragraphs[index]
            print "found:", paragraphs[index][m4.start():m4.end()]
            print "groups:", m4.group(0), ", ", m4.group(1), ", ", m4.group(2)
            print "speaker:", m4.group(2)
            if '(' in m4.group(2) and ')' in m4.group(2):
                str_surname = remove_spaces_and_newline(get_text_between(m4.group(2), '(',')'))
            else:
                str_surname = m4.group(2)
            print "speaker2:", str_surname
            print "speach:", paragraphs[index][m4.end():]
        print "-"*120
        index_mr = paragraphs[index].find(u"El señor")
        index_mrs = paragraphs[index].find(u"La señora")
        index_par = paragraphs[index].find(u"(")
        if index_mrs > 0:
            new_paragraph = paragraphs[index][index_mrs:index_par] + paragraphs[index][0:index_mrs].lstrip() + paragraphs[index][index_par:]
            print new_paragraph
        elif index_mr:
            new_paragraph = paragraphs[index][index_mr:index_par] + paragraphs[index][0:index_mr].lstrip() + paragraphs[index][index_par:]
            print new_paragraph
        get_speaker(new_paragraph)
        
    index += 1
# Out:
# ----------------------------------------------------
# (0, 0, 1)
# (s substitutions, i insertions, d deletions)
# OK 3      El seño BONO ARA: Gracias, señora presidenta.
# found:      El seño BONO ARA:
# groups:      El seño BONO ARA: ,  El seño ,  BONO ARA
# speaker: BONO ARA
# speaker2: BONO ARA
# speach:  Gracias, señora presidenta.
# ----------------------------------------------------
# (0, 0, 0)
# (s substitutions, i insertions, d deletions)
# OK 3      El señor BONO ARA: Gracias, señora presidenta.
# found:      El señor BONO ARA:
# groups:      El señor BONO ARA: ,  El señor ,  BONO ARA
# speaker: BONO ARA
# speaker2: BONO ARA
# speach:  Gracias, señora presidenta.
# ----------------------------------------------------
# (0, 1, 0)
# (s substitutions, i insertions, d deletions)
# OK 3      El señora BONO ARA: Gracias, señora presidenta.
# found:      El señora BONO ARA:
# groups:      El señora BONO ARA: ,  El señora ,  BONO ARA
# speaker: BONO ARA
# speaker2: BONO ARA
# speach:  Gracias, señora presidenta.
# ----------------------------------------------------
# (1, 0, 0)
# (s substitutions, i insertions, d deletions)
# OK 3     EL señor MINISTRO DE ASUNTOS EXTERIORES Y COOPERACIÓN (Moratinos Cuyaubé):
# found:     EL señor MINISTRO DE ASUNTOS EXTERIORES Y COOPERACIÓN (Moratinos Cuyaubé):
# groups:     EL señor MINISTRO DE ASUNTOS EXTERIORES Y COOPERACIÓN (Moratinos Cuyaubé): ,  EL señor ,  MINISTRO DE ASUNTOS EXTERIORES Y COOPERACIÓN (Moratinos Cuyaubé)
# speaker: MINISTRO DE ASUNTOS EXTERIORES Y COOPERACIÓN (Moratinos Cuyaubé)
# speaker2: Moratinos Cuyaubé
# speach:
# ----------------------------------------------------
# (0, 1, 0)
# (s substitutions, i insertions, d deletions)
# OK 3    (La señora vicepresidenta, Villalobos Talero, ocupa la Presidencia).
# found:    (La señora vicepresidenta, Villalobos Talero, ocupa la Presidencia).
# groups:    (La señora vicepresidenta, Villalobos Talero, ocupa la Presidencia). ,  (La señora ,  vicepresidenta, Villalobos Talero, ocupa la Presidencia)
# speaker: vicepresidenta, Villalobos Talero, ocupa la Presidencia)
# speaker2: vicepresidenta, Villalobos Talero, ocupa la Presidencia)
# speach:
# ----------------------------------------------------
# (0, 0, 0)
# (s substitutions, i insertions, d deletions)
# OK 3     El señor MINISTRO DE SANIDAD, SERVICIOS SOCIALES E IGUALDAD (Alonso     Aranegui)): Muchas gracias, señor presidente.
# found:     El señor MINISTRO DE SANIDAD, SERVICIOS SOCIALES E IGUALDAD (Alonso     Aranegui)):
# groups:     El señor MINISTRO DE SANIDAD, SERVICIOS SOCIALES E IGUALDAD (Alonso     Aranegui)): ,  El señor ,  MINISTRO DE SANIDAD, SERVICIOS SOCIALES E IGUALDAD (Alonso     Aranegui))
# speaker: MINISTRO DE SANIDAD, SERVICIOS SOCIALES E IGUALDAD (Alonso     Aranegui))
# speaker2: Alonso Aranegui)
# speach:  Muchas gracias, señor presidente.
# ----------------------------------------------------
# (0, 0, 0)
# (s substitutions, i insertions, d deletions)
# OK 3     El señor MINISTRO DE EDUCACIÓN, CULTURA Y DEPORTE (Wert Ortega): Muchas
# found:     El señor MINISTRO DE EDUCACIÓN, CULTURA Y DEPORTE (Wert Ortega):
# groups:     El señor MINISTRO DE EDUCACIÓN, CULTURA Y DEPORTE (Wert Ortega): ,  El señor ,  MINISTRO DE EDUCACIÓN, CULTURA Y DEPORTE (Wert Ortega)
# speaker: MINISTRO DE EDUCACIÓN, CULTURA Y DEPORTE (Wert Ortega)
# speaker2: Wert Ortega
# speach:  Muchas
# ----------------------------------------------------
# No results.
# ------------------------------------------------------------------------------------------------------------------------
# (0, 0, 0)
# (s substitutions, i insertions, d deletions)
# OK 4    Y TECNOLOGÍA La señora MINISTRA DE CIENCIA (Birulés Bertrán):
# found: La señora MINISTRA DE CIENCIA (Birulés Bertrán):
# groups: La señora MINISTRA DE CIENCIA (Birulés Bertrán): ,  La señora ,  MINISTRA DE CIENCIA (Birulés Bertrán)
# speaker: MINISTRA DE CIENCIA (Birulés Bertrán)
# speaker2: Birulés Bertrán
# speach:
# ------------------------------------------------------------------------------------------------------------------------
# La señora MINISTRA DE CIENCIA Y TECNOLOGÍA (Birulés Bertrán):
# (0, 0, 0)
# (s substitutions, i insertions, d deletions)
# OK 3 La señora MINISTRA DE CIENCIA Y TECNOLOGÍA (Birulés Bertrán):
# found: La señora MINISTRA DE CIENCIA Y TECNOLOGÍA (Birulés Bertrán):
# groups: La señora MINISTRA DE CIENCIA Y TECNOLOGÍA (Birulés Bertrán): ,  La señora ,  MINISTRA DE CIENCIA Y TECNOLOGÍA (Birulés Bertrán)
# speaker: MINISTRA DE CIENCIA Y TECNOLOGÍA (Birulés Bertrán)
# speaker2: Birulés Bertrán
# speach:
# ----------------------------------------------------
# No results.
# ------------------------------------------------------------------------------------------------------------------------
# (0, 0, 0)
# (s substitutions, i insertions, d deletions)
# OK 4    DE FOMENTO El señor MINISTRO (ÁlvarezCascos Fernández): Señora presidenta
# found: El señor MINISTRO (ÁlvarezCascos Fernández):
# groups: El señor MINISTRO (ÁlvarezCascos Fernández): ,  El señor ,  MINISTRO (ÁlvarezCascos Fernández)
# speaker: MINISTRO (ÁlvarezCascos Fernández)
# speaker2: ÁlvarezCascos Fernández
# speach:  Señora presidenta
# ------------------------------------------------------------------------------------------------------------------------
# El señor MINISTRO DE FOMENTO (ÁlvarezCascos Fernández): Señora presidenta
# (0, 0, 0)
# (s substitutions, i insertions, d deletions)
# OK 3 El señor MINISTRO DE FOMENTO (ÁlvarezCascos Fernández): Señora presidenta
# found: El señor MINISTRO DE FOMENTO (ÁlvarezCascos Fernández):
# groups: El señor MINISTRO DE FOMENTO (ÁlvarezCascos Fernández): ,  El señor ,  MINISTRO DE FOMENTO (ÁlvarezCascos Fernández)
# speaker: MINISTRO DE FOMENTO (ÁlvarezCascos Fernández)
# speaker2: ÁlvarezCascos Fernández
# speach:  Señora presidenta
